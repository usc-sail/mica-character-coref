# %%
from mica_text_coref.coref.movie_coref import data
import os
import collections
import numpy as np

# %%
litbank = data.CorefCorpus(os.path.join(os.getenv("DATA_DIR"), "mica_text_coref/litbank/books.jsonlines"))

# %%
moviebank = data.CorefCorpus(os.path.join(os.getenv("DATA_DIR"), 
                                          "mica_text_coref/movie_coref/results/regular/train.jsonlines"))

# %%
litbank_folds_dir = "/proj/sbaruah/data/lrec2020-coref/data/litbank_tenfold_splits"
litbank_fold = 0

train_corpus = data.CorefCorpus()
dev_corpus = data.CorefCorpus()
test_corpus = data.CorefCorpus()
train_ids, dev_ids, test_ids = [], [], []

with open(os.path.join(litbank_folds_dir, str(litbank_fold), "train.ids")) as fr:
    for line in fr:
        line = line.strip()
        if line:
            train_ids.append(line[:-len("_brat.tsv")])

with open(os.path.join(litbank_folds_dir, str(litbank_fold), "dev.ids")) as fr:
    for line in fr:
        line = line.strip()
        if line:
            dev_ids.append(line[:-len("_brat.tsv")])

with open(os.path.join(litbank_folds_dir, str(litbank_fold), "test.ids")) as fr:
    for line in fr:
        line = line.strip()
        if line:
            test_ids.append(line[:-len("_brat.tsv")])

train_corpus.documents = [document for document in litbank if document.movie in train_ids]
dev_corpus.documents = [document for document in litbank if document.movie in dev_ids]
test_corpus.documents = [document for document in litbank if document.movie in test_ids]

print(len(train_corpus), len(dev_corpus), len(test_corpus))
# Out:
# 80 10 10

# %%
def split_screenplay(document: data.CorefDocument, split_len: int, overlap_len: int, 
                     exclude_subdocuments_with_no_clusters: bool = True, verbose = False):
    """Split screenplay document into smaller documents

    Args:
        document: CorefDocument object representing the original screenplay document
        split_len: Length of the smaller CorefDocument objects in words
        overlap_len: number of words overlapping between successive smaller CorefDocuments
        exclude_subdocuments_with_no_clusters: if true, exclude subdocuments if they contain no clusters
    
    Returns:
        Generator of CorefDocument objects.
    """
    # initialize offsets and sentence offsets
    n_words = len(document.token)
    n_mentions = sum([len(cluster) for cluster in document.clusters.values()])
    n_clusters = len(document.clusters)
    if verbose:
        print(f"{document.movie}: {n_words} words, {n_mentions} mentions, {n_clusters} clusters")
    doc_offsets: list[tuple[int, int]] = []
    sentence_offsets = np.array(document.sentence_offsets)

    # find segment boundaries
    segment_boundaries = np.zeros(len(document.token), dtype=int)
    for i, _ in document.sentence_offsets:
        segment_boundaries[i] = 1

    # find subdocument offsets
    i = 0
    prevj = 0
    while i < len(document.token):
        j = min(i + split_len, len(document.token))
        if j < len(document.token):
            while j >= prevj and segment_boundaries[j] == 0:
                j -= 1
            k = j - overlap_len
            while k >= prevj and segment_boundaries[k] == 0:
                k -= 1
            nexti = k
        else:
            nexti = j
        prevj = j
        assert i < nexti, "Document length is 0!"
        doc_offsets.append((i, j))
        i = nexti
    
    # assert at most two subdocuments overlap
    for i in range(len(doc_offsets)):
        if i > 1:
            i0, j0 = doc_offsets[i-2]
            i1, j1 = doc_offsets[i-1]
            i2, j2 = doc_offsets[i]
            assert i0 < i1 <= j0 < i2 <= j1 < j2, "at most two subdocuments should overlap"

    # split screenplay into subdocument according to offsets
    for k, (i, j) in enumerate(doc_offsets):
        _document = data.CorefDocument()

        # populate subdocument-length fields
        _document.movie = document.movie + f"_{k + 1}"
        _document.rater = document.rater
        _document.token = document.token[i: j]
        _document.parse = document.parse[i: j]
        _document.parse_ids = [data.parse_labelset[x] for x in _document.parse]
        _document.pos = document.pos[i: j]
        _document.pos_ids = [data.pos_labelset[x] for x in _document.pos]
        _document.ner = document.ner[i: j]
        _document.ner_ids = [data.ner_labelset[x] for x in _document.ner]
        _document.is_pronoun = document.is_pronoun[i: j]
        _document.is_punctuation = document.is_punctuation[i: j]
        _document.speaker = document.speaker[i: j]

        # populate sentence offsets
        si = np.nonzero(sentence_offsets[:,0] == i)[0][0]
        sj = np.nonzero(sentence_offsets[:,1] == j - 1)[0][0] + 1
        _document.sentence_offsets = (sentence_offsets[si: sj] - sentence_offsets[si, 0]).tolist()

        # populate clusters
        clusters: dict[str, set[data.Mention]] = collections.defaultdict(set)
        n_mentions = 0
        for character, mentions in document.clusters.items():
            for mention in mentions:
                assert (mention.end < i or i <= mention.begin <= mention.end < j or j <= mention.begin), (
                    f"Mention crosses subdocument boundaries mention={mention} i={i} j={j}")
                if i <= mention.begin <= mention.end < j:
                    new_mention = data.Mention(mention.begin - i, mention.end - i, mention.head - i)
                    clusters[character].add(new_mention)
                    n_mentions += 1
        
        # go to next document if clusters is empty
        if exclude_subdocuments_with_no_clusters and len(clusters) == 0:
            continue

        # fill the clusters field and its derivaties, and the offset
        _document.clusters = clusters
        _document.word_cluster_ids = document.word_cluster_ids[i: j]
        _document.word_head_ids = document.word_head_ids[i: j]
        _document.offset = (i, j)
        if verbose:
            print(f"{_document.movie}: {len(_document.token)} words, {n_mentions} mentions, "
                        f"{len(_document.clusters)} clusters")
        yield _document

# %%
document_lens = [512, 1024, 2048]
overlap_lens = [0]
document_and_overlap_len_to_error_files = collections.defaultdict(list)

for document_len in document_lens:
    for overlap_len in overlap_lens:
        print(document_len, overlap_len)
        for document in litbank:
            print("\t", document.movie, len(document.token))
            for subdocument in split_screenplay(document, document_len, overlap_len, 
                                                exclude_subdocuments_with_no_clusters=False, verbose=False):
                print("\t\t", subdocument.offset)
# Out:
# 512 0
# 	 5230_the_invisible_man_a_grotesque_romance 2016
# 		 (0, 505)
# 		 (505, 995)
# 		 (995, 1499)
# 		 (1499, 1997)
# 		 (1997, 2016)
# 	 2641_a_room_with_a_view 2009
# 		 (0, 508)
# 		 (508, 1019)
# 		 (1019, 1531)
# 		 (1531, 2009)
# 	 2891_howards_end 2022
# 		 (0, 498)
# 		 (498, 998)
# 		 (998, 1502)
# 		 (1502, 1988)
# 		 (1988, 2022)
# 	 472_the_house_behind_the_cedars 2024
# 		 (0, 511)
# 		 (511, 1014)
# 		 (1014, 1496)
# 		 (1496, 1999)
# 		 (1999, 2024)
# 	 208_daisy_miller_a_study 2005
# 		 (0, 510)
# 		 (510, 1012)
# 		 (1012, 1513)
# 		 (1513, 2005)
# 	 940_the_last_of_the_mohicans_a_narrative_of_1757 2247
# 		 (0, 511)
# 		 (511, 1008)
# 		 (1008, 1518)
# 		 (1518, 2024)
# 		 (2024, 2247)
# 	 9830_the_beautiful_and_damned 2072
# 		 (0, 509)
# 		 (509, 979)
# 		 (979, 1467)
# 		 (1467, 1970)
# 		 (1970, 2072)
# 	 2814_dubliners 2003
# 		 (0, 499)
# 		 (499, 989)
# 		 (989, 1469)
# 		 (1469, 1976)
# 		 (1976, 2003)
# 	 41286_miss_marjoribanks 2744
# 		 (0, 506)
# 		 (506, 988)
# 		 (988, 1487)
# 		 (1487, 1949)
# 		 (1949, 2430)
# 		 (2430, 2744)
# 	 174_the_picture_of_dorian_gray 2016
# 		 (0, 512)
# 		 (512, 1011)
# 		 (1011, 1520)
# 		 (1520, 2016)
# 	 120_treasure_island 2220
# 		 (0, 509)
# 		 (509, 987)
# 		 (987, 1467)
# 		 (1467, 1976)
# 		 (1976, 2220)
# 	 4300_ulysses 2034
# 		 (0, 509)
# 		 (509, 1018)
# 		 (1018, 1529)
# 		 (1529, 2034)
# 	 932_the_fall_of_the_house_of_usher 2177
# 		 (0, 504)
# 		 (504, 1008)
# 		 (1008, 1498)
# 		 (1498, 1960)
# 		 (1960, 2177)
# 	 24_o_pioneers 2041
# 		 (0, 512)
# 		 (512, 1022)
# 		 (1022, 1525)
# 		 (1525, 2009)
# 		 (2009, 2041)
# 	 4051_lady_bridget_in_the_nevernever_land_a_story_of_australian_life 2089
# 		 (0, 491)
# 		 (491, 961)
# 		 (961, 1456)
# 		 (1456, 1961)
# 		 (1961, 2089)
# 	 599_vanity_fair 2043
# 		 (0, 510)
# 		 (510, 1020)
# 		 (1020, 1504)
# 		 (1504, 1989)
# 		 (1989, 2043)
# 	 76_adventures_of_huckleberry_finn 2153
# 		 (0, 487)
# 		 (487, 990)
# 		 (990, 1489)
# 		 (1489, 2001)
# 		 (2001, 2153)
# 	 45_anne_of_green_gables 2000
# 		 (0, 484)
# 		 (484, 982)
# 		 (982, 1458)
# 		 (1458, 1963)
# 		 (1963, 2000)
# 	 1064_the_masque_of_the_red_death 2094
# 		 (0, 505)
# 		 (505, 885)
# 		 (885, 1388)
# 		 (1388, 1874)
# 		 (1874, 2094)
# 	 1342_pride_and_prejudice 2021
# 		 (0, 491)
# 		 (491, 999)
# 		 (999, 1504)
# 		 (1504, 1993)
# 		 (1993, 2021)
# 	 2084_the_way_of_all_flesh 2052
# 		 (0, 485)
# 		 (485, 971)
# 		 (971, 1454)
# 		 (1454, 1921)
# 		 (1921, 2052)
# 	 18581_adrift_in_new_york_tom_and_florence_braving_the_world 2016
# 		 (0, 507)
# 		 (507, 1009)
# 		 (1009, 1494)
# 		 (1494, 1997)
# 		 (1997, 2016)
# 	 84_frankenstein_or_the_modern_prometheus 2385
# 		 (0, 495)
# 		 (495, 1006)
# 		 (1006, 1495)
# 		 (1495, 1983)
# 		 (1983, 2385)
# 	 1327_elizabeth_and_her_german_garden 2046
# 		 (0, 459)
# 		 (459, 934)
# 		 (934, 1445)
# 		 (1445, 1890)
# 		 (1890, 2046)
# 	 238_dear_enemy 2019
# 		 (0, 495)
# 		 (495, 989)
# 		 (989, 1497)
# 		 (1497, 1992)
# 		 (1992, 2019)
# 	 219_heart_of_darkness 2043
# 		 (0, 471)
# 		 (471, 952)
# 		 (952, 1460)
# 		 (1460, 1921)
# 		 (1921, 2043)
# 	 969_the_tenant_of_wildfell_hall 2043
# 		 (0, 474)
# 		 (474, 934)
# 		 (934, 1444)
# 		 (1444, 1946)
# 		 (1946, 2043)
# 	 1260_jane_eyre_an_autobiography 2034
# 		 (0, 506)
# 		 (506, 912)
# 		 (912, 1398)
# 		 (1398, 1892)
# 		 (1892, 2034)
# 	 6593_history_of_tom_jones_a_foundling 2034
# 		 (0, 420)
# 		 (420, 918)
# 		 (918, 1316)
# 		 (1316, 1794)
# 		 (1794, 2034)
# 	 32_herland 2005
# 		 (0, 505)
# 		 (505, 1015)
# 		 (1015, 1527)
# 		 (1527, 2005)
# 	 74_the_adventures_of_tom_sawyer 2000
# 		 (0, 507)
# 		 (507, 1016)
# 		 (1016, 1523)
# 		 (1523, 2000)
# 	 1400_great_expectations 2045
# 		 (0, 502)
# 		 (502, 1014)
# 		 (1014, 1522)
# 		 (1522, 1987)
# 		 (1987, 2045)
# 	 160_the_awakening_and_selected_short_stories 2020
# 		 (0, 493)
# 		 (493, 991)
# 		 (991, 1493)
# 		 (1493, 1962)
# 		 (1962, 2020)
# 	 78_tarzan_of_the_apes 2025
# 		 (0, 483)
# 		 (483, 951)
# 		 (951, 1459)
# 		 (1459, 1966)
# 		 (1966, 2025)
# 	 36_the_war_of_the_worlds 2017
# 		 (0, 502)
# 		 (502, 1013)
# 		 (1013, 1519)
# 		 (1519, 2017)
# 	 11231_bartleby_the_scrivener_a_story_of_wallstreet 2622
# 		 (0, 503)
# 		 (503, 949)
# 		 (949, 1439)
# 		 (1439, 1898)
# 		 (1898, 2385)
# 		 (2385, 2622)
# 	 11_alices_adventures_in_wonderland 2129
# 		 (0, 455)
# 		 (455, 964)
# 		 (964, 1427)
# 		 (1427, 1890)
# 		 (1890, 2129)
# 	 145_middlemarch 1999
# 		 (0, 511)
# 		 (511, 1017)
# 		 (1017, 1520)
# 		 (1520, 1999)
# 	 434_the_circular_staircase 2060
# 		 (0, 510)
# 		 (510, 1006)
# 		 (1006, 1488)
# 		 (1488, 1957)
# 		 (1957, 2060)
# 	 95_the_prisoner_of_zenda 2305
# 		 (0, 509)
# 		 (509, 999)
# 		 (999, 1510)
# 		 (1510, 1990)
# 		 (1990, 2305)
# 	 766_david_copperfield 2016
# 		 (0, 488)
# 		 (488, 899)
# 		 (899, 1324)
# 		 (1324, 1823)
# 		 (1823, 2016)
# 	 367_country_of_the_pointed_firs 2052
# 		 (0, 489)
# 		 (489, 987)
# 		 (987, 1472)
# 		 (1472, 1978)
# 		 (1978, 2052)
# 	 8867_the_magnificent_ambersons 2143
# 		 (0, 492)
# 		 (492, 996)
# 		 (996, 1480)
# 		 (1480, 1918)
# 		 (1918, 2143)
# 	 4217_a_portrait_of_the_artist_as_a_young_man 2141
# 		 (0, 510)
# 		 (510, 1021)
# 		 (1021, 1530)
# 		 (1530, 2033)
# 		 (2033, 2141)
# 	 351_of_human_bondage 2004
# 		 (0, 500)
# 		 (500, 991)
# 		 (991, 1502)
# 		 (1502, 2004)
# 	 1245_night_and_day 2225
# 		 (0, 469)
# 		 (469, 977)
# 		 (977, 1471)
# 		 (1471, 1970)
# 		 (1970, 2225)
# 	 73_the_red_badge_of_courage_an_episode_of_the_american_civil_war 2043
# 		 (0, 506)
# 		 (506, 993)
# 		 (993, 1483)
# 		 (1483, 1991)
# 		 (1991, 2043)
# 	 2166_king_solomons_mines 2078
# 		 (0, 500)
# 		 (500, 980)
# 		 (980, 1465)
# 		 (1465, 1962)
# 		 (1962, 2078)
# 	 215_the_call_of_the_wild 2016
# 		 (0, 472)
# 		 (472, 971)
# 		 (971, 1475)
# 		 (1475, 1958)
# 		 (1958, 2016)
# 	 541_the_age_of_innocence 2011
# 		 (0, 494)
# 		 (494, 946)
# 		 (946, 1453)
# 		 (1453, 1937)
# 		 (1937, 2011)
# 	 432_the_ambassadors 2279
# 		 (0, 369)
# 		 (369, 872)
# 		 (872, 1370)
# 		 (1370, 1874)
# 		 (1874, 2279)
# 	 217_sons_and_lovers 2006
# 		 (0, 492)
# 		 (492, 997)
# 		 (997, 1487)
# 		 (1487, 1998)
# 		 (1998, 2006)
# 	 2852_the_hound_of_the_baskervilles 2075
# 		 (0, 504)
# 		 (504, 1012)
# 		 (1012, 1511)
# 		 (1511, 2011)
# 		 (2011, 2075)
# 	 1206_the_flying_u_ranch 2021
# 		 (0, 508)
# 		 (508, 994)
# 		 (994, 1495)
# 		 (1495, 1992)
# 		 (1992, 2021)
# 	 155_the_moonstone 2030
# 		 (0, 493)
# 		 (493, 1001)
# 		 (1001, 1486)
# 		 (1486, 1995)
# 		 (1995, 2030)
# 	 543_main_street 2095
# 		 (0, 492)
# 		 (492, 999)
# 		 (999, 1496)
# 		 (1496, 2006)
# 		 (2006, 2095)
# 	 6053_evelina_or_the_history_of_a_young_ladys_entrance_into_the_world 2001
# 		 (0, 511)
# 		 (511, 1007)
# 		 (1007, 1494)
# 		 (1494, 2001)
# 	 113_the_secret_garden 2014
# 		 (0, 493)
# 		 (493, 1003)
# 		 (1003, 1502)
# 		 (1502, 2014)
# 	 2807_to_have_and_to_hold 2002
# 		 (0, 454)
# 		 (454, 962)
# 		 (962, 1474)
# 		 (1474, 1977)
# 		 (1977, 2002)
# 	 77_the_house_of_the_seven_gables 2140
# 		 (0, 450)
# 		 (450, 940)
# 		 (940, 1441)
# 		 (1441, 1943)
# 		 (1943, 2140)
# 	 805_this_side_of_paradise 2000
# 		 (0, 503)
# 		 (503, 975)
# 		 (975, 1462)
# 		 (1462, 1959)
# 		 (1959, 2000)
# 	 550_silas_marner 2049
# 		 (0, 507)
# 		 (507, 996)
# 		 (996, 1411)
# 		 (1411, 1864)
# 		 (1864, 2049)
# 	 521_the_life_and_adventures_of_robinson_crusoe 2276
# 		 (0, 431)
# 		 (431, 672)
# 		 (672, 979)
# 		 (979, 1466)
# 		 (1466, 1958)
# 		 (1958, 2276)
# 	 2095_clotelle_a_tale_of_the_southern_states 2015
# 		 (0, 494)
# 		 (494, 978)
# 		 (978, 1488)
# 		 (1488, 1991)
# 		 (1991, 2015)
# 	 33_the_scarlet_letter 2165
# 		 (0, 479)
# 		 (479, 990)
# 		 (990, 1499)
# 		 (1499, 1949)
# 		 (1949, 2165)
# 	 730_oliver_twist 2056
# 		 (0, 445)
# 		 (445, 940)
# 		 (940, 1445)
# 		 (1445, 1949)
# 		 (1949, 2056)
# 	 60_the_scarlet_pimpernel 2028
# 		 (0, 488)
# 		 (488, 986)
# 		 (986, 1482)
# 		 (1482, 1981)
# 		 (1981, 2028)
# 	 1695_the_man_who_was_thursday_a_nightmare 2067
# 		 (0, 498)
# 		 (498, 1001)
# 		 (1001, 1497)
# 		 (1497, 2005)
# 		 (2005, 2067)
# 	 1023_bleak_house 2269
# 		 (0, 485)
# 		 (485, 947)
# 		 (947, 1413)
# 		 (1413, 1883)
# 		 (1883, 2269)
# 	 974_the_secret_agent_a_simple_tale 2507
# 		 (0, 508)
# 		 (508, 991)
# 		 (991, 1503)
# 		 (1503, 1967)
# 		 (1967, 2454)
# 		 (2454, 2507)
# 	 110_tess_of_the_durbervilles_a_pure_woman 2002
# 		 (0, 489)
# 		 (489, 976)
# 		 (976, 1486)
# 		 (1486, 1988)
# 		 (1988, 2002)
# 	 105_persuasion 2088
# 		 (0, 481)
# 		 (481, 993)
# 		 (993, 1488)
# 		 (1488, 1990)
# 		 (1990, 2088)
# 	 829_gullivers_travels_into_several_remote_nations_of_the_world 3419
# 		 (0, 501)
# 		 (501, 986)
# 		 (986, 1443)
# 		 (1443, 1893)
# 		 (1893, 2404)
# 		 (2404, 2891)
# 		 (2891, 3380)
# 		 (3380, 3419)
# 	 4276_north_and_south 2001
# 		 (0, 498)
# 		 (498, 985)
# 		 (985, 1476)
# 		 (1476, 1982)
# 		 (1982, 2001)
# 	 171_charlotte_temple 2041
# 		 (0, 463)
# 		 (463, 968)
# 		 (968, 1471)
# 		 (1471, 1983)
# 		 (1983, 2041)
# 	 2489_moby_dick 2173
# 		 (0, 497)
# 		 (497, 983)
# 		 (983, 1472)
# 		 (1472, 1953)
# 		 (1953, 2173)
# 	 5348_ragged_dick_or_street_life_in_new_york_with_the_bootblacks 2096
# 		 (0, 498)
# 		 (498, 1007)
# 		 (1007, 1486)
# 		 (1486, 1971)
# 		 (1971, 2096)
# 	 711_allan_quatermain 2000
# 		 (0, 489)
# 		 (489, 973)
# 		 (973, 1483)
# 		 (1483, 1974)
# 		 (1974, 2000)
# 	 876_life_in_the_ironmills_or_the_korl_woman 2163
# 		 (0, 505)
# 		 (505, 1001)
# 		 (1001, 1509)
# 		 (1509, 2014)
# 		 (2014, 2163)
# 	 2775_the_good_soldier 2321
# 		 (0, 475)
# 		 (475, 985)
# 		 (985, 1497)
# 		 (1497, 1995)
# 		 (1995, 2321)
# 	 41_the_legend_of_sleepy_hollow 2171
# 		 (0, 468)
# 		 (468, 949)
# 		 (949, 1429)
# 		 (1429, 1889)
# 		 (1889, 2171)
# 	 62_a_princess_of_mars 2022
# 		 (0, 491)
# 		 (491, 988)
# 		 (988, 1499)
# 		 (1499, 1965)
# 		 (1965, 2022)
# 	 271_black_beauty 2014
# 		 (0, 497)
# 		 (497, 973)
# 		 (973, 1474)
# 		 (1474, 1962)
# 		 (1962, 2014)
# 	 27_far_from_the_madding_crowd 2322
# 		 (0, 495)
# 		 (495, 1007)
# 		 (1007, 1497)
# 		 (1497, 2000)
# 		 (2000, 2322)
# 	 3457_the_man_of_the_forest 2038
# 		 (0, 497)
# 		 (497, 1008)
# 		 (1008, 1494)
# 		 (1494, 2006)
# 		 (2006, 2038)
# 	 514_little_women 2014
# 		 (0, 500)
# 		 (500, 1012)
# 		 (1012, 1509)
# 		 (1509, 2014)
# 	 44_the_song_of_the_lark 2051
# 		 (0, 506)
# 		 (506, 1004)
# 		 (1004, 1513)
# 		 (1513, 2023)
# 		 (2023, 2051)
# 	 768_wuthering_heights 2034
# 		 (0, 496)
# 		 (496, 999)
# 		 (999, 1475)
# 		 (1475, 1977)
# 		 (1977, 2034)
# 	 2005_piccadilly_jim 2084
# 		 (0, 508)
# 		 (508, 1018)
# 		 (1018, 1512)
# 		 (1512, 2006)
# 		 (2006, 2084)
# 	 233_sister_carrie_a_novel 2061
# 		 (0, 496)
# 		 (496, 1000)
# 		 (1000, 1502)
# 		 (1502, 2012)
# 		 (2012, 2061)
# 	 3268_the_mysteries_of_udolpho 2003
# 		 (0, 486)
# 		 (486, 985)
# 		 (985, 1481)
# 		 (1481, 1981)
# 		 (1981, 2003)
# 	 209_the_turn_of_the_screw 2027
# 		 (0, 512)
# 		 (512, 1018)
# 		 (1018, 1528)
# 		 (1528, 2027)
# 	 502_desert_gold 2054
# 		 (0, 496)
# 		 (496, 996)
# 		 (996, 1491)
# 		 (1491, 1973)
# 		 (1973, 2054)
# 	 12677_personality_plus_some_experiences_of_emma_mcchesney_and_her_son_jock 2020
# 		 (0, 488)
# 		 (488, 995)
# 		 (995, 1493)
# 		 (1493, 2002)
# 		 (2002, 2020)
# 	 345_dracula 2251
# 		 (0, 512)
# 		 (512, 997)
# 		 (997, 1506)
# 		 (1506, 2009)
# 		 (2009, 2251)
# 	 1155_the_secret_adversary 2105
# 		 (0, 505)
# 		 (505, 1017)
# 		 (1017, 1522)
# 		 (1522, 2025)
# 		 (2025, 2105)
# 	 1661_the_adventures_of_sherlock_holmes 2095
# 		 (0, 486)
# 		 (486, 967)
# 		 (967, 1479)
# 		 (1479, 1989)
# 		 (1989, 2095)
# 	 158_emma 2063
# 		 (0, 510)
# 		 (510, 999)
# 		 (999, 1500)
# 		 (1500, 1987)
# 		 (1987, 2063)
# 	 15265_the_quest_of_the_silver_fleece_a_novel 2002
# 		 (0, 500)
# 		 (500, 989)
# 		 (989, 1495)
# 		 (1495, 2002)
# 	 16357_mary_a_fiction 2044
# 		 (0, 447)
# 		 (447, 940)
# 		 (940, 1405)
# 		 (1405, 1917)
# 		 (1917, 2044)
# 1024 0
# 	 5230_the_invisible_man_a_grotesque_romance 2016
# 		 (0, 995)
# 		 (995, 2016)
# 	 2641_a_room_with_a_view 2009
# 		 (0, 1019)
# 		 (1019, 2009)
# 	 2891_howards_end 2022
# 		 (0, 1021)
# 		 (1021, 2022)
# 	 472_the_house_behind_the_cedars 2024
# 		 (0, 1014)
# 		 (1014, 2024)
# 	 208_daisy_miller_a_study 2005
# 		 (0, 1012)
# 		 (1012, 2005)
# 	 940_the_last_of_the_mohicans_a_narrative_of_1757 2247
# 		 (0, 1008)
# 		 (1008, 2024)
# 		 (2024, 2247)
# 	 9830_the_beautiful_and_damned 2072
# 		 (0, 979)
# 		 (979, 1970)
# 		 (1970, 2072)
# 	 2814_dubliners 2003
# 		 (0, 1018)
# 		 (1018, 2003)
# 	 41286_miss_marjoribanks 2744
# 		 (0, 988)
# 		 (988, 1949)
# 		 (1949, 2744)
# 	 174_the_picture_of_dorian_gray 2016
# 		 (0, 1011)
# 		 (1011, 2016)
# 	 120_treasure_island 2220
# 		 (0, 987)
# 		 (987, 1995)
# 		 (1995, 2220)
# 	 4300_ulysses 2034
# 		 (0, 1023)
# 		 (1023, 2034)
# 	 932_the_fall_of_the_house_of_usher 2177
# 		 (0, 1008)
# 		 (1008, 1960)
# 		 (1960, 2177)
# 	 24_o_pioneers 2041
# 		 (0, 1022)
# 		 (1022, 2041)
# 	 4051_lady_bridget_in_the_nevernever_land_a_story_of_australian_life 2089
# 		 (0, 1012)
# 		 (1012, 2023)
# 		 (2023, 2089)
# 	 599_vanity_fair 2043
# 		 (0, 1020)
# 		 (1020, 2043)
# 	 76_adventures_of_huckleberry_finn 2153
# 		 (0, 1010)
# 		 (1010, 2031)
# 		 (2031, 2153)
# 	 45_anne_of_green_gables 2000
# 		 (0, 1020)
# 		 (1020, 2000)
# 	 1064_the_masque_of_the_red_death 2094
# 		 (0, 885)
# 		 (885, 1908)
# 		 (1908, 2094)
# 	 1342_pride_and_prejudice 2021
# 		 (0, 1024)
# 		 (1024, 2021)
# 	 2084_the_way_of_all_flesh 2052
# 		 (0, 1002)
# 		 (1002, 1976)
# 		 (1976, 2052)
# 	 18581_adrift_in_new_york_tom_and_florence_braving_the_world 2016
# 		 (0, 1009)
# 		 (1009, 2016)
# 	 84_frankenstein_or_the_modern_prometheus 2385
# 		 (0, 1006)
# 		 (1006, 1983)
# 		 (1983, 2385)
# 	 1327_elizabeth_and_her_german_garden 2046
# 		 (0, 1000)
# 		 (1000, 1974)
# 		 (1974, 2046)
# 	 238_dear_enemy 2019
# 		 (0, 989)
# 		 (989, 1992)
# 		 (1992, 2019)
# 	 219_heart_of_darkness 2043
# 		 (0, 1014)
# 		 (1014, 2013)
# 		 (2013, 2043)
# 	 969_the_tenant_of_wildfell_hall 2043
# 		 (0, 1023)
# 		 (1023, 2043)
# 	 1260_jane_eyre_an_autobiography 2034
# 		 (0, 912)
# 		 (912, 1925)
# 		 (1925, 2034)
# 	 6593_history_of_tom_jones_a_foundling 2034
# 		 (0, 1013)
# 		 (1013, 2034)
# 	 32_herland 2005
# 		 (0, 1015)
# 		 (1015, 2005)
# 	 74_the_adventures_of_tom_sawyer 2000
# 		 (0, 1016)
# 		 (1016, 2000)
# 	 1400_great_expectations 2045
# 		 (0, 1024)
# 		 (1024, 2045)
# 	 160_the_awakening_and_selected_short_stories 2020
# 		 (0, 1016)
# 		 (1016, 2020)
# 	 78_tarzan_of_the_apes 2025
# 		 (0, 1022)
# 		 (1022, 2025)
# 	 36_the_war_of_the_worlds 2017
# 		 (0, 1013)
# 		 (1013, 2017)
# 	 11231_bartleby_the_scrivener_a_story_of_wallstreet 2622
# 		 (0, 949)
# 		 (949, 1973)
# 		 (1973, 2622)
# 	 11_alices_adventures_in_wonderland 2129
# 		 (0, 1017)
# 		 (1017, 2032)
# 		 (2032, 2129)
# 	 145_middlemarch 1999
# 		 (0, 1024)
# 		 (1024, 1999)
# 	 434_the_circular_staircase 2060
# 		 (0, 1006)
# 		 (1006, 2001)
# 		 (2001, 2060)
# 	 95_the_prisoner_of_zenda 2305
# 		 (0, 999)
# 		 (999, 1990)
# 		 (1990, 2305)
# 	 766_david_copperfield 2016
# 		 (0, 1011)
# 		 (1011, 2016)
# 	 367_country_of_the_pointed_firs 2052
# 		 (0, 987)
# 		 (987, 1992)
# 		 (1992, 2052)
# 	 8867_the_magnificent_ambersons 2143
# 		 (0, 996)
# 		 (996, 1993)
# 		 (1993, 2143)
# 	 4217_a_portrait_of_the_artist_as_a_young_man 2141
# 		 (0, 1021)
# 		 (1021, 2033)
# 		 (2033, 2141)
# 	 351_of_human_bondage 2004
# 		 (0, 1023)
# 		 (1023, 2004)
# 	 1245_night_and_day 2225
# 		 (0, 1014)
# 		 (1014, 2000)
# 		 (2000, 2225)
# 	 73_the_red_badge_of_courage_an_episode_of_the_american_civil_war 2043
# 		 (0, 1021)
# 		 (1021, 2043)
# 	 2166_king_solomons_mines 2078
# 		 (0, 1022)
# 		 (1022, 2027)
# 		 (2027, 2078)
# 	 215_the_call_of_the_wild 2016
# 		 (0, 1007)
# 		 (1007, 2016)
# 	 541_the_age_of_innocence 2011
# 		 (0, 1008)
# 		 (1008, 2011)
# 	 432_the_ambassadors 2279
# 		 (0, 1019)
# 		 (1019, 2010)
# 		 (2010, 2279)
# 	 217_sons_and_lovers 2006
# 		 (0, 1016)
# 		 (1016, 2006)
# 	 2852_the_hound_of_the_baskervilles 2075
# 		 (0, 1021)
# 		 (1021, 2036)
# 		 (2036, 2075)
# 	 1206_the_flying_u_ranch 2021
# 		 (0, 994)
# 		 (994, 1992)
# 		 (1992, 2021)
# 	 155_the_moonstone 2030
# 		 (0, 1001)
# 		 (1001, 2015)
# 		 (2015, 2030)
# 	 543_main_street 2095
# 		 (0, 1024)
# 		 (1024, 2037)
# 		 (2037, 2095)
# 	 6053_evelina_or_the_history_of_a_young_ladys_entrance_into_the_world 2001
# 		 (0, 1007)
# 		 (1007, 2001)
# 	 113_the_secret_garden 2014
# 		 (0, 1015)
# 		 (1015, 2014)
# 	 2807_to_have_and_to_hold 2002
# 		 (0, 1007)
# 		 (1007, 2002)
# 	 77_the_house_of_the_seven_gables 2140
# 		 (0, 1017)
# 		 (1017, 2011)
# 		 (2011, 2140)
# 	 805_this_side_of_paradise 2000
# 		 (0, 1021)
# 		 (1021, 2000)
# 	 550_silas_marner 2049
# 		 (0, 996)
# 		 (996, 2020)
# 		 (2020, 2049)
# 	 521_the_life_and_adventures_of_robinson_crusoe 2276
# 		 (0, 979)
# 		 (979, 1958)
# 		 (1958, 2276)
# 	 2095_clotelle_a_tale_of_the_southern_states 2015
# 		 (0, 978)
# 		 (978, 1991)
# 		 (1991, 2015)
# 	 33_the_scarlet_letter 2165
# 		 (0, 990)
# 		 (990, 2012)
# 		 (2012, 2165)
# 	 730_oliver_twist 2056
# 		 (0, 992)
# 		 (992, 2007)
# 		 (2007, 2056)
# 	 60_the_scarlet_pimpernel 2028
# 		 (0, 1022)
# 		 (1022, 2028)
# 	 1695_the_man_who_was_thursday_a_nightmare 2067
# 		 (0, 1001)
# 		 (1001, 2024)
# 		 (2024, 2067)
# 	 1023_bleak_house 2269
# 		 (0, 947)
# 		 (947, 1945)
# 		 (1945, 2269)
# 	 974_the_secret_agent_a_simple_tale 2507
# 		 (0, 991)
# 		 (991, 1967)
# 		 (1967, 2507)
# 	 110_tess_of_the_durbervilles_a_pure_woman 2002
# 		 (0, 976)
# 		 (976, 1988)
# 		 (1988, 2002)
# 	 105_persuasion 2088
# 		 (0, 993)
# 		 (993, 2015)
# 		 (2015, 2088)
# 	 829_gullivers_travels_into_several_remote_nations_of_the_world 3419
# 		 (0, 986)
# 		 (986, 1893)
# 		 (1893, 2891)
# 		 (2891, 3419)
# 	 4276_north_and_south 2001
# 		 (0, 1023)
# 		 (1023, 2001)
# 	 171_charlotte_temple 2041
# 		 (0, 968)
# 		 (968, 1983)
# 		 (1983, 2041)
# 	 2489_moby_dick 2173
# 		 (0, 1017)
# 		 (1017, 2016)
# 		 (2016, 2173)
# 	 5348_ragged_dick_or_street_life_in_new_york_with_the_bootblacks 2096
# 		 (0, 1007)
# 		 (1007, 2019)
# 		 (2019, 2096)
# 	 711_allan_quatermain 2000
# 		 (0, 1017)
# 		 (1017, 2000)
# 	 876_life_in_the_ironmills_or_the_korl_woman 2163
# 		 (0, 1001)
# 		 (1001, 2014)
# 		 (2014, 2163)
# 	 2775_the_good_soldier 2321
# 		 (0, 1000)
# 		 (1000, 1995)
# 		 (1995, 2321)
# 	 41_the_legend_of_sleepy_hollow 2171
# 		 (0, 995)
# 		 (995, 1994)
# 		 (1994, 2171)
# 	 62_a_princess_of_mars 2022
# 		 (0, 988)
# 		 (988, 1965)
# 		 (1965, 2022)
# 	 271_black_beauty 2014
# 		 (0, 973)
# 		 (973, 1962)
# 		 (1962, 2014)
# 	 27_far_from_the_madding_crowd 2322
# 		 (0, 1007)
# 		 (1007, 2011)
# 		 (2011, 2322)
# 	 3457_the_man_of_the_forest 2038
# 		 (0, 1008)
# 		 (1008, 2029)
# 		 (2029, 2038)
# 	 514_little_women 2014
# 		 (0, 1012)
# 		 (1012, 2014)
# 	 44_the_song_of_the_lark 2051
# 		 (0, 1004)
# 		 (1004, 2023)
# 		 (2023, 2051)
# 	 768_wuthering_heights 2034
# 		 (0, 999)
# 		 (999, 2018)
# 		 (2018, 2034)
# 	 2005_piccadilly_jim 2084
# 		 (0, 1018)
# 		 (1018, 2038)
# 		 (2038, 2084)
# 	 233_sister_carrie_a_novel 2061
# 		 (0, 1000)
# 		 (1000, 2012)
# 		 (2012, 2061)
# 	 3268_the_mysteries_of_udolpho 2003
# 		 (0, 985)
# 		 (985, 2003)
# 	 209_the_turn_of_the_screw 2027
# 		 (0, 1018)
# 		 (1018, 2027)
# 	 502_desert_gold 2054
# 		 (0, 1012)
# 		 (1012, 2026)
# 		 (2026, 2054)
# 	 12677_personality_plus_some_experiences_of_emma_mcchesney_and_her_son_jock 2020
# 		 (0, 1006)
# 		 (1006, 2020)
# 	 345_dracula 2251
# 		 (0, 997)
# 		 (997, 2009)
# 		 (2009, 2251)
# 	 1155_the_secret_adversary 2105
# 		 (0, 1021)
# 		 (1021, 2025)
# 		 (2025, 2105)
# 	 1661_the_adventures_of_sherlock_holmes 2095
# 		 (0, 1013)
# 		 (1013, 2036)
# 		 (2036, 2095)
# 	 158_emma 2063
# 		 (0, 999)
# 		 (999, 2017)
# 		 (2017, 2063)
# 	 15265_the_quest_of_the_silver_fleece_a_novel 2002
# 		 (0, 1018)
# 		 (1018, 2002)
# 	 16357_mary_a_fiction 2044
# 		 (0, 983)
# 		 (983, 1975)
# 		 (1975, 2044)
# 2048 0
# 	 5230_the_invisible_man_a_grotesque_romance 2016
# 		 (0, 2016)
# 	 2641_a_room_with_a_view 2009
# 		 (0, 2009)
# 	 2891_howards_end 2022
# 		 (0, 2022)
# 	 472_the_house_behind_the_cedars 2024
# 		 (0, 2024)
# 	 208_daisy_miller_a_study 2005
# 		 (0, 2005)
# 	 940_the_last_of_the_mohicans_a_narrative_of_1757 2247
# 		 (0, 2024)
# 		 (2024, 2247)
# 	 9830_the_beautiful_and_damned 2072
# 		 (0, 2014)
# 		 (2014, 2072)
# 	 2814_dubliners 2003
# 		 (0, 2003)
# 	 41286_miss_marjoribanks 2744
# 		 (0, 2034)
# 		 (2034, 2744)
# 	 174_the_picture_of_dorian_gray 2016
# 		 (0, 2016)
# 	 120_treasure_island 2220
# 		 (0, 2038)
# 		 (2038, 2220)
# 	 4300_ulysses 2034
# 		 (0, 2034)
# 	 932_the_fall_of_the_house_of_usher 2177
# 		 (0, 1960)
# 		 (1960, 2177)
# 	 24_o_pioneers 2041
# 		 (0, 2041)
# 	 4051_lady_bridget_in_the_nevernever_land_a_story_of_australian_life 2089
# 		 (0, 2023)
# 		 (2023, 2089)
# 	 599_vanity_fair 2043
# 		 (0, 2043)
# 	 76_adventures_of_huckleberry_finn 2153
# 		 (0, 2047)
# 		 (2047, 2153)
# 	 45_anne_of_green_gables 2000
# 		 (0, 2000)
# 	 1064_the_masque_of_the_red_death 2094
# 		 (0, 2048)
# 		 (2048, 2094)
# 	 1342_pride_and_prejudice 2021
# 		 (0, 2021)
# 	 2084_the_way_of_all_flesh 2052
# 		 (0, 1976)
# 		 (1976, 2052)
# 	 18581_adrift_in_new_york_tom_and_florence_braving_the_world 2016
# 		 (0, 2016)
# 	 84_frankenstein_or_the_modern_prometheus 2385
# 		 (0, 1983)
# 		 (1983, 2385)
# 	 1327_elizabeth_and_her_german_garden 2046
# 		 (0, 2046)
# 	 238_dear_enemy 2019
# 		 (0, 2019)
# 	 219_heart_of_darkness 2043
# 		 (0, 2043)
# 	 969_the_tenant_of_wildfell_hall 2043
# 		 (0, 2043)
# 	 1260_jane_eyre_an_autobiography 2034
# 		 (0, 2034)
# 	 6593_history_of_tom_jones_a_foundling 2034
# 		 (0, 2034)
# 	 32_herland 2005
# 		 (0, 2005)
# 	 74_the_adventures_of_tom_sawyer 2000
# 		 (0, 2000)
# 	 1400_great_expectations 2045
# 		 (0, 2045)
# 	 160_the_awakening_and_selected_short_stories 2020
# 		 (0, 2020)
# 	 78_tarzan_of_the_apes 2025
# 		 (0, 2025)
# 	 36_the_war_of_the_worlds 2017
# 		 (0, 2017)
# 	 11231_bartleby_the_scrivener_a_story_of_wallstreet 2622
# 		 (0, 2014)
# 		 (2014, 2622)
# 	 11_alices_adventures_in_wonderland 2129
# 		 (0, 2032)
# 		 (2032, 2129)
# 	 145_middlemarch 1999
# 		 (0, 1999)
# 	 434_the_circular_staircase 2060
# 		 (0, 2001)
# 		 (2001, 2060)
# 	 95_the_prisoner_of_zenda 2305
# 		 (0, 1990)
# 		 (1990, 2305)
# 	 766_david_copperfield 2016
# 		 (0, 2016)
# 	 367_country_of_the_pointed_firs 2052
# 		 (0, 2020)
# 		 (2020, 2052)
# 	 8867_the_magnificent_ambersons 2143
# 		 (0, 2022)
# 		 (2022, 2143)
# 	 4217_a_portrait_of_the_artist_as_a_young_man 2141
# 		 (0, 2033)
# 		 (2033, 2141)
# 	 351_of_human_bondage 2004
# 		 (0, 2004)
# 	 1245_night_and_day 2225
# 		 (0, 2039)
# 		 (2039, 2225)
# 	 73_the_red_badge_of_courage_an_episode_of_the_american_civil_war 2043
# 		 (0, 2043)
# 	 2166_king_solomons_mines 2078
# 		 (0, 2027)
# 		 (2027, 2078)
# 	 215_the_call_of_the_wild 2016
# 		 (0, 2016)
# 	 541_the_age_of_innocence 2011
# 		 (0, 2011)
# 	 432_the_ambassadors 2279
# 		 (0, 2010)
# 		 (2010, 2279)
# 	 217_sons_and_lovers 2006
# 		 (0, 2006)
# 	 2852_the_hound_of_the_baskervilles 2075
# 		 (0, 2047)
# 		 (2047, 2075)
# 	 1206_the_flying_u_ranch 2021
# 		 (0, 2021)
# 	 155_the_moonstone 2030
# 		 (0, 2030)
# 	 543_main_street 2095
# 		 (0, 2037)
# 		 (2037, 2095)
# 	 6053_evelina_or_the_history_of_a_young_ladys_entrance_into_the_world 2001
# 		 (0, 2001)
# 	 113_the_secret_garden 2014
# 		 (0, 2014)
# 	 2807_to_have_and_to_hold 2002
# 		 (0, 2002)
# 	 77_the_house_of_the_seven_gables 2140
# 		 (0, 2011)
# 		 (2011, 2140)
# 	 805_this_side_of_paradise 2000
# 		 (0, 2000)
# 	 550_silas_marner 2049
# 		 (0, 2020)
# 		 (2020, 2049)
# 	 521_the_life_and_adventures_of_robinson_crusoe 2276
# 		 (0, 1958)
# 		 (1958, 2276)
# 	 2095_clotelle_a_tale_of_the_southern_states 2015
# 		 (0, 2015)
# 	 33_the_scarlet_letter 2165
# 		 (0, 2012)
# 		 (2012, 2165)
# 	 730_oliver_twist 2056
# 		 (0, 2033)
# 		 (2033, 2056)
# 	 60_the_scarlet_pimpernel 2028
# 		 (0, 2028)
# 	 1695_the_man_who_was_thursday_a_nightmare 2067
# 		 (0, 2024)
# 		 (2024, 2067)
# 	 1023_bleak_house 2269
# 		 (0, 2030)
# 		 (2030, 2269)
# 	 974_the_secret_agent_a_simple_tale 2507
# 		 (0, 1967)
# 		 (1967, 2507)
# 	 110_tess_of_the_durbervilles_a_pure_woman 2002
# 		 (0, 2002)
# 	 105_persuasion 2088
# 		 (0, 2015)
# 		 (2015, 2088)
# 	 829_gullivers_travels_into_several_remote_nations_of_the_world 3419
# 		 (0, 2028)
# 		 (2028, 3419)
# 	 4276_north_and_south 2001
# 		 (0, 2001)
# 	 171_charlotte_temple 2041
# 		 (0, 2041)
# 	 2489_moby_dick 2173
# 		 (0, 2043)
# 		 (2043, 2173)
# 	 5348_ragged_dick_or_street_life_in_new_york_with_the_bootblacks 2096
# 		 (0, 2043)
# 		 (2043, 2096)
# 	 711_allan_quatermain 2000
# 		 (0, 2000)
# 	 876_life_in_the_ironmills_or_the_korl_woman 2163
# 		 (0, 2040)
# 		 (2040, 2163)
# 	 2775_the_good_soldier 2321
# 		 (0, 2046)
# 		 (2046, 2321)
# 	 41_the_legend_of_sleepy_hollow 2171
# 		 (0, 2041)
# 		 (2041, 2171)
# 	 62_a_princess_of_mars 2022
# 		 (0, 2022)
# 	 271_black_beauty 2014
# 		 (0, 2014)
# 	 27_far_from_the_madding_crowd 2322
# 		 (0, 2046)
# 		 (2046, 2322)
# 	 3457_the_man_of_the_forest 2038
# 		 (0, 2038)
# 	 514_little_women 2014
# 		 (0, 2014)
# 	 44_the_song_of_the_lark 2051
# 		 (0, 2038)
# 		 (2038, 2051)
# 	 768_wuthering_heights 2034
# 		 (0, 2034)
# 	 2005_piccadilly_jim 2084
# 		 (0, 2038)
# 		 (2038, 2084)
# 	 233_sister_carrie_a_novel 2061
# 		 (0, 2046)
# 		 (2046, 2061)
# 	 3268_the_mysteries_of_udolpho 2003
# 		 (0, 2003)
# 	 209_the_turn_of_the_screw 2027
# 		 (0, 2027)
# 	 502_desert_gold 2054
# 		 (0, 2043)
# 		 (2043, 2054)
# 	 12677_personality_plus_some_experiences_of_emma_mcchesney_and_her_son_jock 2020
# 		 (0, 2020)
# 	 345_dracula 2251
# 		 (0, 2043)
# 		 (2043, 2251)
# 	 1155_the_secret_adversary 2105
# 		 (0, 2025)
# 		 (2025, 2105)
# 	 1661_the_adventures_of_sherlock_holmes 2095
# 		 (0, 2048)
# 		 (2048, 2095)
# 	 158_emma 2063
# 		 (0, 2017)
# 		 (2017, 2063)
# 	 15265_the_quest_of_the_silver_fleece_a_novel 2002
# 		 (0, 2002)
# 	 16357_mary_a_fiction 2044
# 		 (0, 2044)

# %%
n_singletons = 0
n_empty_clusters = 0
for book in litbank:
    for cluster in book.clusters.values():
        n_singletons += len(cluster) == 1
        n_empty_clusters += len(cluster) == 0
print(n_singletons)
print(n_empty_clusters)
# Out:
# 5803
# 0

# %%
n_singletons = 0
for movie in moviebank:
    for cluster in movie.clusters.values():
        n_singletons += len(cluster) == 1
print(n_singletons)
# Out:
# 43
