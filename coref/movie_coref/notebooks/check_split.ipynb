# %%
import jsonlines

# %%
docs = []
with jsonlines.open("/home/sbaruah_usc_edu/mica_text_coref/data/movie_coref/results/regular/dev_wl.jsonlines") as reader:
    for doc in reader:
        docs.append(doc)

# %%
for doc in docs:
    print(sorted(doc.keys()))
# Out:
# ['cased_words', 'clusters', 'document_id', 'movie', 'ner', 'parse', 'pos', 'rater', 'sent_id', 'sent_offset', 'speaker', 'token']
# ['cased_words', 'clusters', 'document_id', 'movie', 'ner', 'parse', 'pos', 'rater', 'sent_id', 'sent_offset', 'speaker', 'token']
# ['cased_words', 'clusters', 'document_id', 'movie', 'ner', 'parse', 'pos', 'rater', 'sent_id', 'sent_offset', 'speaker', 'token']

# %%
doc["clusters"]
# Out:
# {'READER': [[9, 9, 9],
#   [238, 238, 238],
#   [980, 980, 980],
#   [1082, 1082, 1082],
#   [1605, 1605, 1605],
#   [1608, 1608, 1608],
#   [1641, 1645, 1645],
#   [2564, 2564, 2564],
#   [3405, 3405, 3405],
#   [4419, 4419, 4419],
#   [5336, 5336, 5336],
#   [5470, 5470, 5470],
#   [6200, 6200, 6200],
#   [6239, 6239, 6239],
#   [6496, 6496, 6496]],
#  'LT. HICOX': [[45, 47, 47],
#   [61, 61, 61],
#   [101, 101, 101],
#   [117, 119, 119],
#   [120, 120, 120],
#   [129, 129, 129],
#   [137, 139, 139],
#   [154, 154, 154],
#   [211, 213, 213],
#   [325, 327, 327],
#   [352, 354, 354],
#   [358, 360, 360],
#   [371, 371, 371],
#   [390, 392, 392],
#   [411, 413, 413],
#   [448, 448, 448],
#   [458, 458, 458],
#   [485, 487, 487],
#   [497, 497, 497],
#   [499, 501, 501],
#   [511, 511, 511],
#   [525, 525, 525],
#   [536, 539, 539],
#   [560, 560, 560],
#   [570, 570, 570],
#   [577, 579, 579],
#   [614, 616, 616],
#   [693, 695, 695],
#   [712, 714, 714],
#   [757, 759, 759],
# ...
