# %%
import re
import spacy
import numpy as np
import pandas as pd
from tqdm import tqdm
from copy import deepcopy
from spacy import displacy
from IPython.display import display
from sklearn.model_selection import ParameterGrid
from allennlp.predictors.predictor import Predictor
from evaluate_coreference import evaluate_coreference
from collections import defaultdict, Counter, OrderedDict
from evaluate_by_joining_elements import evaluate_coreference_by_joining_elements

# %%
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz")
# Out:
# Did not use initialization regex that was passed: _context_layer._module.weight_hh.*
# Did not use initialization regex that was passed: _context_layer._module.weight_ih.*

# %%
basterds_result = evaluate_coreference_by_joining_elements("data/annotation/basterds.script_parsed.txt", "data/annotation/basterds.coref.mapped.csv", -1, use_speaker_sep=True, coreference_model=predictor)
# Out:
# loading spacy model
#   2%|▏         | 10/591 [00:00<00:06, 91.79it/s]
# spacy tokenization of screenplay elements
# 100%|██████████| 591/591 [00:06<00:00, 89.44it/s]
# finding global gold mention positions
# 	1008 gold mentions
# 	988 (98.01587301587301%) gold mentions found after parse
# 	980 (97.22222222222223%) gold mentions' spacy tokenization span found
# finding gold clusters
# 23 gold clusters
# finding sys clusters
# 	using 'says' after character names
# 	allennlp coreference resolution
# /pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# 40 sys clusters
#
#
# MUC  : P = 0.7876 R = 0.6782 F1 = 0.7288
# B3   : P = 0.5691 R = 0.2532 F1 = 0.3505
# CEAFe: P = 0.2100 R = 0.3653 F1 = 0.2667
# CoNLL 2012 score: 0.4487

# %%
basterds_result.keys()
# Out:
# dict_keys(['evaluation', 'gold_clusters', 'sys_clusters', 'coref_dataframe', 'document', 'mention_tags'])

# %%
basterds_evaluation = basterds_result["evaluation"]
basterds_gold_entity_to_cluster = basterds_result["gold_clusters"]
basterds_sys_clusters = basterds_result["sys_clusters"]
basterds_coref_df = basterds_result["coref_dataframe"]
basterds_document = basterds_result["document"]
basterds_mention_tags = basterds_result["mention_tags"]

# %%
spacy_nlp = spacy.load("en_core_web_sm")
spacy_basterds_document = spacy_nlp(basterds_document)

# %%
len(spacy_basterds_document), len(basterds_mention_tags)
# Out:
# (7828, 7828)

# %%
evaluate_coreference(basterds_gold_entity_to_cluster.values(), basterds_sys_clusters)
# Out:
# MUC  : P = 0.7876 R = 0.6782 F1 = 0.7288
# B3   : P = 0.5691 R = 0.2532 F1 = 0.3505
# CEAFe: P = 0.2100 R = 0.3653 F1 = 0.2667
# CoNLL 2012 score: 0.4487
# {'muc': {'R': 0.6781609195402298,
#   'P': 0.787621359223301,
#   'F1': 0.7288040426726559},
#  'bcubed': {'R': 0.25324783617337143,
#   'P': 0.5691203940018071,
#   'F1': 0.3505206135514073},
#  'ceafe': {'R': 0.36529256819057865,
#   'P': 0.21004322670958273,
#   'F1': 0.2667215577264543},
#  'conll2012': {'R': 0.4322337746347267,
#   'P': 0.5222616599782303,
#   'F1': 0.4486820713168392}}

# %%
len(basterds_sys_clusters)
# Out:
# 40

# %%
len(basterds_gold_entity_to_cluster)
# Out:
# 23

# %%
for p, sys_cluster in enumerate(basterds_sys_clusters):
    for i, j in sys_cluster:
        k = spacy_basterds_document[i].idx
        l = spacy_basterds_document[j].idx + len(spacy_basterds_document[j])
        mention_text = re.sub("\s+", " ", basterds_document[k:l]).strip()
        mention_tags = basterds_mention_tags[i: j + 1]
        mention_ner_tags = [token.ent_type_ for token in spacy_basterds_document[i: j + 1]]
        
        if len(set(mention_tags)) == 1:
            mention_tags_text = mention_tags[0]
        else:
            mention_tags_text = ",".join(mention_tags)
            
        if len(set(mention_ner_tags)) == 1:
            mention_ner_text = mention_ner_tags[0]
        else:
            mention_ner_text = ",".join(mention_ner_tags)
        
        print(f"{p + 1:2d}. {mention_text:30s} {mention_tags_text:10s} {mention_ner_text}")
    print()
# Out:
#  1. ALDO                           C          ORG
#  1. Aldo with his hands up         D
#  1. ALDO'S                         C          ORG,
#  1. ALDO'S                         C          ORG,
#  1. ALDO'S                         C          ORG
#  1. I                              D
#  1. ALDO'S                         C          GPE,
#  1. you                            D
#  1. ALDO                           C          ORG
#  1. LT.ALDO                        D          ORG
#  1. his                            D
#  1. LT.ALDO                        C          ORG
#  1. my                             D
#  1. I                              D
#  1. WILLI                          C          PERSON
#  1. ALDO                           C          ORG
#  1. ALDO                           C          ORG
#  1. Willi                          N          ORG
#  1. ALDO                           C          ORG
#  1. You                            D
#  1. ALDO'S                         C          ORG,
#  1. your                           D
#  1. me                             D
#  1. Aldo                           D          ORG
#  1. ALDO                           C          ORG
#  1. my                             D
#  1. Aldo                           D          ORG
#  1. I                              D
#  1. ALDO                           C          ORG
#  1. He                             D
#  1. ALDO                           C          ORG
#  1. my                             N
#  1. Aldo                           N          ORG
#  1. you                            D
#  1. Aldo                           D          ORG
#  1. him                            D
#  1. yours                          D
#  1. my                             D
#  1. Aldo                           D          PERSON
#  1. I                              D
#  1. Willi                          D
#  1. i                              D
#  1. your                           D
#  1. Aldo                           D          PERSON
#  1. I                              D
#  1. Willi                          D          ORG
#  1. ALDO                           C          ORG
#  1. ALDO                           N          ORG
#  1. Aldo                           N          ORG
#  1. He                             D
#  1. I                              D
#  1. I                              N
#  1. ALDO'S                         C          ORG
#  1. he                             D
#  1. ALDO'S                         C          ORG,
#  1. that man                       D
#  1. he                             D
#  1. I                              N
#  1. Aldo                           E,X
#  1. ALDO'S                         C          ORG,
#  1. Aldo                           D
#  1. you                            D
#  1. Aldo                           D          ORG
#  1. Lieutenant                     D          PRODUCT
#  1. you                            D
#  1. Aldo's                         D          ORG,
#  1. ALDO'S                         C          ORG,
#  1. your                           D
#  1. you                            D
#  1. I                              D
#  1. your                           D
#  1. Willi                          D          ORG
#  1. I                              D
#  1. He                             D
#  1. I                              D
#  1. your                           D
#  1. he                             D
#  1. Willi                          D
#  1. Aldo                           D          PERSON
#  1. He                             D
#  1. ALDO'S                         C          ORG,
#  1. you                            D
#  1. Aldo                           D          ORG
#
#  2. Cap't                          D
#  2. Major                          D
#  2. I                              D
#  2. the Major                      D          ,PERSON
#  2. You                            D
#  2. I                              D
#  2. LT.HICOX                       D
#  2. LT.HICOX                       C
#  2. My                             D
#  2. Your                           D
#  2. I                              D
#  2. my                             D
#  2. I                              D
#  2. my                             D
#  2. Your                           D
#  2. I                              D
#  2. MAJOR HELLSTROM                C          ORG
#  2. MAJOR HELLSTROM                C
#  2. MAJOR HELLSTROM                C
#  2. LT.HICOX                       C
#  2. LT.HICOX                       C
#  2. Lt.Hicox                       D          ,,PERSON
#  2. my                             D
#  2. MAJOR HELLSTROM                C
#  2. your                           D
#  2. you                            D
#  2. his                            D
#  2. COX                            C          ORG
#  2. Lieutenant                     D          PERSON
#  2. Major                          D          PERSON
#  2. I                              D
#  2. my                             D
#  2. Major                          D
#  2. you                            D
#  2. LT.HICOX                       C
#  2. Major                          D          PERSON
#  2. Major                          D
#  2. You                            D
#  2. I                              D
#  2. you                            D
#  2. I                              D
#  2. I                              C
#  2. his                            D
#  2. me                             D
#  2. MAJOR HELLSTROM                C          ORG
#  2. you                            D
#  2. me                             D
#  2. I                              D
#  2. you                            D
#  2. I                              D
#  2. me                             D
#  2. LT.HICOX                       C
#  2. I                              D
#  2. LT.HICOX                       C
#  2. you                            D
#  2. Lt.Hicox                       D
#  2. LT.HICOX                       C
#  2. my                             D
#  2. MAJOR HELLSTROM                C          ORG
#  2. MAJOR HELLSTROM                C
#  2. MAJOR HELLSTROM                C
#  2. Lt.Hicox                       D          ,,PERSON
#  2. myself                         D
#  2. LT.HICOX                       C
#  2. MAJOR HELLSTROM                C          ORG
#  2. LT.HICOX                       C
#  2. I                              D
#  2. LT.HICOX                       C
#  2. I                              D
#  2. MAJOR HELLSTROM                C          ORG
#  2. I                              D
#  2. my                             D
#  2. sir                            D
#  2. MAJOR HELLSTROM                C
#  2. MAJOR HELLSTROM                C          ORG
#  2. the Young Cap't                D          WORK_OF_ART
#  2. my                             D
#  2. Hicox                          D          PERSON
#  2. I                              C
#  2. MAJOR HELLSTROM                C
#  2. you                            D
#  2. him                            E
#  2. Lt.Hicox                       D
#  2. I                              D
#  2. The Major                      D          ,ORG
#  2. I                              D
#  2. his                            D
#  2. Major                          D
#  2. HICOX                          C
#  2. you                            D
#  2. my                             D
#  2. I                              C
#  2. I                              D
#  2. you                            D
#  2. LT.HICOX                       C
#  2. me                             D
#  2. yourself                       D
#  2. MAJOR HELLSTROM                C          ORG
#  2. Hicox                          D          PERSON
#  2. me                             D
#  2. LT.HICOX                       C
#  2. Hicox                          D          PERSON
#  2. I                              D
#  2. HELLSTROM                      D
#  2. LT.HICOX                       C
#  2. I                              D
#  2. LT.HICOX                       C
#  2. I                              D
#  2. your                           D
#  2. You                            D
#  2. I                              D
#  2. Your                           D
#  2. Major                          D          PERSON
#  2. LT.HICOX                       C
#  2. HELLSTROM'S                    C          ORG,
#  2. He                             D
#  2. LT.HICOX                       C
#  2. MAJOR HELLSTROM                C          ORG
#  2. Hellstrom                      D          PERSON
#  2. MAJOR HELLSTROM (ENGLISH)      N          ,,,WORK_OF_ART,
#  2. MAJOR HELLSTROM (ENGLISH)      N          ,,,WORK_OF_ART,
#  2. the limy Lieutenant            N          ,,PRODUCT
#  2. MAJOR HELLSTROM                C
#  2. LT.HICOX                       C
#  2. LT.HICOX                       C
#  2. my                             D
#  2. HELLSTROM                      C          ORG
#
#  3. you                            D
#  3. Wicki                          D          ORG
#  3. WICKI                          N
#  3. WICKI                          C          PERSON
#  3. Wilhelm                        D          PERSON
#  3. WICKI                          C          PERSON
#  3. Wicki                          D          ORG
#  3. Wicki                          E          ORG
#  3. WICKI                          C          PERSON
#  3. WICKI                          C          PERSON
#  3. Wilhelm                        D          PERSON
#  3. WICKI                          C          PERSON
#  3. Wilhelm                        D          PERSON
#  3. he                             D
#  3. ya                             D
#  3. Wicki                          D          ORG
#  3. Wilhelm                        D
#  3. Wicki                          D          NORP
#  3. WICKI                          D          PERSON
#  3. Wilhelm Wicki                  D          PERSON
#  3. WICKI                          C          PERSON
#  3. Wilhelm                        D
#  3. Wilhelm                        D          PERSON
#  3. WICKI                          C          PERSON
#  3. his                            D
#
#  4. This Gerry of yours, Stiglitz  D          PERSON,PERSON,,,,PERSON
#  4. him                            D
#  4. you                            C
#  4. your                           D
#  4. Hugo Stiglitz                  D          PERSON
#  4. STIGLITZ                       C          ORG
#  4. STIGLITZ                       C          ORG
#  4. Stiglitz                       D          PERSON
#  4. his                            N
#  4. Stiglitz                       D
#  4. Hugo Stiglitz                  D          PERSON
#  4. Hugo Stiglitz                  D          PERSON
#  4. his                            D
#  4. Stiglitz                       E          PERSON
#  4. himself                        D
#  4. his                            D
#  4. He                             D
#  4. Stiglitz                       D          ORG
#  4. his                            D
#  4. he                             D
#  4. The renegade Gerry Sergeant    N          ,,PERSON,PERSON
#  4. his                            D
#  4. that                           D
#  4. I                              D
#  4. Stiglitz                       D          PERSON
#  4. Hugo                           N          EVENT
#  4. his                            N
#  4. STIGLITZ                       C          ORG
#  4. He                             D
#  4. himself                        D
#  4. .Stiglitz                      D
#  4. Stiglitz                       D          PERSON
#  4. you                            D
#  4. Hugo                           N          EVENT
#  4. STIGLITZ                       N
#  4. Stiglitz                       D          PERSON
#  4. him                            D
#
#  5. LT.NICOX                       C
#  5. sir                            D
#
#  6. Bridget                        D,X
#  6. BRIDGET                        C          ORG
#  6. I                              D
#  6. Bridget LOW in GERMAN          D,X,C,C,C  ,,,,ORG
#  6. The Barmaid                    N          ,PERSON
#  6. Bridget's                      D          ORG,
#  6. BRIDGET'S                      C          ORG,
#  6. Von Hammersmark                D          PERSON
#  6. Frau Von Hammersmark           D          PERSON
#  6. she                            D
#  6. her                            D
#  6. Fraulein Von Hammersmark       D          PERSON
#  6. her                            D
#  6. your                           D
#  6. She                            D
#  6. Frau Von Hammersmark           D          PERSON
#  6. you                            D
#  6. the German celebrity           D          ,NORP,
#  6. she                            D
#  6. BRIDGET                        D          ORG
#  6. herself                        D
#  6. her                            D
#  6. she                            D
#  6. her                            D
#  6. Bridget                        D          ORG
#  6. I                              D
#  6. you                            D
#  6. you                            D
#  6. BRIDGET                        D          PERSON
#  6. Bridget                        N          ORG
#  6. the alive Bridget Von Hammersmark D          ,,PERSON,PERSON,PERSON
#  6. The French Barmaid             N          ,NORP,
#  6. .Bridget Von Hammersmark       D          ,PERSON,PERSON
#  6. you                            D
#  6. your                           D
#  6. Frau Von Hammersmark           D          PERSON
#  6. You                            D
#  6. Frau Von Hammersmark           D          PERSON
#  6. BRIDGET                        C          ORG
#  6. the greatest actress in Germany D          ,,,,GPE
#  6. BRIDGET                        C          ORG
#  6. her                            N
#  6. BRIDGET                        C          ORG
#  6. Her                            D
#  6. I                              D
#  6. your                           D
#  6. you                            D
#  6. I                              D
#  6. your                           D
#  6. I                              D
#  6. Bridget                        D          PERSON
#  6. Bridget                        D          ORG
#  6. She                            D
#  6. Bridget                        D
#  6. BRIDGET                        C          ORG
#  6. Bridget                        N
#  6. she                            D
#  6. BRIDGET                        C          ORG
#  6. the YOUNG FRENCH BARMAID, the only other person in the establishment D
#  6. Fraulein Von Hammersmark       N          PERSON
#  6. Bridget                        D
#  6. She                            D
#  6. She                            N
#  6. i                              D
#  6. BRIDGET                        C          ORG
#  6. she                            E
#  6. BRIDGET                        C          PERSON
#  6. Bridget                        D,X
#  6. the female German celebrity    D          ,,NORP,
#  6. Frau Von Hammersmark           D          PERSON
#  6. her                            D
#  6. she                            N
#  6. You                            D
#  6. She                            D
#  6. She                            D
#  6. my                             D
#  6. She                            D
#  6. BRIDGET                        C          ORG
#  6. BRIDGET                        C          ORG
#  6. you                            D
#  6. Frau Von Hammersmark's         D          PERSON
#  6. her                            N
#  6. I                              D
#  6. BRIDGET                        C          ORG
#  6. Bridget Von Hammersmark        D          PERSON
#  6. she                            D
#  6. BRIDGET                        D          ORG
#  6. BRIDGET                        C          ORG
#  6. Von Hammersmark                D          PERSON
#  6. Bridget Von Hammersmark        D          ,PERSON,PERSON
#  6. you                            D
#  6. She                            D
#  6. Bridget LOW in GERMAN          D,X,C,C,C  ,,,,ORG
#  6. Bridget                        D          ORG
#
#  7. I                              D
#  7. PFC.HIRSCHBERG                 C
#  7. I                              D
#  7. me                             D
#
#  8. I                              D
#  8. him                            D
#  8. LT.HICOX                       C          PERSON
#  8. LT.HICOX                       C
#  8. your                           D
#  8. you                            D
#
#  9. Sgt                            D          PERSON
#  9. SGT.DONOWITZ                   C
#
# 10. S.S. dagger                    D
# 10. the dagger                     D
# 10. the DAGGER                     D,X,C
#
# 11. your                           D
# 11. your                           D
# 11. you                            D
# 11. I                              D
# 11. SGT.POLA NEGRI                 C          ,ORG
# 11. MASTER SGT #1 , a powerfully built stocky type POLA NEGRI D,D,D,D,D,X,E,E,E,E,E,E,E
# 11. me                             D
# 11. you                            D
# 11. You                            D
# 11. SGT.POLA NEGRI                 C          ,ORG
# 11. your                           D
# 11. OS GERMAN SGT                  E,X,C,C
# 11. the young German Sgt, with the machine gunn D          ,,NORP,,,,,,
# 11. I                              D
# 11. your                           D
# 11. I                              D
# 11. The young German Sgt           D          ,,NORP,
# 11. his                            D
# 11. you                            D
# 11. your                           D
# 11. SGT.POLA NEGRI                 C          ,ORG
# 11. My                             D
# 11. soldier                        D
# 11. ONE GERMAN MASTER SGT          D          CARDINAL,,,
# 11. you                            D
# 11. your                           D
# 11. your                           D
# 11. GERMAN SGT                     C          ORG
# 11. my                             D
# 11. he                             D
# 11. Sgt.                           D          PERSON,
# 11. You                            D
# 11. SGT.POLA NEGRI                 C          ,ORG
# 11. you                            D
# 11. you                            D
# 11. you                            D
# 11. The German Master Sgt.         D          ,NORP,,,
# 11. the German Sgt                 D          ,NORP,
# 11. SGT.POLA NEGRI                 C          ,ORG
# 11. your                           D
# 11. I                              D
# 11. his                            D
# 11. Sgt                            D          ORG
# 11. You                            D
# 11. his                            D
# 11. you                            D
# 11. you                            D
# 11. I                              D
# 11. The German Master Sgt          D          ,NORP,,
# 11. he                             D
# 11. he                             D
#
# 12. Bridget Von Hammersmark, who wears her card in the brim of her fedora N          PERSON,PERSON,PERSON,,,,,,,,,,,
# 12. her                            N
# 12. BRIDGET/GENGUS                 C          ORG,,
# 12. her                            N
#
# 13. me                             D
# 13. Winnetou                       N          PERSON
# 13. I                              D
# 13. He                             D
# 13. WINNETOU                       C          PERSON
# 13. the character                  D
# 13. WINNETOU                       C
# 13. He                             D
# 13. he                             D
# 13. you                            D
# 13. WINNETOU                       C          PERSON
# 13. he                             D
# 13. The Character                  D          ,ORG
# 13. WINNETOU                       C
# 13. he                             D
# 13. my                             D
# 13. this character                 D
# 13. I                              D
# 13. WINNETOU                       N
# 13. he                             D
# 13. WINNETOU                       C          PERSON
# 13. he                             D
# 13. He                             D
# 13. he                             D
# 13. the character                  D
# 13. I                              D
# 13. WINNETOU                       C          PERSON
# 13. you                            D
# 13. WINNETOU                       C
# 13. WINNETOU                       N
# 13. I                              D
# 13. I                              D
# 13. I                              D
# 13. he                             D
#
# 14. FEMALE SGT #2(BEETHOVEN)       N          ,,,MONEY,
# 14. FEMALE SGT/BEETHOVEN           C
#
# 15. EDGAR WALLACE                  N
# 15. EDGAR WALLACE                  C
# 15. Edgar Wallace                  E          FAC
# 15. EDGAR WALLACE                  D
# 15. EDGAR WALLACE                  C          PERSON
#
# 16. the table                      N
# 16. the table                      D
# 16. his table                      D
# 16. That table                     D
# 16. the Table                      E
# 16. They                           D
# 16. The Table                      D
# 16. gentlemen                      D
# 16. your                           D
# 16. gentlemen                      D
# 16. The table                      D
# 16. the table                      D
# 16. you                            D
# 16. The Table                      D
# 16. The Table                      D
# 16. the table                      D
# 16. your table                     D
# 16. the table                      D
# 16. THE REAL GERMAN TABLE          N          WORK_OF_ART
# 16. The Tablesays                  D          ,WORK_OF_ART
# 16. The TABLE                      D
# 16. the table                      D
# 16. your                           D
# 16. The whole table                D
# 16. the masquerading Germans table D          ,,NORP,
# 16. the table                      D
# 16. us                             D
# 16. THE GERMAN TABLE               N
# 16. The TABLE                      C          ,ORG
# 16. the Table                      D
# 16. THE BASTERDS TABLE             N
# 16. the whole Table                D
# 16. you                            D
# 16. you                            D
# 16. the table                      E
# 16. The Table                      D
# 16. The TABLE                      C
# 16. The table                      D
# 16. the table                      D
# 16. The Table                      D
# 16. your                           D
# 16. you                            D
# 16. They                           D
# 16. you                            D
# 16. the table                      D
# 16. gentlemen                      D
# 16. you all                        D
# 16. your                           D
# 16. They                           D
# 16. his table                      D
# 16. the impostors table            D
#
# 17. I                              D
# 17. your                           D
# 17. my                             D
# 17. I                              D
# 17. BRIDGET                        C          ORG
# 17. BRIDGET                        C          ORG
# 17. I                              D
# 17. her                            D
# 17. BRIDGET                        C          ORG
# 17. She                            D
# 17. The English film critic, commando N          ,LANGUAGE,,,,
# 17. the Sgt                        D          ,ORG
# 17. your                           D
# 17. Bridget's                      D          ORG,
# 17. her                            D
# 17. This handsome happy Sgt        D          ,,,PERSON
# 17. The German Master Sgt          D          ,NORP,,PERSON
# 17. your                           D
# 17. BRIDGET                        C          ORG
# 17. his                            D
# 17. you                            D
# 17. Bridget's                      D          ORG,
# 17. You                            D
# 17. I                              D
# 17. you                            D
# 17. I                              D
# 17. BRIDGET                        C          ORG
# 17. BRIDGET                        C          ORG
# 17. Bridget                        D
# 17. yourself                       D
# 17. BRIDGET                        C          ORG
# 17. his                            D
# 17. her                            D
# 17. your                           D
# 17. You                            D
# 17. Bridget                        D
# 17. you                            N
# 17. BRIDGET                        C          ORG
# 17. the B.G., the German Master Sgt D          ,GPE,,,NORP,,
# 17. I                              D
# 17. the German Master Sgt          D          ,NORP,,PERSON
# 17. this German Sgt                D          ,NORP,
# 17. BRIDGET                        C          ORG
# 17. BRIDGET                        C          ORG
# 17. old boy                        N
# 17. BRIDGET                        C          ORG
# 17. BRIDGET                        C          ORG
# 17. his                            D
# 17. Bridget's                      N          ORG,
# 17. yours                          D
# 17. She                            D
# 17. my                             D
# 17. Bridget                        D          ORG
# 17. BRIDGET                        C          ORG
# 17. his                            D
# 17. you                            D
# 17. you                            D
# 17. BRIDGET                        C          ORG
# 17. BRIDGET                        C          ORG
#
# 18. WINNETOU                       C          ORG
# 18. the Apache Chief               D
# 18. Winnetou                       E
# 18. he                             D
# 18. his                            D
# 18. I                              D
#
# 19. HATA HARI                      C          ORG,
# 19. MATA HARI                      C
# 19. I                              D
# 19. MATA HARI                      C          PERSON
# 19. My                             D
# 19. Mata Hari                      D          PERSON
# 19. MATA HARI                      C
#
# 20. SGT.POLA NEGRI                 C          ,ORG
# 20. the Master Sgt                 D          ORG
#
# 21. I                              C
# 21. EDGER WALLACE                  C
# 21. He                             D
#
# 22. I                              D
# 22. LT.HICOX                       C
#
# 23. BASTERDS                       N          PERSON
# 23. BASTERDS                       C          PERSON
# 23. You                            D
# 23. your                           D
# 23. You                            D
#
# 24. SGT.POLA NEGRI                 C          ,ORG
# 24. his                            N
# 24. I                              D
# 24. his                            D
# 24. I                              D
# 24. I                              D
# 24. the young father               D
# 24. I                              D
# 24. his                            D
# 24. he                             N
# 24. He                             D
# 24. my                             D
# 24. SGT.POLA NEGRI                 C          ,ORG
# 24. He                             D
#
# 25. her                            D
# 25. Hicox                          E          PERSON
# 25. Hicox                          D          PERSON
# 25. LT.HICOX                       C
# 25. HICOX                          D          PERSON
# 25. Hicox                          D          PERSON
# 25. Hicox                          E
# 25. I                              D
# 25. HICOX                          D          NORP
# 25. HICOX'S                        D
# 25. I                              D
#
# 26. Lieutenant                     D          PERSON
# 26. YOU                            C
# 26. your                           D
# 26. YOU                            C
# 26. STIGLITZ                       C
# 26. Stiglitz                       N          PERSON
# 26. Stiglitz                       D          PERSON
# 26. Stiglitz                       D          PERSON
# 26. Even the slightly psychotic Stiglitz D          ,,,,ORG
# 26. STIGLITZ                       C
# 26. STIGLITZ                       N
# 26. SGT.STIGLITZ                   C
# 26. STIGLITZ                       D          ORG
# 26. STIGLITZ                       C          ORG
# 26. STIGLITZ                       C
# 26. STIGLITZ                       C          ORG
# 26. you                            D
# 26. STIGLITZ                       C          ORG
# 26. you                            D
#
# 27. France                         D          GPE
# 27. FRANCE                         C          GPE
# 27. France                         D          GPE
# 27. France                         D          GPE
# 27. France                         D          GPE
#
# 28. LT.HICOX                       C
# 28. Cap't                          D
# 28. I                              D
# 28. I                              D
# 28. the officer                    D
# 28. Lt.Hicox                       N          ,,PERSON
# 28. your                           D
# 28. me                             D
# 28. LT.HICOX                       C
#
# 29. Cap't                          D
# 29. you                            D
# 29. you                            D
# 29. he                             E
# 29. I                              D
# 29. He                             D
# 29. I                              D
# 29. MAJOR HELLSTROM                C          ORG
# 29. MAJOR HELLSTROM                C          ORG
# 29. MAJOR HELLSTROM                C
# 29. Major Hellstrom                N          ,PERSON
# 29. MAJOR HELLSTROM                C          ORG
# 29. The Gestapo Major              D          ,ORG,
# 29. The Major                      D
# 29. MAJOR HELLSTROM                C
# 29. MAJOR HELLSTROM                C
# 29. I                              D
# 29. his                            D
# 29. HIM                            N          ORG
# 29. Major                          D          PERSON
# 29. MAJOR DEITER HELLSTROM of the GESTAPO D          ,,,,,ORG
# 29. the Majors                     D          ,PRODUCT
# 29. MAJOR HELLSTROM                N
# 29. He                             D
# 29. MAJOR HELLSTROM                C          ORG
# 29. You                            D
# 29. the Gestapo Major              D          PRODUCT
# 29. The Gestapo Major              D          ORG
# 29. I                              D
# 29. MAJOR HELLSTROM                C          ORG
# 29. MAJOR HELLSTROM                C
# 29. I                              D
# 29. MAJOR HELLSTROM                C          ORG
# 29. MAJOR HELLSTROM                C          ORG
# 29. Major Hellstrom, the highest ranking officer in the room D          PERSON,PERSON,,,,,,,,
# 29. MAJOR HELLSTROM                C          ORG
# 29. MAJOR HELLSTROM                C
# 29. I                              D
# 29. He                             D
# 29. I                              D
# 29. MAJOR HELLSTROM                C
# 29. I                              D
# 29. MAJOR HELLSTROM                C          ORG
# 29. he                             D
# 29. me                             D
#
# 30. I                              D
# 30. I                              D
# 30. you                            D
# 30. I                              D
# 30. I                              D
# 30. him                            D
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C
# 30. you                            D
# 30. My                             D
# 30. my                             D
# 30. I                              D
# 30. I                              D
# 30. he                             D
# 30. I                              C
# 30. I                              D
# 30. I                              D
# 30. my                             D
# 30. I                              D
# 30. MAJ.KING KONG                  C
# 30. I                              D
# 30. I                              D
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C          ,PERSON
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C
# 30. MAJ.KING KONG                  C
# 30. I                              D
# 30. I                              D
# 30. MAJ.KING KONG                  C
# 30. my                             D
# 30. my                             D
# 30. me                             D
# 30. I                              D
# 30. I                              D
# 30. I                              C
# 30. I                              D
#
# 31. Cap't                          D
# 31. LT.HICOX                       C
# 31. I                              D
# 31. I                              D
#
# 32. Eric                           D          PERSON
# 32. you                            D
# 32. Eric                           D          PERSON
# 32. You                            D
# 32. Eric the owner                 D          PERSON,,
# 32. ERIC                           C          PERSON
# 32. Eric                           D          PERSON
#
# 33. his                            D
# 33. the Nazi Major                 N          ,NORP,
# 33. sir                            D
# 33. the Nazi MAJOR                 D,D,X,C    ,NORP,,ORG
# 33. The Gestapo Major              D          ,ORG,
# 33. Major Helistrom                D          ,PERSON
# 33. his                            D
# 33. the Nazi Major's               D          ORG
#
# 34. his                            E
# 34. his                            D
# 34. I                              N
# 34. He                             D
# 34. I                              D
# 34. He                             N
# 34. LT.HICOX                       C
# 34. Lt.Hicox                       D          ,,PERSON
# 34. LT.HICOX                       C
# 34. I                              D
# 34. LT.HICOX                       C          PERSON
# 34. I                              N
# 34. LT.HICOX (ENGLISH)             N          ,,WORK_OF_ART,
# 34. LT.HICOX                       C
#
# 35. your balls                     D
# 35. HELLSTROM'S BALLS              C          ORG,,
#
# 36. WICKI and HATA HARI            C          PERSON,,ORG,
# 36. both                           D
#
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. You despicable traitor         D
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG
# 37. ALDO'S VOICE                   C          ORG
# 37. ALDO'S VOICE                   C          ORG
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. that fucking traitor           D
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. Aldo's Voice                   D          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          ORG,,
# 37. ALDO'S VOICE                   C          GPE,,
# 37. you                            D
#
# 38. the voice                      D
# 38. BRIDGET'S VOICE                C          ORG,,
#
# 39. Willi                          D          PERSON
# 39. you                            D
# 39. his                            D
# 39. Willi                          D          PERSON
# 39. Willi                          D          ORG
# 39. Willi                          D          ORG
# 39. you                            D
# 39. Willi                          D
# 39. you                            D
# 39. you                            D
# 39. ya                             D
# 39. Willi                          D          ORG
# 39. Willi                          D          ORG
# 39. Willi                          D          ORG
# 39. you                            D
# 39. you                            D
# 39. Willi                          D
# 39. I                              D
# 39. WILLI                          C          ORG
# 39. Willi                          D          ORG
# 39. Willi                          D          ORG
# 39. you                            D
# 39. Willi                          D          ORG
# 39. Willi                          D          ORG
# 39. WILLI                          C          PERSON
# 39. you                            D
# 39. WILLI                          C          PERSON
# 39. I                              D
# 39. Willi                          D
# 39. me                             D
# 39. I                              D
#
# 40. Hirschberg                     D          ORG
# 40. Hirschberg                     D          PERSON
# 40. you                            D
# 40. Hirscberg                      D          ORG
# 40. HIRSCHBERG                     C          ORG
# 40. I                              D
# 40. HIRSCHBERG                     C          ORG
# 40. HIRSCHBERG                     C          ORG
# 40. HIRSCHBERG                     C          PERSON
# 40. him                            D
# 40. Hirschberg                     N
# 40. Hirschbeg                      D
# 40. Hirschberg                     N          PERSON
# 40. Hirschberg                     D          PERSON
# 40. Hirscberg                      N          PERSON

# %%
basterds_coref_result = predictor.predict(document=basterds_document)

# %%
basterds_coref_result.keys()
# Out:
# dict_keys(['top_spans', 'antecedent_indices', 'predicted_antecedents', 'document', 'clusters'])

# %%
len(basterds_coref_result["clusters"])
# Out:
# 171

# %%
len(basterds_gold_entity_to_cluster)
# Out:
# 23

# %%
basterds_gold_entity_to_cluster.keys()
# Out:
# dict_keys(['BRIDGET VON HAMMERSMARK', 'Barmaid', 'Donowitz', 'Eric', 'FEMALE SGT #2/BEETHOVEN', 'GERMAN PRIVATE #3/MATA HARI', 'GERMAN PRIVATE #4/EDGAR WALLACE', 'GERMAN PRIVATE #5/WINNETOU', 'Goebbels', 'Hirschberg', 'LT. ALDO RAINE', 'LT. HICOX', 'Leni', 'MAJOR HELLSTROM', 'MASTER SGT #1/POLA NEGRI', 'MAXIMILIAN', 'NAZI PRIVATE', 'READER', 'STIGLITZ', "Tavern's Proprietor", 'The Fubrer', 'Utivich', 'WILHELM WICKI'])

# %%
basterds_multiton_gold_entity_to_cluster = dict([(entity, cluster) for entity, cluster in basterds_gold_entity_to_cluster.items() if len(cluster) > 1])

# %%
len(basterds_multiton_gold_entity_to_cluster)
# Out:
# 23

# %%
basterds_sys_person_clusters = []

for sys_cluster in basterds_sys_clusters:
    for i, j in sys_cluster:
        is_person = any([spacy_basterds_document[k].ent_type_ == "PERSON" for k in range(i, j + 1)])
        if is_person:
            basterds_sys_person_clusters.append(sys_cluster)
            break

# %%
len(basterds_sys_person_clusters)
# Out:
# 25

# %%
evaluate_coreference(basterds_gold_entity_to_cluster.values(), basterds_sys_person_clusters)
# Out:
# MUC  : P = 0.8685 R = 0.6489 F1 = 0.7428
# B3   : P = 0.6184 R = 0.2489 F1 = 0.3549
# CEAFe: P = 0.3065 R = 0.3332 F1 = 0.3193
# CoNLL 2012 score: 0.4724
# {'muc': {'R': 0.6489028213166145,
#   'P': 0.8685314685314686,
#   'F1': 0.742822966507177},
#  'bcubed': {'R': 0.24887330294662618,
#   'P': 0.6184243422803197,
#   'F1': 0.35491692969055527},
#  'ceafe': {'R': 0.33320147088209007,
#   'P': 0.3065453532115228,
#   'F1': 0.319318076262003},
#  'conll2012': {'R': 0.4103258650484436,
#   'P': 0.5978337213411037,
#   'F1': 0.4723526574865784}}

# %%
configs = {"x": [1,2,3], "b": [3,4], "d": [1]}

# %%
def add(c, d, x, b):
    return c + d + x + b

# %%
for config in ParameterGrid(configs):
    print(list(config.values()))
    print(add(0,**config))
# Out:
# [3, 1, 1]
# 5
# [3, 1, 2]
# 6
# [3, 1, 3]
# 7
# [4, 1, 1]
# 6
# [4, 1, 2]
# 7
# [4, 1, 3]
# 8

# %%
evaluation_df = pd.read_csv("results/coreference_evaluation.joining.csv", index_col=None)

# %%
evaluation_df.columns
# Out:
# Index(['script', 'use_speaker_sep', 'keep_only_speaker_gold_clusters',
#        'remove_singleton_gold_clusters', 'keep_person_sys_clusters',
#        'keep_speaker_sys_clusters', 'muc_R', 'muc_P', 'muc_F1', 'bcubed_R',
#        'bcubed_P', 'bcubed_F1', 'ceafe_R', 'ceafe_P', 'ceafe_F1',
#        'conll2012_R', 'conll2012_P', 'conll2012_F1', 'nec_F1',
#        'nec_per_chains_missed', 'nec_name_F1', 'nec_pronoun_F1',
#        'nec_nominal_F1'],
#       dtype='object')

# %% [markdown]
# ## Keep all gold clusters

# %%
for script, df in evaluation_df.groupby("script"):
    print(script)
    df = df[~df.keep_only_speaker_gold_clusters & ~df.remove_singleton_gold_clusters]
    df = df.sort_values(by="conll2012_F1", ascending=False)
    display_df = pd.concat([df.iloc[:,:6], df[["conll2012_F1", "nec_F1"]]], axis=1)
    display(display_df)
# Out:
# basterds
#       script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 9   basterds             True                            False
# 13  basterds             True                            False
# 5   basterds             True                            False
# 8   basterds            False                            False
# 12  basterds            False                            False
# 1   basterds             True                            False
# 4   basterds            False                            False
# 0   basterds            False                            False
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 9                            False                      True
# 13                           False                      True
# 5                            False                     False
# 8                            False                      True
# 12                           False                      True
# 1                            False                     False
# 4                            False                     False
# 0                            False                     False
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 9                       False      0.473133  0.510325
# 13                       True      0.472353  0.383182
# 5                        True      0.448682  0.420086
# 8                       False      0.441704  0.445630
# 12                       True      0.421643  0.320749
# 1                       False      0.396567  0.647229
# 4                        True      0.394878  0.379082
# 0                       False      0.359593  0.603963
# bourne
#     script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 37  bourne             True                            False
# 45  bourne             True                            False
# 36  bourne            False                            False
# 41  bourne             True                            False
# 44  bourne            False                            False
# 33  bourne             True                            False
# 40  bourne            False                            False
# 32  bourne            False                            False
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 37                           False                     False
# 45                           False                      True
# 36                           False                     False
# 41                           False                      True
# 44                           False                      True
# 33                           False                     False
# 40                           False                      True
# 32                           False                     False
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 37                       True      0.670066  0.458270
# 45                       True      0.576487  0.390369
# 36                       True      0.576051  0.445663
# 41                      False      0.541976  0.390369
# 44                       True      0.523946  0.384439
# 33                      False      0.517408  0.531441
# 40                      False      0.490964  0.384439
# 32                      False      0.451429  0.517092
# shawshank
#        script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 69  shawshank             True                            False
# 73  shawshank             True                            False
# 77  shawshank             True                            False
# 68  shawshank            False                            False
# 65  shawshank             True                            False
# 64  shawshank            False                            False
# 72  shawshank            False                            False
# 76  shawshank            False                            False
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 69                           False                     False
# 73                           False                      True
# 77                           False                      True
# 68                           False                     False
# 65                           False                     False
# 64                           False                     False
# 72                           False                      True
# 76                           False                      True
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 69                       True      0.654428  0.510292
# 73                      False      0.586169  0.419578
# 77                       True      0.581947  0.305292
# 68                       True      0.571401  0.391707
# 65                      False      0.517815  0.674578
# 64                      False      0.465475  0.564921
# 72                      False      0.429565  0.317053
# 76                       True      0.406140  0.202605

# %% [markdown]
# ## Keep only speaker gold clusters

# %%
for script, df in evaluation_df.groupby("script"):
    print(script)
    df = df[df.keep_only_speaker_gold_clusters & ~df.remove_singleton_gold_clusters]
    df = df.sort_values(by="conll2012_F1", ascending=False)
    display_df = pd.concat([df.iloc[:,:6], df[["conll2012_F1", "nec_F1"]]], axis=1)
    display(display_df)
# Out:
# basterds
#       script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 29  basterds             True                             True
# 21  basterds             True                             True
# 28  basterds            False                             True
# 25  basterds             True                             True
# 20  basterds            False                             True
# 24  basterds            False                             True
# 17  basterds             True                             True
# 16  basterds            False                             True
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 29                           False                      True
# 21                           False                     False
# 28                           False                      True
# 25                           False                      True
# 20                           False                     False
# 24                           False                      True
# 17                           False                     False
# 16                           False                     False
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 29                       True      0.498769  0.542173
# 21                       True      0.466281  0.598950
# 28                       True      0.452392  0.451152
# 25                      False      0.436209  0.542173
# 20                       True      0.413258  0.540896
# 24                      False      0.408732  0.451152
# 17                      False      0.360241  0.598950
# 16                      False      0.319984  0.540896
# bourne
#     script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 53  bourne             True                             True
# 52  bourne            False                             True
# 61  bourne             True                             True
# 60  bourne            False                             True
# 57  bourne             True                             True
# 56  bourne            False                             True
# 49  bourne             True                             True
# 48  bourne            False                             True
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 53                           False                     False
# 52                           False                     False
# 61                           False                      True
# 60                           False                      True
# 57                           False                      True
# 56                           False                      True
# 49                           False                     False
# 48                           False                     False
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 53                       True      0.753552  0.785606
# 52                       True      0.647253  0.763994
# 61                       True      0.646275  0.669204
# 60                       True      0.591379  0.659038
# 57                      False      0.589287  0.669204
# 56                      False      0.536885  0.659038
# 49                      False      0.477235  0.785606
# 48                      False      0.415551  0.763994
# shawshank
#        script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 85  shawshank             True                             True
# 93  shawshank             True                             True
# 84  shawshank            False                             True
# 89  shawshank             True                             True
# 81  shawshank             True                             True
# 92  shawshank            False                             True
# 80  shawshank            False                             True
# 88  shawshank            False                             True
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 85                           False                     False
# 93                           False                      True
# 84                           False                     False
# 89                           False                      True
# 81                           False                     False
# 92                           False                      True
# 80                           False                     False
# 88                           False                      True
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 85                       True      0.711293  0.723526
# 93                       True      0.652021  0.469680
# 84                       True      0.639093  0.602626
# 89                      False      0.586132  0.469680
# 81                      False      0.476966  0.723526
# 92                       True      0.456209  0.311700
# 80                      False      0.425092  0.641087
# 88                      False      0.420916  0.325686

# %% [markdown]
# ## Remove singleton gold clusters

# %%
for script, df in evaluation_df.groupby("script"):
    print(script)
    df = df[~df.keep_only_speaker_gold_clusters & df.remove_singleton_gold_clusters]
    df = df.sort_values(by="conll2012_F1", ascending=False)
    display_df = pd.concat([df.iloc[:,:6], df[["conll2012_F1", "nec_F1"]]], axis=1)
    display(display_df)
# Out:
# basterds
#       script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 11  basterds             True                            False
# 15  basterds             True                            False
# 7   basterds             True                            False
# 10  basterds            False                            False
# 14  basterds            False                            False
# 3   basterds             True                            False
# 6   basterds            False                            False
# 2   basterds            False                            False
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 11                            True                      True
# 15                            True                      True
# 7                             True                     False
# 10                            True                      True
# 14                            True                      True
# 3                             True                     False
# 6                             True                     False
# 2                             True                     False
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 11                      False      0.473133  0.510325
# 15                       True      0.472353  0.383182
# 7                        True      0.448682  0.420086
# 10                      False      0.441704  0.445630
# 14                       True      0.421643  0.320749
# 3                       False      0.396567  0.647229
# 6                        True      0.394878  0.379082
# 2                       False      0.359593  0.603963
# bourne
#     script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 39  bourne             True                            False
# 38  bourne            False                            False
# 47  bourne             True                            False
# 43  bourne             True                            False
# 46  bourne            False                            False
# 35  bourne             True                            False
# 42  bourne            False                            False
# 34  bourne            False                            False
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 39                            True                     False
# 38                            True                     False
# 47                            True                      True
# 43                            True                      True
# 46                            True                      True
# 35                            True                     False
# 42                            True                      True
# 34                            True                     False
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 39                       True      0.703688  0.611027
# 38                       True      0.604069  0.594218
# 47                       True      0.596911  0.520492
# 43                      False      0.554220  0.520492
# 46                       True      0.544755  0.512585
# 35                      False      0.519526  0.708588
# 42                      False      0.504075  0.512585
# 34                      False      0.452243  0.689456
# shawshank
#        script  use_speaker_sep  keep_only_speaker_gold_clusters  \
# 71  shawshank             True                            False
# 79  shawshank             True                            False
# 75  shawshank             True                            False
# 70  shawshank            False                            False
# 67  shawshank             True                            False
# 66  shawshank            False                            False
# 74  shawshank            False                            False
# 78  shawshank            False                            False
#
#     remove_singleton_gold_clusters  keep_person_sys_clusters  \
# 71                            True                     False
# 79                            True                      True
# 75                            True                      True
# 70                            True                     False
# 67                            True                     False
# 66                            True                     False
# 74                            True                      True
# 78                            True                      True
#
#     keep_speaker_sys_clusters  conll2012_F1    nec_F1
# 71                       True      0.682106  0.566991
# 79                       True      0.606030  0.339213
# 75                      False      0.604243  0.466197
# 70                       True      0.591465  0.435230
# 67                      False      0.522452  0.749531
# 66                      False      0.468845  0.627690
# 74                      False      0.444488  0.352281
# 78                       True      0.421801  0.225117

# %% [markdown]
# ## Visualize sys clusters

# %%
for token in spacy_basterds_document:
    print(token.ent)

# %%
token
# Out:
# .

# %%
token.ent_type
# Out:
# 0

# %%
token.ent_type_
# Out:
# ''

# %%
token.ent_id
# Out:
# 0

# %%
token.ent_id_
# Out:
# ''

# %%
coref_spacy_basterds_document = deepcopy(spacy_basterds_document)

for token in coref_spacy_basterds_document:
    token.ent_type = 0
    
for i, sys_cluster in enumerate(basterds_sys_clusters):
    for j, k in sys_cluster:
        for l in range(j, k + 1):
            token = coref_spacy_basterds_document[l]
            token.ent_type = i + 1
            token.ent_type_ = f"E{i + 1}"

# %%
displacy.render(coref_spacy_basterds_document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EXT - LA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  LOUISIANE (TAVERN) - NIGHT</br>We see a small basement tavern, with a old rustic sign out front that reads, &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La Louisiane
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# &quot;.</br>A SUBTITLE APPEARS: says &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Village of
# NADINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FRANCE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">E27</span>
# </mark>
# &quot; says
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TWO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SHOT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  LT.HICOX and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LT.ALDO RAINE Aldo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">E1</span>
# </mark>
#  is dressed like a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  civilian.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hicox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">E2</span>
# </mark>
#  is dressed in a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  grey S.S. Cap't uniform. They look out of a window, in a apartment, in the village of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nadine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# , overlooking the tavern.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LT.ALDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  says You didn't say the goddamn rendez-vous was in a fuckin basement.</br>LT.HICOX says I didn't know.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LT.ALDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  says You said it was in a tavern?</br>LT.HICOX says it is a tavern.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LT.ALDO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  says Yeah, in a basement. You know, fightin in a basement offers a lot of difficulties, number
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  being, your fighting in a basement.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wilhelm Wicki
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">E3</span>
# </mark>
# , joins the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SHOT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
# , dressed in a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S.S. Lieutenant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  uniform.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WICKI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">E3</span>
# </mark>
#  says What if we go in there, and she's not even there?</br>LT.HICOX says We wait. Don't worry, she's a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"></span>
# </mark>
#  spy, she'll make the rendez-vous. WE SEE the other
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Basterds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform:

# %%
from IPython.core.display import display, HTML

# %%
display(HTML(open("gpr_pub/visualization/highlight.css").read()))
display(HTML(open("gpr_pub/visualization/highlight.js").read()))
# Out:
# <style>
#
# .highlight {
#   border: 2px solid;
#   color: #232323;
#   margin: 4px 6px 4px 3px;
#   vertical-align: middle;
#   box-shadow: 2px 4px 20px rgba(0,0,0,0.1);
#   position: relative;
#   cursor: default;
#   min-width: 26px;
#   line-height: 22px;
#   display: inline-flex;
# }
#
# .highlight:last-child {
#   margin-right: 4px;
# }
#
# .highlight:first-child {
#   margin-left: 0;
# }
#
# .highlight,
# .highlight span {
#   transition: background-color .1s ease,
#               color .1s ease,
#               box-shadow .1s ease,
#               opacity .1s ease;
# }
#
# .highlight.short-text {
#   text-align: center;
# }
#
# .highlight__label {
#   align-items: center;
#   justify-content: center;
#   padding: 0 8px;
#   text-align: center;
#   user-select: none;
# }
#
# .highlight__label strong,
# .highlight__label span.highlight__label__secondary-label {
#   display: block;
#   font-size: 11px;
#   color: #fff;
#   -webkit-font-smoothing: subpixel-antialiased;
#   letter-spacing: 0.1em;
# }
#
# .highlight__label strong {
#   text-transform: uppercase;
# }
#
# .highlight__label span.highlight__label__secondary-label {
#   opacity: .75;
#   padding-left: 6px;
# }
#
# .highlight__content {
#   flex-wrap: wrap;
#   align-items: center;
#   padding: 2px 2px 2px 6px;
# }
#
#
# .highlight-container.highlight-container--bottom-labels .highlight.bottom {
#   margin-top: 6px;
# }
#
# .highlight.bottom {
#   display: block;
#   white-space: normal;
# }
#
# .highlight.bottom .highlight__content:after {
#   content: " ";
#   padding-right: 3px;
# }
#
# .highlight.bottom .highlight__label {
#   line-height: 14px;
#   padding-top: 1px;
# }
#
#
# .highlight.top {
#   flex-direction: column;
#   white-space: normal;
# }
#
# .highlight.top .highlight__label {
#   min-height: 22px;
# }
#
#
# .highlight.active,
# .highlight.active span {
#   color: #fff;
# }
#
# .highlight.active .highlight:not(.active) span {
#   color: #232323;
# }
#
# .highlight.clickable {
#   cursor: pointer;
# }
#
# .highlight.clickable.clickable.selected {
#   cursor: default;
# }
#
# .highlight.clickable.clicking {
#   opacity: 0.66;
#   transition-duration: 0s;
# }
#
# .clicking .highlight,
# .clicking .highlight span,
# .clicking .highlight:before,
# .clicking .highlight:after {
#   transition-duration: 0s;
# }
#
#
# .highlight.gray {
#   background: #f2f4f6;
# }
#
# .highlight.gray,
# .highlight-arrow--gray .highlight-arrow__triangle {
#   border-color: #a0aab5;
# }
#
# .highlight.gray .highlight__label,
# .highlight-arrow--gray .highlight-arrow__stalk,
# .highlight.gray .highlight__button .highlight__button__body {
#   background-color: #a0aab5;
# }
#
# .highlight.gray.active {
#   background: #a0aab5;
# }
#
# .highlight.gray.active .highlight__label {
#   background-color: #aab3bd;
# }
#
# .highlight.gray .highlight__button svg {
#   fill: #a0aab5;
# }
#
#
#
# .highlight.blue {
#   background: #edf4fa;
# }
#
# .highlight.blue,
# .highlight-arrow--blue .highlight-arrow__triangle {
#   border-color: #4db1f7;
# }
#
# .highlight.blue > .highlight__label,
# .highlight-arrow--blue .highlight-arrow__stalk,
# .highlight.blue .highlight__button .highlight__button__body {
#   background-color: #4db1f7;
# }
#
# .highlight.blue.active {
#   background: #4db1f7;
# }
#
# .highlight.blue.active > .highlight__label {
#   background-color: #5fb9f8;
# }
#
# .highlight.blue .highlight__button svg {
#   fill: #4db1f7;
# }
#
#
# .highlight.green {
#   background: #f1f4f1;
# }
#
# .highlight.green,
# .highlight-arrow--green .highlight-arrow__triangle {
#   border-color: #90ac4e;
# }
#
# .highlight.green > .highlight__label,
# .highlight-arrow--green .highlight-arrow__stalk,
# .highlight.green .highlight__button .highlight__button__body {
#   background-color: #90ac4e;
# }
#
# .highlight.green.active {
#   background: #90ac4e;
# }
#
# .highlight.green.active > .highlight__label {
#   background-color: #9bb460;
# }
#
# .highlight.green .highlight__button svg {
#   fill: #90ac4e;
# }
#
#
# .highlight.pink {
#   background: #f4f1f4;
# }
#
# .highlight.pink,
# .highlight-arrow--pink .highlight-arrow__triangle {
#   border-color: #ce6587;
# }
#
# .highlight.pink > .highlight__label,
# .highlight-arrow--pink .highlight-arrow__stalk,
# .highlight.pink .highlight__button .highlight__button__body {
#   background-color: #ce6587;
# }
#
# .highlight.pink.active {
#   background: #ce6587;
# }
#
# .highlight.pink.active > .highlight__label {
#   background-color: #d37593;
# }
#
# .highlight.pink .highlight__button svg {
#   fill: #ce6587;
# }
#
#
# .highlight.orange {
#   background: #f2f4f4;
# }
#
# .highlight.orange,
# .highlight-arrow--orange .highlight-arrow__triangle {
#   border-color: #dd9e3e;
# }
#
# .highlight.orange > .highlight__label,
# .highlight-arrow--orange .highlight-arrow__stalk,
# .highlight.orange .highlight__button .highlight__button__body {
#   background-color: #dd9e3e;
# }
#
# .highlight.orange.active {
#   background: #dd9e3e;
# }
#
# .highlight.orange.active > .highlight__label {
#   background-color: #e0a852;
# }
#
# .highlight.orange .highlight__button svg {
#   fill: #dd9e3e;
# }
#
#
# .highlight.purple {
#   background: #f1f0f7;
# }
#
# .highlight.purple,
# .highlight-arrow--purple .highlight-arrow__triangle {
#   border-color: #9a5eba;
# }
#
# .highlight.purple > .highlight__label,
# .highlight-arrow--purple .highlight-arrow__stalk,
# .highlight.purple .highlight__button .highlight__button__body {
#   background-color: #9a5eba;
# }
#
# .highlight.purple.active {
#   background: #9a5eba;
# }
#
# .highlight.purple.active > .highlight__label {
#   background-color: #a46ec1;
# }
#
# .highlight.purple .highlight__button svg {
#   fill: #9a5eba;
# }
#
#
# .highlight.teal {
#   background: #eef4f6;
# }
#
# .highlight.teal,
# .highlight-arrow--teal .highlight-arrow__triangle {
#   border-color: #5bb1ad;
# }
#
# .highlight.teal > .highlight__label,
# .highlight-arrow--teal .highlight-arrow__stalk,
# .highlight.teal .highlight__button .highlight__button__body {
#   background-color: #5bb1ad;
# }
#
# .highlight.teal.active {
#   background: #5bb1ad;
# }
#
# .highlight.teal.active > .highlight__label {
#   background-color: #6cb9b5;
# }
#
# .highlight.teal .highlight__button svg {
#   fill: #5bb1ad;
# }
#
#
# .highlight.tan {
#   background: #f2f4f4;
# }
#
# .highlight.tan,
# .highlight-arrow--tan .highlight-arrow__triangle {
#   border-color: #b0a481;
# }
#
# .highlight.tan > .highlight__label,
# .highlight-arrow--tan .highlight-arrow__stalk,
# .highlight.tan .highlight__button .highlight__button__body {
#   background-color: #b0a481;
# }
#
# .highlight.tan.active {
#   background: #b0a481;
# }
#
# .highlight.tan.active > .highlight__label {
#   background-color: #b8ad8e;
# }
#
# .highlight.tan .highlight__button svg {
#   fill: #b0a481;
# }
#
#
# .highlight.red {
#   background: #f5eef0;
# }
#
# .highlight.red,
# .highlight-arrow--red .highlight-arrow__triangle {
#   border-color: #df3838;
# }
#
# .highlight.red > .highlight__label,
# .highlight-arrow--red .highlight-arrow__stalk,
# .highlight.red .highlight__button .highlight__button__body {
#   background-color: #df3838;
# }
#
# .highlight.red.active {
#   background: #df3838;
# }
#
# .highlight.red.active > .highlight__label {
#   background-color: #e24c4c;
# }
#
# .highlight.red .highlight__button svg {
#   fill: #df3838;
# }
#
#
# .highlight.cobalt {
#   background: #eef0f5;
# }
#
# .highlight.cobalt,
# .highlight-arrow--cobalt .highlight-arrow__triangle {
#   border-color: #5f5b97;
# }
#
# .highlight.cobalt > .highlight__label,
# .highlight-arrow--cobalt .highlight-arrow__stalk,
# .highlight.cobalt .highlight__button .highlight__button__body {
#   background-color: #5f5b97;
# }
#
# .highlight.cobalt.active {
#   background: #5f5b97;
# }
#
# .highlight.cobalt.active > .highlight__label {
#   background-color: #6f6ca2;
# }
#
# .highlight.cobalt .highlight__button svg {
#   fill: #5f5b97;
# }
#
#
# .highlight.brown {
#   background: #f2f4f6;
# }
#
# .highlight.brown,
# .highlight-arrow--brown .highlight-arrow__triangle {
#   border-color: #6a4e3d;
# }
#
# .highlight.brown > .highlight__label,
# .highlight-arrow--brown .highlight-arrow__stalk,
# .highlight.brown .highlight__button .highlight__button__body {
#   background-color: #6a4e3d;
# }
#
# .highlight.brown.active {
#   background: #6a4e3d;
# }
#
# .highlight.brown.active > .highlight__label {
#   background-color: #796051;
# }
#
# .highlight.brown .highlight__button svg {
#   fill: #6a4e3d;
# }
#
#
# .highlight.slate {
#   background: #eceff1;
# }
#
# .highlight.slate,
# .highlight-arrow--slate .highlight-arrow__triangle {
#   border-color: #3b4247;
# }
#
# .highlight.slate > .highlight__label,
# .highlight-arrow--slate .highlight-arrow__stalk,
# .highligh
# <script>
#
# function handleHighlightMouseOver(el) {
#     $('[id='+el.getAttribute('id')+']').addClass('active');
#   }
#
# function handleHighlightMouseOut(el) {
#     $('[id='+el.getAttribute('id')+']').removeClass('active');
# }
#
# </script>

# %%
from gpr_pub import visualization

# %%
import importlib

# %%
importlib.reload(visualization)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-2190e0fc1a2f> in <module>
# ----> 1 importlib.reload(visualization.render)
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/importlib/__init__.py in reload(module)
#     137     """
#     138     if not module or not isinstance(module, types.ModuleType):
# --> 139         raise TypeError("reload() argument must be a module")
#     140     try:
#     141         name = module.__spec__.name
#
# TypeError: reload() argument must be a module

# %%
visualization.render(basterds_coref_result, allen=True, jupyter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-7c84ab2d2833> in <module>
# ----> 1 visualization.render(basterds_coref_result, allen=True, jupyter=True)
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/__init__.py in unified_data(data, **kwargs)
#      16             tokens, clusters = labelled_pronoun(data)
#      17
# ---> 18         return fn(tokens, clusters, **kwargs)
#      19
#      20     return unified_data
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/__init__.py in render(tokens, clusters, style, stanford, allen, huggingface, proref, jupyter)
#      32             jupyter=True):
#      33
# ---> 34     html = to_html(tokens, clusters)
#      35
#      36     if jupyter:
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/__init__.py in to_html(tokens, clusters)
#      95 def to_html(tokens, clusters):
#      96     tree = transform_to_tree(tokens, clusters)
# ---> 97     html = ''.join(span_wrapper(tree, 0))
#      98     html = '<div style="padding: 16px;">{}</div>'.format(html)
#      99     return html
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/html_template.py in span_wrapper(tree, depth)
#      82
#      83 # Wraps the tree representation into spans indicating cluster-wise depth
# ---> 84 def span_wrapper(tree, depth):
#      85       return [gen_elem(token, idx, depth) for idx, token in enumerate(tree)]
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/html_template.py in <listcomp>(.0)
#      82
#      83 # Wraps the tree representation into spans indicating cluster-wise depth
# ---> 84 def span_wrapper(tree, depth):
#      85       return [gen_elem(token, idx, depth) for idx, token in enumerate(tree)]
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/html_template.py in gen_elem(token, idx, depth)
#      72                 onmouseout="handleHighlightMouseOut(this)" labelPosition="left">\
#      73                 <span class="highlight__label"><strong>{}</strong></span>\
# ---> 74                 <span class="highlight__content">{}</span></span>'.format(idx,
#      75                                                                           get_highlight_color(token['cluster']),
#      76                                                                           depth,
#
# /proj/sbaruah/movie/coreference/gpr_pub/visualization/html_template.py in get_highlight_color(index)
#      21     if index <= len(HIGHLIGHT_COLORS):
#      22         return HIGHLIGHT_COLORS[index]
# ---> 23     else:
#      24         return HIGHLIGHT_COLORS[index - (len(HIGHLIGHT_COLORS) * math.floor(index / len(HIGHLIGHT_COLORS)))]
#      25
#
# NameError: name 'math' is not defined
