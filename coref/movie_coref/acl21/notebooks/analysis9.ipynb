# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
from allennlp.predictors.predictor import Predictor
import allennlp_models.coref
from transformers import BertTokenizer
from allennlp.data.tokenizers.pretrained_transformer_tokenizer import PretrainedTransformerTokenizer
import spacy
from tqdm import tqdm, trange
from scorch import scores
from scipy.optimize import linear_sum_assignment

# %% [markdown]
# ## Read Coreference Mapped File

# %%
coref_df = pd.read_csv("data/annotation/basterds.coref.mapped.csv", index_col=None)

# %%
coref_df
# Out:
#       begin    end  begin_segment  end_segment  begin_line  end_line  \
# 0        56     58            NaN          NaN          -1        -1
# 1       262    270            NaN          NaN          -1        -1
# 2       275    288            NaN          NaN          -1        -1
# 3       299    303            NaN          NaN          -1        -1
# 4       339    344            NaN          NaN          -1        -1
# ...     ...    ...            ...          ...         ...       ...
# 1003  45932  45936            NaN          NaN          -1        -1
# 1004  45938  45948            NaN          NaN          -1        -1
# 1005  45950  45957            NaN          NaN          -1        -1
# 1006  45959  45967            NaN          NaN          -1        -1
# 1007  45973  45980            NaN          NaN          -1        -1
#
#                           leftContext        surface  \
# 0     le in, and\n          take off.             We
# 1     le in, and\n          take off.       LT.HICOX
# 2     le in, and\n          take off.  LT.ALDO RAINE
# 3     le in, and\n          take off.           Aldo
# 4     le in, and\n          take off.          Hicox
# ...                               ...            ...
# 1003  le in, and\n          take off.           Aldo
# 1004  le in, and\n          take off.     Hirschberg
# 1005  le in, and\n          take off.        Bridget
# 1006  le in, and\n          take off.       Donowitz
# 1007  le in, and\n          take off.        Utivich
#
#                         rightContext  entityNum  ... DIFFICULT.1  APPOSITION  \
# 0               EXT - LA LOUISIANE (          7  ...       False       False
# 1               EXT - LA LOUISIANE (          4  ...       False       False
# 2               EXT - LA LOUISIANE (         17  ...       False       False
# 3               EXT - LA LOUISIANE (         17  ...       False       False
# 4               EXT - LA LOUISIANE (          4  ...       False       False
# ...                              ...        ...  ...         ...         ...
# 1003            EXT - LA LOUISIANE (         17  ...       False       False
# 1004            EXT - LA LOUISIANE (          5  ...       False       False
# 1005            EXT - LA LOUISIANE (          1  ...       False       False
# 1006            EXT - LA LOUISIANE (         20  ...       False       False
# 1007            EXT - LA LOUISIANE (         13  ...       False       False
#
#        pbegin  pbegin_ind  pbegin_pos     pend  pend_ind  pend_pos  \
# 0        35.0         1.0         0.0     36.0       1.0       1.0
# 1       185.0         5.0         9.0    192.0       5.0      16.0
# 2       198.0         5.0        22.0    210.0       5.0      34.0
# 3       212.0         5.0        36.0    215.0       5.0      39.0
# 4       252.0         5.0        76.0    256.0       5.0      80.0
# ...       ...         ...         ...      ...       ...       ...
# 1003  32032.0       590.0       160.0  32035.0     590.0     163.0
# 1004  32038.0       590.0       166.0  32047.0     590.0     175.0
# 1005  32050.0       590.0       178.0  32056.0     590.0     184.0
# 1006  32059.0       590.0       187.0  32066.0     590.0     194.0
# 1007  32073.0       590.0       201.0  32079.0     590.0     207.0
#
#       parsed_mention        mention
# 0                 We             We
# 1           LT.HICOX       LT.HICOX
# 2      LT.ALDO RAINE  LT.ALDO RAINE
# 3               Aldo           Aldo
# 4              Hicox          Hicox
# ...              ...            ...
# 1003            Aldo           Aldo
# 1004      Hirschberg     Hirschberg
# 1005         Bridget        Bridget
# 1006        Donowitz       Donowitz
# 1007         Utivich        Utivich
#
# [1008 rows x 24 columns]

# %%
coref_df.columns
# Out:
# Index(['begin', 'end', 'begin_segment', 'end_segment', 'begin_line',
#        'end_line', 'leftContext', 'surface', 'rightContext', 'entityNum',
#        'entityLabel', 'entityGroup', 'DIFFICULT', 'SPEAKER', 'DIFFICULT.1',
#        'APPOSITION', 'pbegin', 'pbegin_ind', 'pbegin_pos', 'pend', 'pend_ind',
#        'pend_pos', 'parsed_mention', 'mention'],
#       dtype='object')

# %% [markdown]
# ## Find tags and elements of parsed script

# %%
tags, elements = [], []

for line in open("data/annotation/basterds.script_parsed.txt").read().strip().split("\n"):
    tag, element = line[0], line[2:].strip()
    tags.append(tag)
    elements.append(element)
    
print(f"{len(elements)} elements")
print(Counter(tags))
# Out:
# 591 elements
# Counter({'C': 257, 'D': 257, 'E': 37, 'N': 36, 'S': 4})

# %% [markdown]
# ## Print gold mentions for each screenplay element

# %%
for i, df in coref_df.groupby("pbegin_ind"):
    tag, element = tags[int(i)], elements[int(i)]
    entity_to_mentions = defaultdict(list)
    sorted_df = df.sort_values(by="pbegin_pos").copy()
    
    for _, row in sorted_df.iterrows():
        j, k, l = int(row.pend_ind), int(row.pbegin_pos), int(row.pend_pos)
        if i == j:
            mention = element[k: l + 1]
            entity = row.entityLabel
            entity_to_mentions[entity].append(mention)
            
    if entity_to_mentions:
        print(f"tag : {tag}\ndoc : {element}")
        for entity, mentions in entity_to_mentions.items():
            print(f"\t{entity:20s} : {mentions}")
        print()
# Out:
# tag : N
# doc : We see a small basement tavern, with a old rustic sign out front that reads, "La Louisiane".
# 	READER               : ['We']
#
# tag : D
# doc : TWO SHOT LT.HICOX and LT.ALDO RAINE Aldo is dressed like a French civilian. Hicox is dressed in a German grey S.S. Cap't uniform. They look out of a window, in a apartment, in the village of Nadine, overlooking the tavern.
# 	LT. HICOX            : ['LT.HICOX', 'Hicox']
# 	LT. ALDO RAINE       : ['LT.ALDO RAINE', 'Aldo']
#
# tag : C
# doc : LT.ALDO
# 	LT. ALDO RAINE       : ['LT.ALDO']
#
# tag : D
# doc : You didn't say the goddamn rendez-vous was in a fuckin basement.
# 	LT. HICOX            : ['You']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : I didn't know.
# 	LT. HICOX            : ['I']
#
# tag : C
# doc : LT.ALDO
# 	LT. ALDO RAINE       : ['LT.ALDO']
#
# tag : D
# doc : You said it was in a tavern?
# 	LT. HICOX            : ['You']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : C
# doc : LT.ALDO
# 	LT. ALDO RAINE       : ['LT.ALDO']
#
# tag : D
# doc : Yeah, in a basement. You know, fightin in a basement offers a lot of difficulties, number one being, your fighting in a basement. Wilhelm Wicki, joins the SHOT, dressed in a German S.S. Lieutenant uniform.
# 	LT. HICOX            : ['You']
# 	WILHELM WICKI        : ['Wilhelm Wicki']
#
# tag : C
# doc : WICKI
# 	WILHELM WICKI        : ['WICKI']
#
# tag : D
# doc : What if we go in there, and she's not even there?
# 	BRIDGET VON HAMMERSMARK : ['she']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz...
# 	BRIDGET VON HAMMERSMARK : ['she', 'she']
# 	READER               : ['WE']
# 	Donowitz             : ['Donowitz']
# 	Hirschberg           : ['Hirschberg']
# 	Utivich              : ['Utivich']
# 	STIGLITZ             : ['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz']
# 	LT. HICOX            : ['Lt.Hicox', 'Lt.Hicox']
#
# tag : C
# doc : LT.NICOX
# 	LT. HICOX            : ['LT.NICOX']
#
# tag : D
# doc : Stiglitz, right?
# 	STIGLITZ             : ['Stiglitz']
#
# tag : C
# doc : STIGLITZ
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : That's right, sir. He continues bringing the blades edge, up, then, down on the leather strap.
# 	LT. HICOX            : ['sir']
# 	STIGLITZ             : ['He']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : I hear your pretty good with that? Meaning the blade. Stiglitz doesn't answer.
# 	STIGLITZ             : ['your', 'Stiglitz']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : You know, we're not looking for trouble, right now. We're simply making contact with our agent. Should be uneventful. However, on the off chance I'm wrong, and things prove eventful. I need to know, we can all remain calm.
# 	STIGLITZ             : ['You']
# 	LT. HICOX            : ['I', 'I']
#
# tag : N
# doc : The renegade Gerry Sergeant, stops his blades progress, and looks up at the limy Lieutenant.
# 	STIGLITZ             : ['The renegade Gerry Sergeant', 'his']
# 	LT. HICOX            : ['the limy Lieutenant']
#
# tag : C
# doc : STIGLITZ
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : I don't look calm to you?
# 	STIGLITZ             : ['I']
# 	LT. HICOX            : ['you']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Well, now you put it like that,
# 	STIGLITZ             : ['you']
#
# tag : C
# doc : I guess you do.
# 	LT. HICOX            : ['I']
# 	STIGLITZ             : ['you']
#
# tag : D
# doc : He turns his attention back to his blade. Hicox moves over to Aldo, and asks him privately;
# 	STIGLITZ             : ['He', 'his', 'his']
# 	LT. HICOX            : ['Hicox']
# 	LT. ALDO RAINE       : ['Aldo', 'him']
#
# tag : C
# doc : LT. HI COX
# 	LT. HICOX            : ['LT. HI COX']
#
# tag : D
# doc : This Gerry of yours, Stiglitz? Not exactly the loquacious type, is he? Aldo just looks at him.
# 	STIGLITZ             : ['This Gerry of yours, Stiglitz', 'he']
# 	LT. ALDO RAINE       : ['yours', 'Aldo']
# 	LT. HICOX            : ['him']
#
# tag : C
# doc : LT.ALDO
# 	LT. ALDO RAINE       : ['LT.ALDO']
#
# tag : D
# doc : Is that the kinds man you need, the loquacious type?
# 	LT. HICOX            : ['you']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Fair point, Lieutenant.
# 	LT. ALDO RAINE       : ['Lieutenant']
#
# tag : C
# doc : LT.ALDO
# 	LT. ALDO RAINE       : ['LT.ALDO']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : If we get into trouble, we can handle it. But if trouble does happen, we need you to make damn sure no Germans, or French, for matter, escape from that basement. If Frau Von Hammersmark's cover is compromised, the mission is kaput.
# 	BRIDGET VON HAMMERSMARK : ["Frau Von Hammersmark's"]
#
# tag : C
# doc : SGT.DONOWITZ
# 	Donowitz             : ['SGT.DONOWITZ']
#
# tag : D
# doc : Speaking of Frau Von Hammersmark, who's idea was it for the death trap redez-vous?
# 	BRIDGET VON HAMMERSMARK : ['Frau Von Hammersmark']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : She chose the spot.
# 	BRIDGET VON HAMMERSMARK : ['She']
#
# tag : C
# doc : SGT.DONOWITZ
# 	Donowitz             : ['SGT.DONOWITZ']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Look, she's not a military strategist. She's just a actress.
# 	BRIDGET VON HAMMERSMARK : ['she', 'She']
#
# tag : C
# doc : LT.ALDO
# 	LT. ALDO RAINE       : ['LT.ALDO']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : She wasn't picking a place to fight. She was picking a place, isolated, and without germans.
# 	BRIDGET VON HAMMERSMARK : ['She', 'She']
#
# tag : C
# doc : PFC.HIRSCHBERG
# 	Hirschberg           : ['PFC.HIRSCHBERG']
#
# tag : D
# doc : Lieutenant, I hate to be contrary, but I got me a Nazi pissin on Louisianna two-o'clock. They move to the window, and sure enough, ONE LONE NAZI PRIVATE, relieves himself against the side wall. Lt.Bicox, this was definitely, not the plan.
# 	LT. HICOX            : ['Lieutenant', 'Lt.Bicox']
# 	Hirschberg           : ['I', 'I']
# 	NAZI PRIVATE         : ['a Nazi', 'ONE LONE NAZI PRIVATE', 'himself']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Shit. Sgt.Donowitz chides him;
# 	Donowitz             : ['Sgt.Donowitz']
# 	LT. HICOX            : ['him']
#
# tag : C
# doc : SGT.DONOWITZ
# 	Donowitz             : ['SGT.DONOWITZ']
#
# tag : D
# doc : So what do you think your fraulein Von Hammer -
# 	LT. HICOX            : ['you', 'your']
# 	BRIDGET VON HAMMERSMARK : ['your fraulein Von Hammer']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : - Obviously, I don't know,Sgt. The British officer watches the German soldier, who's not suppose to be there. When Hugo Stiglitz joins him at the window. Stiglitz looks down at the urinating Nazi, S.S. dagger in hand.
# 	LT. HICOX            : ['I', 'The British officer', 'him']
# 	Donowitz             : ['Sgt.']
# 	NAZI PRIVATE         : ['the German soldier', 'the urinating Nazi']
# 	STIGLITZ             : ['Hugo Stiglitz', 'Stiglitz']
#
# tag : C
# doc : STIGLITZ
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : If we're going, let's go. He sheaths the dagger.
# 	STIGLITZ             : ['He']
#
# tag : N
# doc : The GERMAN PISSING PRIVATE, sloppily finishes his task. Craming his noodle back in his pants, he descends the stairs that lead him back into the basement tavern. We Follow him...
# 	NAZI PRIVATE         : ['The GERMAN PISSING PRIVATE', 'his', 'his', 'his', 'he', 'him', 'him']
# 	READER               : ['We']
#
# tag : N
# doc : .Inside the basement tavern, La Louisiane. it has a very low hanging basement ceiling. A old looking wood bar off to the right. And the only other space in the little tavern, is taken up by two large(at least in here) tables, which take up both half's of the room. And despite rumors to the contrary, one of the two tables, is completely filled with drunken celebrating Nazi enlisted men, of which our urinating friend is one of five.
# 	READER               : ['our']
# 	NAZI PRIVATE         : ['our urinating friend']
#
# tag : D
# doc : ONE GERMAN MASTER SGT, ONE FEMALE GERMAN SGT , and THREE MALE GERMAN PRIVATES. The Five Nazi's are sitting around the table, drinking, and playing a very fun game with none other then the fraulein of the hour, UFA diva, BRIDGET VON HAMMERSMARK. Dressed to the nines in a chic Forties style women's suit, complete with fedora. The game their playing consists of each player having a card with the name of a famous person, real or imaginary, stuck to their forehead. The player doesn't know what name is on their forehead. So they ask the others questions to figure out who they are. The Five Germans, five cards read; MASTER SGT #1 ,
# 	MASTER SGT #1/POLA NEGRI : ['ONE GERMAN MASTER SGT']
# 	BRIDGET VON HAMMERSMARK : ['the fraulein of the hour, UFA diva, BRIDGET VON HAMMERSMARK']
#
# tag : N
# doc : FEMALE SGT #2(BEETHOVEN), GERMAN PRIVATE #3(MATA HARI), GERMAN PRIVATE #4 (EDGAR WALLACE), GERMAN PRIVATE #5 (WINNETOU). And Bridget Von Hammersmark, who wears her card in the brim of her fedora, has GENGHIS KHAN. It's German#5 (WINNETOU) turn to ask questions. The DIALOGUE will be in GERMAN, and SUBTITLED into ENGLISH. Also, while some dialogue will be written for the German Soldiers, it will be mostly made up from the exuberance of their game playing, and celebrating.
# 	FEMALE SGT #2/BEETHOVEN : ['FEMALE SGT #2(BEETHOVEN)']
# 	GERMAN PRIVATE #3/MATA HARI : ['GERMAN PRIVATE #3(MATA HARI)']
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['GERMAN PRIVATE #4 (EDGAR WALLACE)']
# 	GERMAN PRIVATE #5/WINNETOU : ['GERMAN PRIVATE #5 (WINNETOU)', 'German#5 (WINNETOU)']
# 	BRIDGET VON HAMMERSMARK : ['Bridget Von Hammersmark', 'her', 'her']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : .okay, I'm not German. Am I American? The whole table bursts out laughing.
# 	GERMAN PRIVATE #5/WINNETOU : ['I', 'I']
#
# tag : C
# doc : FEMALE SGT/BEETHOVEN
# 	FEMALE SGT #2/BEETHOVEN : ['FEMALE SGT/BEETHOVEN']
#
# tag : D
# doc : Yes you arel
# 	GERMAN PRIVATE #5/WINNETOU : ['you']
#
# tag : C
# doc : EDGAR WALLACE
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['EDGAR WALLACE']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : What do you mean, not really? Of course he is.
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['you']
# 	GERMAN PRIVATE #5/WINNETOU : ['he']
#
# tag : C
# doc : EDGAR WALLACE
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['EDGAR WALLACE']
#
# tag : D
# doc : Well if he's so American, how come he's never been translated into English? He's not American. He's suppose to be American, but he's not a American creation. In fact, he's something very different.
# 	GERMAN PRIVATE #5/WINNETOU : ['he', 'he', 'He', 'He', 'he', 'he']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : Okay, I'm a fictional, literary character, from the past, I'm American, and that's controversial.
# 	GERMAN PRIVATE #5/WINNETOU : ['I', 'I']
#
# tag : C
# doc : BRIDGET/GENGUS
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET/GENGUS']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : Well I'm glad that's settled. If I had a wife, would she be called a squaw? He's got it. The table Laughs. The TABLE
# 	GERMAN PRIVATE #5/WINNETOU : ['I', 'I', 'He']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : Is my bloodbrother, Old Shatterhand?
# 	GERMAN PRIVATE #5/WINNETOU : ['my']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : Did Karl May write me?
# 	GERMAN PRIVATE #5/WINNETOU : ['me']
#
# tag : D
# doc : Yes! In the BACKGROUND, WE SEE, our three counterfeit German Officers, Hicox, Wicki, and Stiglitz, enter the basement tavern. They obviously. see the five German soldiers, but their too far away for us to read their face. No doubt their less then happy. Fraulein Von Hammersmark see's them as well. Without getting up, she waves to them.
# 	READER               : ['WE', 'our']
# 	LT. HICOX            : ['Hicox']
# 	WILHELM WICKI        : ['Wicki']
# 	STIGLITZ             : ['Stiglitz']
# 	BRIDGET VON HAMMERSMARK : ['Fraulein Von Hammersmark', 'she']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Hello, my lovelies, I will join you in moments. I'm finishing up a game with my five new friends here.
# 	BRIDGET VON HAMMERSMARK : ['my', 'I', 'I', 'my']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : No hurry, Frau Von Hammersmark. Take your time, enjoy yourself.
# 	BRIDGET VON HAMMERSMARK : ['Frau Von Hammersmark', 'your', 'yourself']
#
# tag : D
# doc : So who are you?
# 	GERMAN PRIVATE #5/WINNETOU : ['you']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : I am WINNETOU, CHIEF of the APACHES! The table CHEERS, and APPLAUD the Apache Chief, as he takes the card off his forehead. The other Four German Soldiers drink down there beer . Bridget Von Hammersmark knock backs her champagne.
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU, CHIEF of the APACHES', 'the Apache Chief', 'he', 'his']
# 	BRIDGET VON HAMMERSMARK : ['Bridget Von Hammersmark', 'her']
#
# tag : C
# doc : MATA HARI
# 	GERMAN PRIVATE #3/MATA HARI : ['MATA HARI']
#
# tag : D
# doc : Frau Von Hammersmark, when your friends came in, did you realize you did a double take, like in the movies?
# 	BRIDGET VON HAMMERSMARK : ['Frau Von Hammersmark', 'your', 'you', 'you']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Really? No, I wasn't aware of that at all.
# 	BRIDGET VON HAMMERSMARK : ['I']
#
# tag : C
# doc : MATA HARI
# 	GERMAN PRIVATE #3/MATA HARI : ['MATA HARI']
#
# tag : D
# doc : They must be second nature to you now? Did they teach you how to do a double take in the movies?
# 	BRIDGET VON HAMMERSMARK : ['you', 'you']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Do one for us. The Tableheartily agrees. Bridget looks directly at the Master Sgt, and does a perfect, and perfectly funny, Double Take. The Table loves it.
# 	BRIDGET VON HAMMERSMARK : ['Bridget']
# 	MASTER SGT #1/POLA NEGRI : ['the Master Sgt']
#
# tag : C
# doc : MATA HARI
# 	GERMAN PRIVATE #3/MATA HARI : ['MATA HARI']
#
# tag : D
# doc : My turn, I want to try. Mata Hari, looks directly at Beethoven, and does a Double Take.
# 	GERMAN PRIVATE #3/MATA HARI : ['My', 'I', 'Mata Hari']
# 	FEMALE SGT #2/BEETHOVEN : ['Beethoven']
#
# tag : C
# doc : EDGER WALLACE I want to try.
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['EDGER WALLACE', 'I']
#
# tag : D
# doc : He does. Soon the whole Table is doing dueling Double Takes.
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['He']
#
# tag : N
# doc : HICOX - WICKI - STIGLITZ watch the table do dueling Double Takes. Obviously, they don't understand.
# 	LT. HICOX            : ['HICOX']
# 	WILHELM WICKI        : ['WICKI']
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : .Bridget Von Hammersmark rises, and excuses herself from the Table. She removes the card stuck in her fedora, looking at the name Gengus Khaun for the first time.
# 	BRIDGET VON HAMMERSMARK : ['Bridget Von Hammersmark', 'herself', 'She', 'her']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Gengus Khaun! I would never of gotten that. She walks over, and joins the masquerading Germans table, the Gentlemen rise. She greets each warmly with a french cheek kiss, as if she knows them well. They all take a seat. The two Basterds, and one Brit, drink Whiskey. The taverns PROPRIETOR, a older, big bellyed Frenchman named EARL, comes over to the table, and pours more champagne into Bridget's Champagne glass. He leaves, returning back behind the bar, with the YOUNG FRENCH BARMAID, the only other person in the establishment. Obviously, they speak GERMAN, SUBTITLED into ENGLISH;
# 	BRIDGET VON HAMMERSMARK : ['I', 'She', 'She', 'she', "Bridget's"]
# 	LT. HICOX            : ['one Brit']
# 	Tavern's Proprietor  : ['The taverns PROPRIETOR, a older, big bellyed Frenchman named EARL', 'He']
# 	Barmaid              : ['the YOUNG FRENCH BARMAID, the only other person in the establishment']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : I thought this place was suppose to have more French then Germans?
# 	LT. HICOX            : ['I']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Normally that's true. The Sgt over there's wife, just had a baby. His commanding officer gave him, and his mates the night off to celebrate.
# 	MASTER SGT #1/POLA NEGRI : ["The Sgt over there's", 'His', 'him', 'his']
#
# tag : C
# doc : WICXI
# 	WILHELM WICKI        : ['WICXI']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : F No, we should stay. For one drink at least. I've been waiting for you in a bar, it would look strange if we left before we had a drink.
# 	BRIDGET VON HAMMERSMARK : ['I']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : She's right, just be calm, and enjoy your booze.
# 	BRIDGET VON HAMMERSMARK : ['She']
# 	WILHELM WICKI        : ['your']
#
# tag : N
# doc : BACK TO THE GERMAN TABLE The French Barmaid, has taken Bridget's place in the rousing, rowdy game. She tells them, her person must be French, or she won't know them. Winnetou thinks for a moment, then writes a name on a card. The Barmaid puts it on her forehead, It says;
# 	Barmaid              : ['The French Barmaid', 'She', 'her', 'she', 'The Barmaid', 'her']
# 	BRIDGET VON HAMMERSMARK : ["Bridget's"]
# 	GERMAN PRIVATE #5/WINNETOU : ['Winnetou']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : No one knows. But that in itself shouldn't be a problem. The cinema it's been changed to is considerably smaller then The Ritz. So whatever materials you brought for The Ritz, should be doubly effective here. Now this next piece of information is colossal, try not to over react. The Fubrer, will be attending tomorrow. Hugo Stiglitz does a SPIT TAKE. Bridget's eyes bore holes in him.
# 	The Fubrer           : ['The Fubrer']
# 	STIGLITZ             : ['Hugo Stiglitz', 'him']
# 	BRIDGET VON HAMMERSMARK : ["Bridget's"]
#
# tag : N
# doc : BACK TO THE REAL GERMANS They see Hugo do the spit take, and burst out laughing. Keeping it up, they begin to do dueling spit takes, like they did dueling double takes earlier. Needless to say, they all get wet. BACK TO BASTERDS
# 	STIGLITZ             : ['Hugo']
#
# tag : D
# doc : You'll be going as Ernst Schuller. You'll say your a associate producer on Riefenstahl's "Tiefland". It's the one German production not under Goebbels control, and Leni wouldn't be caught dead at a Goebbels film affair.
# 	LT. HICOX            : ['You', 'You', 'your']
# 	Goebbels             : ['Goebbels', 'Goebbels']
# 	Leni                 : ['Leni']
#
# tag : N
# doc : BACK TO REAL GERMAN TABLE Master Sgt.Pola Negri, drinks his beer, as he looks over, dreamily, at Bridget Von Hammersmark at the other table.
# 	MASTER SGT #1/POLA NEGRI : ['Master Sgt.Pola Negri', 'his', 'he']
# 	BRIDGET VON HAMMERSMARK : ['Bridget Von Hammersmark']
#
# tag : D
# doc : We See in Bridget continues to brief Hicox on his identity. the B.G., the German Master Sgt stand up from his table, and head toward Fraulein Von Bammersmark.
# 	READER               : ['We']
# 	BRIDGET VON HAMMERSMARK : ['Bridget', 'Fraulein Von Bammersmark']
# 	LT. HICOX            : ['Hicox', 'his']
# 	MASTER SGT #1/POLA NEGRI : ['the German Master Sgt', 'his']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : .the films gone through many delays, and Leni's heath is deteriorating, so if you have to speak... Hicox, seeing the German Master Sgt approach, signals for her to cool it.
# 	Leni                 : ["Leni's"]
# 	LT. HICOX            : ['you', 'Hicox']
# 	MASTER SGT #1/POLA NEGRI : ['the German Master Sgt']
# 	BRIDGET VON HAMMERSMARK : ['her']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Frau Von Hammersmark, I was just thinking, could you sign a autograph to my son on his birthday?
# 	BRIDGET VON HAMMERSMARK : ['Frau Von Hammersmark', 'you']
# 	MASTER SGT #1/POLA NEGRI : ['I', 'my']
# 	MAXIMILIAN           : ['my son', 'his']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : I'd love to Wilhelm. This handsome happy Sgt, just became a father today. The Pretend Officers offer congratulations to the Sgt. The German Master Sgt, CLICKS his heels, and bows before his superior officers.
# 	BRIDGET VON HAMMERSMARK : ['I']
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm', 'This handsome happy Sgt', 'the Sgt', 'The German Master Sgt', 'his', 'his']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Thank you, heil Hitler. He raises his hand .... as do the seated phony officers; "Heil Hitler". As she takes a rather fancy fountain pen from her clutch..
# 	The Fubrer           : ['Hitler', 'Hitler']
# 	MASTER SGT #1/POLA NEGRI : ['He', 'his']
# 	BRIDGET VON HAMMERSMARK : ['she', 'her']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : So Wilhelm, do you know the name of this progeny yet?
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm']
# 	MAXIMILIAN           : ['this progeny']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : I most certainly do, fraulein. His name is Maximilian. Even the slightly psychotic Stiglitz, likes this German Sgt.
# 	MASTER SGT #1/POLA NEGRI : ['I', 'this German Sgt']
# 	BRIDGET VON HAMMERSMARK : ['fraulein']
# 	MAXIMILIAN           : ['His']
# 	STIGLITZ             : ['the slightly psychotic Stiglitz']
#
# tag : C
# doc : STIGLITZ
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : Wonderful name, Sgt.
# 	MASTER SGT #1/POLA NEGRI : ['Sgt']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Thank you, Lieutenant. When he's old enough to ride a bicycle, I will buy him a blue one. And I will paint on the side "The Blue Max". He thrusts out his beer stein, for the officers to cheers. They do. Bridget finishes signing her autograph, with a big flourish.
# 	STIGLITZ             : ['Lieutenant']
# 	MAXIMILIAN           : ['he', 'him']
# 	MASTER SGT #1/POLA NEGRI : ['I', 'I', 'He', 'his']
# 	BRIDGET VON HAMMERSMARK : ['Bridget', 'her']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : There you go. But wait, I'm not finished yet. She reaches into her clutch, and pulls out some lipstick. Applies some ruby red color to her lips, and then kisses the napkin, leaving a big red lip print. Then hands the treasured item to the young father.
# 	MASTER SGT #1/POLA NEGRI : ['you', 'the young father']
# 	BRIDGET VON HAMMERSMARK : ['I', 'She', 'her', 'her']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Nothing but the best for little Maximilian.
# 	MAXIMILIAN           : ['little Maximilian']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Thank you fraulein, thank you. Max may not know who you are now. But he will. I will show him all of your movies. He will grow up with your films, and this napkin on his wall. Then, to the whole tavern...
# 	BRIDGET VON HAMMERSMARK : ['you', 'fraulein', 'you', 'you', 'your', 'your']
# 	MAXIMILIAN           : ['Max', 'he', 'him', 'He', 'his']
# 	MASTER SGT #1/POLA NEGRI : ['I']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : I purpose a toast to the greatest actress in Germany! There is no Dietrich, there is no Riefenstahl, only Von Hammersmark! The whole room toasts. This would be a good time for the German Sgt to go back to his table, and his men. And he almost does.... but... since he is drunk, and star struck, he out wears his welcome.
# 	MASTER SGT #1/POLA NEGRI : ['I', 'the German Sgt', 'his', 'his', 'he', 'he', 'he', 'his']
# 	BRIDGET VON HAMMERSMARK : ['Von Hammersmark']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : So, Frau Von Hammersmark, what brings you to France?
# 	BRIDGET VON HAMMERSMARK : ['Frau Von Hammersmark', 'you']
#
# tag : N
# doc : 97 . Feeling any good Nazi officer's patience would of been exhausted long ago, Lt.Hicox butts in.
# 	LT. HICOX            : ['Lt.Hicox']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : None of your business,Sgt. You might not have worn out your welcome with the fraulein, with your drunken boorish behavior, but you have wore out your welcome with me. The Table of game playing Soldiers, hear this, and get quiet.
# 	MASTER SGT #1/POLA NEGRI : ['your', 'Sgt', 'You', 'your', 'your', 'you', 'your']
# 	BRIDGET VON HAMMERSMARK : ['the fraulein']
# 	LT. HICOX            : ['me']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Might I remind you Sgt.,your a enlisted man. This is a officers table. I suggest you stop pestering the fraulein, and rejoin your table. The German Master Sgt., looks quizzically at the officer.
# 	LT. HICOX            : ['I', 'I', 'the officer']
# 	MASTER SGT #1/POLA NEGRI : ['you', 'Sgt.', 'your', 'you', 'your', 'The German Master Sgt.']
# 	BRIDGET VON HAMMERSMARK : ['the fraulein']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Excuse me Cap't, but your accent is is very unusual. The whole room pauses-for different reasons...
# 	MASTER SGT #1/POLA NEGRI : ['me']
# 	LT. HICOX            : ["Cap't", 'your']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : Where are you from? A silent moment passes between the two tables, then the two German born impostors spring into action.
# 	LT. HICOX            : ['you']
#
# tag : C
# doc : WICKI
# 	WILHELM WICKI        : ['WICKI']
#
# tag : D
# doc : Sgt.! You must be ether drunk or mad, to speak to a superior officer with such impertinentness! Stiglitz, STANDS and YELLS to the other table;
# 	MASTER SGT #1/POLA NEGRI : ['Sgt.', 'You']
# 	STIGLITZ             : ['Stiglitz']
#
# tag : C
# doc : STIGLITZ I'm making YOU,...
# 	STIGLITZ             : ['STIGLITZ']
# 	GERMAN PRIVATE #5/WINNETOU : ['YOU']
#
# tag : C
# doc : WINNETOU) .and YOU,..
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['YOU']
#
# tag : D
# doc : .responsible, for him. I suggest you take hold of your friend, or he'll spend Max's first birthday in jail for public drunkenness!
# 	MASTER SGT #1/POLA NEGRI : ['him', 'he']
# 	GERMAN PRIVATE #5/WINNETOU : ['I']
# 	MAXIMILIAN           : ["Max's"]
#
# tag : N
# doc : The Germans SPRING UP, and take hold of Sgt.Pola... 1W
# 	MASTER SGT #1/POLA NEGRI : ['Sgt.Pola']
#
# tag : D
# doc : A GERMAN VOICE rings out;
# 	MAJOR HELLSTROM      : ['A GERMAN VOICE']
#
# tag : C
# doc : GERMAN VOICE Then might I inquire?
# 	MAJOR HELLSTROM      : ['GERMAN VOICE', 'I']
#
# tag : D
# doc : The Five known Germans move aside, reveling the unknown German in the room, unseen till now, our old friend from before MAJOR DEITER HELLSTROM of the GESTAPO. The Major stands from the little table he was sitting at.
# 	MAJOR HELLSTROM      : ['the unknown German', 'MAJOR DEITER HELLSTROM of the GESTAPO', 'The Major', 'he']
# 	READER               : ['our']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Like the young newly christened father, I too have a acute ear for accents. And like him, I too find yours odd. From where do you hail, Cap't? Wicki jumps in;
# 	MASTER SGT #1/POLA NEGRI : ['the young newly christened father', 'him']
# 	MAJOR HELLSTROM      : ['I', 'I']
# 	LT. HICOX            : ['yours', 'you', "Cap't"]
# 	WILHELM WICKI        : ['Wicki']
#
# tag : C
# doc : WICKI
# 	WILHELM WICKI        : ['WICKI']
#
# tag : D
# doc : Major, this is highly inappr -
# 	MAJOR HELLSTROM      : ['Major']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : T wasn't speaking to you Lt.Saltzberg, (Turning to
# 	MAJOR HELLSTROM      : ['T']
# 	WILHELM WICKI        : ['you Lt.Saltzberg']
#
# tag : C
# doc : STIGLITZ)
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : or you ether, Lt.Berlin. (Looking at
# 	STIGLITZ             : ['you', 'Lt.Berlin']
#
# tag : C
# doc : HICOX)
# 	LT. HICOX            : ['HICOX']
#
# tag : D
# doc : I was speaking to Cap't I--don't-know-what. The Gestapo Major is now standing beside Sgt.Pola, before the impostors table. Lt.Hicox, calmly explains his origin.
# 	MAJOR HELLSTROM      : ['I', 'I', 'The Gestapo Major']
# 	LT. HICOX            : ["Cap't", 'Lt.Hicox', 'his']
# 	MASTER SGT #1/POLA NEGRI : ['Sgt.Pola']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : I was born in the village that rests in the shadow of Piz Palu.
# 	LT. HICOX            : ['I']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Yes. In that village we all speak like this. Have you seen the Riefenstahl film?
# 	MAJOR HELLSTROM      : ['you']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : LT. HICOX
# 	LT. HICOX            : ['LT. HICOX']
#
# tag : D
# doc : Then you saw me. You remember the skiing torch scene?
# 	MAJOR HELLSTROM      : ['you', 'You']
# 	LT. HICOX            : ['me']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Yes I do.
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : In that scene was myself, my father, my sister, and my two brothers. My brother is so handsome, the director Pabst, gave him a Close Up. As Bridget Von Hammersmark places a cigarette in a ivory cigarette holder, which Hicox, as if on cue, lights for her, she says;
# 	LT. HICOX            : ['myself', 'my', 'my', 'my', 'My', 'Hicox']
# 	BRIDGET VON HAMMERSMARK : ['Bridget Von Hammersmark', 'her', 'she']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Major, if my word means anything, I can vouch for everything the Young Cap't has just said. He does hail from the bottom of Piz Palu, he was in the film, and his brother is far more handsome then he. The impostors laugh. Then....so does the Gestapo Major. He turns to the Sgt.
# 	MAJOR HELLSTROM      : ['Major', 'the Gestapo Major']
# 	BRIDGET VON HAMMERSMARK : ['my', 'I']
# 	LT. HICOX            : ["the Young Cap't", 'He', 'he', 'his', 'he']
# 	MASTER SGT #1/POLA NEGRI : ['the Sgt']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : You should rejoin your friends. Which the young Sgt is more then happy to do. That table begins playing there game again. Major Hellstrom, the highest ranking officer in the room, bows graciously to the female German celebrity.
# 	MASTER SGT #1/POLA NEGRI : ['You', 'your', 'the young Sgt']
# 	MAJOR HELLSTROM      : ['Major Hellstrom']
# 	BRIDGET VON HAMMERSMARK : ['the female German celebrity']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : May I join you?
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : By all means, Major. The Gestapo Major sits at the table, opposite Lt.Hicox, and Wicki. The French Barmaid brings over the Majors beer stein.
# 	MAJOR HELLSTROM      : ['Major', 'The Gestapo Major', 'the Majors']
# 	LT. HICOX            : ['Lt.Hicox']
# 	WILHELM WICKI        : ['Wicki']
# 	Barmaid              : ['The French Barmaid']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : So that's the source of your bazaar accent? Extraordinary. So what are you doing here Cap't?
# 	LT. HICOX            : ['your', 'you', "Cap't"]
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Aside from having a drink with the lovely fraulein?
# 	BRIDGET VON HAMMERSMARK : ['the lovely fraulein']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : I mean in country. Your obviously not stationed in France, or I'd know who you are.
# 	MAJOR HELLSTROM      : ['I', 'I']
# 	LT. HICOX            : ['Your', 'you']
#
# tag : C
# doc : LT I'! I COX
# 	LT. HICOX            : ["LT I'! I COX"]
#
# tag : D
# doc : You know every German in France?
# 	MAJOR HELLSTROM      : ['You']
#
# tag : C
# doc : MAJOR BELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR BELLSTROM']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : All levity aside, what are you doing in France?
# 	LT. HICOX            : ['you']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Attending Goebbels film premiere as the frauleins escort.
# 	Goebbels             : ['Goebbels']
# 	BRIDGET VON HAMMERSMARK : ['the frauleins']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Your the frauleins escort?
# 	LT. HICOX            : ['Your']
# 	BRIDGET VON HAMMERSMARK : ['the frauleins']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : The Captain is my date, but all three are my guests. We're old friends Major, who go back along time. Longer then a actress would care to admit. Chuckle chuckle.
# 	LT. HICOX            : ['The Captain']
# 	BRIDGET VON HAMMERSMARK : ['my', 'my']
# 	MAJOR HELLSTROM      : ['Major']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Well, in that case, let me raise a glass to the three luckiest men in the room.
# 	MAJOR HELLSTROM      : ['me']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : I'll drink to that.
# 	BRIDGET VON HAMMERSMARK : ['I']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : I must say, that game their playing looks like a good bit of fun. I didn't join them, because your quite right Cap't, officers and enlisted men shouldn't fraternize. But seeing as we're all officers here, (Bowing to
# 	MAJOR HELLSTROM      : ['I', 'I']
# 	LT. HICOX            : ['your', "Cap't"]
#
# tag : C
# doc : BRIDGET)
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : .and sophisticated lady friends of officers. What say we play the game? Lt.Hicox begins to refuse, when Bridget , interrupts him;
# 	LT. HICOX            : ['Lt.Hicox']
# 	BRIDGET VON HAMMERSMARK : ['Bridget , interrupt']
#
# tag : E
# doc : feeling she knows better
# 	BRIDGET VON HAMMERSMARK : ['she']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : N
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : The Major borrows five cards from the other table, and lays them out in front of Bridget and the officers.
# 	MAJOR HELLSTROM      : ['The Major']
# 	BRIDGET VON HAMMERSMARK : ['Bridget']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : So the object of the game, is to write the name of a famous person on your card. Real or fictitious, doesn't matter. For instance, you could write Confucius or Fu Manchu. (He SNAPS his
# 	MAJOR HELLSTROM      : ['He', 'his']
#
# tag : D
# doc : Eric' More pens. And they must be famous. No Aunt Inga's. When you finish writing, put the card face down on the table, and move it to the person to your left. The person to your right, will move their card in front of you. You pick up the card without looking at it, lick the back, and stick it on your forehead like so. He demonstrates.
# 	Eric                 : ['Eric']
# 	MAJOR HELLSTROM      : ['He']
#
# tag : N
# doc : )oz. MAJOR HELLSTROM (CON'T) And in ten yes or no questions, you must guess who you are... As Major Hellstrom finishes explaining the finer points of the game, The CAMERA PANS OFF HIM, and BEGINS SLOWLY ZOOMING INTO STIGLITZ. The Majors dialogue begins to FADE AWAY. Untill we're in a SPAGHETTI WESTERN FLASHBACK. Which is RED FILTERED FOOTAGE of Hugo being savagely WHIPPED by somebody wearing a GESTAPO UNIFORM, SUPERIMPOSED over his CLOSE UP. The Flashback disappears. It's driving Stiglitz crazy, being this close to a Gestapo uniform, and not plunging a knife into it. The Majors Voice comes back on the soundtrack.
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM', 'Major Hellstrom', 'HIM', 'Majors', 'The Majors']
# 	STIGLITZ             : ['STIGLITZ', 'Hugo', 'his', 'Stiglitz']
# 	READER               : ['we']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : I'll start, give you the idea.
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : Am I German?
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : C
# doc : MAJ.KING KONG Am I a American?
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG', 'I']
#
# tag : D
# doc : They laugh - but then Wicki says;
# 	WILHELM WICKI        : ['Wicki']
#
# tag : C
# doc : WICKI
# 	WILHELM WICKI        : ['WICKI']
#
# tag : D
# doc : Wait a minute, he goes to
# 	MAJOR HELLSTROM      : ['he']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Don't be ridiculous, obviously he wasn't born in America.
# 	MAJOR HELLSTROM      : ['he']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : So... . I visited America, aye? The Table says; "Yes".
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : C
# doc : WICKI
# 	WILHELM WICKI        : ['WICKI']
#
# tag : D
# doc : Not for you.
# 	MAJOR HELLSTROM      : ['you']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : .Bummm. My native land, is it what one would call, exotic? The Table confers, and decides, yes it is exotic.
# 	MAJOR HELLSTROM      : ['My']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : Hummmm. That could be ether a reference to the jungle, or the Orient. I'm going to let my first instinct take over, and ask, am I from the jungle? The Tablesays; "Yes you are".
# 	MAJOR HELLSTROM      : ['I', 'my', 'I', 'you']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : Now gentlemen, around this time you could ask, weather your real or fictitious. I however, think that's too easy, so I won't ask that, yet. Okay, my native land is the jungle? I visited America, but my visit was not fortuitous to me, but the implication is that it was to somebody else. When I went from the jungle to America,... .Did I go by boat? "Yes".
# 	MAJOR HELLSTROM      : ['I', 'I', 'my', 'I', 'my', 'me', 'I', 'I']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : Did I go against my will? "Yes".
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : On this boat ride, ... . Was I in chains?
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : When I arrived in America,...Was I displayed in chains? "Yes".
# 	MAJOR HELLSTROM      : ['I', 'I']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : Am I the story of the Negro in America? The Table says, "No".
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : MAJ.KING KONG
# 	MAJOR HELLSTROM      : ['MAJ.KING KONG']
#
# tag : D
# doc : Well then I must be King Kong. Be throws the card on the table. They applaud him.
# 	MAJOR HELLSTROM      : ['I', 'Be', 'him']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Nov since I answered correctly, you all need to finnish your drinks. The three counterfeit Nazi's knock back their whiskey.
# 	MAJOR HELLSTROM      : ['I']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Major, I don't mean to be rude. But the four of us are very good friends. And the four of us haven't seen each other in quite a while. So... Major, I'm afraid, you are intruding.
# 	MAJOR HELLSTROM      : ['Major', 'Major', 'you']
# 	LT. HICOX            : ['I', 'I']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : I beg to differ Cap't. It's only if the fraulein considers my presence a intrusion, that I become a intruder. How about it fraulein? Am I intruding?
# 	MAJOR HELLSTROM      : ['I', 'my', 'I', 'I']
# 	LT. HICOX            : ["Cap't"]
# 	BRIDGET VON HAMMERSMARK : ['the fraulein', 'fraulein']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Of course not, Major.
# 	MAJOR HELLSTROM      : ['Major']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : I didn't think so. It's simply the young Cap't is immune to my charms. The Table's not sure what to do, is this a confrontation? Then, the Major laughs.
# 	MAJOR HELLSTROM      : ['I', 'my', 'the Major']
# 	LT. HICOX            : ["the young Cap't"]
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : I'm just joking, of course I'm intruding.
# 	MAJOR HELLSTROM      : ['I', 'I']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Allow me to refill your glasses gentlemen, and I will bid you and the fraulein adieu. Eric has a bottle of thirty-three year old single malt scotch whisky from the Scottish highlands. What do you say gentlemen?
# 	MAJOR HELLSTROM      : ['me', 'I']
# 	BRIDGET VON HAMMERSMARK : ['the fraulein']
# 	Eric                 : ['Eric']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Your most gracious, sir.
# 	MAJOR HELLSTROM      : ['Your']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Eric, the thirty-three, and new glasses! You don't want to contaminate the thirty- three with the swill you were drinking.
# 	Eric                 : ['Eric']
#
# tag : C
# doc : ERIC
# 	Eric                 : ['ERIC']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Not me. I like scotch, scotch doesn't like me.
# 	MAJOR HELLSTROM      : ['me', 'I', 'me']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Nor I. I'll stay with bubbly. Lt.Bicox, hold up three fingers , to Eric the owner.
# 	BRIDGET VON HAMMERSMARK : ['I', 'I']
# 	LT. HICOX            : ['Lt.Bicox']
# 	Eric                 : ['Eric']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Three glasses. Eric brings the three glasses, and the old bottle, pouring for the three soldiers. Major Helistrom lifts up his beer stein, and toasts;
# 	Eric                 : ['Eric']
# 	MAJOR HELLSTROM      : ['Major Helistrom', 'his']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : To a thousand year Reich! They all mutter, "a thousand year reich", and toast glasses. The Gestapo Major puts down his beer stein, and then WE HEAR a CLICK, under the table.
# 	MAJOR HELLSTROM      : ['The Gestapo Major', 'his']
# 	READER               : ['WE']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Did you hear that? That's the sound of my Luger pointed right at your testicles.
# 	LT. HICOX            : ['you', 'your']
# 	MAJOR HELLSTROM      : ['my']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Why do you have a Luger pointed at my testicles?
# 	MAJOR HELLSTROM      : ['you']
# 	LT. HICOX            : ['my']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Because you've just given yourself away, Cap't. Your no more German then that scotch.
# 	LT. HICOX            : ['you', 'yourself', "Cap't", 'Your']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : Well, -Major -
# 	MAJOR HELLSTROM      : ['Major']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : - Major -
# 	MAJOR HELLSTROM      : ['Major']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : - Shut up slut. You were saying?
# 	BRIDGET VON HAMMERSMARK : ['slut']
# 	LT. HICOX            : ['You']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : I was saying that makes two of us. I've had a gun pointed at your balls since you sat down.
# 	LT. HICOX            : ['I', 'I']
# 	MAJOR HELLSTROM      : ['your', 'you']
#
# tag : C
# doc : SGT.STIGLITZ
# 	STIGLITZ             : ['SGT.STIGLITZ']
#
# tag : D
# doc : We See all three guns pointed at appropriate crotches. As well as Bridget's legs, right besides the Nazi Major's. Her pretty gams are sure to be chewed up in the possible crossfire.
# 	READER               : ['We']
# 	BRIDGET VON HAMMERSMARK : ["Bridget's", 'Her']
# 	MAJOR HELLSTROM      : ["the Nazi Major's"]
#
# tag : C
# doc : SGT.STIGLITZ
# 	STIGLITZ             : ['SGT.STIGLITZ']
#
# tag : D
# doc : And at this range, I'm a real Fredrick Zoller. Hugo alsobrings out his dagger, and sitcks it in the table top.
# 	STIGLITZ             : ['I', 'Hugo', 'his']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : LT. H ICOX
# 	LT. HICOX            : ['LT. H ICOX']
#
# tag : D
# doc : What's going to happen, Major, is your going to stand up, and walk out that door with us.
# 	MAJOR HELLSTROM      : ['Major', 'your']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : No no no no no no, I don't think so. I'm afraid you and I both know, no matter what happens to anybody else in this room, the two of us aren't going anywhere.
# 	MAJOR HELLSTROM      : ['I', 'I', 'I']
# 	LT. HICOX            : ['you']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Then Major, i implore you. For the sake of those German troops, will you please leave with us?
# 	MAJOR HELLSTROM      : ['Major', 'you', 'you']
# 	BRIDGET VON HAMMERSMARK : ['i']
#
# tag : C
# doc : MAJOR HELLSTROM
# 	MAJOR HELLSTROM      : ['MAJOR HELLSTROM']
#
# tag : D
# doc : Oh Bridget, your concern for German troops, gets me .right here. You mean for the sake your whore legs, don't you? You can't afford to get any bullet holes in them, your not finished spreading them for all the Hollywood Jews. Lt.Hicox picks up his thirty-three year old single malt scotch, and says;
# 	BRIDGET VON HAMMERSMARK : ['Bridget', 'your', 'You', 'your', 'you', 'You', 'your']
# 	LT. HICOX            : ['Lt.Hicox', 'his']
#
# tag : N
# doc : LT.HICOX (ENGLISH) 'Well, if this is it old boy, I hope you dont mind if I go out speaking the kings? MAJOR HELLSTROM (ENGLISH) By all means, Cap't. The English film critic, commando, picks up the thirty-three the Nazi Major bought him, and says;
# 	LT. HICOX            : ['LT.HICOX', 'I', 'I', "Cap't", 'The English film critic, commando', 'him']
# 	MAJOR HELLSTROM      : ['old boy', 'you', 'MAJOR HELLSTROM', 'the Nazi Major']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : There's a special rung in hell reserved for people who waste good scotch. And seeing as I might be rapping on the door momentarily... He downs the stuff.
# 	LT. HICOX            : ['I', 'He']
#
# tag : C
# doc : LT.HICOX
# 	LT. HICOX            : ['LT.HICOX']
#
# tag : D
# doc : I must say, damn good stuff, sir.
# ...
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : C
# doc : HELLSTROM
# 	MAJOR HELLSTROM      : ['HELLSTROM']
#
# tag : D
# doc : FIRES into HICOX'S BALLS and KNEE CAPS.
# 	LT. HICOX            : ["HICOX'S"]
#
# tag : C
# doc : STIGLITZ
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : D
# doc : then JUMPS over the table, and begins STABBING HELLSTROM with the
# 	MAJOR HELLSTROM      : ['HELLSTROM']
#
# tag : D
# doc : HICOX FALLS to the floor....DEAD. BRIDGET FALLS to the floor.,SHOT.
# 	LT. HICOX            : ['HICOX']
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : C
# doc : WICKI
# 	WILHELM WICKI        : ['WICKI']
#
# tag : D
# doc : brings his weapon out from underneath the table, and BEGINS FIRING across at The GERMANS at the table, who unaware, were still PLAYING THE GAME.
# 	WILHELM WICKI        : ['his']
#
# tag : C
# doc : WINNETOU
# 	GERMAN PRIVATE #5/WINNETOU : ['WINNETOU']
#
# tag : D
# doc : is SHOT IN THE BACK, before he even knew what was happening. EDGAR WALLACE and The FRENCH BARMAID are both SHOT by WICKI.
# 	GERMAN PRIVATE #5/WINNETOU : ['he']
# 	GERMAN PRIVATE #4/EDGAR WALLACE : ['EDGAR WALLACE']
# 	Barmaid              : ['The FRENCH BARMAID']
# 	WILHELM WICKI        : ['WICKI']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : FALLS to the floor in the confusion. FEMALE SGT.BEETHOVEN and STIGLITZ bring their guns toward each other and FIRE. They BOTH TAKE and GIVE each other so many BULLETS, it's almost romantic when they collapse DEAD on the floor.
# 	FEMALE SGT #2/BEETHOVEN : ['FEMALE SGT.BEETHOVEN']
# 	STIGLITZ             : ['STIGLITZ']
#
# tag : C
# doc : I 09. WICKI and HATA HARI
# 	WILHELM WICKI        : ['WICKI']
# 	GERMAN PRIVATE #3/MATA HARI : ['HATA HARI']
#
# tag : C
# doc : SGT.POLA NEGRI
# 	MASTER SGT #1/POLA NEGRI : ['SGT.POLA NEGRI']
#
# tag : D
# doc : The SHOOTING STOPS...the SMOKE caused by the gunfire ... starts to DISSIPATE... The only one in the room left alive, is the young German Sgt, with the machine gunn. WE HEAR the feet of the soldiers outside, reach the basement entrance. The door opens... , .The German Sgt, sends FIFTY BULLETS in the doors direction... No one goes through it. What we have here, is a rabbit hole like situation. No one inside is getting out, no one outside is getting in. The young German Sgt, YELLS in ENGLISH, to the outside;
# 	MASTER SGT #1/POLA NEGRI : ['the young German Sgt', 'The German Sgt', 'The young German Sgt']
# 	READER               : ['WE', 'we']
#
# tag : C
# doc : GERMAN SGT
# 	MASTER SGT #1/POLA NEGRI : ['GERMAN SGT']
#
# tag : D
# doc : You outside! Who are you? British, American, what? Aldo's Voice YELLS down the hole;
# 	LT. ALDO RAINE       : ["Aldo's"]
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Were American's 1 What are you?
# 	MASTER SGT #1/POLA NEGRI : ['you']
#
# tag : C
# doc : GERMAN SGT
# 	MASTER SGT #1/POLA NEGRI : ['GERMAN SGT']
#
# tag : D
# doc : I'm a German you idiot!
# 	MASTER SGT #1/POLA NEGRI : ['I']
# 	LT. ALDO RAINE       : ['you']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : You speak English pretty good for a German!
# 	MASTER SGT #1/POLA NEGRI : ['You']
#
# tag : C
# doc : GERMAN SGT
# 	MASTER SGT #1/POLA NEGRI : ['GERMAN SGT']
#
# tag : D
# doc : I agree! So let's talk!
# 	MASTER SGT #1/POLA NEGRI : ['I']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : C
# doc : GERMAN SGT
# 	MASTER SGT #1/POLA NEGRI : ['GERMAN SGT']
#
# tag : D
# doc : I'm a father! My baby was born today in Frankfurt! Five hours ago! His name is Max! We were in here drinking and celebrating! They're the ones that came in shooting and killing! It's not my fault!
# 	MASTER SGT #1/POLA NEGRI : ['I', 'My', 'my']
# 	MAXIMILIAN           : ['His']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Okay, okay, it wasn't your fault! What's your name soldier?
# 	MASTER SGT #1/POLA NEGRI : ['your', 'your']
#
# tag : C
# doc : GERMAN SGT
# 	MASTER SGT #1/POLA NEGRI : ['GERMAN SGT']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : That's the same name as one of the guys you just killed!
# 	MASTER SGT #1/POLA NEGRI : ['you']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Okay Wilhelm... .is anybody alive on our side?
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : No! We hear a VOICE OFF SCREEN, yell out;
# 	READER               : ['We']
#
# tag : C
# doc : BRIDGET'S VOICE
# 	BRIDGET VON HAMMERSMARK : ["BRIDGET'S"]
#
# tag : D
# doc : I'm alive! Wilhelm spins in the direction of the voice.
# 	BRIDGET VON HAMMERSMARK : ['I']
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm']
#
# tag : D
# doc : On the floor, with a bullet in her BLOODY LEG, lies the alive Bridget Von Hammersmark. The German Sgt points the muzzle of the machine gunn at the German celebrity; with hate in his eyes.
# 	BRIDGET VON HAMMERSMARK : ['her', 'Bridget Von Hammersmark', 'the German celebrity']
# 	MASTER SGT #1/POLA NEGRI : ['The German Sgt', 'his']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : (To BRIDGET,
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : Make a sound whore, and I spit! Meaning the muzzle.
# 	BRIDGET VON HAMMERSMARK : ['whore']
# 	MASTER SGT #1/POLA NEGRI : ['I']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Wilhelm, who is that?
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : is the girl on your side? Pause.
# 	BRIDGET VON HAMMERSMARK : ['the girl']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : 1 Who do you think, Von Hammersmark!
# 	LT. ALDO RAINE       : ['you']
# 	BRIDGET VON HAMMERSMARK : ['Von Hammersmark']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Yeah, she's oar's!
# 	BRIDGET VON HAMMERSMARK : ['she']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : (To Bridget
# 	BRIDGET VON HAMMERSMARK : ['Bridget']
#
# tag : D
# doc : I thought so. So you run with the American's now, huh? Now times are bad?
# 	MASTER SGT #1/POLA NEGRI : ['I']
# 	BRIDGET VON HAMMERSMARK : ['you']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Is she okay?
# 	BRIDGET VON HAMMERSMARK : ['she']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : (To Bridget
# 	BRIDGET VON HAMMERSMARK : ['Bridget']
#
# tag : D
# doc : You despicable traitor. She's been shot, but she's alive. (To Bridget
# 	BRIDGET VON HAMMERSMARK : ['You', 'She', 'she', 'Bridget']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Okay Wilhelm, what'd ya say we make a deal?
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm', 'ya']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : D
# doc : What's your name?
# 	LT. ALDO RAINE       : ['your']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Aldo. Wilhelm, can I call yap Willi?
# 	MASTER SGT #1/POLA NEGRI : ['Wilhelm', 'yap']
# 	LT. ALDO RAINE       : ['I']
#
# tag : C
# doc : WILHELM
# 	MASTER SGT #1/POLA NEGRI : ['WILHELM']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : So Willi, you know we could lob three or four or five or six grenades down there, and your little war story ends here. But good fer you, bad fer her, you die, she dies. So what say we make a swap?
# 	MASTER SGT #1/POLA NEGRI : ['Willi', 'you', 'your', 'you', 'you']
# 	BRIDGET VON HAMMERSMARK : ['her', 'she']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Okay, Willi here's my deal! You let me and one of my men come down to take the girl away! And we take the girl, and leave! That simple, Willi! You go your way, we go ours! And little Max, gets to grow up playing catch with his daddy! So what'ya say, Willi, we got a deal? Willi thinks... Bridget watches Willi think...
# 	MASTER SGT #1/POLA NEGRI : ['Willi', 'Willi', 'You', 'your', 'his daddy', 'ya', 'Willi', 'Willi', 'Willi']
# 	LT. ALDO RAINE       : ['my', 'You', 'me', 'my']
# 	BRIDGET VON HAMMERSMARK : ['the girl', 'the girl', 'Bridget']
# 	MAXIMILIAN           : ['little Max', 'his']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : Aldo?
# 	LT. ALDO RAINE       : ['Aldo']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : I'm here Willi!
# 	LT. ALDO RAINE       : ['I']
# 	MASTER SGT #1/POLA NEGRI : ['Willi']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : I want to trust you.... But howcanI?
# 	MASTER SGT #1/POLA NEGRI : ['I']
# 	LT. ALDO RAINE       : ['you']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : What choice ya got?
# 	MASTER SGT #1/POLA NEGRI : ['ya']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : I could kill the girl!
# 	MASTER SGT #1/POLA NEGRI : ['I']
# 	BRIDGET VON HAMMERSMARK : ['the girl']
#
# tag : C
# doc : ALDO'S VOICE
# 	LT. ALDO RAINE       : ["ALDO'S"]
#
# tag : D
# doc : Well now, Willi, that's true enough. But something you need to know, so you don't get the wrong idea. Ain't none of us give a fuck bout that girl. But, admittedly, if you kill her, it would fuck up our plans. But you'll be dead by then anyway, so what'd you care? And lets not forget that little gatzenjammer Max, growin up without a pop. So in the spirit of gettin you home to him, we got a deal, Willi?
# 	MASTER SGT #1/POLA NEGRI : ['Willi', 'you', 'you', 'you', 'you', 'you', 'you', 'Willi']
# 	BRIDGET VON HAMMERSMARK : ['girl', 'her']
# 	MAXIMILIAN           : ['that little gatzenjammer Max', 'him']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : Okay Aldo, I'm going to trust you! Come down, no guns! Aldo and Hirschberg come down the stairs, showing open hands. Willi keeps his machine gunn trained on them. Aldo with his hands up, says;
# 	LT. ALDO RAINE       : ['Aldo', 'you', 'Aldo', 'Aldo', 'his']
# 	MASTER SGT #1/POLA NEGRI : ['I', 'Willi', 'his']
# 	Hirschberg           : ['Hirschberg']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : Hey Willi, what's with the machine gunny I thought we had a deal?
# 	MASTER SGT #1/POLA NEGRI : ['Willi']
# 	LT. ALDO RAINE       : ['I']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : We do have a deal, now git the girl and go.
# 	BRIDGET VON HAMMERSMARK : ['the girl']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : Not so fast, Willi, we only have a deal, we trust each other. A Mexican stand off ain't trust.
# 	MASTER SGT #1/POLA NEGRI : ['Willi']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : You need guns on me for it to be a Mexican stand off.
# 	LT. ALDO RAINE       : ['You']
# 	MASTER SGT #1/POLA NEGRI : ['me']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : you got guns on us, you decide to shoot, we're dead. Up top, they got grenades, they drop 'em down here, your dead. That's a Mexican stand off, and that wasn't the deal.
# 	MASTER SGT #1/POLA NEGRI : ['you', 'you', 'your']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : Just take that fucking traitor, and go! See? Now your down here Now you get tricky - t
# 	BRIDGET VON HAMMERSMARK : ['that fucking traitor']
# 	LT. ALDO RAINE       : ['your', 'you']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : - No tricks!- Ain't nobody gittin tricky, Willi; I swear to god, I'm too damn dumb toget tricky. But
# 	MASTER SGT #1/POLA NEGRI : ['Willi']
# 	LT. ALDO RAINE       : ['I', 'I']
#
# tag : C
# doc : HIRSCHBERG)
# 	Hirschberg           : ['HIRSCHBERG']
#
# tag : D
# doc : him and I lived upto the deal. We came down without guns. Now it's your turn. No trust,no deal. Willi pointing gunn at them.,,, -thinking...
# 	Hirschberg           : ['him']
# 	LT. ALDO RAINE       : ['I']
# 	MASTER SGT #1/POLA NEGRI : ['your', 'Willi']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : i know your scarred. I'm scarred, he's scarred, we're all scarred. So what's it gonnabe Willi? Ether we got a deal, or you might as well just shoot us now. Willi decides... He puts the machine gunn down on the bar.
# 	LT. ALDO RAINE       : ['i', 'I']
# 	MASTER SGT #1/POLA NEGRI : ['your', 'Willi', 'you', 'Willi', 'He']
# 	Hirschberg           : ['he']
#
# tag : C
# doc : WILLI
# 	MASTER SGT #1/POLA NEGRI : ['WILLI']
#
# tag : D
# doc : Fine. Take that fucking traitor and get her out of my sight.
# 	BRIDGET VON HAMMERSMARK : ['that fucking traitor', 'her']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : Danka, Willi, danka. okay, Hirschbeg, you grab her shoulder -
# 	MASTER SGT #1/POLA NEGRI : ['Willi']
# 	Hirschberg           : ['Hirschbeg']
# 	BRIDGET VON HAMMERSMARK : ['her']
#
# tag : D
# doc : From behind Aldo and Hirschberg, Bridget lifts up Major Hellstroms Luger, and EMPTIES the remaining bullets into Sgt.Willi, who FALLS to the floor, DEAD. Aldo and Hirscberg spin around shocked.
# 	LT. ALDO RAINE       : ['Aldo', 'Aldo']
# 	Hirschberg           : ['Hirschberg', 'Hirscberg']
# 	BRIDGET VON HAMMERSMARK : ['Bridget']
# 	MAJOR HELLSTROM      : ['Major Hellstroms']
# 	MASTER SGT #1/POLA NEGRI : ['Sgt.Willi']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : You fuckin bitch! I had a deal with that man! From the floor, the bloody, sweaty, and in excoriating pain , German movie star, says to the two American soldier's she's just meeting for the first time;
# 	BRIDGET VON HAMMERSMARK : ['You fuckin bitch', 'German movie star', 'she']
# 	LT. ALDO RAINE       : ['I']
# 	MASTER SGT #1/POLA NEGRI : ['that man']
#
# tag : C
# doc : BRIDGET
# 	BRIDGET VON HAMMERSMARK : ['BRIDGET']
#
# tag : D
# doc : He was a enemy soldier, who knew who I was. He couldn't live.
# 	MASTER SGT #1/POLA NEGRI : ['He', 'He']
# 	BRIDGET VON HAMMERSMARK : ['I']
#
# tag : N
# doc : Hirscberg loses control, and RICKS the woman on the floor, hard in the side.
# 	Hirschberg           : ['Hirscberg']
# 	BRIDGET VON HAMMERSMARK : ['the woman']
#
# tag : C
# doc : HIRSCHBERG
# 	Hirschberg           : ['HIRSCHBERG']
#
# tag : D
# doc : I ought'a beat your fuckin head in
# 	Hirschberg           : ['I']
# 	BRIDGET VON HAMMERSMARK : ['your']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : Stop it. Just pick her up, and get that bitch outta here.
# 	BRIDGET VON HAMMERSMARK : ['her', 'that bitch']
#
# tag : C
# doc : HIRSCHBERG
# 	Hirschberg           : ['HIRSCHBERG']
#
# tag : D
# doc : Aldo, she just-
# 	LT. ALDO RAINE       : ['Aldo']
# 	BRIDGET VON HAMMERSMARK : ['she']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : - She's right.
# 	BRIDGET VON HAMMERSMARK : ['She']
#
# tag : C
# doc : HIRSCHBERG
# 	Hirschberg           : ['HIRSCHBERG']
#
# tag : C
# doc : ALDO
# 	LT. ALDO RAINE       : ['ALDO']
#
# tag : D
# doc : I said, she's right. He was a Nazi soldier. If he lived, he would doomed the mission.
# 	LT. ALDO RAINE       : ['I']
# 	BRIDGET VON HAMMERSMARK : ['she']
# 	MASTER SGT #1/POLA NEGRI : ['He', 'he', 'he']
#
# tag : N
# doc : ELI )Is,. ALDO (CON'T) Don't mean I like it, don't mean I like her, but she's right. Now as Willi said, "take this fuckin traitor, and get 'er outta my sight".
# 	LT. ALDO RAINE       : ['ALDO', 'I', 'I', 'my']
# 	BRIDGET VON HAMMERSMARK : ['her', 'she', 'this fuckin traitor', "'er"]
# 	MASTER SGT #1/POLA NEGRI : ['Willi']
#
# tag : N
# doc : Hirschberg, carrying Fraulein Von Hammersmark, and Aldo emerge from the bowels of the basement. Bridget points at a fancy black sedan, telling them it's her's. Aldo, Hirschberg, Bridget, Donowitz, and Utivich pile in, and take off.
# 	Hirschberg           : ['Hirschberg', 'Hirschberg']
# 	BRIDGET VON HAMMERSMARK : ['Fraulein Von Hammersmark', 'Bridget', "her's", 'Bridget']
# 	LT. ALDO RAINE       : ['Aldo', 'Aldo']
# 	Donowitz             : ['Donowitz']
# 	Utivich              : ['Utivich']

# %% [markdown]
# ## Load Coreference Model

# %%
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz")
# Out:
# Did not use initialization regex that was passed: _context_layer._module.weight_ih.*
# Did not use initialization regex that was passed: _context_layer._module.weight_hh.*

# %%
predictor.cuda_device
# Out:
# -1

# %% [markdown]
# ## Test Coreference Model

# %%
text = "We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz..."

# %%
coref_result = predictor.predict(document=text)

# %%
coref_result.keys()
# Out:
# dict_keys(['top_spans', 'antecedent_indices', 'predicted_antecedents', 'document', 'clusters'])

# %%
coref_result["document"]
# Out:
# ['We',
#  'wait',
#  '.',
#  'Do',
#  "n't",
#  'worry',
#  ',',
#  'she',
#  "'s",
#  'a',
#  'British',
#  'spy',
#  ',',
#  'she',
#  "'ll",
#  'make',
#  'the',
#  'rendez',
#  '-',
#  'vous',
#  '.',
#  'WE',
#  'SEE',
#  'the',
#  'other',
#  'Basterds',
#  ',',
#  'dressed',
#  'in',
#  'French',
#  'civilian',
#  'clothes',
#  ',',
#  'are',
#  'in',
#  'the',
#  'room',
#  'as',
#  'well',
#  ',',
#  'they',
#  'are',
#  ',',
#  'Donowitz',
#  ',',
#  'Hirschberg',
#  ',',
#  'and',
#  'Utivich',
#  '.',
#  'And',
#  'in',
#  'the',
#  'back',
#  'of',
#  'the',
#  'room',
#  ',',
#  'dressed',
#  'in',
#  'the',
#  'grey',
#  'uniform',
#  'of',
#  'a',
#  'S.S.',
#  'Lieutenant',
#  ',',
#  'Hugo',
#  'Stiglitz',
#  'sits',
#  'off',
#  'by',
#  'himself',
#  ',',
#  'sharpening',
#  'his',
#  'S.S.',
#  'DAGGER',
#  'on',
#  'his',
#  'leather',
#  'belt',
#  'looped',
#  'around',
#  'his',
#  'boot',
#  '.',
#  'Anybody',
#  'not',
#  'in',
#  'the',
#  'scene',
#  'from',
#  'the',
#  'Basterds',
#  'opening',
#  'chapter',
#  ',',
#  'is',
#  'dead',
#  '.',
#  'Lt',
#  '.',
#  'Hicox',
#  'watches',
#  'Stiglitz',
#  'off',
#  'by',
#  'himself',
#  'on',
#  'the',
#  'other',
#  'side',
#  'of',
#  'the',
#  'room',
#  ',',
#  'SHARPENS',
#  'his',
#  'dagger',
#  'menacingly',
#  '.',
#  '.Stiglitz',
#  'is',
#  'fucking',
#  'werid',
#  '...',
#  'Lt',
#  '.',
#  'Hicox',
#  'approaches',
#  'Stiglitz',
#  '...']

# %%
coref_result["clusters"]
# Out:
# [[[7, 7], [13, 13]],
#  [[0, 0], [21, 21]],
#  [[23, 31], [40, 40]],
#  [[35, 36], [55, 56], [115, 116]],
#  [[68, 69],
#   [73, 73],
#   [76, 76],
#   [80, 80],
#   [85, 85],
#   [109, 109],
#   [119, 119],
#   [123, 123],
#   [132, 132]],
#  [[76, 86], [119, 120]],
#  [[102, 104], [128, 130]]]

# %%
document = coref_result["document"]

for cluster in coref_result["clusters"]:
    mentions = []
    for i, j in cluster:
        mention = " ".join(document[i: j + 1])
        mentions.append(mention)
    print(mentions)
# Out:
# ['she', 'she']
# ['We', 'WE']
# ['the other Basterds , dressed in French civilian clothes', 'they']
# ['the room', 'the room', 'the room']
# ['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'himself', 'his', '.Stiglitz', 'Stiglitz']
# ['his S.S. DAGGER on his leather belt looped around his boot', 'his dagger']
# ['Lt . Hicox', 'Lt . Hicox']

# %%
coref_results = predictor.predict_batch_json([{"document":text}, {"document":text}])

# %%
len(coref_results)
# Out:
# 2

# %%
coref_results[0] == coref_results[1]
# Out:
# True

# %%
coref_result == coref_results[0]
# Out:
# True

# %%
long_text = "We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz..."

short_text = "A"

# %%
coref_results = predictor.predict_batch_json(inputs=[{"document": long_text}, {"document": short_text}])

# %%
coref_results[0] == coref_results[1]
# Out:
# False

# %%
coref_results[1]["clusters"]
# Out:
# []

# %% [markdown]
# ## Word Piece tokenization

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %%
tokenizer.tokenize("I have a new GPU!")
# Out:
# ['i', 'have', 'a', 'new', 'gp', '##u', '!']

# %%
cased_tokenizer = BertTokenizer.from_pretrained("bert-base-cased")

# %%
cased_tokens = cased_tokenizer.tokenize("We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz...")

# %%
cased_tokens
# Out:
# ['We',
#  'wait',
#  '.',
#  'Don',
#  "'",
#  't',
#  'worry',
#  ',',
#  'she',
#  "'",
#  's',
#  'a',
#  'British',
#  'spy',
#  ',',
#  'she',
#  "'",
#  'll',
#  'make',
#  'the',
#  're',
#  '##nde',
#  '##z',
#  '-',
#  'v',
#  '##ous',
#  '.',
#  'W',
#  '##E',
#  'SE',
#  '##E',
#  'the',
#  'other',
#  'Ba',
#  '##ster',
#  '##ds',
#  ',',
#  'dressed',
#  'in',
#  'French',
#  'civilian',
#  'clothes',
#  ',',
#  'are',
#  'in',
#  'the',
#  'room',
#  'as',
#  'well',
#  ',',
#  'they',
#  'are',
#  ',',
#  'Don',
#  '##ow',
#  '##itz',
#  ',',
#  'Hi',
#  '##rsch',
#  '##berg',
#  ',',
#  'and',
#  'U',
#  '##ti',
#  '##vich',
#  '.',
#  'And',
#  'in',
#  'the',
#  'back',
#  'of',
#  'the',
#  'room',
#  ',',
#  'dressed',
#  'in',
#  'the',
#  'grey',
#  'uniform',
#  'of',
#  'a',
#  'S',
#  '.',
#  'S',
#  '.',
#  'Lieutenant',
#  ',',
#  'Hugo',
#  'St',
#  '##ig',
#  '##litz',
#  'sits',
#  'off',
#  'by',
#  'himself',
#  ',',
#  'sharp',
#  '##ening',
#  'his',
#  'S',
#  '.',
#  'S',
#  '.',
#  'D',
#  '##AG',
#  '##GE',
#  '##R',
#  'on',
#  'his',
#  'leather',
#  'belt',
#  'loop',
#  '##ed',
#  'around',
#  'his',
#  'boot',
#  '.',
#  'Any',
#  '##body',
#  'not',
#  'in',
#  'the',
#  'scene',
#  'from',
#  'the',
#  'Ba',
#  '##ster',
#  '##ds',
#  'opening',
#  'chapter',
#  ',',
#  'is',
#  'dead',
#  '.',
#  'Lt',
#  '.',
#  'Hi',
#  '##co',
#  '##x',
#  'watches',
#  'St',
#  '##ig',
#  '##litz',
#  'off',
#  'by',
#  'himself',
#  'on',
#  'the',
#  'other',
#  'side',
#  'of',
#  'the',
#  'room',
#  ',',
#  'SH',
#  '##AR',
#  '##P',
#  '##EN',
#  '##S',
#  'his',
#  'dagger',
#  'menacing',
#  '##ly',
#  '.',
#  '.',
#  'St',
#  '##ig',
#  '##litz',
#  'is',
#  'fucking',
#  'we',
#  '##rid',
#  '.',
#  '.',
#  '.',
#  'Lt',
#  '.',
#  'Hi',
#  '##co',
#  '##x',
#  'approaches',
#  'St',
#  '##ig',
#  '##litz',
#  '.',
#  '.',
#  '.']

# %%
len(cased_tokens), len(coref_result["document"])
# Out:
# (187, 134)

# %%
predictor.__dict__
# Out:
# {'_model': CoreferenceResolver(
#    (_text_field_embedder): BasicTextFieldEmbedder(
#      (token_embedder_tokens): PretrainedTransformerMismatchedEmbedder(
#        (_matched_embedder): PretrainedTransformerEmbedder(
#          (transformer_model): BertModel(
#            (embeddings): BertEmbeddings(
#              (word_embeddings): Embedding(28996, 1024, padding_idx=0)
#              (position_embeddings): Embedding(512, 1024)
#              (token_type_embeddings): Embedding(2, 1024)
#              (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#              (dropout): Dropout(p=0.1, inplace=False)
#            )
#            (encoder): BertEncoder(
#              (layer): ModuleList(
#                (0): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (1): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (2): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (3): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (4): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (5): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (6): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (7): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (8): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (9): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (10): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (11): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (12): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (13): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (14): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (15): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (16): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (17): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (18): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (19): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (20): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (21): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (22): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#                (23): BertLayer(
#                  (attention): BertAttention(
#                    (self): BertSelfAttention(
#                      (query): Linear(in_features=1024, out_features=1024, bias=True)
#                      (key): Linear(in_features=1024, out_features=1024, bias=True)
#                      (value): Linear(in_features=1024, out_features=1024, bias=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                    (output): BertSelfOutput(
#                      (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                      (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                      (dropout): Dropout(p=0.1, inplace=False)
#                    )
#                  )
#                  (intermediate): BertIntermediate(
#                    (dense): Linear(in_features=1024, out_features=4096, bias=True)
#                  )
#                  (output): BertOutput(
#                    (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                    (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                    (dropout): Dropout(p=0.1, inplace=False)
#                  )
#                )
#              )
#            )
#            (pooler): BertPooler(
#              (dense): Linear(in_features=1024, out_features=1024, bias=True)
#              (activation): Tanh()
#            )
#          )
#        )
#      )
#    )
#    (_context_layer): PassThroughEncoder()
#    (_mention_feedforward): TimeDistributed(
#      (_module): FeedForward(
#        (_activations): ModuleList(
#          (0): ReLU()
#          (1): ReLU()
#        )
#        (_linear_layers): ModuleList(
#          (0): Linear(in_features=3092, out_features=1500, bias=True)
#          (1): Linear(in_features=1500, out_features=1500, bias=True)
#        )
#        (_dropout): ModuleList(
#          (0): Dropout(p=0.3, inplace=False)
#          (1): Dropout(p=0.3, inplace=False)
#        )
#      )
#    )
#    (_mention_scorer): TimeDistributed(
#      (_module): Linear(in_features=1500, out_features=1, bias=True)
#    )
#    (_antecedent_feedforward): TimeDistributed(
#      (_module): FeedForward(
#        (_activations): ModuleList(
#          (0): ReLU()
#          (1): ReLU()
#        )
#        (_linear_layers): ModuleList(
#          (0): Linear(in_features=9296, out_features=1500, bias=True)
#          (1): Linear(in_features=1500, out_features=1500, bias=True)
#        )
#        (_dropout): ModuleList(
#          (0): Dropout(p=0.3, inplace=False)
#          (1): Dropout(p=0.3, inplace=False)
#        )
#      )
#    )
#    (_antecedent_scorer): TimeDistributed(
#      (_module): Linear(in_features=1500, out_features=1, bias=True)
#    )
#    (_endpoint_span_extractor): EndpointSpanExtractor(
#      (_span_width_embedding): Embedding()
#    )
#    (_attentive_span_extractor): SelfAttentiveSpanExtractor(
#      (_global_attention): TimeDistributed(
#        (_module): Linear(in_features=1024, out_features=1, bias=True)
#      )
#    )
#    (_distance_embedding): Embedding()
#    (_coarse2fine_scorer): Linear(in_features=3092, out_features=3092, bias=True)
#    (_span_updating_gated_sum): GatedSum(
#      (_gate): Linear(in_features=6184, out_features=1, bias=True)
#      (_activation): Sigmoid()
#    )
#    (_lexical_dropout): Dropout(p=0.2, inplace=False)
#  ),
#  '_dataset_reader': <allennlp_models.coref.dataset_readers.conll.ConllCorefReader at 0x7f1d4f8e3240>,
#  'cuda_device': -1,
#  '_spacy': <spacy.lang.en.English at 0x7f1c8f8e9160>}

# %%
pretrained_transformer_tokenizer = PretrainedTransformerTokenizer("bert-base-cased")
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=433.0), HTML(value='')))

# %%
pretrained_transformer_tokenizer.tokenize("We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz...")
# Out:
# [[CLS],
#  We,
#  wait,
#  .,
#  Don,
#  ',
#  t,
#  worry,
#  ,,
#  she,
#  ',
#  s,
#  a,
#  British,
#  spy,
#  ,,
#  she,
#  ',
#  ll,
#  make,
#  the,
#  re,
#  ##nde,
#  ##z,
#  -,
#  v,
#  ##ous,
#  .,
#  W,
#  ##E,
#  SE,
#  ##E,
#  the,
#  other,
#  Ba,
#  ##ster,
#  ##ds,
#  ,,
#  dressed,
#  in,
#  French,
#  civilian,
#  clothes,
#  ,,
#  are,
#  in,
#  the,
#  room,
#  as,
#  well,
#  ,,
#  they,
#  are,
#  ,,
#  Don,
#  ##ow,
#  ##itz,
#  ,,
#  Hi,
#  ##rsch,
#  ##berg,
#  ,,
#  and,
#  U,
#  ##ti,
#  ##vich,
#  .,
#  And,
#  in,
#  the,
#  back,
#  of,
#  the,
#  room,
#  ,,
#  dressed,
#  in,
#  the,
#  grey,
#  uniform,
#  of,
#  a,
#  S,
#  .,
#  S,
#  .,
#  Lieutenant,
#  ,,
#  Hugo,
#  St,
#  ##ig,
#  ##litz,
#  sits,
#  off,
#  by,
#  himself,
#  ,,
#  sharp,
#  ##ening,
#  his,
#  S,
#  .,
#  S,
#  .,
#  D,
#  ##AG,
#  ##GE,
#  ##R,
#  on,
#  his,
#  leather,
#  belt,
#  loop,
#  ##ed,
#  around,
#  his,
#  boot,
#  .,
#  Any,
#  ##body,
#  not,
#  in,
#  the,
#  scene,
#  from,
#  the,
#  Ba,
#  ##ster,
#  ##ds,
#  opening,
#  chapter,
#  ,,
#  is,
#  dead,
#  .,
#  Lt,
#  .,
#  Hi,
#  ##co,
#  ##x,
#  watches,
#  St,
#  ##ig,
#  ##litz,
#  off,
#  by,
#  himself,
#  on,
#  the,
#  other,
#  side,
#  of,
#  the,
#  room,
#  ,,
#  SH,
#  ##AR,
#  ##P,
#  ##EN,
#  ##S,
#  his,
#  dagger,
#  menacing,
#  ##ly,
#  .,
#  .,
#  St,
#  ##ig,
#  ##litz,
#  is,
#  fucking,
#  we,
#  ##rid,
#  .,
#  .,
#  .,
#  Lt,
#  .,
#  Hi,
#  ##co,
#  ##x,
#  approaches,
#  St,
#  ##ig,
#  ##litz,
#  .,
#  .,
#  .,
#  [SEP]]

# %%
# %%debug
# predictor.predict("We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz...")
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(2)<module>()
# ipdb>  c

# %%
len([token for token in cased_tokens if not token.startswith("##")])
# Out:
# 148

# %%
merged_cased_tokens = []

for cased_token in cased_tokens:
    if cased_token.startswith("##"):
        merged_cased_tokens[-1] += cased_token
    else:
        merged_cased_tokens.append(cased_token)

# %%
len(merged_cased_tokens), len(coref_result["document"])
# Out:
# (148, 134)

# %%
n = min(len(merged_cased_tokens), len(coref_result["document"]))
for i in range(n):
    print(f"{coref_result['document'][i]:20s} {merged_cased_tokens[i]:20s}")
if n < len(coref_result["document"]):
    for token in coref_result["document"][n:]:
        print(f"{token:20s}")
if n < len(merged_cased_tokens):
    for token in merged_cased_tokens[n:]:
        print(f"{'':20s} {token:20s}")
# Out:
# We                   We
# wait                 wait
# .                    .
# Do                   Don
# n't                  '
# worry                t
# ,                    worry
# she                  ,
# 's                   she
# a                    '
# British              s
# spy                  a
# ,                    British
# she                  spy
# 'll                  ,
# make                 she
# the                  '
# rendez               ll
# -                    make
# vous                 the
# .                    re##nde##z
# WE                   -
# SEE                  v##ous
# the                  .
# other                W##E
# Basterds             SE##E
# ,                    the
# dressed              other
# in                   Ba##ster##ds
# French               ,
# civilian             dressed
# clothes              in
# ,                    French
# are                  civilian
# in                   clothes
# the                  ,
# room                 are
# as                   in
# well                 the
# ,                    room
# they                 as
# are                  well
# ,                    ,
# Donowitz             they
# ,                    are
# Hirschberg           ,
# ,                    Don##ow##itz
# and                  ,
# Utivich              Hi##rsch##berg
# .                    ,
# And                  and
# in                   U##ti##vich
# the                  .
# back                 And
# of                   in
# the                  the
# room                 back
# ,                    of
# dressed              the
# in                   room
# the                  ,
# grey                 dressed
# uniform              in
# of                   the
# a                    grey
# S.S.                 uniform
# Lieutenant           of
# ,                    a
# Hugo                 S
# Stiglitz             .
# sits                 S
# off                  .
# by                   Lieutenant
# himself              ,
# ,                    Hugo
# sharpening           St##ig##litz
# his                  sits
# S.S.                 off
# DAGGER               by
# on                   himself
# his                  ,
# leather              sharp##ening
# belt                 his
# looped               S
# around               .
# his                  S
# boot                 .
# .                    D##AG##GE##R
# Anybody              on
# not                  his
# in                   leather
# the                  belt
# scene                loop##ed
# from                 around
# the                  his
# Basterds             boot
# opening              .
# chapter              Any##body
# ,                    not
# is                   in
# dead                 the
# .                    scene
# Lt                   from
# .                    the
# Hicox                Ba##ster##ds
# watches              opening
# Stiglitz             chapter
# off                  ,
# by                   is
# himself              dead
# on                   .
# the                  Lt
# other                .
# side                 Hi##co##x
# of                   watches
# the                  St##ig##litz
# room                 off
# ,                    by
# SHARPENS             himself
# his                  on
# dagger               the
# menacingly           other
# .                    side
# .Stiglitz            of
# is                   the
# fucking              room
# werid                ,
# ...                  SH##AR##P##EN##S
# Lt                   his
# .                    dagger
# Hicox                menacing##ly
# approaches           .
# Stiglitz             .
# ...                  St##ig##litz
#                      is
#                      fucking
#                      we##rid
#                      .
#                      .
#                      .
#                      Lt
#                      .
#                      Hi##co##x
#                      approaches
#                      St##ig##litz
#                      .
#                      .
#                      .

# %%
spacy_nlp = spacy.load("en_core_web_sm")

# %%
doc = spacy_nlp("We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz...")

# %%
len(doc)
# Out:
# 134

# %%
spacy_nlp

# %%
_doc = predictor._spacy("We wait. Don't worry, she's a British spy, she'll make the rendez-vous. WE SEE the other Basterds, dressed in French civilian clothes, are in the room as well, they are, Donowitz, Hirschberg, and Utivich. And in the back of the room, dressed in the grey uniform of a S.S. Lieutenant, Hugo Stiglitz sits off by himself, sharpening his S.S. DAGGER on his leather belt looped around his boot. Anybody not in the scene from the Basterds opening chapter, is dead. Lt.Hicox watches Stiglitz off by himself on the other side of the room, SHARPENS his dagger menacingly. .Stiglitz is fucking werid... Lt.Hicox approaches Stiglitz...")

# %%
len(_doc)
# Out:
# 134

# %% [markdown]
# ## Evaluation Metrics

# %%
element_corefs = []
element_spacy_docs = []

for element in tqdm(elements):
    try:
        result = predictor.predict(document=element)
        doc = predictor._spacy(element)
        element_corefs.append(result)
        element_spacy_docs.append(doc)
    except Exception:
        element_corefs.append(None)
        element_spacy_docs.append(None)
# Out:
# 100%|██████████| 591/591 [02:07<00:00,  4.64it/s]

# %%
n_element_corefs = sum([coref is not None for coref in element_corefs])
n_equal_tokens = sum([coref is not None and len(coref["document"]) == len(doc) for coref, doc in zip(element_corefs, element_spacy_docs)])
n_element_corefs, n_equal_tokens
# Out:
# (331, 331)

# %%
spacy_nlp.path
# Out:
# PosixPath('/home/sbaruah/.pyenv/versions/allennlp/lib/python3.6/site-packages/en_core_web_sm/en_core_web_sm-2.2.5')

# %%
predictor._spacy.path
# Out:
# PosixPath('/home/sbaruah/.pyenv/versions/allennlp/lib/python3.6/site-packages/en_core_web_sm/en_core_web_sm-2.2.5')

# %%
key = [{'a','b','c'}, {'d','e','f','g'}]
response = [{'a','b'}, {'c','d'}, {'f','h','i'}]

# %%
key1 = key + [{'g'}]
print(scores.muc(key, response))
print(scores.b_cubed(key, response))
print(scores.ceaf_e(key, response))
# Out:
# (0.2, 0.25, 0.2222222222222222)
# (0.3095238095238095, 0.4761904761904762, 0.3751803751803751)
# (0.5666666666666667, 0.37777777777777777, 0.45333333333333337)

# %%
print(scores.muc(key1, response))
print(scores.b_cubed(key1, response))
print(scores.ceaf_e(key1, response))
, this was definitely, not the plan. LT.HICOX Shit. Sgt.Donowitz chides him; SGT.DONOWITZ So what do you think your fraulein Von Hammer - LT.HICOX - Obviously, I don't know,Sgt. The British officer watches the German soldier, who's not suppose to be there. When Hugo Stiglitz joins him at the window. Stiglitz looks down at the urinating Nazi, S.S. dagger in hand. STIGLITZ If we're going, let's go. He sheaths the dagger. EXT - LA LOUISIANE (BASEMENT TAVERN) - NIGHT The GERMAN PISSING PRIVATE, sloppily finishes his task. Craming his noodle back in his pants, he descends the stairs that lead him back into the b ...

# %%
joined_coref = predictor.predict(document=joined_element_text)
# Out:
# /pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.

# %%
len(joined_coref["clusters"])
# Out:
# 180

# %%
script = open("data/annotation/basterds.script.txt").read()

# %%
script_coref = predictor.predict(document=script)

# %% [markdown]
# ## Check Spacy token offsets

# %%
text = "I am going to submit my paper to ACL."
doc = spacy_nlp(text)

for token in doc:
    print(token.text, token.i, text[token.idx: token.idx + len(token)])
# Out:
# I 0 I
# am 1 am
# going 2 going
# to 3 to
# submit 4 submit
# my 5 my
# paper 6 paper
# to 7 to
# ACL 8 ACL
# . 9 .

# %%
x = True

# %%
x |= False and False

# %%
x
# Out:
# True

# %% [markdown]
# ## Find Spacy tokenized gold clusters

# %%
element_spacy_docs = [spacy_nlp(element) for element in tqdm(elements)]
# Out:
# 100%|██████████| 591/591 [00:04<00:00, 129.46it/s]

# %%
parsed_coref_df = coref_df[coref_df.pbegin.notna() & (coref_df.pbegin_ind == coref_df.pend_ind) & (coref_df.mention == coref_df.parsed_mention)].astype({"pbegin_ind": int, "pbegin_pos": int, "pend_pos": int})
tj_col, tk_col = [], []

for _, row in parsed_coref_df.iterrows():
    i, j, k = row.pbegin_ind, row.pbegin_pos, row.pend_pos
    element_spacy_doc = element_spacy_docs[i]
    tj, tk = np.nan, np.nan
    for token in element_spacy_doc:
        if token.idx == j:
            tj = token.i
        if token.idx + len(token) == k + 1:
            tk = token.i
    tj_col.append(tj)
    tk_col.append(tk)

# %%
parsed_coref_df["tj"] = tj_col
parsed_coref_df["tk"] = tk_col

# %%
parsed_coref_df[(parsed_coref_df.tj.isna() | parsed_coref_df.tk.isna())]
# Out:
#      begin    end  begin_segment  end_segment  begin_line  end_line  \
# 33    1883   1891            NaN          NaN          -1        -1
# 217  11443  11466            NaN          NaN          -1        -1
# 378  18553  18557            NaN          NaN          -1        -1
# 640  31335  31336            NaN          NaN          -1        -1
# 665  32362  32367            NaN          NaN          -1        -1
# 767  37295  37309            NaN          NaN          -1        -1
# 867  41266  41268            NaN          NaN          -1        -1
#
#                          leftContext                  surface  \
# 33   le in, and\n          take off.                 Stiglitz
# 217  le in, and\n          take off.  Bridget Von Hammersmark
# 378  le in, and\n          take off.                     your
# 640  le in, and\n          take off.                        I
# 665  le in, and\n          take off.                    Major
# 767  le in, and\n          take off.           The German Sgt
# 867  le in, and\n          take off.                       ya
#
#                        rightContext  entityNum  ...   pbegin  pbegin_ind  \
# 33             EXT - LA LOUISIANE (         21  ...   1387.0          19
# 217            EXT - LA LOUISIANE (          1  ...   8192.0         129
# 378            EXT - LA LOUISIANE (          6  ...  13439.0         190
# 640            EXT - LA LOUISIANE (          1  ...  22249.0         358
# 665            EXT - LA LOUISIANE (          0  ...  22956.0         372
# 767            EXT - LA LOUISIANE (          6  ...  26360.0         435
# 867            EXT - LA LOUISIANE (          6  ...  28876.0         525
#
#      pbegin_pos     pend  pend_ind  pend_pos           parsed_mention  \
# 33          564   1394.0      19.0       571                 Stiglitz
# 217           1   8214.0     129.0        23  Bridget Von Hammersmark
# 378          24  13442.0     190.0        27                     your
# 640           4  22249.0     358.0         4                        I
# 665           7  22960.0     372.0        11                    Major
# 767         257  26373.0     435.0       270           The German Sgt
# 867         242  28877.0     525.0       243                       ya
#
#                      mention   tj     tk
# 33                  Stiglitz  NaN  123.0
# 217  Bridget Von Hammersmark  NaN    2.0
# 378                     your  NaN    6.0
# 640                        I  1.0    NaN
# 665                    Major  NaN    2.0
# 767           The German Sgt  NaN   56.0
# 867                       ya  NaN   62.0
#
# [7 rows x 26 columns]

# %%
index = 867
row = parsed_coref_df.loc[index]
i, j, k = row.pbegin_ind, row.pbegin_pos, row.pend_pos

print(elements[i][:j] + "<<" + elements[i][j:k + 1] + ">>" + elements[i][k + 1:])
for token in element_spacy_docs[i]:
    print("[" + token.text + "]", end=" ")
# Out:
# Okay, Willi here's my deal! You let me and one of my men come down to take the girl away! And we take the girl, and leave! That simple, Willi! You go your way, we go ours! And little Max, gets to grow up playing catch with his daddy! So what'<<ya>> say, Willi, we got a deal? Willi thinks... Bridget watches Willi think...
# [Okay] [,] [Willi] [here] ['s] [my] [deal] [!] [You] [let] [me] [and] [one] [of] [my] [men] [come] [down] [to] [take] [the] [girl] [away] [!] [And] [we] [take] [the] [girl] [,] [and] [leave] [!] [That] [simple] [,] [Willi] [!] [You] [go] [your] [way] [,] [we] [go] [ours] [!] [And] [little] [Max] [,] [gets] [to] [grow] [up] [playing] [catch] [with] [his] [daddy] [!] [So] [what'ya] [say] [,] [Willi] [,] [we] [got] [a] [deal] [?] [Willi] [thinks] [...] [Bridget] [watches] [Willi] [think] [...]

# %%
joined_element = "\n\n".join(elements)

# %%
joined_element_spacy_doc = spacy_nlp(joined_element)

# %%
n = sum(len(doc) for doc in element_spacy_docs) + len(element_spacy_docs) - 1
m = len(joined_element_spacy_doc)
print(n, m)
# Out:
# 7828 7828

# %%
n = 0
for i in range(len(elements)):
    partial_joined_element = "\n\n".join(elements[:i + 1])
    partial_joined_element_spacy_doc = spacy_nlp(partial_joined_element)
    m = len(partial_joined_element_spacy_doc)
    n += len(element_spacy_docs[i]) + (i > 0)
    print(i, n, m)
    if n != m:
        print("Element Tokens -")
        for j in range(i + 1):
            print(f"{j:3d}. ", end="")
            for token in element_spacy_docs[j]:
                print(f"[{token.text}] ", end="")
            print()
        print("\nJoined Tokens -")
        for token in partial_joined_element_spacy_doc:
# 166 2690 2690
# 167 2726 2726
# 168 2728 2728
# 169 2742 2742
# 170 2745 2745
# 171 2769 2769
# 172 2771 2771
# 173 2777 2777
# 174 2780 2780
# 175 2844 2844
# 176 2846 2846
# 177 2904 2904
# 178 2906 2906
# 179 2915 2915
# 180 2918 2918
# 181 2970 2970
# 182 2973 2973
# 183 3047 3047
# 184 3050 3050
# 185 3063 3063
# 186 3086 3086
# 187 3088 3088
# 188 3138 3138
# 189 3140 3140
# 190 3183 3183
# 191 3186 3186
# 192 3208 3208
# 193 3211 3211
# 194 3236 3236
# 195 3238 3238
# 196 3270 3270
# 197 3278 3278
# 198 3282 3282
# 199 3289 3289
# 200 3318 3318
# 201 3328 3328
# 202 3343 3343
# 203 3346 3346
# 204 3353 3353
# 205 3361 3361
# 206 3405 3405
# 207 3407 3407
# 208 3410 3410
# 209 3449 3449
# 210 3451 3451
# 211 3459 3459
# 212 3462 3462
# 213 3476 3476
# 214 3479 3479
# 215 3491 3491
# 216 3494 3494
# 217 3533 3533
# 218 3535 3535
# 219 3551 3551
# 220 3554 3554
# 221 3558 3558
# 222 3560 3560
# 223 3579 3579
# 224 3582 3582
# 225 3585 3585
# 226 3589 3589
# 227 3593 3593
# 228 3606 3606
# 229 3609 3609
# 230 3614 3614
# 231 3616 3616
# 232 3678 3678
# 233 3680 3680
# 234 3745 3745
# 235 3748 3748
# 236 3793 3793
# 237 3796 3796
# 238 3802 3802
# 239 3804 3804
# 240 3837 3837
# 241 3840 3840
# 242 3861 3861
# 243 3863 3863
# 244 3874 3874
# 245 3878 3878
# 246 3881 3881
# 247 3892 3892
# 248 3895 3895
# 249 3916 3916
# 250 3923 3923
# 251 3931 3931
# 252 3934 3934
# 253 3938 3938
# 254 3940 3940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-152-36ebf157698b> in <module>
#       2 for i in range(len(elements)):
#       3     partial_joined_element = "\n\n".join(elements[:i + 1])
# ----> 4     partial_joined_element_spacy_doc = spacy_nlp(partial_joined_element)
#       5     m = len(partial_joined_element_spacy_doc)
#       6     n += len(element_spacy_docs[i]) + (i > 0)
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     437             if not hasattr(proc, "__call__"):
#     438                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 439             doc = proc(doc, **component_cfg.get(name, {}))
#     440             if doc is None:
#     441                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      27
#      28     def begin_update(self, X, drop=0.0):
# ---> 29         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      30         if isinstance(X, list):
#      31             output = [X[i] + y[i] for i in range(len(X))]
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      60     def begin_update(self, X, drop=0.0):
#      61         if self.child is not None:
# ---> 62             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      63         else:
#      64             backprop_child = None
#
# ~/.pyenv/versions/allennlp/lib/python3.6/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
# ---> 79         best__bo, which__bo = self.ops.maxout(output__boc)
#      80         best__bo, bp_dropout = self.ops.dropout(best__bo, drop)
#      81
#
# KeyboardInterrupt:

# %%
len(element_spacy_docs[0])
# Out:
# 9

# %%
gold_entity_to_mentions = defaultdict(set)
mention_tags = []

for i in range(len(element_spacy_docs)):
    tag = tags[i]
    if i:
        mention_tags.append("X")
    mention_tags.extend([tag] * len(element_spacy_docs[i]))
    
len_element_spacy_docs = [len(doc) for doc in element_spacy_docs]
    
for _, row in parsed_coref_df.iterrows():
    i, tj, tk = row.pbegin_ind, row.tj, row.tk
    if pd.notna(tj) and pd.notna(tk):
        tj, tk = int(tj), int(tk)
        label = row.entityLabel
        offset = sum(len_element_spacy_docs[:i]) + i
        gold_entity_to_mentions[label].add((offset + tj, offset + tk))

# %%
len(mention_tags)
# Out:
# 7828

# %%
gold_entity_to_mentions
# Out:
# defaultdict(list,
#             {'READER': [[10, 10],
#               [227, 227],
#               [949, 949],
#               [1047, 1047],
#               [1564, 1564],
#               [1567, 1567],
#               [2541, 2541],
#               [3381, 3381],
#               [4431, 4431],
#               [5352, 5352],
#               [5490, 5490],
#               [6224, 6224],
#               [6262, 6262],
#               [6523, 6523]],
#              'LT. HICOX': [[50, 50],
#               [62, 62],
#               [97, 97],
#               [113, 113],
#               [115, 115],
#               [123, 123],
#               [132, 132],
#               [148, 148],
#               [204, 204],
#               [308, 310],
#               [334, 336],
#               [341, 341],
#               [354, 354],
#               [374, 374],
#               [394, 394],
#               [428, 428],
#               [437, 437],
#               [463, 465],
#               [476, 476],
#               [479, 479],
#               [491, 491],
#               [506, 506],
#               [518, 521],
#               [543, 543],
#               [553, 553],
#               [561, 561],
#               [597, 597],
#               [674, 674],
#               [692, 692],
#               [733, 733],
#               [759, 759],
#               [802, 804],
#               [815, 815],
#               [823, 823],
#               [831, 831],
#               [833, 833],
#               [839, 839],
#               [844, 844],
#               [851, 853],
#               [871, 871],
#               [1573, 1573],
#               [1665, 1665],
#               [1924, 1924],
#               [2036, 2037],
#               [2105, 2105],
#               [2107, 2107],
#               [2202, 2202],
#               [2313, 2313],
#               [2455, 2455],
#               [2463, 2463],
#               [2466, 2466],
#               [2548, 2548],
#               [2550, 2550],
#               [2592, 2592],
#               [2597, 2597],
#               [3080, 3082],
#               [3087, 3087],
#               [3122, 3122],
#               [3139, 3139],
#               [3142, 3142],
#               [3158, 3158],
#               [3180, 3181],
#               [3189, 3189],
#               [3192, 3192],
#               [3214, 3214],
#               [3434, 3434],
#               [3440, 3440],
#               [3443, 3443],
#               [3492, 3492],
#               [3499, 3499],
#               [3524, 3526],
#               [3530, 3530],
#               [3534, 3534],
#               [3536, 3536],
#               [3559, 3559],
#               [3590, 3592],
#               [3597, 3597],
#               [3615, 3615],
#               [3621, 3621],
#               [3623, 3623],
#               [3626, 3626],
#               [3630, 3630],
#               [3634, 3634],
#               [3664, 3664],
#               [3694, 3696],
#               [3701, 3701],
#               [3711, 3711],
#               [3718, 3718],
#               [3725, 3725],
#               [3820, 3822],
#               [3847, 3847],
#               [3856, 3856],
#               [3859, 3859],
#               [3862, 3862],
#               [3901, 3901],
#               [3913, 3913],
#               [3939, 3939],
#               [3971, 3971],
#               [3982, 3982],
#               [3997, 3997],
#               [4003, 4003],
#               [4018, 4019],
#               [4140, 4140],
#               [4143, 4143],
#               [4183, 4185],
#               [4981, 4981],
#               [4985, 4985],
#               [5022, 5022],
#               [5038, 5038],
#               [5184, 5184],
#               [5231, 5231],
#               [5264, 5266],
#               [5283, 5283],
#               [5366, 5366],
#               [5380, 5380],
#               [5388, 5388],
#               [5398, 5398],
#               [5406, 5406],
#               [5410, 5410],
#               [5413, 5413],
#               [5415, 5415],
#               [5424, 5424],
#               [5445, 5445],
#               [5453, 5453],
#               [5455, 5455],
#               [5464, 5464],
#               [5576, 5579],
#               [5624, 5624],
#               [5768, 5770],
#               [5773, 5773],
#               [5792, 5792],
#               [5806, 5806],
#               [5813, 5813],
#               [5829, 5829],
#               [5831, 5836],
#               [5848, 5848],
#               [5854, 5854],
#               [5874, 5874],
#               [5883, 5883],
#               [5889, 5889],
#               [5899, 5899],
#               [5910, 5910],
#               [5917, 5917],
#               [5960, 5960],
#               [5986, 5986],
#               [6003, 6004],
#               [6029, 6029]],
#              'LT. ALDO RAINE': [[52, 53],
#               [54, 54],
#               [95, 95],
#               [121, 121],
#               [140, 140],
#               [510, 510],
#               [514, 514],
#               [526, 526],
#               [539, 539],
#               [546, 546],
#               [566, 566],
#               [569, 569],
#               [710, 710],
#               [6317, 6318],
#               [6326, 6327],
#               [6348, 6348],
#               [6352, 6353],
#               [6380, 6381],
#               [6445, 6446],
#               [6474, 6475],
#               [6502, 6503],
#               [6599, 6600],
#               [6634, 6635],
#               [6659, 6660],
#               [6674, 6674],
#               [6681, 6682],
#               [6727, 6728],
#               [6789, 6790],
#               [6812, 6812],
#               [6816, 6817],
#               [6825, 6825],
#               [6838, 6839],
#               [6901, 6902],
#               [6910, 6910],
#               [6913, 6913],
#               [6915, 6915],
#               [6919, 6919],
#               [6990, 6990],
#               [6993, 6994],
#               [6997, 6997],
#               [7011, 7011],
#               [7017, 7018],
#               [7038, 7039],
#               [7150, 7150],
#               [7157, 7157],
#               [7165, 7165],
#               [7186, 7186],
#               [7188, 7188],
#               [7197, 7197],
#               [7208, 7208],
#               [7232, 7232],
#               [7262, 7262],
#               [7277, 7277],
#               [7339, 7339],
#               [7343, 7343],
#               [7349, 7349],
#               [7362, 7362],
#               [7367, 7367],
#               [7385, 7385],
#               [7421, 7421],
#               [7423, 7423],
#               [7428, 7428],
#               [7495, 7495],
#               [7518, 7518],
#               [7547, 7547],
#               [7555, 7555],
#               [7561, 7561],
#               [7659, 7659],
#               [7679, 7679],
#               [7684, 7684],
#               [7697, 7697],
#               [7699, 7699],
#               [7728, 7728],
#               [7735, 7735],
#               [7742, 7742],
#               [7767, 7767],
#               [7787, 7787],
#               [7811, 7811]],
#              'WILHELM WICKI': [[171, 172],
#               [187, 187],
#               [1575, 1575],
#               [1926, 1926],
#               [2156, 2156],
#               [2214, 2214],
#               [3237, 3237],
#               [3445, 3445],
#               [3450, 3450],
#               [3825, 3825],
#               [4600, 4600],
#               [4604, 4604],
#               [4665, 4665],
#               [6046, 6046],
#               [6049, 6049],
#               [6104, 6104],
#               [6158, 6158]],
#              'BRIDGET VON HAMMERSMARK': [[197, 197],
#               [213, 213],
#               [219, 219],
#               [638, 641],
#               [656, 658],
#               [676, 676],
#               [696, 696],
#               [703, 703],
#               [735, 735],
#               [744, 744],
#               [1234, 1236],
#               [1240, 1240],
#               [1246, 1246],
#               [1439, 1441],
#               [1613, 1615],
#               [1626, 1626],
#               [1637, 1637],
#               [1641, 1641],
#               [1644, 1644],
#               [1651, 1651],
#               [1658, 1658],
#               [1670, 1672],
#               [1675, 1675],
#               [1679, 1679],
#               [1733, 1735],
#               [1738, 1738],
#               [1750, 1752],
#               [1755, 1755],
#               [1761, 1761],
#               [1763, 1763],
#               [1775, 1775],
#               [1781, 1781],
#               [1800, 1800],
#               [1806, 1806],
#               [1818, 1818],
#               [1847, 1847],
#               [1955, 1955],
#               [1960, 1960],
#               [1966, 1966],
#               [1981, 1981],
#               [1986, 1986],
#               [1993, 1993],
#               [2008, 2008],
#               [2020, 2020],
#               [2066, 2067],
#               [2121, 2121],
#               [2163, 2163],
#               [2178, 2178],
#               [2204, 2204],
#               [2229, 2230],
#               [2297, 2297],
#               [2318, 2318],
#               [2393, 2394],
#               [2528, 2530],
#               [2544, 2544],
#               [2569, 2571],
#               [2574, 2574],
#               [2608, 2608],
#               [2617, 2619],
#               [2627, 2627],
#               [2639, 2639],
#               [2641, 2641],
#               [2715, 2715],
#               [2723, 2723],
#               [2727, 2727],
#               [2751, 2751],
#               [2833, 2833],
#               [2836, 2836],
#               [2845, 2845],
#               [2854, 2854],
#               [2860, 2860],
#               [2863, 2863],
#               [2878, 2878],
#               [2905, 2905],
#               [2920, 2920],
#               [2921, 2921],
#               [2924, 2924],
#               [2931, 2931],
#               [2945, 2945],
#               [2953, 2953],
#               [2996, 2997],
#               [3053, 3055],
#               [3059, 3059],
#               [3105, 3106],
#               [3163, 3164],
#               [3651, 3653],
#               [3673, 3673],
#               [3675, 3675],
#               [3679, 3679],
#               [3684, 3684],
#               [3689, 3689],
#               [3788, 3791],
#               [3803, 3803],
#               [3989, 3990],
#               [3998, 3999],
#               [4016, 4016],
#               [4021, 4021],
#               [4028, 4028],
#               [4080, 4080],
#               [4082, 4082],
#               [4166, 4166],
#               [4198, 4198],
#               [4202, 4202],
#               [4232, 4232],
#               [4582, 4582],
#               [4618, 4618],
#               [5061, 5061],
#               [5068, 5068],
#               [5151, 5152],
#               [5254, 5254],
#               [5258, 5258],
#               [5431, 5431],
#               [5443, 5443],
#               [5503, 5504],
#               [5514, 5514],
#               [5690, 5690],
#               [5695, 5695],
#               [5719, 5719],
#               [5721, 5721],
#               [5732, 5732],
#               [5737, 5737],
#               [5743, 5743],
#               [5745, 5745],
#               [5757, 5757],
#               [5994, 5994],
#               [6037, 6037],
#               [6534, 6535],
#               [6538, 6538],
#               [6566, 6566],
#               [6573, 6575],
#               [6588, 6590],
#               [6614, 6614],
#               [6623, 6623],
#               [6650, 6651],
#               [6677, 6678],
#               [6687, 6687],
#               [6699, 6699],
#               [6711, 6711],
#               [6732, 6732],
#               [6742, 6742],
#               [6749, 6749],
#               [6753, 6753],
#               [6759, 6759],
#               [6765, 6765],
#               [6876, 6876],
#               [6881, 6881],
#               [6925, 6926],
#               [6980, 6980],
#               [7034, 7035],
#               [7078, 7078],
#               [7087, 7087],
#               [7226, 7227],
#               [7329, 7331],
#               [7483, 7485],
#               [7488, 7488],
#               [7509, 7509],
#               [7522, 7522],
#               [7557, 7559],
#               [7583, 7585],
#               [7594, 7594],
#               [7611, 7611],
#               [7622, 7622],
#               [7637, 7638],
#               [7654, 7654],
#               [7666, 7666],
#               [7671, 7672],
#               [7681, 7681],
#               [7687, 7687],
#               [7702, 7702],
#               [7744, 7744],
#               [7747, 7747],
#               [7764, 7765],
#               [7782, 7784],
#               [7796, 7796],
#               [7808, 7809],
#               [7815, 7815]],
#              'Donowitz': [[249, 249],
#               [652, 652],
#               [682, 682],
#               [819, 821],
#               [826, 826],
#               [849, 850],
#               [7817, 7817]],
#              'Hirschberg': [[251, 251],
#               [757, 757],
#               [761, 761],
#               [768, 768],
#               [7167, 7167],
#               [7380, 7380],
#               [7383, 7383],
#               [7432, 7432],
#               [7505, 7505],
#               [7520, 7520],
#               [7549, 7549],
#               [7631, 7631],
#               [7649, 7649],
#               [7651, 7651],
#               [7677, 7677],
#               [7692, 7692],
#               [7779, 7779],
#               [7813, 7813]],
#              'Utivich': [[254, 254], [7820, 7820]],
#              'STIGLITZ': [[274, 275],
#               [279, 279],
#               [282, 282],
#               [286, 286],
#               [291, 291],
#               [312, 312],
#               [315, 315],
#               [325, 325],
#               [338, 338],
#               [343, 343],
#               [348, 348],
#               [356, 356],
#               [378, 378],
#               [388, 388],
#               [396, 396],
#               [449, 452],
#               [455, 455],
#               [468, 468],
#               [470, 470],
#               [484, 484],
#               [493, 493],
#               [497, 497],
#               [499, 499],
#               [503, 503],
#               [523, 528],
#               [537, 537],
#               [868, 869],
#               [876, 876],
#               [890, 890],
#               [901, 901],
#               [1578, 1578],
#               [1928, 1928],
#               [2386, 2387],
#               [2399, 2399],
#               [2409, 2409],
#               [2759, 2762],
#               [2770, 2770],
#               [2784, 2784],
#               [3260, 3260],
#               [3271, 3271],
#               [3477, 3477],
#               [3481, 3481],
#               [3484, 3486],
#               [4420, 4420],
#               [4445, 4445],
#               [4458, 4458],
#               [4469, 4469],
#               [5479, 5479],
#               [5529, 5529],
#               [5536, 5536],
#               [5543, 5543],
#               [5546, 5546],
#               [5962, 5962],
#               [5965, 5965],
#               [5976, 5976],
#               [6011, 6011],
#               [6121, 6121]],
#              'NAZI PRIVATE': [[771, 772],
#               [796, 796],
#               [855, 857],
#               [880, 882],
#               [918, 921],
#               [925, 925],
#               [929, 929],
#               [933, 933],
#               [936, 936],
#               [942, 942],
#               [951, 951],
#               [1047, 1049]],
#              'MASTER SGT #1/POLA NEGRI': [[1060, 1063],
#               [1346, 1347],
#               [1835, 1836],
#               [1851, 1853],
#               [2140, 2140],
#               [2144, 2144],
#               [2147, 2147],
#               [2510, 2514],
#               [2517, 2517],
#               [2521, 2521],
#               [2556, 2559],
#               [2563, 2563],
#               [2600, 2603],
#               [2614, 2615],
#               [2621, 2621],
#               [2632, 2632],
#               [2645, 2645],
#               [2647, 2650],
#               [2664, 2665],
#               [2667, 2670],
#               [2673, 2673],
#               [2679, 2679],
#               [2688, 2689],
#               [2697, 2697],
#               [2699, 2699],
#               [2730, 2730],
#               [2743, 2744],
#               [2746, 2746],
#               [2765, 2767],
#               [2775, 2775],
#               [2778, 2779],
#               [2796, 2796],
#               [2805, 2805],
#               [2817, 2817],
#               [2820, 2820],
#               [2848, 2848],
#               [2900, 2902],
#               [2916, 2917],
#               [2939, 2939],
#               [2971, 2972],
#               [2974, 2974],
#               [3011, 3013],
#               [3018, 3018],
#               [3022, 3022],
#               [3026, 3026],
#               [3033, 3033],
#               [3041, 3041],
#               [3044, 3044],
#               [3048, 3049],
#               [3091, 3091],
#               [3094, 3094],
#               [3096, 3096],
#               [3102, 3102],
#               [3109, 3109],
#               [3115, 3115],
#               [3119, 3119],
#               [3144, 3144],
#               [3145, 3146],
#               [3160, 3160],
#               [3168, 3168],
#               [3171, 3175],
#               [3184, 3185],
#               [3188, 3188],
#               [3209, 3210],
#               [3239, 3240],
#               [3242, 3242],
#               [3293, 3293],
#               [3305, 3305],
#               [3338, 3340],
#               [3412, 3416],
#               [3429, 3429],
#               [3515, 3517],
#               [3742, 3743],
#               [3749, 3749],
#               [3752, 3752],
#               [3756, 3758],
#               [6107, 6108],
#               [6174, 6175],
#               [6287, 6290],
#               [6301, 6302],
#               [6336, 6336],
#               [6341, 6342],
#               [6344, 6344],
#               [6356, 6356],
#               [6368, 6369],
#               [6371, 6371],
#               [6391, 6392],
#               [6394, 6394],
#               [6399, 6399],
#               [6438, 6438],
#               [6456, 6456],
#               [6461, 6461],
#               [6468, 6469],
#               [6488, 6488],
#               [6495, 6495],
#               [6507, 6507],
#               [6519, 6519],
#               [6542, 6542],
#               [6577, 6579],
#               [6595, 6595],
#               [6610, 6610],
#               [6626, 6626],
#               [6638, 6638],
#               [6647, 6647],
#               [6669, 6669],
#               [6695, 6695],
#               [6706, 6706],
#               [6738, 6738],
#               [6794, 6794],
#               [6798, 6798],
#               [6808, 6808],
#               [6822, 6822],
#               [6827, 6827],
#               [6833, 6833],
#               [6843, 6843],
#               [6845, 6845],
#               [6862, 6862],
#               [6872, 6872],
#               [6878, 6878],
#               [6895, 6895],
#               [6907, 6907],
#               [6941, 6941],
#               [6943, 6943],
#               [6945, 6945],
#               [6963, 6964],
#               [6970, 6970],
#               [6977, 6977],
#               [6982, 6982],
#               [6988, 6988],
#               [7000, 7000],
#               [7005, 7005],
#               [7007, 7007],
#               [7023, 7023],
#               [7029, 7029],
#               [7031, 7031],
#               [7045, 7045],
#               [7054, 7054],
#               [7060, 7060],
#               [7085, 7085],
#               [7097, 7097],
#               [7108, 7108],
#               [7132, 7132],
#               [7142, 7142],
#               [7147, 7147],
#               [7152, 7152],
#               [7177, 7177],
#               [7179, 7179],
#               [7200, 7200],
#               [7216, 7216],
#               [7238, 7238],
#               [7260, 7260],
#               [7266, 7266],
#               [7279, 7279],
#               [7285, 7285],
#               [7307, 7307],
#               [7325, 7325],
#               [7360, 7360],
#               [7400, 7400],
#               [7409, 7409],
#               [7425, 7425],
#               [7446, 7446],
#               [7455, 7455],
#               [7464, 7464],
#               [7467, 7467],
#               [7478, 7478],
#               [7499, 7499],
#               [7535, 7537],
#               [7566, 7567],
#               [7613, 7613],
#               [7625, 7625],
#               [7706, 7706],
#               [7713, 7713],
#               [7716, 7716],
#               [7753, 7753]],
#              'FEMALE SGT #2/BEETHOVEN': [[1203, 1207],
#               [1328, 1331],
#               [1893, 1893],
#               [6118, 6119]],
#              'GERMAN PRIVATE #3/MATA HARI': [[1209, 1214],
#               [1747, 1748],
#               [1791, 1792],
#               [1876, 1877],
#               [1879, 1879],
#               [1882, 1882],
#               [1887, 1888],
#               [6160, 6161]],
#              'GERMAN PRIVATE #4/EDGAR WALLACE': [[1216, 1223],
#               [1337, 1338],
#               [1351, 1351],
#               [1363, 1364],
#               [1902, 1903],
#               [1904, 1904],
#               [1910, 1910],
#               [3286, 3286],
#               [6094, 6095]],
#              'GERMAN PRIVATE #5/WINNETOU': [[1255, 1258],
#               [1307, 1307],
#               [1311, 1311],
#               [1317, 1317],
#               [1334, 1334],
#               [1359, 1359],
#               [1368, 1368],
#               [1375, 1375],
#               [1383, 1383],
#               [1388, 1388],
#               [1396, 1396],
#               [1406, 1406],
#               [1413, 1413],
#               [1417, 1417],
#               [1429, 1429],
#               [1492, 1492],
#               [1495, 1495],
#               [1503, 1503],
#               [1515, 1515],
#               [1530, 1530],
#               [1533, 1533],
#               [1546, 1546],
#               [1552, 1552],
#               [1687, 1687],
#               [1693, 1693],
#               [1697, 1702],
#               [1710, 1712],
#               [1715, 1715],
#               [1720, 1720],
#               [2256, 2256],
#               [3275, 3275],
#               [3283, 3283],
#               [3295, 3295],
#               [6078, 6078],
#               [6087, 6087]],
#              "Tavern's Proprietor": [[2071, 2071]],
#              'Barmaid': [[2223, 2225],
#               [2239, 2239],
#               [2243, 2243],
#               [2250, 2250],
#               [2270, 2271],
#               [2275, 2275],
#               [3827, 3829],
#               [6097, 6099]],
#              'The Fubrer': [[2378, 2379], [2695, 2695], [2711, 2711]],
#              'Goebbels': [[2485, 2485], [2497, 2497], [3985, 3985]],
#              'Leni': [[2489, 2489], [2584, 2585]],
#              'MAXIMILIAN': [[2632, 2633],
#               [2635, 2635],
#               [2738, 2739],
#               [2753, 2753],
#               [2787, 2787],
#               [2799, 2799],
#               [2912, 2913],
#               [2926, 2926],
#               [2936, 2936],
#               [2942, 2942],
#               [2948, 2948],
#               [2960, 2960],
#               [3308, 3309],
#               [6411, 6411],
#               [6963, 6963],
#               [7135, 7135]],
#              'MAJOR HELLSTROM': [[3347, 3349],
#               [3354, 3355],
#               [3358, 3358],
#               [3370, 3372],
#               [3386, 3391],
#               [3393, 3394],
#               [3400, 3400],
#               [3408, 3409],
#               [3418, 3418],
#               [3431, 3431],
#               [3452, 3452],
#               [3460, 3461],
#               [3463, 3463],
#               [3495, 3495],
#               [3500, 3500],
#               [3508, 3510],
#               [3552, 3553],
#               [3573, 3573],
#               [3580, 3581],
#               [3595, 3595],
#               [3599, 3599],
#               [3607, 3608],
#               [3611, 3611],
#               [3681, 3681],
#               [3735, 3737],
#               [3746, 3747],
#               [3774, 3775],
#               [3794, 3795],
#               [3798, 3798],
#               [3809, 3809],
#               [3811, 3813],
#               [3832, 3833],
#               [3838, 3839],
#               [3879, 3880],
#               [3893, 3894],
#               [3896, 3896],
#               [3909, 3909],
#               [3924, 3924],
#               [3932, 3933],
#               [3962, 3963],
#               [3994, 3995],
#               [4035, 4035],
#               [4056, 4057],
#               [4066, 4066],
#               [4114, 4115],
#               [4117, 4117],
#               [4133, 4133],
#               [4210, 4211],
#               [4215, 4216],
#               [4238, 4239],
#               [4281, 4281],
#               [4283, 4283],
#               [4366, 4366],
#               [4377, 4378],
#               [4398, 4399],
#               [4413, 4413],
#               [4423, 4423],
#               [4488, 4489],
#               [4498, 4499],
#               [4560, 4561],
#               [4563, 4563],
#               [4574, 4574],
#               [4587, 4588],
#               [4590, 4590],
#               [4610, 4610],
#               [4626, 4626],
#               [4634, 4635],
#               [4640, 4640],
#               [4655, 4656],
#               [4669, 4669],
#               [4672, 4673],
#               [4677, 4677],
#               [4703, 4704],
#               [4722, 4722],
#               [4727, 4727],
#               [4737, 4737],
#               [4747, 4747],
#               [4752, 4753],
#               [4771, 4771],
#               [4781, 4781],
#               [4791, 4791],
#               [4798, 4798],
#               [4803, 4803],
#               [4809, 4809],
#               [4823, 4823],
#               [4833, 4833],
#               [4843, 4844],
#               [4847, 4847],
#               [4858, 4859],
#               [4869, 4869],
#               [4877, 4878],
#               [4881, 4881],
#               [4887, 4887],
#               [4897, 4898],
#               [4901, 4901],
#               [4919, 4920],
#               [4924, 4924],
#               [4930, 4930],
#               [4940, 4940],
#               [4943, 4944],
#               [4948, 4948],
#               [4971, 4972],
#               [4983, 4983],
#               [5020, 5020],
#               [5026, 5026],
#               [5031, 5032],
#               [5034, 5034],
#               [5047, 5047],
#               [5053, 5053],
#               [5064, 5064],
#               [5074, 5074],
#               [5077, 5078],
#               [5080, 5080],
#               [5095, 5095],
#               [5114, 5115],
#               [5119, 5120],
#               [5122, 5122],
#               [5129, 5129],
#               [5134, 5135],
#               [5138, 5138],
#               [5146, 5146],
#               [5186, 5186],
#               [5193, 5194],
#               [5237, 5238],
#               [5241, 5241],
#               [5243, 5243],
#               [5251, 5251],
#               [5305, 5306],
#               [5309, 5309],
#               [5317, 5318],
#               [5341, 5343],
#               [5346, 5346],
#               [5362, 5363],
#               [5375, 5375],
#               [5392, 5392],
#               [5402, 5403],
#               [5434, 5434],
#               [5437, 5438],
#               [5471, 5471],
#               [5474, 5474],
#               [5509, 5512],
#               [5558, 5559],
#               [5587, 5587],
#               [5590, 5590],
#               [5605, 5606],
#               [5615, 5615],
#               [5621, 5621],
#               [5626, 5626],
#               [5655, 5656],
#               [5693, 5693],
#               [5697, 5697],
#               [5708, 5708],
#               [5715, 5716],
#               [5803, 5804],
#               [5808, 5808],
#               [5820, 5821],
#               [5844, 5846],
#               [5907, 5907],
#               [5943, 5943],
#               [5948, 5949],
#               [5972, 5972],
#               [5979, 5980],
#               [5991, 5991],
#               [5999, 5999],
#               [6022, 6022]],
#              'Eric': [[4288, 4288],
#               [5155, 5155],
#               [5196, 5196],
#               [5224, 5224],
#               [5274, 5274],
#               [5288, 5288]]})

# %%
for entity, mention_spans in gold_entity_to_mentions.items():
    print(entity)
    for j, k in mention_spans:
        mention = " ".join(token.text for token in joined_element_spacy_doc[j: k + 1])
        print(f"\t{mention}")
# Out:
# READER
# 	We
# 	WE
# 	We
# 	our
# 	WE
# 	our
# 	We
# 	our
# 	we
# 	WE
# 	We
# 	WE
# 	we
# 	We
# LT. HICOX
# 	LT.HICOX
# 	Hicox
# 	You
# 	LT.HICOX
# 	I
# 	You
# 	LT.HICOX
# 	You
# 	LT.HICOX
# 	Lt . Hicox
# 	Lt . Hicox
# 	LT.NICOX
# 	sir
# 	LT.HICOX
# 	LT.HICOX
# 	I
# 	I
# 	the limy Lieutenant
#   (6982, 6982),
#   (7000, 7000),
#   (7023, 7023),
#   (7031, 7031),
#   (7045, 7045),
#   (7054, 7054),
#   (7060, 7060),
#   (7085, 7085),
#   (7097, 7097),
#   (7108, 7108),
#   (7132, 7132),
#   (7142, 7142),
#   (7152, 7152),
#   (7177, 7177),
#   (7179, 7179),
#   (7200, 7200),
#   (7216, 7216),
#   (7238, 7238),
#   (7260, 7260),
#   (7325, 7325),
#   (7360, 7360),
#   (7409, 7409),
#   (7446, 7446),
#   (7464, 7464),
#   (7467, 7467),
#   (7478, 7478),
#   (7491, 7491),
#   (7499, 7499),
#   (7753, 7753),
#   (7767, 7767)],
#  [(251, 251),
#   (7167, 7167),
#   (7380, 7380),
#   (7383, 7383),
#   (7432, 7432),
#   (7505, 7505),
#   (7507, 7507),
#   (7549, 7549),
#   (7573, 7585),
#   (7631, 7631),
#   (7649, 7649),
#   (7654, 7654),
#   (7677, 7677),
#   (7692, 7692),
#   (7779, 7779),
#   (7813, 7813)]]

# %%
print(scores.muc(gold_entity_to_mentions.values(), speaker_sys_clusters))
print(scores.ceaf_e(gold_entity_to_mentions.values(), speaker_sys_clusters))
print(scores.b_cubed(gold_entity_to_mentions.values(), speaker_sys_clusters))
# Out:
# (0.617678381256656, 0.7571801566579635, 0.6803519061583577)
# (0.33197184664509966, 0.20093032823256032, 0.2503394253389276)
# (0.1977557284619311, 0.4460696352675774, 0.274027183881338)

# %%
scores.conll2012(gold_entity_to_mentions.values(), speaker_sys_clusters)
# Out:
# 0.4015728384595411

# %%
i = 0

speaker_sys_cluster = speaker_sys_clusters[i]
speaker_sys_cluster = sorted(speaker_sys_cluster)

i = 0
for j, k in speaker_sys_cluster:
    for l in range(i, j):
        print(joined_element_spacy_doc[l].text, end=" ")
    print("<<", end="")
    for l in range(j, k):
        print(joined_element_spacy_doc[l], end = " ")
    print(joined_element_spacy_doc[k], end=">> ")
    i = k + 1
# Out:
# EXT - LA LOUISIANE ( TAVERN ) - NIGHT
#
#  We see a small basement tavern , with a old rustic sign out front that reads , " La Louisiane " .
#
#  A SUBTITLE APPEARS :
#
#  " The Village of
#
#  NADINE , FRANCE "
#
#  TWO SHOT <<LT.HICOX>> and LT.ALDO RAINE Aldo is dressed like a French civilian . <<Hicox>> is dressed in a German grey S.S. Cap't uniform . They look out of a window , in a apartment , in the village of Nadine , overlooking the tavern .
#
#  LT.ALDO
#
#  You did n't say the goddamn rendez - vous was in a fuckin basement .
#
#  <<LT.HICOX>>
#
#  <<I>> did n't know .
#
#  LT.ALDO
#
#  You said it was in a tavern ?
#
#  <<LT.HICOX>>
#
#  it is a tavern .
#
#  LT.ALDO
#
#  Yeah , in a basement . You know , fightin in a basement offers a lot of difficulties , number one being , your fighting in a basement . Wilhelm Wicki , joins the SHOT , dressed in a German S.S. Lieutenant uniform .
#
#  WICKI
#
#  What if we go in there , and she 's not even there ?
#
#  <<LT.HICOX>>
#
#  We wait . Do n't worry , she 's a British spy , she 'll make the rendez - vous . WE SEE the other Basterds , dressed in French civilian clothes , are in the room as well , they are , Donowitz , Hirschberg , and Utivich . And in the back of the room , dressed in the grey uniform of a S.S. Lieutenant , Hugo Stiglitz sits off by himself , sharpening his S.S. DAGGER on his leather belt looped around his boot . Anybody not in the scene from the Basterds opening chapter , is dead . <<Lt . Hicox>> watches Stiglitz off by himself on the other side of the room , SHARPENS <<his>> dagger menacingly . .Stiglitz is fucking werid ... <<Lt . Hicox>> approaches Stiglitz ...
#
#  LT.NICOX
#
#  Stiglitz , right ?
#
#  STIGLITZ
#
#  That 's right , <<sir>> . <<He>> continues bringing the blades edge , up , then , down on the leather strap .
#
#  LT.HICOX
#
#  <<I>> hear <<your>> pretty good with that ? Meaning the blade . Stiglitz does n't answer .
#
#  <<LT.HICOX>>
#
#  You know , we 're not looking for trouble , right now . We 're simply making contact with our agent . Should be uneventful . However , on the off chance <<I>> 'm wrong , and things prove eventful . <<I>> need to know , we can all remain calm .
#
#  The renegade Gerry Sergeant , stops his blades progress , and looks up at <<the limy Lieutenant>> .
#
#  STIGLITZ
#
#  I do n't look calm to you ?
#
#  <<LT.HICOX>>
#
#  Well , now you put it like that ,
#
#  <<I>> guess you do .
#
#  He turns his attention back to his blade . <<Hicox>> moves over to Aldo , and asks him privately ;
#
#  LT . HI COX
#
#  This Gerry of yours , Stiglitz ? Not exactly the loquacious type , is he ? Aldo just looks at him .
#
#  LT.ALDO
#
#  Is that the kinds man you need , the loquacious type ?
#
#  <<LT.HICOX>>
#
#  Fair point , <<Lieutenant>> .
#
#  LT.ALDO
#
#  So y' all git in trouble in there , what are we suppose to do ? Make bets on how it all comes out ?
#
#  <<LT.HICOX>>
#
#  If we get into trouble , we can handle it . But if trouble does happen , we need you to make damn sure no Germans , or French , for matter , escape from that basement . If Frau Von Hammersmark 's cover is compromised , the mission is kaput .
#
#  SGT.DONOWITZ
#
#  Speaking of Frau Von Hammersmark , who 's idea was it for the death trap redez - vous ?
#
#  <<LT.HICOX>>
#
#  She chose the spot .
#
#  SGT.DONOWITZ
#
#  Well is n't that just dandy ?
#
#  <<LT.HICOX>>
#
#  Look , she 's not a military strategist . She 's just a actress .
#
#  LT.ALDO
#
#  Ya do n't got to be Stonewall Jackson to know you do n't want to fight in a basement .
#
#  LT.HICOX
#
#  She was n't picking a place to fight . She was picking a place , isolated , and without germans .
#
#  PFC.HIRSCHBERG
#
#  <<Lieutenant>> , I hate to be contrary , but I got me a Nazi pissin on Louisianna two - o'clock . They move to the window , and sure enough , ONE LONE NAZI PRIVATE , relieves himself against the side wall . Lt . Bicox , this was definitely , not the plan .
#
#  LT.HICOX
#
#  Shit . Sgt . Donowitz chides him ;
#
#  SGT.DONOWITZ
#
#  So what do you think your fraulein Von Hammer -
#
#  LT.HICOX
#
#  - Obviously , I do n't know , Sgt . The British officer watches the German soldier , who 's not suppose to be there . When Hugo Stiglitz joins him at the window . Stiglitz looks down at the urinating Nazi , S.S. dagger in hand .
#
#  STIGLITZ
#
#  If we 're going , let 's go . He sheaths the dagger .
#
#  EXT - LA LOUISIANE ( BASEMENT TAVERN ) - NIGHT
#
#  The GERMAN PISSING PRIVATE , sloppily finishes his task . Craming his noodle back in his pants , he descends the stairs that lead him back into the basement tavern . We Follow him ...
#
#  INT - LA LOUISIANE ( BASEMENT TAVERN)- NIGHT
#
#  .Inside the basement tavern , La Louisiane . it has a very low hanging basement ceiling . A old looking wood bar off to the right . And the only other space in the little tavern , is taken up by two large(at least in here ) tables , which take up both half 's of the room . And despite rumors to the contrary , one of the two tables , is completely filled with drunken celebrating Nazi enlisted men , of which our urinating friend is one of five .
#
#  FIVE NAZI 'S
#
#  ONE GERMAN MASTER SGT , ONE FEMALE GERMAN SGT , and THREE MALE GERMAN PRIVATES . The Five Nazi 's are sitting around the table , drinking , and playing a very fun game with none other then the fraulein of the hour , UFA diva , BRIDGET VON HAMMERSMARK . Dressed to the nines in a chic Forties style women 's suit , complete with fedora . The game their playing consists of each player having a card with the name of a famous person , real or imaginary , stuck to their forehead . The player does n't know what name is on their forehead . So they ask the others questions to figure out who they are . The Five Germans , five cards read ; MASTER SGT # 1 ,
#
#  a powerfully built stocky type POLA NEGRI
#
#  FEMALE SGT # 2(BEETHOVEN ) , GERMAN PRIVATE # 3(MATA HARI ) , GERMAN PRIVATE # 4 ( EDGAR WALLACE ) , GERMAN PRIVATE # 5 ( WINNETOU ) . And Bridget Von Hammersmark , who wears her card in the brim of her fedora , has GENGHIS KHAN . It 's German#5 ( WINNETOU ) turn to ask questions . The DIALOGUE will be in GERMAN , and SUBTITLED into ENGLISH . Also , while some dialogue will be written for the German Soldiers , it will be mostly made up from the exuberance of their game playing , and celebrating .
#
#  WINNETOU
#
#  .okay , I 'm not German . Am I American ? The whole table bursts out laughing .
#
#  FEMALE SGT / BEETHOVEN
#
#  Yes you arel
#
#  EDGAR WALLACE
#
#  Well , not really .
#
#  SGT.POLA NEGRI
#
#  What do you mean , not really ? Of course he is .
#
#  EDGAR WALLACE
#
#  Well if he 's so American , how come he 's never been translated into English ? He 's not American . He 's suppose to be American , but he 's not a American creation . In fact , he 's something very different .
#
#  WINNETOU
#
#  Okay , I 'm a fictional , literary character , from the past , I 'm American , and that 's controversial .
#
#  BRIDGET / GENGUS
#
#  No it 's not controversial . The nationally of the author , has nothing to do with the nationally of the character . The Character is the character . Hamlet 's not British , he 's Danish . So yes , this character was born in America .
#
#  WINNETOU
#
#  Well I 'm glad that 's settled . If I had a wife , would she be called a squaw ? He 's got it . The table Laughs . The TABLE
#
#  YES !
#
#  WINNETOU
#
#  Is <<my>> bloodbrother , Old Shatterhand ?
#
#  The TABLE
#
#  Yes !
#
#  WINNETOU
#
#  Did Karl May write me ?
#
#  The TABLE
#
#  Yes ! In the BACKGROUND , WE SEE , our three counterfeit German Officers , Hicox , Wicki , and Stiglitz , enter the basement tavern . They obviously . see the five German soldiers , but their too far away for us to read their face . No doubt their less then happy . Fraulein Von Hammersmark see 's them as well . Without getting up , she waves to them .
#
#  the audience
#
#  QZ
#
#  BRIDGET
#
#  Hello , my lovelies , I will join you in moments . I 'm finishing up a game with my five new friends here .
#
#  LT.HICOX
#
#  No hurry , Frau Von Hammersmark . Take your time , enjoy yourself .
#
#  BRIDGET
#
#  So who are you ?
#
#  To Winnetou
#
#  WINNETOU
#
#  I am WINNETOU , CHIEF of the APACHES ! The table CHEERS , and APPLAUD the Apache Chief , as he takes the card off his forehead . The other Four German Soldiers drink down there beer . Bridget Von Hammersmark knock backs her champagne .
#
#  part of the game
#
#  MATA HARI
#
#  Frau Von Hammersmark , when your friends came in , did you realize you did a double take , like in the movies ?
#
#  BRIDGET
#
#  Really ? No , I was n't aware of that at all .
#
#  MATA HARI
#
#  They must be second nature to you now ? Did they teach you how to do a double take in the movies ?
#
#  BRIDGET
#
#  Well , yes they did , but it 's not really that difficult .
#
#  SGT.POLA NEGRI
#
#  Do one for us . The Tableheartily agrees . Bridget looks directly at the Master Sgt , and does a perfect , and perfectly funny , Double Take . The Table loves it .
#
#  q3 .
#
#  MATA HARI
#
#  My turn , I want to try . Mata Hari , looks directly at Beethoven , and does a Double Take .
#
#  EDGER WALLACE I want to try .
#
#  He does . Soon the whole Table is doing dueling Double Takes .
#
#  HICOX - WICKI - STIGLITZ watch the table do dueling Double Takes . Obviously , they do n't understand .
#
#  THEN ...
#
#  .Bridget Von Hammersmark rises , and excuses herself from the Table . She removes the card stuck in her fedora , looking at the name Gengus Khaun for the first time .
#
#  BRIDGET
#
#  Gengus Khaun ! I would never of gotten that . She walks over , and joins the masquerading Germans table , the Gentlemen rise . She greets each warmly with a french cheek kiss , as if she knows them well . They all take a seat . The two Basterds , and one Brit , drink Whiskey . The taverns PROPRIETOR , a older , big bellyed Frenchman named EARL , comes over to the table , and pours more champagne into Bridget 's Champagne glass . He leaves , returning back behind the bar , with the YOUNG FRENCH BARMAID , the only other person in the establishment . Obviously , they speak GERMAN , SUBTITLED into ENGLISH ;
#
#  LT.HICOX
#
#  I thought this place was suppose to have more French then Germans ?
#
#  BRIDGET
#
#  Normally that 's true . The Sgt over there 's wife , just had a baby . His commanding officer gave him , and his mates the night off to celebrate .
#
#  WICXI
#
#  We should leave .
#
#  BRIDGET
#
#  F No , we should stay . For one drink at least . I 've been waiting for you in a bar , it would look strange if we left before we had a drink .
#
#  LT.HICOX
#
#  She 's right , just be calm , and enjoy your booze .
#
#  BACK TO THE GERMAN TABLE The French Barmaid , has taken Bridget 's place in the rousing , rowdy game . She tells them , her person must be French , or she wo n't know them . Winnetou thinks for a moment , then writes a name on a card . The Barmaid puts it on her forehead , It says ;
#
#  NAPOLEON .
#
#  The Germans all laugh .
#
#  BACK TO THE BASTERDS TABLE
#
#  BRIDGET
#
#  There 's been some new developments . The cinema venue has changed .
#
#  LT.HICOX
#
#  Why ?
#
#  BRIDGET
#
#  No one knows . But that in itself should n't be a problem . The cinema it 's been changed to is considerably smaller then The Ritz . So whatever materials you brought for The Ritz , should be doubly effective here . Now this next piece of information is colossal , try not to over react . The Fubrer , will be attending tomorrow . Hugo Stiglitz does a SPIT TAKE . Bridget 's eyes bore holes in him .
#
#  BACK TO THE REAL GERMANS They see Hugo do the spit take , and burst out laughing . Keeping it up , they begin to do dueling spit takes , like they did dueling double takes earlier . Needless to say , they all get wet . BACK TO BASTERDS
#  SGT.POLA NEGRI
#
#  Excuse <<me>> Cap't , but your accent is is very unusual . The whole room pauses - for different reasons ...
#
#  SGT.POLA NEGRI
#
#  Where are you from ? A silent moment passes between the two tables , then the two German born impostors spring into action .
#
#  WICKI
#
#  Sgt . ! You must be ether drunk or mad , to speak to a superior officer with such impertinentness ! Stiglitz , STANDS and YELLS to the other table ;
#
#  STIGLITZ <<I>> 'm making YOU , ...
#
#  ( Pointing at
#
#  WINNETOU ) .and YOU , ..
#
#  .responsible , for him . <<I>> suggest you take hold of your friend , or he 'll spend Max 's first birthday in jail for public drunkenness !
#
#  Pointing at Edgar Wallace Pointing at Sgt . Pola
#
#  The Germans SPRING UP , and take hold of Sgt . Pola ... 1W
#
#  WHEN ...
#
#  A GERMAN VOICE rings out ;
#
#  GERMAN VOICE Then might <<I>> inquire ?
#
#  The Five known Germans move aside , reveling the unknown German in the room , unseen till now , our old friend from before MAJOR DEITER HELLSTROM of the GESTAPO . The Major stands from the little table he was sitting at .
#
#  OS
#
#  MAJOR HELLSTROM
#
#  Like the young newly christened father , <<I>> too have a acute ear for accents . And like him , <<I>> too find yours odd . From where do you hail , Cap't ? Wicki jumps in ;
#
#  WICKI
#
#  Major , this is highly inappr -
#
#  MAJOR HELLSTROM
#
#  T was n't speaking to you Lt . Saltzberg , ( Turning to
#
#  STIGLITZ )
#
#  or you ether , Lt . Berlin . ( Looking at
#
#  <<HICOX>> )
#
#  <<I>> was speaking to Cap't <<I>> -- don't - know - what . The Gestapo Major is now standing beside Sgt . Pola , before the impostors table . <<Lt . Hicox>> , calmly explains his origin .
#
#  LT.HICOX
#
#  I was born in the village that rests in the shadow of Piz Palu .
#
#  MAJOR HELLSTROM
#
#  The mountain ?
#
#  LT.HICOX
#
#  Yes . In that village we all speak like this . Have you seen the Riefenstahl film ?
#
#  MAJOR HELLSTROM
#
#  Yes .
#
#  f q s
#
#  LT . HICOX
#
#  Then you saw <<me>> . You remember the skiing torch scene ?
#
#  MAJOR HELLSTROM
#
#  Yes I do .
#
#  LT.HICOX
#
#  In that scene was <<myself>> , <<my>> father , <<my>> sister , and <<my>> two brothers . <<My>> brother is so handsome , the director Pabst , gave him a Close Up . As Bridget Von Hammersmark places a cigarette in a ivory cigarette holder , which <<Hicox>> , as if on cue , lights for her , she says ;
#
#  BRIDGET
#
#  Major , if my word means anything , I can vouch for everything the Young Cap't has just said . He does hail from the bottom of Piz Palu , he was in the film , and his brother is far more handsome then he . The impostors laugh . Then .... so does the Gestapo Major . He turns to the Sgt .
#
#  MAJOR HELLSTROM
#
#  You should rejoin your friends . Which the young Sgt is more then happy to do . That table begins playing there game again . Major Hellstrom , the highest ranking officer in the room , bows graciously to the female German celebrity .
#
#  MAJOR HELLSTROM
#
#  May <<I>> join you ?
#
#  BRIDGET
#
#  By all means , Major . The Gestapo Major sits at the table , opposite Lt . Hicox , and Wicki . The French Barmaid brings over the Majors beer stein .
#
#  MAJOR HELLSTROM
#
#  So that 's the source of your bazaar accent ? Extraordinary . So what are you doing here Cap't ?
#
#  LT.HICOX
#
#  Aside from having a drink with the lovely fraulein ?
#
#  , 00 .
#
#  MAJOR HELLSTROM
#
#  Well that pleasure requires no explanation . Chuckle ... Chuckle
#
#  MAJOR HELLSTROM
#
#  <<I>> mean in country . Your obviously not stationed in France , or <<I>> 'd know who you are .
#
#  LT I ' ! <<I>> COX
#
#  You know every German in France ?
#
#  MAJOR BELLSTROM
#
#  Worth knowing .
#
#  LT.HICOX
#
#  Well , there in lies the problem . We never claimed to be worth knowing . Chuckle ... Chuckle .
#
#  MAJOR HELLSTROM
#
#  All levity aside , what are you doing in France ?
#
#  Chuckling as he asks
#
#  LT.HICOX
#
#  Attending Goebbels film premiere as the frauleins escort .
#
#  MAJOR HELLSTROM
#
#  Your the frauleins escort ?
#
#  LT.HICOX
#
#  Somebody has to carry the lighter . Chuckle chuckle .
#
#  BRIDGET
#
#  The Captain is my date , but all three are my guests . We 're old friends Major , who go back along time . Longer then a actress would care to admit . Chuckle chuckle .
#
#  MAJOR HELLSTROM
#
#  Well , in that case , let me raise a glass to the three luckiest men in the room .
#
#  BRIDGET
#
#  I 'll drink to that .
#
#  They cheers . BACK TO THE REAL GERMAN TABLE They continue to have alot of fun playing their game . BACK TO OFFICERS TABLE
#
#  MAJOR HELLSTROM
#
#  <<I>> must say , that game their playing looks like a good bit of fun . <<I>> did n't join them , because your quite right Cap't , officers and enlisted men should n't fraternize . But seeing as we 're all officers here , ( Bowing to
#
#  BRIDGET )
#
#  .and sophisticated lady friends of officers . What say we play the game ? Lt . Hicox begins to refuse , when Bridget , interrupts him ;
#
#  feeling she knows better
#
#  BRIDGET
#
#  okay , one game .
#
#  MAJOR HELLSTROM
#
#  WUNDERBAR
#
#  The Major borrows five cards from the other table , and lays them out in front of Bridget and the officers .
#
#  MAJOR HELLSTROM
#
#  So the object of the game , is to write the name of a famous person on your card . Real or fictitious , does n't matter . For instance , you could write Confucius or Fu Manchu . ( He SNAPS his
#
#  FINGERS )
#
#  Eric ' More pens . And they must be famous . No Aunt Inga 's . When you finish writing , put the card face down on the table , and move it to the person to your left . The person to your right , will move their card in front of you . You pick up the card without looking at it , lick the back , and stick it on your forehead like so . He demonstrates .
#
#  Back to players
#
#  ) oz . MAJOR HELLSTROM ( CON'T ) And in ten yes or no questions , you must guess who you are ... As Major Hellstrom finishes explaining the finer points of the game , The CAMERA PANS OFF HIM , and BEGINS SLOWLY ZOOMING INTO STIGLITZ . The Majors dialogue begins to FADE AWAY . Untill we 're in a SPAGHETTI WESTERN FLASHBACK . Which is RED FILTERED FOOTAGE of Hugo being savagely WHIPPED by somebody wearing a GESTAPO UNIFORM , SUPERIMPOSED over his CLOSE UP . The Flashback disappears . It 's driving Stiglitz crazy , being this close to a Gestapo uniform , and not plunging a knife into it . The Majors Voice comes back on the soundtrack .
#
#  MAJOR HELLSTROM
#
#  .So let 's give it a try , shall we ? Everybody write your names . The Five players write their names ... Then move their cards to the right ... Everybody sticks their cards on their forehead ...
#
#  MAJORBRIDGETWILHELMARCHIEHUGO
#
#  HELLSTROMVON HAMMERSMARKWICKIHICOXSTIGLITZ
#
#  is is is is is
#
#  KING MARCOBULLDOGBRIGITTEG.W. KONG POLO DRUMMOND HELM PABST
#
#  MAJ.KING KONG
#
#  <<I>> 'll start , give you the idea .
#
#  Am <<I>> German ?
#
#  They laugh .
#
#  BRIDGET
#
#  No .
#
#  MAJ.KING KONG Am <<I>> a American ?
#
#  They laugh - but then Wicki says ;
#
#  WICKI
#
#  Wait a minute , he goes to
#
#  ! 03 .
#
#  BRIDGET
#
#  Do n't be ridiculous , obviously he was n't born in America .
#
#  MAJ.KING KONG
#
#  So ... . <<I>> visited America , aye ? The Table says ; " Yes " .
#
#  MAJ.KING KONG
#
#  Was this vist ... fortuitous ?
#
#  WICKI
#
#  Not for you .
#
#  MAJ.KING KONG
#
#  .Bummm . <<My>> native land , is it what one would call , exotic ? The Table confers , and decides , yes it is exotic .
#
#  MAJ.KING KONG
#
#  Hummmm . That could be ether a reference to the jungle , or the Orient . <<I>> 'm going to let <<my>> first instinct take over , and ask , am <<I>> from the jungle ? The Tablesays ; " Yes <<you>> are " .
#
#  MAJ.KING KONG
#
#  Now gentlemen , around this time you could ask , weather <<your>> real or fictitious . I however , think that 's too easy , so I wo n't ask that , yet . Okay , <<my>> native land is the jungle ? <<I>> visited America , but <<my>> visit was not fortuitous to <<me>> , but the implication is that it was to somebody else . When <<I>> went from the jungle to America , ... .Did <<I>> go by boat ? " Yes " .
#
#  MAJ.KING KONG
#
#  Did <<I>> go against <<my>> will ? " Yes " .
#
#  MAJ.KING KONG
#
#  On this boat ride , ... . Was <<I>> in chains ?
#
#  " YESIS
#
#  MAJ.KING KONG
#
#  When <<I>> arrived in America, ... Was <<I>> displayed in chains ? " Yes " .
#
#  MAJ.KING KONG
#
#  Am <<I>> the story of the Negro in America ? The Table says , " No " .
#
#  MAJ.KING KONG
#
#  Well then <<I>> must be King Kong . Be throws the card on the table . They applaud <<him>> .
#
#  MAJOR HELLSTROM
#
#  Nov since <<I>> answered correctly , you all need to finnish your drinks . The three counterfeit Nazi 's knock back their whiskey .
#
#  MAJOR HELLSTROM
#
#  Now , who 's next ?
#
#  LT.HICOX
#
#  Major , <<I>> do n't mean to be rude . But the four of us are very good friends . And the four of us have n't seen each other in quite a while . So ... Major , I 'm afraid , you are intruding .
#
#  MAJOR HELLSTROM
#
#  I beg to differ Cap't . It 's only if the fraulein considers my presence a intrusion , that I become a intruder . How about it fraulein ? Am I intruding ?
#
#  BRIDGET
#
#  Of course not , Major .
#
#  MAJOR HELLSTROM
#
#  I did n't think so . It 's simply the young Cap't is immune to my charms . The Table 's not sure what to do , is this a confrontation ? Then , the Major laughs .
#
#  MAJOR HELLSTROM
#
#  I 'm just joking , of course I 'm intruding .
#
#  MAJOR HELLSTROM
#
#  Allow <<me>> to refill your glasses gentlemen , and <<I>> will bid you and the fraulein adieu . Eric has a bottle of thirty - three year old single malt scotch whisky from the Scottish highlands . What do you say gentlemen ?
#
#  Leaning in
#
#  LT.HICOX
#
#  Your most gracious , sir .
#
#  MAJOR HELLSTROM
#
#  Eric , the thirty - three , and new glasses ! You do n't want to contaminate the thirty- three with the swill you were drinking .
#
#  ERIC
#
#  How many glasses ?
#
#  LT.HICOX
#
#  Five glasses .
#
#  MAJOR HELLSTROM
#
#  Not me . I like scotch , scotch does n't like me .
#
#  BRIDGET
#
#  Nor I. I 'll stay with bubbly . Lt . Bicox , hold up three fingers , to Eric the owner .
#
#  pinky to index
#
#  LT.HICOX
#
#  Three glasses . Eric brings the three glasses , and the old bottle , pouring for the three soldiers . Major Helistrom lifts up his beer stein , and toasts ;
#
#  MAJOR HELLSTROM
#
#  To a thousand year Reich ! They all mutter , " a thousand year reich " , and toast glasses . The Gestapo Major puts down his beer stein , and then WE HEAR a CLICK , under the table .
#
#  MAJOR HELLSTROM
#
#  Did you hear that ? That 's the sound of <<my>> Luger pointed right at your testicles .
#
#  ! Q (
#
#  LT.HICOX
#
#  Why do you have a Luger pointed at my testicles ?
#
#  MAJOR HELLSTROM
#
#  Because you 've just given yourself away , Cap't . Your no more German then that scotch .
#
#  LT.HICOX
#
#  Well , -Major -
#
#  BRIDGET
#
#  - Major -
#
#  MAJOR HELLSTROM
#
#  - Shut up slut . You were saying ?
#
#  To Hicox
#
#  LT.HICOX
#
#  I was saying that makes two of us . I 've had a gun pointed at your balls since you sat down .
#
#  SGT.STIGLITZ
#
#  That makes three of us .
#
#  UNDERTABLE
#
#  We See all three guns pointed at appropriate crotches . As well as Bridget 's legs , right besides the Nazi Major 's . Her pretty gams are sure to be chewed up in the possible crossfire .
#
#  SGT.STIGLITZ
#
#  And at this range , I 'm a real Fredrick Zoller . Hugo alsobrings out his dagger , and sitcks it in the table top .
#
#  MAJOR HELLSTROM
#
#  Hummmmm ... Looks like we have a bit of a sticky situation here .
#
#  LT . H ICOX
#
#  What 's going to happen , Major , is your going to stand up , and walk out that door with us .
#
#  MAJOR HELLSTROM
#
#  No no no no no no , I do n't think so . I 'm afraid you and I both know , no matter what happens to anybody else in this room , the two of us are n't going anywhere .
#
#  " 7 .
#
#  MAJOR HELLSTROM
#
#  Too bad about them though . They seem like a likeable You two will have to shoot them .
#
#  pointing behind him at the table referring to Stiglitz and Wicki
#
#  BRIDGET
#
#  Then Major , <<i>> implore you . For the sake of those German troops , will you please leave with us ?
#
#  MAJOR HELLSTROM
#
#  Oh Bridget , your concern for German troops , gets <<me>> .right here . You mean for the sake your whore legs , do n't you ? You ca n't afford to get any bullet holes in them , your not finished spreading them for all the Hollywood Jews . Lt . Hicox picks up his thirty - three year old single malt scotch , and says ;
#
#  Pointing at his heart
#
#  LT.HICOX ( ENGLISH ) ' Well , if this is it old boy , I hope you do nt mind if I go out speaking the kings ? MAJOR HELLSTROM ( ENGLISH ) By all means , Cap't . The English film critic , commando , picks up the thirty - three the Nazi Major bought him , and says ;
#
#  LT.HICOX
#
#  There 's a special rung in hell reserved for people who waste good scotch . And seeing as <<I>> might be rapping on the door momentarily ... He downs the stuff .
#
#  LT.HICOX
#
#  ( To the Nazi
#
#  MAJOR )
#
#  <<I>> must say , damn good stuff , <<sir>> .
#
#  He puts the glass down .
#
#  LT.HICOX
#
#  Now about this , " Pickle " , we find ourself 's in . It would appear , there 's only thing left for you to do .
#
#  MAJOR HELLSTROM ( ENGLISH ) And what would that be ?
#
#  LT.HICOX
#
#  Stiglitz .
#
#  STIGLITZ
#
#  Say , auf wiedersehen to your balls !
#
#  STIGLITZ FIRES into HELLSTROM 'S BALLS ...
#
#  As does <<HICOX>> , HITTING not only Hellstrom , but BRIDGET as well .
#
#  HELLSTROM
#
#  FIRES into <<HICOX 'S>> BALLS and KNEE CAPS .
#
#  STIGLITZ
#
#  then JUMPS over the table , and begins STABBING HELLSTROM with the
#
#  DAGGER .
#
#  <<HICOX>> FALLS to the floor .... DEAD . BRIDGET FALLS to the floor . ,SHOT .
#
#  WICKI
#
#  brings his weapon out from underneath the table , and BEGINS FIRING across at The GERMANS at the table , who unaware , were still PLAYING THE GAME .
#
#  WINNETOU
#
#  is SHOT IN THE BACK , before he even knew what was happening . EDGAR WALLACE and The FRENCH BARMAID are both SHOT by WICKI .
#
#  SGT.POLA NEGRI
#
#  FALLS to the floor in the confusion . FEMALE SGT.BEETHOVEN and STIGLITZ bring their guns toward each other and FIRE . They BOTH TAKE and GIVE each other so many BULLETS , it 's almost romantic when they collapse DEAD on the floor .
#
#  I 09 . WICKI and HATA HARI
#
#  both ON THERE atMATA AARI is HIT THREE TIM atally)G
#
#  SGT.POLA NEGRI
#
#  comes the a CHINE GUNN ,
#
#  whole thehroom;,BWIPI NGERIC .
#
#  The SHOOTING STOPS ... the SMOKE caused by the gunfire ... starts to DISSIPATE ... The only one in the room left alive , is the young German Sgt , with the machine gunn . WE HEAR the feet of the soldiers outside , reach the basement entrance . The door opens ... , .The German Sgt , sends FIFTY BULLETS in the doors direction ... No one goes through it . What we have here , is a rabbit hole like situation . No one inside is getting out , no one outside is getting in . The young German Sgt , YELLS in ENGLISH , to the outside ;
#
#  GERMAN SGT
#
#  You outside ! Who are you ? British , American , what ? Aldo 's Voice YELLS down the hole ;
#
#  ALDO 'S VOICE
#
#  Were American 's 1 What are you ?
#
#  OS
#
#  GERMAN SGT
#
#  I 'm a German you idiot !
#
#  ALDO 'S VOICE
#
#  <<You>> speak English pretty good for a German !
#
#  OS
#
#  GERMAN SGT
#
#  I agree ! So let 's talk !
#
#  ALDO 'S VOICE
#
#  Okay , talk !
#
#  OS
#
#  GERMAN SGT
#
#  I 'm a father ! My baby was born today in Frankfurt ! Five hours ago ! His name is Max ! We were in here drinking and celebrating ! They 're the ones that came in shooting and killing ! It 's not my fault !
#
#  Ito .
#
#  ALDO 'S VOICE
#
#  Okay , okay , it was n't your fault ! What 's your name soldier ?
#
#  OS
#
#  GERMAN SGT
#
#  Wilhelm !
#
#  ALDO 'S VOICE
#
#  That 's the same name as one of the guys you just killed !
#
#  OS
#
#  WILHELM
#
#  They attacked us !
#
#  ALDO 'S VOICE
#
#  Okay Wilhelm ... .is anybody alive on our side ?
#
#  OS
#
#  WILHELM
#
#  No ! We hear a VOICE OFF SCREEN , yell out ;
#
#  BRIDGET 'S VOICE
#
#  I 'm alive ! Wilhelm spins in the direction of the voice .
#
#  OS
#
#  STILL
#
#  R
#
#  On the floor , with a bullet in her BLOODY LEG , lies the alive Bridget Von Hammersmark . The German Sgt points the muzzle of the machine gunn at the German celebrity ; with hate in his eyes .
#
#  ALDO 'S VOICE
#
#  Who 's that ?
#
#  OS
#
#  WILHELM
#
#  ( To BRIDGET ,
#
#  LOW )
#
#  Make a sound whore , and I spit ! Meaning the muzzle .
#
#  ALDO 'S VOICE
#
#  Wilhelm , who is that ?
#
#  OS
#
#  WILHELM
#
#  is the girl on your side ? Pause .
#
#  ALDO 'S VOICE
#
#  Which girl ?
#
#  OS
#
#  WILHELM
#
#  1 Who do you think , Von Hammersmark !
#
#  ALDO 'S VOICE
#
#  Yeah , she 's oar 's !
#
#  OS
#
#  WILHELM
#
#  ( To Bridget
#
#  LOW in GERMAN )
#
#  I thought so . So you run with the American 's now , huh ? Now times are bad ?
#
#  ALDO 'S VOICE
#
#  Is she okay ?
#
#  OS
#
#  WILHELM
#
#  ( To Bridget
#
#  LOW in GERMAN )
#
#  You despicable traitor . She 's been shot , but she 's alive . ( To Bridget
#
#  To Aldo
#
#  LOW in GERMAN )
#
#  For now . We hear The Basterds Curse their luck Off Screen .
#
#  ALDO 'S VOICE
#
#  Okay Wilhelm , what 'd ya say we make a deal ?
#
#  OS
#
#  WILHELM
#
#  What 's your name ?
#
#  ALDO 'S VOICE
#
#  Aldo . Wilhelm , can <<I>> call yap Willi ?
#
#  OS
#
#  WILHELM
#
#  Yes .
#
#  ALDO 'S VOICE
#
#  So Willi , you know we could lob three or four or five or six grenades down there , and your little war story ends here . But good fer you , bad fer her , you die , she dies . So what say we make a swap ?
#
#  OS
#
#  WILLI
#
#  Keep talking ?
#
#  ALDO 'S VOICE
#
#  Okay , Willi here 's my deal ! You let me and one of my men come down to take the girl away ! And we take the girl , and leave ! That simple , Willi ! You go your way , we go ours ! And little Max , gets to grow up playing catch with his daddy ! So what'ya say , Willi , we got a deal ? Willi thinks ... Bridget watches Willi think ...
#
#  OS
#
#  WILLI
#
#  Aldo ?
#
#  ALDO 'S VOICE
#
#  I 'm here Willi !
#
#  OS
#
#  WILLI
#
#  <<I>> want to trust you .... But howcanI ?
#
#  ALDO 'S VOICE
#
#  What choice ya got ?
#
#  OS
#
#  WILLI
#
#  I could kill the girl !
#
#  ALDO 'S VOICE
#
#  Well now , Willi , that 's true enough . But something you need to know , so you do n't get the wrong idea . Ai n't none of us give a fuck bout that girl . But , admittedly , if you kill her , it would fuck up our plans . But you 'll be dead by then anyway , so what 'd you care ? And lets not forget that little gatzenjammer Max , growin up without a pop . So in the spirit of gettin you home to him , we got a deal , Willi ?
#
#  OS
#
#  WILLI
#
#  Okay Aldo , I 'm going to trust you ! Come down , no guns ! Aldo and Hirschberg come down the stairs , showing open hands . Willi keeps his machine gunn trained on them . Aldo with his hands up , says ;
#
#  A
#
#  ALDO
#
#  Hey Willi , what 's with the machine gunny I thought we had a deal ?
#
#  WILLI
#
#  We do have a deal , now git the girl and go .
#
#  ALDO
#
#  Not so fast , Willi , we only have a deal , we trust each other . A Mexican stand off ai n't trust .
#
#  WILLI
#
#  <<You>> need guns on <<me>> for it to be a Mexican stand off .
#
#  ALDO
#
#  you got guns on us , you decide to shoot , we 're dead . Up top , they got grenades , they drop 'em down here , your dead . That 's a Mexican stand off , and that was n't the deal .
#
#  WILLI
#
#  Just take that fucking traitor , and go ! See ? Now your down here Now <<you>> get tricky - t
#
#  ALDO
#
#  - No tricks!- Ai n't nobody gittin tricky , Willi ; I swear to god , I 'm too damn dumb toget tricky . But
#
#  ( MEANING
#
#  HIRSCHBERG )
#
#  him and I lived upto the deal . We came down without guns . Now it 's <<your>> turn . No trust , no deal . Willi pointing gunn at them . , , , -thinking ...
#
#  ALDO
#
#  <<i>> know your scarred . <<I>>

# %%
gold_clusters = list(gold_entity_to_mentions.values())

# %%
for gc in gold_clusters:
    print(len(gc))
# Out:
# 14
# 147
# 78
# 17
# 176
# 7
# 18
# 2
# 57
# 12
# 174
# 4
# 8
# 9
# 35
# 1
# 8
# 3
# 3
# 2
# 16
# 165
# 6

# %%
sys_clusters = []

for sys_cluster in joined_coref["clusters"]:
    sys_clusters.append(set([(j, k) for j, k in sys_cluster]))

# %%
sys_clusters
# Out:
# [{(2, 6),
#   (12, 30),
#   (91, 92),
#   (134, 134),
#   (909, 914),
#   (945, 947),
#   (956, 960),
#   (964, 970),
#   (968, 969),
#   (971, 971),
#   (996, 998),
#   (1581, 1583),
#   (2091, 2092),
#   (2109, 2110),
#   (2966, 2968)},
#  {(50, 50),
#   (62, 62),
#   (113, 113),
#   (115, 115),
#   (132, 132),
#   (204, 204),
#   (308, 310),
#   (325, 325),
#   (334, 336),
#   (354, 354),
#   (356, 356),
#   (376, 376),
#   (378, 378),
#   (394, 394),
#   (428, 428),
#   (437, 437),
#   (463, 465),
#   (479, 479),
#   (491, 491),
#   (506, 506),
#   (561, 561),
#   (566, 566),
#   (597, 597),
#   (674, 674),
#   (692, 692),
#   (759, 759),
#   (1533, 1533),
#   (2924, 2924),
#   (3142, 3142),
#   (3158, 3158),
#   (3188, 3188),
#   (3272, 3272),
#   (3295, 3295),
#   (3358, 3358),
#   (3418, 3418),
#   (3431, 3431),
#   (3492, 3492),
#   (3495, 3495),
#   (3500, 3500),
#   (3524, 3526),
#   (3597, 3597),
#   (3621, 3621),
#   (3623, 3623),
#   (3626, 3626),
#   (3630, 3630),
#   (3634, 3634),
#   (3664, 3664),
#   (3798, 3798),
#   (3896, 3896),
#   (3909, 3909),
#   (3921, 3921),
#   (4117, 4117),
#   (4133, 4133),
#   (4563, 4563),
#   (4574, 4574),
#   (4590, 4590),
#   (4640, 4640),
#   (4677, 4677),
#   (4722, 4722),
#   (4727, 4727),
#   (4737, 4737),
#   (4747, 4747),
#   (4766, 4766),
#   (4791, 4791),
#   (4798, 4798),
#   (4803, 4803),
#   (4809, 4809),
#   (4823, 4823),
#   (4833, 4833),
#   (4847, 4847),
#   (4850, 4850),
#   (4869, 4869),
#   (514, 514),
#   (526, 526),
#   (539, 539),
#   (618, 618),
#   (712, 712),
#   (6317, 6318),
#   (6326, 6327),
#   (6352, 6353),
#   (6380, 6381),
#   (6445, 6446),
#   (6474, 6475),
#   (6599, 6600),
#   (6727, 6728),
#   (6768, 6769),
#   (6789, 6790),
#   (6838, 6839),
#   (6901, 6902),
#   (6910, 6910),
#   (6915, 6915),
#   (6919, 6919),
#   (6990, 6990),
#   (6993, 6994),
#   (6997, 6997),
#   (7011, 7011),
#   (7017, 7018),
#   (7150, 7150),
#   (7157, 7157),
#   (7165, 7165),
#   (7188, 7188),
#   (7197, 7197),
#   (7232, 7232),
#   (7277, 7277),
#   (7279, 7279),
#   (7285, 7285),
#   (7349, 7349),
#   (7421, 7421),
#   (7425, 7425),
#   (7495, 7495),
#   (7547, 7547),
#   (7555, 7555),
#   (7659, 7659),
#   (7679, 7679),
#   (7684, 7684),
#   (7684, 7685),
#   (7697, 7697),
#   (7699, 7699),
#   (7728, 7728),
#   (7735, 7735),
#   (7742, 7742),
#   (7787, 7787),
#   (7811, 7811)},
#  {(572, 573), (582, 582), (600, 600), (605, 605), (616, 616)},
#  {(603, 603), (608, 608)},
#  {(638, 641),
#   (656, 658),
#   (676, 676),
#   (696, 696),
#   (703, 703),
#   (735, 735),
#   (744, 744),
#   (1613, 1615),
#   (1626, 1626),
#   (1641, 1641),
#   (1644, 1644),
#   (1651, 1651),
#   (1658, 1658),
#   (1670, 1672),
#   (1675, 1675),
#   (1679, 1679),
#   (1733, 1735),
#   (1738, 1738),
#   (1750, 1752),
#   (1755, 1755),
#   (1761, 1761),
#   (1763, 1763),
#   (1781, 1781),
#   (1955, 1955),
#   (1960, 1960),
#   (1966, 1966),
#   (1993, 1993),
#   (2008, 2008),
#   (2020, 2020),
#   (2351, 2351),
#   (2617, 2619),
#   (2621, 2621),
#   (2627, 2627),
#   (2632, 2632),
#   (2715, 2715),
#   (2723, 2723),
#   (2733, 2733),
#   (2746, 2746),
#   (2782, 2782),
#   (2784, 2784),
#   (2920, 2920),
#   (2921, 2921),
#   (2979, 2983),
#   (3053, 3055),
#   (3059, 3059),
#   (3105, 3106),
#   (3163, 3164),
#   (3573, 3573),
#   (3595, 3595),
#   (3599, 3599),
#   (3607, 3608),
#   (3611, 3611),
#   (3651, 3653),
#   (3673, 3673),
#   (3675, 3675),
#   (3684, 3684),
#   (3689, 3689),
#   (3788, 3791),
#   (3870, 3872),
#   (4971, 4972),
#   (5044, 5045),
#   (5061, 5061),
#   (5151, 5152),
#   (5443, 5443),
#   (5445, 5445),
#   (5455, 5455),
#   (6677, 6678),
#   (7594, 7594),
#   (7604, 7604),
#   (7782, 7784)},
#  {(757, 757), (761, 761), (768, 768), (770, 770)},
#  {(790, 793),
#   (796, 796),
#   (855, 865),
#   (880, 882),
#   (918, 921),
#   (925, 925),
#   (929, 929),
#   (933, 933),
#   (936, 936),
#   (942, 942),
#   (951, 951),
#   (1047, 1049)},
#  {(815, 815), (823, 823), (831, 831), (833, 833), (844, 844), (849, 849)},
#   (6930, 6930),
#   (6948, 6948),
#   (6950, 6950),
#   (7072, 7072),
#   (7093, 7093),
#   (7137, 7137),
#   (7165, 7167),
#   (7184, 7184),
#   (7383, 7385),
#   (7391, 7391),
#   (7413, 7413),
#   (7518, 7520),
#   (7547, 7549)},
#  {(7086, 7086), (7089, 7089)},
#  {(251, 251),
#   (7167, 7167),
#   (7380, 7380),
#   (7383, 7383),
#   (7432, 7432),
#   (7505, 7505),
#   (7507, 7507),
#   (7549, 7549),
#   (7573, 7585),
#   (7631, 7631),
#   (7649, 7649),
#   (7654, 7654),
#   (7677, 7677),
#   (7692, 7692),
#   (7779, 7779),
#   (7813, 7813)},
#  {(7174, 7175), (7188, 7189)},
#  {(7186, 7190), (7208, 7208)},
#  {(7283, 7283), (7290, 7290)},
#  {(7297, 7297), (7301, 7301)},
#  {(7299, 7299), (7303, 7303)},
#  {(7321, 7322), (7388, 7389)},
#  {(7497, 7497), (7501, 7501)},
#  {(7542, 7543), (7570, 7571), (7640, 7641)},
#  {(634, 635), (7793, 7794)},
#  {(7799, 7802), (7806, 7806)},
#  {(254, 254), (7820, 7820)}]

# %%
intersection_matrix = np.zeros((len(gold_clusters), len(sys_clusters)))

for i, gc in enumerate(gold_clusters):
    for j, sc in enumerate(sys_clusters):
        intersection_matrix[i, j] = len(gc.intersection(sc))

# %%
row_ind, sys_ind = linear_sum_assignment(intersection_matrix, maximize=True)

# %%
intersection_matrix[row_ind, sys_ind].sum()
# Out:
# 369.0

# %%
matched_sys_clusters = [sys_clusters[ind] for ind in sys_ind]

# %%
scores.conll2012(gold_clusters, matched_sys_clusters)
# Out:
# 0.48953349035025384

# %%
sorted_gold_clusters = sorted(gold_clusters, key=lambda gc: len(gc), reverse=True)

# %%
sorted_intersection_matrix = np.zeros((len(sorted_gold_clusters), len(sys_clusters)))

for i, gc in enumerate(sorted_gold_clusters):
    for j, sc in enumerate(sys_clusters):
        sorted_intersection_matrix[i, j] = len(gc.intersection(sc))

# %%
row_ind, sorted_sys_ind = linear_sum_assignment(sorted_intersection_matrix, maximize=True)

# %%
intersection_matrix[row_ind, sys_ind].sum()
# Out:
# 369.0

# %%
matched_sorted_sys_clusters = [sys_clusters[ind] for ind in sorted_sys_ind]

# %%
scores.conll2012(gold_clusters, matched_sorted_sys_clusters)
# Out:
# 0.48953349035025384

# %%
for i in range(1, len(gold_clusters)):
    print(i, scores.conll2012(sorted_gold_clusters[:i], matched_sorted_sys_clusters[:i]))
# Out:
# 1 0.3322367342266573
# 2 0.29510633772348793
# 3 0.3283937392728796
# 4 0.3475449754684685
# 5 0.39426427005928233
# 6 0.4320341105064299
# 7 0.4517761268069382
# 8 0.46652230011889034
# 9 0.47761618147284235
# 10 0.47975365676224513
# 11 0.4717610745487369
# 12 0.4832516707502464
# 13 0.4783503666873969
# 14 0.4875079231326934
# 15 0.49403887552570286
# 16 0.4776269501718442
# 17 0.47799252964670336
# 18 0.4800600787571974
# 19 0.46818611594000814
# 20 0.47299583028429076
# 21 0.4809887925815328
# 22 0.4883272245339733
