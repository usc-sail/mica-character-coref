# %%
from stanza.server import CoreNLPClient
import re
from tqdm import tqdm
import numpy as np
import pandas as pd
import json

# %%
annotators = 'tokenize,ssplit,pos,lemma,ner,depparse,parse,coref'

client = CoreNLPClient(threads=8, annotators=annotators, output_format='serialized', memory='32G', be_quiet=True, timeout=360000000, stderr=open('error.log','w'), properties={'coref.algorithm':'neural'}, max_char_length=100000)
# Out:
# 2020-11-20 17:14:58 INFO: Writing properties to tmp file: corenlp_server-12f9d39515304dcf.props

# %%
bourne_doc = client.annotate(open("/proj/sbaruah/movie/coreference/annotated-data/bourne.script.txt").read(), output_format="serialized")
print("bourne done")

basterds_doc = client.annotate(open("/proj/sbaruah/movie/coreference/annotated-data/basterds.script.txt").read(), output_format="serialized")
print("basterds done")

shawshank_doc = client.annotate(open("/proj/sbaruah/movie/coreference/annotated-data/shawshank.script.txt").read(), output_format="serialized")
print("shawshank done")
# Out:
# bourne done
# basterds done
# shawshank done

# %% [markdown]
# ## Get gold and pred clusters

# %%
def get_gold_and_pred_clusters(script_name, doc = None, verbose = True):
    script = open(f"/proj/sbaruah/movie/coreference/annotated-data/{script_name}.script.txt").read()
    if doc is None:
        doc = client.annotate(script, output_format="serialized")
    annotations = pd.read_csv(f"/proj/sbaruah/movie/coreference/annotated-data/{script_name}.coref.csv", index_col = None)
    
    gold_clusters = []
    for _, df in annotations.groupby("entityLabel"):
        cluster = []
        for _, row in df.iterrows():
            cluster.append((row["begin"], row["end"]))
        cluster = sorted(cluster, key = lambda mention: mention[0])
        gold_clusters.append(cluster)
    gold_clusters = sorted(gold_clusters, key = lambda cluster: len(cluster), reverse = True)
    
    gold_clusters_text = [[script[i:j] for i, j in cluster] for cluster in gold_clusters]
    
    pred_clusters = []
    for chain in doc.corefChain:
        cluster = []
        for mention in chain.mention:
            sentence = doc.sentence[mention.sentenceIndex]
            cluster.append((sentence.token[mention.beginIndex].beginChar, sentence.token[mention.endIndex - 1].endChar))
        cluster = sorted(cluster, key = lambda mention: mention[0])
        pred_clusters.append(cluster)
    pred_clusters = sorted(pred_clusters, key = lambda cluster: len(cluster), reverse = True)
    
    pred_clusters_text = [[script[i:j] for i, j in cluster] for cluster in pred_clusters]
    
    if verbose:
        print(f"{len(gold_clusters)} gold clusters. Top 20 clusters =>")
        for gi, (gold_cluster, gold_cluster_text) in enumerate(zip(gold_clusters[:20], gold_clusters_text[:20])):
            sampled_mentions = gold_cluster_text[:20]
            print(f"{gi:3d}\t{len(gold_cluster):3d} mentions\t{sampled_mentions}")
        print()

        print(f"{len(pred_clusters)} pred clusters. Top 20 clusters =>")
        for pi, (pred_cluster, pred_cluster_text) in enumerate(zip(pred_clusters[:22], pred_clusters_text[:22])):
            sampled_mentions = pred_cluster_text[:20]
            print(f"{pi:3d}\t{len(pred_cluster):3d} mentions\t{sampled_mentions}")
        print()
        
        intersection_map = np.zeros((len(gold_clusters), len(pred_clusters)), dtype=np.int)
        gold_to_pred_map = []

        for i, gold_cluster in enumerate(gold_clusters):
            for j, pred_cluster in enumerate(pred_clusters):
                gold_cluster_set = set([(k, l) for k, l in gold_cluster])
                pred_cluster_set = set([(k, l) for k, l in pred_cluster])
                intersection_map[i, j] = len(gold_cluster_set.intersection(pred_cluster_set))    

        while intersection_map.size and np.max(intersection_map):
            r, c = np.unravel_index(np.argmax(intersection_map, axis = None), intersection_map.shape)
            gold_to_pred_map.append([r, c, np.max(intersection_map)])
            intersection_map[r] = 0
            intersection_map[:,c] = 0

        if verbose:
            for gi, pi, count in gold_to_pred_map[:10]:
                print(f"gold cluster {gi} ({len(gold_clusters[gi])} mentions) <-> pred cluster {pi} ({len(pred_clusters[pi])} mentions): {count} common mentions")
                print(f"gold ==> {gold_clusters_text[gi][:50]}")    
                print(f"pred ==> {pred_clusters_text[pi][:50]}\n\n")
            print()
        
    info = {"script": script, "name": script_name, "doc": doc, "gold": gold_clusters, "pred": pred_clusters}
    return info

# %%
bourne_info = get_gold_and_pred_clusters("bourne", bourne_doc)
# Out:
# 39 gold clusters. Top 20 clusters =>
#   0	425 mentions	['Bourne', 'Bourne', "BOURNE'S", 'Jason\n                  Bourne', 'he', 'Bourne', 'Bourne', 'he', 'he', 'Bourne', 'Bourne', 'Bourne', 'his', 'he', 'BOURNE', 'I', 'me', 'Bourne', 'Bourne', 'you']
#   1	139 mentions	['Vosen', 'his', 'Vosen', 'Vosen', "VOSEN'S", 'His', 'He', 'Vosen', 'Vosen', 'VOSEN', 'VOSEN', 'Vosen', 'VOSEN', 'Vosen', 'VOSEN', 'VOSEN', 'I', 'Vosen', 'his', 'he']
#   2	103 mentions	["LANDY'S", 'Pam', 'You', 'Landy', 'LANDY', 'LANDY', 'you', 'LANDY', 'I', 'I', "LANDY'S", "LANDY'S", 'She', 'LANDY', 'Pamela Landy', 'you', "LANDY'S", 'LANDY', 'her', 'LANDY']
#   3	 72 mentions	["HIRSCH'S", "Hirsch's", 'He', 'DR. HIRSCH, 70', 'He', 'His', 'DR. HIRSCH', 'you', "HIRSCH'S", 'HIRSCH', 'he', 'he', 'HIRSCH', 'I', 'HIRSCH', 'I', 'you', 'HIRSCH', 'I', 'Hirsch']
#   4	 26 mentions	['WILLS', 'Wills', 'WILLS', 'Wills', 'WILLS', 'Wills', 'Wills', 'WILLS', 'Wills', 'Wills', 'WILLS', 'Wills', 'Wills', 'Sir', 'Wills', 'WILLS', 'Wills', 'WILLS', 'WILLS', 'Wills']
#   5	 21 mentions	['Paz', 'his', 'Paz', 'his', 'Paz', 'Paz', 'Paz', 'Paz', 'he', 'Paz', 'Paz', 'Paz', 'Paz', 'his', 'Paz', "Paz's", 'PAZ', 'He', 'his', 'PAZ']
#   6	 16 mentions	['CRONIN', 'CRONIN', "CRONIN'S", 'CRONIN', 'CRONIN', 'CRONIN', "CRONIN'S", 'CRONIN', 'CRONIN', "CRONIN'S", "CRONIN'S", 'CRONIN', 'Cronin', 'CRONIN', 'Cronin', 'CRONIN']
#   7	 11 mentions	['Tac Team Leader', 'TACTICAL TEAM LEADER', 'I', 'TACTICAL TEAM LEADER', 'I', 'TACTICAL TEAM LEADER', 'TACTICAL TEAM LEADER', 'TACTICAL TEAM LEADER', 'TACTICAL TEAM LEADER', 'TACTICAL TEAM LEADER', 'TACTICAL TEAM LEADER']
#   8	 11 mentions	['the on\nedge cop', 'his', 'The police officer', 'the officer', "the officer's", 'Officer', 'the officer', 'the cop', 'your', 'the cops', 'cop']
#   9	 10 mentions	['BACK ROOM TECH', 'BACK ROOM TECH', 'you', 'TECH', 'you', 'you', 'TECH', 'TECH', 'TECH', 'TECH']
#  10	  7 mentions	['the driver', 'The driver', 'his', 'He', 'He', 'The driver', 'The driver']
#  11	  6 mentions	['he', 'he', 'a hooded\n      figure', 'The man', 'the figure', 'he']
#  12	  6 mentions	['the driver', 'The driver', 'his', 'the driver', 'the dazed\ndrivers', 'him']
#  13	  5 mentions	['we', 'we', 'We', 'we', 'We']
#  14	  5 mentions	['passenger side agent', 'passenger-\n        side agent', 'passenger side agent', 'he', 'his']
#  15	  4 mentions	['AGENT 3', 'AGENT 3', 'AGENT 3', 'AGENT 3']
#  16	  4 mentions	['the agent', 'the agent', 'his', 'the gunman']
#  17	  4 mentions	['A security guard', 'you', 'your', 'your']
#  18	  3 mentions	['the CRI agent', 'his', "agent's"]
#  19	  3 mentions	['One agent', 'his', 'CRI AGENT']
#
# 156 pred clusters. Top 20 clusters =>
#   0	259 mentions	['Bourne', 'Bourne', "BOURNE'S", 'Jason\n                  Bourne', 'he', "Bourne's", 'Bourne', 'Bourne', 'he', "Bourne's", '202A\n\n       Bourne', 'his', 'he', 'UNDEFINED SPACE                                       204\n\n                           BOURNE', 'Bourne', 'Bourne', 'UNDEFINED SPACE                               204\n\n                           BOURNE', 'Bourne', 'VOSEN\n                  Jason Bourne', 'Bourne']
#   1	136 mentions	['Vosen', 'his', 'Vosen', 'Vosen', "VOSEN'S", 'His', 'He', 'Vosen', 'VOSEN', 'she', 'him', 'Vosen', 'He', 'Vosen', 'VOSEN', 'Vosen', 'Vosen', "Vosen's", 'Vosen', 'VOSEN']
#   2	115 mentions	['he', 'him', 'him', 'He', "HIRSCH'S", 'He', "HIRSCH'S", 'HIRSCH', 'He', 'he', 'he', 'HIRSCH', 'Hirsch', 'him', 'HIRSCH', 'I', 'I', 'I', 'I', 'Hirsch']
#   3	 53 mentions	["LANDY'S", 'Landy', 'LANDY', 'LANDY (O.S.)', 'LANDY', "LANDY'S", "NEW YORK                203\n\n       LANDY'S", 'She', "LANDY'S", 'OFFICE                                        203\n\n       LANDY', 'her', 'LANDY\n                Bourne', 'Landy', "LANDY'S", 'LANDY', 'you', 'LANDY (V.O.)', "LANDY'S", "LANDY'S OFFICE                                        203\n\n                             LANDY", 'She']
#   4	 34 mentions	["Bourne's car", 'his\n      car', 'his car', "Bourne's\n      car", 'his car', 'the car', 'his over-\n      turned car', "Bourne's car", "Bourne's car", 'the car', 'his\n        car', 'the car', 'his car', 'the NYPD car', 'his car', "Bourne's car", "Bourne's car", "Bourne's car", 'his\n       car', "Bourne's\n       car"]
#   5	 19 mentions	['Landy', 'his', 'CRI AGENT\n                  Landy', 'Landy', 'him', 'you', 'LANDY\n                   4/15/71', 'LANDY', 'Landy', 'Landy', 'She', '95\n\n\n                           LANDY', 'my', 'Landy', 'She', 'Landy', 'Landy', 'LANDY', 'She']
#   6	 16 mentions	['I', 'you', 'I', 'I', 'you', 'I', 'you', 'me', 'My', 'you', 'you', 'you', 'me', 'me', 'him', 'him']
#   7	 14 mentions	['Wills', 'Wills', 'Wills', 'WILLS', 'Wills', 'Wills', 'his', 'Wills', 'HUB                                                 289A\n\n       Wills', 'WILLS', 'She', 'She', 'I', 'me']
#   8	 13 mentions	['two more agents', 'They', 'The agents', 'The agents', 'their', 'their', 'they', 'the armed agents', 'The agents', 'them', 'they', 'the oncoming agents', 'The agents in this sedan']
#   9	 13 mentions	['Tudor City', 'Tudor City', 'Tudor City', 'Tudor city', 'TUDOR CITY', 'Tudor City', 'her', 'her', 'TUDOR CITY', 'her', 'TUDOR CITY', 'TUTOR CITY', 'Tudor City']
#  10	 11 mentions	['another CRI sedan traveling parallel to the\ncourse of the wrecked one', 'this sedan', 'the sedan', "the\nsedan's", 'the sedan', 'the first NYPD sedan', 'The CRI sedan', 'it', 'the other CRI sedan', 'the CRI sedan', 'the CRI sedan']
#  11	 10 mentions	['you', 'You', 'I', 'you', 'I', 'me', 'you', 'you', 'my', 'I']
#  12	 10 mentions	['a third CRI car', 'the CRI car', 'the car', 'the car', "Bourne's car", 'the car', 'the car', "the car's", "the car's", 'the car']
#  13	 10 mentions	['Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', "Paz's"]
#  14	  9 mentions	['Port Authority', 'Port Authority', 'Port Authority', 'Port Authority', 'Port Authority', 'PORT AUTHORITY                     268', 'Port Authority', 'Port Authority', 'Port Authority']
#  15	  8 mentions	['CRONIN\n                  Pam', 'CRONIN', "CRONIN'S", "CRONIN'S", "CRONIN'S OFFICE                                       201\n\n                           CRONIN", 'he', 'CRONIN', 'Pam']
#  16	  7 mentions	['(V.O.)', '(V.O.)', '(V.O.)', '(V.O.)', '(V.O.)', '(V.O.)', '(V.O.)']
#  17	  7 mentions	['CRI', 'CRI', 'CRI', 'itself', 'CRI', 'CRI', 'CRI']
#  18	  7 mentions	['you', 'I', 'I', 'I', 'me', 'I', 'I']
#  19	  7 mentions	['Daniels', 'him', 'his', 'Daniels', 'He', 'Daniels', 'he']
#  20	  7 mentions	['101\n\n\n      Bourne looks down, a gun in his hand', 'his', 'He', 'his', 'he', 'He', 'him']
#  21	  6 mentions	['him', 'his', 'him', 'his', 'he', 'his']
#
# gold cluster 0 (425 mentions) <-> pred cluster 0 (259 mentions): 198 common mentions
# gold ==> ['Bourne', 'Bourne', "BOURNE'S", 'Jason\n                  Bourne', 'he', 'Bourne', 'Bourne', 'he', 'he', 'Bourne', 'Bourne', 'Bourne', 'his', 'he', 'BOURNE', 'I', 'me', 'Bourne', 'Bourne', 'you', 'BOURNE', 'You', 'BOURNE', 'Bourne', 'David Webb', 'your', 'him', 'You', 'you', 'Bourne', 'BOURNE', 'BOURNE', 'He', 'Bourne', 'Jason Bourne', 'He', 'he', 'BOURNE', 'Bourne', 'Bourne', 'Bourne', 'Bourne', "Bourne's", 'his', 'he', "Bourne's", 'BOURNE', 'Jason Bourne', 'BOURNE', 'you']
# pred ==> ['Bourne', 'Bourne', "BOURNE'S", 'Jason\n                  Bourne', 'he', "Bourne's", 'Bourne', 'Bourne', 'he', "Bourne's", '202A\n\n       Bourne', 'his', 'he', 'UNDEFINED SPACE                                       204\n\n                           BOURNE', 'Bourne', 'Bourne', 'UNDEFINED SPACE                               204\n\n                           BOURNE', 'Bourne', 'VOSEN\n                  Jason Bourne', 'Bourne', '224\n\n       BOURNE', 'STAIRWAY                                            226A\n\n       Bourne', 'STAIRWAY                                            226A\n\n       Bourne', 'Bourne', 'Bourne', "Bourne's", "Bourne's", 'BOURNE', 'BOURNE', 'BOURNE', 'BOURNE', 'BOURNE', 'the safe, BOURNE', 'folder Bourne', 'BOURNE', 'SERVICE STAIRS                                          237B\n\n       Bourne', 'his', 'WILLS\n                 Bourne', 'Bourne', 'BOURNE', 'BOURNE', 'CRONIN\n                 Bourne', 'BOURNE', 'BOURNE', 'Bourne', 'He', 'he', 'his', 'Bourne', 'He']
#
#
# gold cluster 1 (139 mentions) <-> pred cluster 1 (136 mentions): 78 common mentions
# gold ==> ['Vosen', 'his', 'Vosen', 'Vosen', "VOSEN'S", 'His', 'He', 'Vosen', 'Vosen', 'VOSEN', 'VOSEN', 'Vosen', 'VOSEN', 'Vosen', 'VOSEN', 'VOSEN', 'I', 'Vosen', 'his', 'he', 'Vosen', 'Vosen', 'he', 'his', 'he', 'VOSEN', 'Vosen', 'VOSEN', 'Bourne', 'VOSEN', 'VOSEN', 'VOSEN', 'VOSEN', 'I', 'VOSEN', 'VOSEN', 'Vosen', "VOSEN'S", 'Vosen', 'VOSEN', 'VOSEN', 'Vosen', "VOSEN'S", 'VOSEN', 'I', "VOSEN'S", 'VOSEN', 'I', 'VOSEN', "VOSEN'S"]
# pred ==> ['Vosen', 'his', 'Vosen', 'Vosen', "VOSEN'S", 'His', 'He', 'Vosen', 'VOSEN', 'she', 'him', 'Vosen', 'He', 'Vosen', 'VOSEN', 'Vosen', 'Vosen', "Vosen's", 'Vosen', 'VOSEN', 'CRI HUB                                     217A\n\n       VOSEN', 'VOSEN\n                         (frustrated)', 'VOSEN', 'VOSEN', 'VOSEN', 'Vosen', "VOSEN'S", 'VOSEN', 'VOSEN', 'He', 'it', 'he', 'CRI', 'Vosen', "VOSEN'S", 'her', "VOSEN'S", "Vosen's", 'VOSEN\n                 Noah Vosen', 'VOSEN', 'he', 'VOSEN', "VOSEN'S", "VOSEN'S", "VOSEN'S", 'his', 'he', 'VOSEN', '234\n\n       VOSEN', "VOSEN'S"]
#
#
# gold cluster 3 (72 mentions) <-> pred cluster 2 (115 mentions): 48 common mentions
# gold ==> ["HIRSCH'S", "Hirsch's", 'He', 'DR. HIRSCH, 70', 'He', 'His', 'DR. HIRSCH', 'you', "HIRSCH'S", 'HIRSCH', 'he', 'he', 'HIRSCH', 'I', 'HIRSCH', 'I', 'you', 'HIRSCH', 'I', 'Hirsch', 'HIRSCH', 'I', 'I', 'Hirsch', 'HIRSCH', 'HIRSCH', 'Hirsch', 'him', 'you', 'Hirsch', 'him', 'him', 'HIRSCH', 'I', 'Hirsch', 'HIRSCH', 'Hirsch', 'you', 'HIRSCH', 'HIRSCH', 'Hirsch', 'his', 'HIRSCH', 'Hirsch', 'HIRSCH', 'me', 'Hirsch', 'his', 'HIRSCH', 'sir']
# pred ==> ['he', 'him', 'him', 'He', "HIRSCH'S", 'He', "HIRSCH'S", 'HIRSCH', 'He', 'he', 'he', 'HIRSCH', 'Hirsch', 'him', 'HIRSCH', 'I', 'I', 'I', 'I', 'Hirsch', 'HIRSCH', 'You', 'you', 'You', 'you', 'I', 'I', 'Hirsch', 'him', 'Hirsch', 'him', 'him', 'HIRSCH', 'I', 'Hirsch', 'I', 'HIRSCH', 'You', 'Hirsch', 'me', 'you', 'me', 'HIRSCH', 'You', 'you', 'You', 'HIRSCH', 'You', 'Hirsch', 'his']
#
#
# gold cluster 2 (103 mentions) <-> pred cluster 3 (53 mentions): 35 common mentions
# gold ==> ["LANDY'S", 'Pam', 'You', 'Landy', 'LANDY', 'LANDY', 'you', 'LANDY', 'I', 'I', "LANDY'S", "LANDY'S", 'She', 'LANDY', 'Pamela Landy', 'you', "LANDY'S", 'LANDY', 'her', 'LANDY', 'Landy', "LANDY'S", 'LANDY', 'I', 'I', 'LANDY', "LANDY'S", 'LANDY', 'She', 'her', 'LANDY', 'she', 'LANDY', "LANDY'S", 'LANDY', 'Pam', 'You', "LANDY'S", 'She', "LANDY'S", 'Landy', 'her', 'Landy', 'Landy', 'Landy', 'she', 'Landy', 'She', 'Landy', 'Landy']
# pred ==> ["LANDY'S", 'Landy', 'LANDY', 'LANDY (O.S.)', 'LANDY', "LANDY'S", "NEW YORK                203\n\n       LANDY'S", 'She', "LANDY'S", 'OFFICE                                        203\n\n       LANDY', 'her', 'LANDY\n                Bourne', 'Landy', "LANDY'S", 'LANDY', 'you', 'LANDY (V.O.)', "LANDY'S", "LANDY'S OFFICE                                        203\n\n                             LANDY", 'She', 'her', 'LANDY\n                David Webb', 'LANDY (V.O.)', "LANDY'S", "LANDY'S", 'She', "LANDY'S", 'DAY                                  212\n\n       Landy', 'her', 'Landy', 'WILLS\n                  Landy', 'Wills', "VOSEN\n                  Check Landy's", 'she', 'DAY                                 217B\n\n       Landy', 'She', 'Landy', 'Wills', 'Landy', 'her', 'Landy', 'Wills', 'LANDY', 'Landy', 'LANDY', 'DAY                                       226\n\n       LANDY', 'Landy', 'Landy', '230\n\n       Landy', 'Landy']
#
#
# gold cluster 5 (21 mentions) <-> pred cluster 13 (10 mentions): 10 common mentions
# gold ==> ['Paz', 'his', 'Paz', 'his', 'Paz', 'Paz', 'Paz', 'Paz', 'he', 'Paz', 'Paz', 'Paz', 'Paz', 'his', 'Paz', "Paz's", 'PAZ', 'He', 'his', 'PAZ', 'asset']
# pred ==> ['Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', 'Paz', "Paz's"]
#
#
# gold cluster 4 (26 mentions) <-> pred cluster 7 (14 mentions): 8 common mentions
# gold ==> ['WILLS', 'Wills', 'WILLS', 'Wills', 'WILLS', 'Wills', 'Wills', 'WILLS', 'Wills', 'Wills', 'WILLS', 'Wills', 'Wills', 'Sir', 'Wills', 'WILLS', 'Wills', 'WILLS', 'WILLS', 'Wills', 'Wills', 'Wills', 'WILLS', 'Wills', 'he', 'WILLS']
# pred ==> ['Wills', 'Wills', 'Wills', 'WILLS', 'Wills', 'Wills', 'his', 'Wills', 'HUB                                                 289A\n\n       Wills', 'WILLS', 'She', 'She', 'I', 'me']
#
#
# gold cluster 6 (16 mentions) <-> pred cluster 15 (8 mentions): 4 common mentions
# gold ==> ['CRONIN', 'CRONIN', "CRONIN'S", 'CRONIN', 'CRONIN', 'CRONIN', "CRONIN'S", 'CRONIN', 'CRONIN', "CRONIN'S", "CRONIN'S", 'CRONIN', 'Cronin', 'CRONIN', 'Cronin', 'CRONIN']
# pred ==> ['CRONIN\n                  Pam', 'CRONIN', "CRONIN'S", "CRONIN'S", "CRONIN'S OFFICE                                       201\n\n                           CRONIN", 'he', 'CRONIN', 'Pam']
#
#
# gold cluster 10 (7 mentions) <-> pred cluster 23 (6 mentions): 3 common mentions
# gold ==> ['the driver', 'The driver', 'his', 'He', 'He', 'The driver', 'The driver']
# pred ==> ['CRI AGENT (RADIO V.O.)', 'He', 'his', 'He', 'He', 'him']
#
#
# gold cluster 20 (3 mentions) <-> pred cluster 19 (7 mentions): 3 common mentions
# gold ==> ['Daniels', 'Daniels', 'Daniels']
# pred ==> ['Daniels', 'him', 'his', 'Daniels', 'He', 'Daniels', 'he']
#
#
# gold cluster 11 (6 mentions) <-> pred cluster 151 (2 mentions): 2 common mentions
# gold ==> ['he', 'he', 'a hooded\n      figure', 'The man', 'the figure', 'he']
# pred ==> ['a hooded\n      figure', 'the figure']

# %%
basterds_info = get_gold_and_pred_clusters("basterds", basterds_doc)
# Out:
# 23 gold clusters. Top 20 clusters =>
#   0	188 mentions	['she', 'she', 'she', "Frau Von Hammersmark's", 'Frau Von Hammersmark', 'She', 'she', 'She', 'She', 'She', 'your fraulein\n          Von Hammer', 'the fraulein of\n          the hour, UFA diva, BRIDGET VON HAMMERSMARK', 'Bridget Von Hammersmark', 'her', 'her', 'BRIDGET/GENGUS', 'Fraulein Von Hammersmark', 'she', 'BRIDGET', 'my']
#   1	180 mentions	['ONE GERMAN MASTER SGT', 'MASTER SGT #1', 'SGT.POLA NEGRI', 'SGT.POLA NEGRI', 'the Master Sgt', 'The Sgt over\n          there', 'His', 'him', 'his', 'Master Sgt.Pola Negri', 'his', 'he', 'the German Master Sgt', 'his', 'the German Master Sgt', 'SGT.POLA NEGRI', 'I', 'my', 'Wilhelm', 'This handsome happy Sgt']
#   2	171 mentions	['A GERMAN VOICE', 'GERMAN VOICE', 'I', 'the unknown German', 'MAJOR DEITER HELLSTROM', 'The Major', 'he', 'MAJOR HELLSTROM', 'I', 'I', 'Major', 'MAJOR HELLSTROM', 'T', 'I', 'I', 'The Gestapo Major', 'MAJOR HELLSTROM', 'you', 'MAJOR HELLSTROM', 'you']
#   3	152 mentions	['LT.HICOX', 'Hicox', 'You', 'LT.HICOX', 'I', 'You', 'LT.HICOX', 'You', 'LT.HICOX', 'Lt.Hicox', 'Lt.Hicox', 'LT.NICOX', 'sir', 'LT.HICOX', 'LT.HICOX', 'I', 'I', 'the limy Lieutenant', 'you', 'LT.HICOX']
#   4	 79 mentions	['LT.ALDO RAINE', 'Aldo', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'Aldo', 'him', 'yours', 'Aldo', 'LT.ALDO', 'Lieutenant', 'LT.ALDO', 'LT.ALDO', "Aldo's", "ALDO'S", 'you', "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S"]
#   5	 59 mentions	['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz', 'Stiglitz', 'STIGLITZ', 'He', 'your', 'Stiglitz', 'You', 'The renegade Gerry Sergeant', 'his', 'STIGLITZ', 'I']
#   6	 36 mentions	['GERMAN PRIVATE #5', 'German#5', 'WINNETOU', 'I', 'I', 'you', 'he', 'he', 'he', 'He', 'He', 'he', 'he', 'WINNETOU', 'I', 'I', 'WINNETOU', 'I', 'I', 'He']
#   7	 19 mentions	['Wilhelm Wicki', 'WICKI', 'Wicki', 'WICKI', 'WICXI', 'your', 'WICKI', 'Wicki', 'WICKI', 'you\n          Lt.Saltzberg', 'Wicki', 'Wicki', 'WICKI', 'WICKI', 'Wicki', 'WICKI', 'his', 'WICKI', 'WICKI']
#   8	 18 mentions	['Hirschberg', 'PFC.HIRSCHBERG', 'I', 'I', 'Hirschberg', 'HIRSCHBERG', 'him', 'he', 'Hirschbeg', 'Hirschberg', 'Hirscberg', 'Hirscberg', 'HIRSCHBERG', 'I', 'HIRSCHBERG', 'HIRSCHBERG', 'Hirschberg', 'Hirschberg']
#   9	 18 mentions	['my son', 'his', 'this progeny', 'His', 'he', 'him', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', "Max's", 'His', 'little\n          Max', 'his', 'that little gatzenjammer\n          Max', 'him']
#  10	 15 mentions	['We', 'WE', 'We', 'our', 'WE', 'our', 'us (the audience)', 'We', 'our', 'we', 'WE', 'We', 'WE', 'we', 'We']
#  11	 13 mentions	['a Nazi', 'ONE LONE NAZI\n          PRIVATE', 'himself', 'the German soldier', 'the urinating Nazi', 'The GERMAN PISSING PRIVATE', 'his', 'his', 'his', 'he', 'him', 'him', 'our urinating friend']
#  12	 10 mentions	['GERMAN PRIVATE #4', 'EDGAR WALLACE', 'you', 'EDGAR WALLACE', 'EDGER WALLACE', 'I', 'He', 'YOU', 'Edgar Wallace', 'EDGAR WALLACE']
#  13	  9 mentions	['the YOUNG FRENCH BARMAID, the only other\n          person in the establishment', 'The French Barmaid', 'She', 'her', 'she', 'The Barmaid', 'her', 'The French Barmaid', 'The FRENCH BARMAID']
#  14	  8 mentions	['GERMAN PRIVATE #3', 'MATA HARI', 'MATA HARI', 'MATA HARI', 'My', 'I', 'Mata Hari', 'HATA HARI']
#  15	  7 mentions	['Donowitz', 'SGT.DONOWITZ', 'SGT.DONOWITZ', 'Sgt.Donowitz', 'SGT.DONOWITZ', 'Sgt.', 'Donowitz']
#  16	  6 mentions	['Eric', 'Eric', 'Eric', 'ERIC', 'Eric', 'Eric']
#  17	  5 mentions	['ONE FEMALE GERMAN SGT', 'FEMALE SGT #2', 'FEMALE SGT/BEETHOVEN', 'Beethoven', 'FEMALE SGT.BEETHOVEN']
#  18	  3 mentions	['Goebbels', 'Goebbels', 'Goebbels']
#  19	  3 mentions	['The Fubrer', 'Hitler', 'Hitler']
#
# 191 pred clusters. Top 20 clusters =>
#   0	 78 mentions	["Aldo's", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", 'she', "ALDO'S", 'she', 'Aldo', 'She', 'she', "ALDO'S", 'ya', 'your']
#   1	 62 mentions	['QZ\n\n          BRIDGET', 'my', 'I', 'I', 'my', 'your', 'yourself', 'BRIDGET', 'you', 'BRIDGET', 'BRIDGET', 'Bridget', 'BRIDGET', 'you', "Bridget's", 'Bridget', 'BRIDGET', 'BRIDGET\n          So Wilhelm', 'you', 'Bridget']
#   2	 57 mentions	['KONG POLO DRUMMOND HELM PABST\n\n          MAJ.KING KONG', 'I', 'I', 'I', 'I', 'My', 'I', 'my', 'I', 'my', 'I', 'my', 'me', 'I', 'I', 'I', 'my', 'I', 'I', 'I']
#   3	 51 mentions	['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz', 'LT.NICOX\n          Stiglitz', 'STIGLITZ', 'He', 'I', 'your', 'Stiglitz', 'I', 'I', 'STIGLITZ', 'I']
#   4	 39 mentions	['yap Willi', 'Willi', 'WILLI\n          Keep', 'Willi', 'Willi', 'Willi', 'Willi', 'Willi', 'WILLI', 'you', 'WILLI', 'Willi', 'you', 'you', 'Willi', 'I', 'Willi', 'his', 'I', 'WILLI']
#   5	 27 mentions	['your', 'your', 'you', 'your', 'me', 'I', 'you', 'your', 'I', 'you', 'me', 'your', 'you', 'I', 'I', 'I', 'I', 'I', 'I', 'I']
#   6	 21 mentions	['BRIDGET VON HAMMERSMARK', 'Bridget Von Hammersmark', 'her', 'MATA HARI\n          Frau Von Hammersmark, when your\n          friends came in', 'Bridget Von Hammersmark', 'herself', 'She', 'her', 'She', 'She', 'she', "Bridget's", "Bridget's", 'SGT.POLA NEGRI\n          Frau Von Hammersmark', 'you', 'Bridget Von Hammersmark', 'her', 'she', 'my', 'I']
#   7	 19 mentions	['we', 'we', 'we', 'we', 'ours', 'we', 'us', 'our', 'we', 'we', 'We', 'we', 'we', 'us', 'we', 'We', 'we', 'we', 'us']
#   8	 18 mentions	['Lt.Hicox', 'LT.HICOX', 'LT.HICOX', 'LT.HICOX', 'it', 'LT.HICOX', 'She', 'she', 'She', 'LT.HICOX', 'She', 'She', 'LT.HICOX', 'She', 'She', 'her', 'she', 'LT.HICOX']
#   9	 18 mentions	['before\n          MAJOR DEITER HELLSTROM of the GESTAPO', 'MAJOR HELLSTROM', 'HELLSTROM', 'MAJOR HELLSTROM', 'the Sgt.\n\n          MAJOR HELLSTROM', 'HELLSTROM', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'HELLSTROM', 'Major Hellstrom', 'HELLSTROM\n          Nov', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'HELLSTROM', "HELLSTROM'S"]
#  10	 15 mentions	['the\n          young German Sgt, with the machine gunn', 'The German Sgt', 'The young German Sgt', 'GERMAN SGT', 'you', 'GERMAN SGT', 'I', 'GERMAN SGT', 'I', 'My', 'my', 'your', 'your', 'The German Sgt', 'his']
#  11	 15 mentions	['You', 'your', 'you', 'you', 'I', 'I', 'you', 'you', 'Your', 'my', 'my', 'me', 'I', 'I', 'I']
#  12	 14 mentions	['The Major', 'The Gestapo Major', 'the Gestapo Major', 'The Gestapo Major', 'The Major', 'Major', 'Major', 'the Major', 'The Gestapo Major', 'his', "the Nazi Major's", 'Major', 'Major', 'the Nazi Major']
#  13	 14 mentions	['GERMAN SGT\n          Wilhelm', 'Wilhelm', 'Wilhelm', 'WILHELM', 'I', 'WILHELM', 'WILHELM\n          1', 'WILHELM', 'I', 'WILHELM', 'Wilhelm', 'WILHELM', 'Wilhelm', 'I']
#  14	 12 mentions	['SGT.POLA NEGRI', 'SGT.POLA NEGRI', 'He', 'his', 'SGT.POLA NEGRI', 'His', 'he', 'him', 'He', 'his', 'SGT.POLA NEGRI', 'SGT.POLA NEGRI']
#  15	 12 mentions	["ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", 'the voice', "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)", "ALDO'S VOICE(OS)"]
#  16	 12 mentions	['Wicki', 'Wicki', 'WICKI', 'he', 'he', 'WICKI', 'Wicki', 'WICKI', 'his', 'he', 'WICKI', 'WICKI']
#  17	 10 mentions	['KONG POLO DRUMMOND', 'MAJ.KING KONG', 'MAJ.KING KONG', 'MAJ.KING KONG', 'MAJ.KING KONG', 'MAJ.KING KONG', 'MAJ.KING KONG', 'MAJ.KING KONG', 'KONG', 'King Kong']
#  18	 10 mentions	['WINNETOU\n          .', 'I', 'I', 'you', 'I', 'I', 'I', 'I', 'my', 'me']
#  19	  8 mentions	['you', 'your', 'you', 'you', 'I', 'you', 'you', 'I']
#  20	  8 mentions	['I', 'my', 'I', 'I', 'I', 'I', 'I', 'I']
#  21	  8 mentions	['she', 'she', 'her', 'she', 'She', 'she', 'her', 'she']
#
# gold cluster 0 (188 mentions) <-> pred cluster 1 (62 mentions): 44 common mentions
# gold ==> ['she', 'she', 'she', "Frau Von Hammersmark's", 'Frau Von Hammersmark', 'She', 'she', 'She', 'She', 'She', 'your fraulein\n          Von Hammer', 'the fraulein of\n          the hour, UFA diva, BRIDGET VON HAMMERSMARK', 'Bridget Von Hammersmark', 'her', 'her', 'BRIDGET/GENGUS', 'Fraulein Von Hammersmark', 'she', 'BRIDGET', 'my', 'I', 'I', 'my', 'Frau Von Hammersmark', 'your', 'yourself', 'BRIDGET', 'Bridget Von Hammersmark', 'her', 'Frau Von Hammersmark', 'your', 'you', 'you', 'BRIDGET', 'I', 'you', 'you', 'BRIDGET', 'Bridget', 'Bridget Von Hammersmark', 'herself', 'She', 'her', 'BRIDGET', 'I', 'She', 'She', 'she', "Bridget's", 'BRIDGET']
# pred ==> ['QZ\n\n          BRIDGET', 'my', 'I', 'I', 'my', 'your', 'yourself', 'BRIDGET', 'you', 'BRIDGET', 'BRIDGET', 'Bridget', 'BRIDGET', 'you', "Bridget's", 'Bridget', 'BRIDGET', 'BRIDGET\n          So Wilhelm', 'you', 'Bridget', 'her', 'BRIDGET', 'you', 'She', 'her', 'her', 'BRIDGET', 'your', 'BRIDGET', 'BRIDGET', 'your', 'BRIDGET', 'BRIDGET', 'Bridget', 'BRIDGET', 'you', 'BRIDGET', 'BRIDGET', 'BRIDGET', 'you', 'you', 'Bridget', 'your', 'me', 'You', 'your', 'you', 'your', 'I', 'you']
#
#
# gold cluster 4 (79 mentions) <-> pred cluster 0 (78 mentions): 41 common mentions
# gold ==> ['LT.ALDO RAINE', 'Aldo', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'Aldo', 'him', 'yours', 'Aldo', 'LT.ALDO', 'Lieutenant', 'LT.ALDO', 'LT.ALDO', "Aldo's", "ALDO'S", 'you', "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", 'you', "ALDO'S", "ALDO'S", 'Aldo', "ALDO'S", 'your', "ALDO'S", 'I', "ALDO'S", "ALDO'S", 'my', 'You', 'me', 'my', 'Aldo', "ALDO'S", 'I', 'you', "ALDO'S", "ALDO'S", 'Aldo', 'you', 'Aldo', 'Aldo', 'his', 'ALDO']
# pred ==> ["Aldo's", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", "ALDO'S", 'she', "ALDO'S", 'she', 'Aldo', 'She', 'she', "ALDO'S", 'ya', 'your', "ALDO'S", 'Aldo', "ALDO'S", 'your', 'you', 'her', 'you', 'she', "ALDO'S", 'my', 'me', 'the girl', 'the\n          girl', 'ya', "ALDO'S", 'I', 'I', "ALDO'S", 'ya', 'I', 'the girl', "ALDO'S", 'her', 'WILLI\n          Okay Aldo', 'you', 'Aldo', 'Aldo', 'his', 'the girl', 'ALDO']
#
#
# gold cluster 2 (171 mentions) <-> pred cluster 2 (57 mentions): 40 common mentions
# gold ==> ['A GERMAN VOICE', 'GERMAN VOICE', 'I', 'the unknown German', 'MAJOR DEITER HELLSTROM', 'The Major', 'he', 'MAJOR HELLSTROM', 'I', 'I', 'Major', 'MAJOR HELLSTROM', 'T', 'I', 'I', 'The Gestapo Major', 'MAJOR HELLSTROM', 'you', 'MAJOR HELLSTROM', 'you', 'You', 'MAJOR HELLSTROM', 'I', 'Major', 'the Gestapo Major', 'MAJOR HELLSTROM', 'Major Hellstrom', 'MAJOR HELLSTROM', 'I', 'Major', 'The Gestapo Major', 'Majors', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'I', 'You', 'MAJOR BELLSTROM', 'MAJOR HELLSTROM', 'he', 'MAJOR HELLSTROM', 'Major', 'MAJOR HELLSTROM', 'me', 'MAJOR HELLSTROM', 'I', 'I', 'MAJOR HELLSTROM', 'The Major', 'MAJOR HELLSTROM']
# pred ==> ['KONG POLO DRUMMOND HELM PABST\n\n          MAJ.KING KONG', 'I', 'I', 'I', 'I', 'My', 'I', 'my', 'I', 'my', 'I', 'my', 'me', 'I', 'I', 'I', 'my', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'you', 'I', 'my', 'I', 'I', 'I', 'my', 'I', 'I', 'me', 'I', 'you', 'Your', 'You', 'you', 'me', 'I', 'me', 'I', 'you', 'my', 'you', 'my', 'yourself', 'Your', 'You']
#
#
# gold cluster 5 (59 mentions) <-> pred cluster 3 (51 mentions): 35 common mentions
# gold ==> ['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz', 'Stiglitz', 'STIGLITZ', 'He', 'your', 'Stiglitz', 'You', 'The renegade Gerry Sergeant', 'his', 'STIGLITZ', 'I', 'you', 'you', 'He', 'his', 'his', 'This Gerry of yours, Stiglitz', 'he', 'Hugo Stiglitz', 'Stiglitz', 'STIGLITZ', 'He', 'Stiglitz', 'STIGLITZ', 'Hugo Stiglitz', 'him', 'Hugo', 'the slightly psychotic Stiglitz', 'STIGLITZ', 'Lieutenant', 'Stiglitz', 'STIGLITZ', 'STIGLITZ', 'you', 'Lt.Berlin', 'STIGLITZ', 'Hugo', 'his', 'Stiglitz', 'SGT.STIGLITZ', 'SGT.STIGLITZ']
# pred ==> ['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz', 'LT.NICOX\n          Stiglitz', 'STIGLITZ', 'He', 'I', 'your', 'Stiglitz', 'I', 'I', 'STIGLITZ', 'I', 'I', 'He', 'his', 'his', 'Stiglitz', 'Hugo Stiglitz', 'him', 'Stiglitz', 'STIGLITZ', 'He', 'his', 'his', 'his', 'he', 'him', 'him', 'Stiglitz', 'Hugo Stiglitz', 'him', 'Stiglitz', 'STIGLITZ', 'Stiglitz', 'STIGLITZ', 'YOU', 'STIGLITZ', 'INTO\n          STIGLITZ', 'Stiglitz', 'Stiglitz', 'STIGLITZ', 'STIGLITZ']
#
#
# gold cluster 1 (180 mentions) <-> pred cluster 4 (39 mentions): 27 common mentions
# gold ==> ['ONE GERMAN MASTER SGT', 'MASTER SGT #1', 'SGT.POLA NEGRI', 'SGT.POLA NEGRI', 'the Master Sgt', 'The Sgt over\n          there', 'His', 'him', 'his', 'Master Sgt.Pola Negri', 'his', 'he', 'the German Master Sgt', 'his', 'the German Master Sgt', 'SGT.POLA NEGRI', 'I', 'my', 'Wilhelm', 'This handsome happy Sgt', 'the Sgt', 'The German Master Sgt', 'his', 'his', 'SGT.POLA NEGRI', 'He', 'his', 'Wilhelm', 'SGT.POLA NEGRI', 'I', 'this German Sgt', 'Sgt', 'SGT.POLA NEGRI', 'I', 'I', 'He', 'his', 'you', 'the young father', 'SGT.POLA NEGRI', 'I', 'SGT.POLA NEGRI', 'I', 'the German Sgt', 'his', 'his', 'he', 'he', 'he', 'his']
# pred ==> ['yap Willi', 'Willi', 'WILLI\n          Keep', 'Willi', 'Willi', 'Willi', 'Willi', 'Willi', 'WILLI', 'you', 'WILLI', 'Willi', 'you', 'you', 'Willi', 'I', 'Willi', 'his', 'I', 'WILLI', 'Willi', 'WILLI', 'You', 'me', 'WILLI', 'Willi', 'I', 'I', 'him', 'I', 'Willi', 'i', 'I', 'Willi', 'Willi', 'He', 'my', 'Willi', 'Willi']
#
#
# gold cluster 3 (152 mentions) <-> pred cluster 5 (27 mentions): 11 common mentions
# gold ==> ['LT.HICOX', 'Hicox', 'You', 'LT.HICOX', 'I', 'You', 'LT.HICOX', 'You', 'LT.HICOX', 'Lt.Hicox', 'Lt.Hicox', 'LT.NICOX', 'sir', 'LT.HICOX', 'LT.HICOX', 'I', 'I', 'the limy Lieutenant', 'you', 'LT.HICOX', 'I', 'Hicox', 'LT. HI COX', 'him', 'you', 'LT.HICOX', 'LT.HICOX', 'LT.HICOX', 'LT.HICOX', 'LT.HICOX', 'Lieutenant', 'Lt.Bicox', 'LT.HICOX', 'him', 'you', 'your', 'LT.HICOX', 'I', 'The British officer', 'him', 'Hicox', 'LT.HICOX', 'HICOX', 'one Brit', 'LT.HICOX', 'I', 'LT.HICOX', 'LT.HICOX', 'Hicox', 'You']
# pred ==> ['your', 'your', 'you', 'your', 'me', 'I', 'you', 'your', 'I', 'you', 'me', 'your', 'you', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'myself', 'my', 'my', 'my', 'My']
#
#
# gold cluster 7 (19 mentions) <-> pred cluster 16 (12 mentions): 9 common mentions
# gold ==> ['Wilhelm Wicki', 'WICKI', 'Wicki', 'WICKI', 'WICXI', 'your', 'WICKI', 'Wicki', 'WICKI', 'you\n          Lt.Saltzberg', 'Wicki', 'Wicki', 'WICKI', 'WICKI', 'Wicki', 'WICKI', 'his', 'WICKI', 'WICKI']
# pred ==> ['Wicki', 'Wicki', 'WICKI', 'he', 'he', 'WICKI', 'Wicki', 'WICKI', 'his', 'he', 'WICKI', 'WICKI']
#
#
# gold cluster 6 (36 mentions) <-> pred cluster 18 (10 mentions): 8 common mentions
# gold ==> ['GERMAN PRIVATE #5', 'German#5', 'WINNETOU', 'I', 'I', 'you', 'he', 'he', 'he', 'He', 'He', 'he', 'he', 'WINNETOU', 'I', 'I', 'WINNETOU', 'I', 'I', 'He', 'WINNETOU', 'my', 'WINNETOU', 'me', 'Winnetou', 'you', 'WINNETOU', 'I', 'he', 'his', 'Winnetou', 'YOU', 'WINNETOU', 'I', 'WINNETOU', 'he']
# pred ==> ['WINNETOU\n          .', 'I', 'I', 'you', 'I', 'I', 'I', 'I', 'my', 'me']
#
#
# gold cluster 9 (18 mentions) <-> pred cluster 25 (8 mentions): 7 common mentions
# gold ==> ['my son', 'his', 'this progeny', 'His', 'he', 'him', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', "Max's", 'His', 'little\n          Max', 'his', 'that little gatzenjammer\n          Max', 'him']
# pred ==> ['Maximilian', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', "Max's"]
#
#
# gold cluster 13 (9 mentions) <-> pred cluster 39 (5 mentions): 5 common mentions
# gold ==> ['the YOUNG FRENCH BARMAID, the only other\n          person in the establishment', 'The French Barmaid', 'She', 'her', 'she', 'The Barmaid', 'her', 'The French Barmaid', 'The FRENCH BARMAID']
# pred ==> ['the YOUNG FRENCH BARMAID, the only other\n          person in the establishment', 'The French Barmaid', 'The Barmaid', 'her', 'The French Barmaid']

# %%
shawshank_info = get_gold_and_pred_clusters("shawshank", shawshank_doc)
# Out:
# 44 gold clusters. Top 20 clusters =>
#   0	293 mentions	["ANDY DUFRESNE, mid-20's, wire rim glasses, three-piece suit", 'He', 'his', 'His', 'He', 'He', 'him', 'He', 'He', 'his', 'He', 'He', 'his', 'His', 'He', 'He', 'His', 'He', 'his', 'he']
#   1	185 mentions	['RED', 'his', 'Red', 'your', 'you', 'You', 'you', 'RED', 'I', 'my', 'I', 'I', 'I', 'him', 'RED', 'his', 'He', 'RED', 'me', 'I']
#   2	 56 mentions	['HEYWOOD', 'HEYWOOD', 'my', 'you', 'Heywood', 'you', 'HEYWOOD', 'I', 'HEYWOOD', 'my', 'You', 'you', 'HEYWOOD', 'I', 'me', 'Heywood', 'HEYWOOD', 'I', 'I', 'HEYWOOD']
#   3	 49 mentions	['that chubby fat-ass', 'Fat-Ass', 'Fat-Ass', 'Faaaat-Ass', 'boy', 'you', 'you', 'you', "FAT-ASS'", 'Fat-Ass', 'you', 'you', 'your', 'yours', 'Fat-Ass', 'FAT-ASS', 'I', 'I', 'FAT-ASS', 'Fat-Ass']
#   4	 40 mentions	['WOMAN', 'her', 'her', 'She', 'her', 'her', 'her', 'She', 'her', 'her', 'her', 'her', 'WOMAN', 'The woman', 'WOMAN', 'I', 'your\n\t\twife', 'she', 'She', 'she']
#   5	 34 mentions	['BYRON HADLEY, captain of the guard', 'his', 'HADLEY', 'I', 'HADLEY', 'Mr. Hadley, captain of the\n\t\tguard', 'Hadley', 'HADLEY', 'Hadley', 'his', 'Hadley', 'his', 'HADLEY', 'I', 'I', 'HADLEY', 'Hadley', 'HADLEY', 'Hadley', 'himself']
#   6	 31 mentions	['D.A.', 'D.A.', 'D.A.', 'his', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'I', 'me', 'D.A.', 'I', 'I', 'D.A.', 'D.A.', 'D.A.', 'D.A.']
#   7	 24 mentions	['BROOKS HATLEN', 'he', 'BROOKS', 'BROOKS', 'Brooks', 'Brooks', 'his', 'BROOKS', 'Brooks', 'his', 'BROOKS', 'Brooks Hatlen', 'He', 'him', 'Brooks', 'He', 'his', 'BROOKS', 'Brooks', 'his']
#   8	 22 mentions	['A MAN', 'He', 'He', 'his', 'his', 'He', 'He', 'him', 'his', 'He', 'him', 'you', 'Mr. Quentin', 'Glenn Quentin', 'The golf pro at the\n\t\tFalmouth Hills Country Club', 'The\n\t\tman', "Mr. Quentin's", 'her lover', 'her\n\t\tlover', 'her lover']
#   9	 16 mentions	['CON', 'the con', 'his', 'YOU', 'YOU', 'YOU', 'YOU', 'YOU', 'YOU', 'YOU', 'YOU', 'YOU MAGGOT-\n\t\tDICK MOTHERFUCKER', "the con's", 'The\n\tman', 'his', 'himself']
#  10	 16 mentions	['WARDEN SAMUEL NORTON', 'a colorless man in a gray\n\tsuit and a church pin in his lapel', 'He', 'he', 'He', 'NORTON', 'Mr. Norton, the warden', 'me', 'I', 'my', "Norton's", "Norton's", 'NORTON', 'I', 'the warden', 'him']
#  11	 12 mentions	['FLOYD', 'FLOYD', 'FLOYD', 'me', 'your', 'FLOYD', 'You', 'son', 'FLOYD', 'Floyd', 'FLOYD', 'my']
#  12	 11 mentions	['We', 'we', 'we', 'we', 'We', 'We', 'we', 'We', 'us', 'we', 'WE']
#  13	  9 mentions	['BOGS DIAMOND', 'Bogs', 'his', 'Bogs', 'BOGS', 'BOGS', 'I', 'Bogs', 'Bogs']
#  14	  8 mentions	['the FIRST CON', 'The con', 'the con', 'that piece of shit', 'The con', 'him', 'his', 'he']
#  15	  8 mentions	['THE JUDGE', 'JUDGE', 'me', 'my', 'me', 'I', 'He', 'his']
#  16	  8 mentions	['a black con, LEONARD', 'Leonard', 'Leonard', 'Leonard', 'his', 'Leonard', 'He', "Leonard's"]
#  17	  7 mentions	['JIGGER', 'JIGGER', 'Joe', 'JIGGER', 'Jigger', 'Jigger', 'Jigger']
#  18	  6 mentions	['Tyrell', 'you', 'TYRELL', 'He', 'his', 'his']
#  19	  5 mentions	['A naked CON', 'his', 'The con', 'his', 'his']
#
# 164 pred clusters. Top 20 clusters =>
#   0	261 mentions	['Andy', "Andy's", 'He', 'his', 'Andy', 'He', 'he', 'his', 'his', 'ANDY', 'ANDY', 'ANDY', 'Andy', 'ANDY', 'I', 'I', 'I', 'my', 'ANDY', 'I']
#   1	 45 mentions	['Red', 'Red', 'Red', 'his', 'Red', 'Red', 'Red', 'Red', 'his', 'Red', 'his', 'his', 'Red', 'He', "RED'S", "Red's", 'Red', "RED'S", "RED'S", 'Red']
#   2	 39 mentions	['BYRON HADLEY, captain of the guard,', 'his', 'HADLEY', 'Hadley', 'his', 'HADLEY', 'Hadley', 'his', 'The\n\tman', 'his', 'himself', 'Hadley', 'his', 'I', 'me', 'HADLEY', 'I', 'I', 'HADLEY', 'Hadley']
#   3	 31 mentions	['He', 'He', 'his', 'his', 'He', 'He', 'him', 'his', 'He', 'him', 'He', 'his', 'His', 'He', 'He', 'him', 'You', 'you', 'He', 'He']
#   4	 30 mentions	['One man\n\tpaces like a caged animal', 'his', 'He', 'his', 'me', 'I', 'you', 'I', 'you', 'you', 'I', 'you', 'you', 'I', 'your', 'yours', 'I', 'I', 'I', 'MY']
#   5	 28 mentions	["HEYWOOD'S", 'HEYWOOD', 'Heywood', "HEYWOOD\n\t\tMornin'", 'Heywood', 'his', 'HEYWOOD', 'Heywood', 'Heywood', 'HEYWOOD', 'HEYWOOD', 'his', 'He', 'He', 'him', 'him', 'his', 'Heywood', 'Heywood', 'Heywood!']
#   6	 24 mentions	['Mr. Dufresne', 'ANDY DUFRESNE', 'He', 'Mr. Dufresne', 'Mr.\n\t\tDufresne', 'Mr. Dufresne', 'You', 'you', 'your', 'Mr. Dufresne', 'I', 'I', "Mr. Dufresne's", 'he', 'his', 'He', 'he', 'he', 'Mr. Dufresne', 'Andy Dufresne']
#   7	 20 mentions	['BROOKS HATLEN', 'he', 'BROOKS', 'You', 'BROOKS', 'You', 'Brooks', 'Brooks', 'his', 'BROOKS', 'Brooks', 'his', 'BROOKS\n\t\tJake', 'his', 'I', 'him', 'he', 'that boy', 'him', 'him']
#   8	 16 mentions	['your\n\t\twife', 'she', 'She', 'she', 'I', 'she', 'She', 'she', 'her', 'your\n\t\twife', 'She', 'your wife', 'her', 'his\n\t\twife', 'his wife', 'she']
#   9	 16 mentions	['you', 'your', 'your', 'I', 'I', 'I', 'you', 'I', 'you', 'your', 'I', 'I', 'you', 'your', 'you', 'you']
#  10	 13 mentions	['D.A.', 'D.A.', 'his', 'D.A', 'D.A', 'D.A.', 'D.A.', 'D.A', 'D.A.', 'I', 'I', 'I', 'I']
#  11	 13 mentions	['You', 'you', 'you', 'your', 'your', 'you', 'You', 'you', 'I', 'my', 'I', 'I', 'I']
#  12	 11 mentions	['her', 'her', 'She', 'her', 'her', 'her', 'She', 'her', 'her', 'her', 'her']
#  13	 11 mentions	['43\n\n\tBrooks Hatlen', 'Brooks', 'He', 'his', 'BROOKS', 'Brooks', 'his', 'He', 'his', 'Brooks', 'his']
#  14	 11 mentions	['A penlight', 'his', 'his', 'his', 'his', 'He', 'me', 'He', 'me', 'He', 'my']
#  15	 10 mentions	['the con', "the con's", 'the FIRST CON', 'The con', 'the con', 'The con', 'him', 'his', 'he', 'The con']
#  16	 10 mentions	['a\n\t\tchanged man', 'him', 'his', 'He', 'me', 'I', 'I', 'you', 'He', 'I']
#  17	  9 mentions	['WARDEN SAMUEL NORTON', 'his', 'He', 'he', 'He', 'NORTON', 'the warden', "Norton's", "Norton's"]
#  18	  9 mentions	['Andy and the others', 'their', 'their', 'them', 'the new men', 'their', 'They', 'they', 'they']
#  19	  8 mentions	['HEYWOOD', 'HEYWOOD', 'Heywood', 'you', 'HEYWOOD', 'HEYWOOD', "'s", 'Heywood']
#  20	  7 mentions	['LEONARD', 'Leonard', 'Leonard', 'Leonard', 'his', 'his', "Leonard's"]
#  21	  7 mentions	['my', 'I', 'I', 'I', 'I', 'you', 'I']
#
# gold cluster 0 (293 mentions) <-> pred cluster 0 (261 mentions): 176 common mentions
# gold ==> ["ANDY DUFRESNE, mid-20's, wire rim glasses, three-piece suit", 'He', 'his', 'His', 'He', 'He', 'him', 'He', 'He', 'his', 'He', 'He', 'his', 'His', 'He', 'He', 'His', 'He', 'his', 'he', 'Andy', "Andy's", 'He', 'his', 'Andy', 'He', 'he', 'his', 'his', 'Mr. Dufresne', 'you', 'your', 'ANDY DUFRESNE', 'He', 'ANDY', 'I', 'your', 'ANDY', 'I', 'I', 'I', 'I', 'you', 'Mr. Dufresne', 'your', 'ANDY', 'I', 'I', 'you', 'your']
# pred ==> ['Andy', "Andy's", 'He', 'his', 'Andy', 'He', 'he', 'his', 'his', 'ANDY', 'ANDY', 'ANDY', 'Andy', 'ANDY', 'I', 'I', 'I', 'my', 'ANDY', 'I', 'I', 'I', 'I', 'You', 'you', 'I', 'you', 'I', 'I', 'I', 'you', 'you', 'ANDY', 'I', 'I', 'I', 'my', 'I', 'I', 'you', 'I', 'your', 'me', 'ANDY', 'I', 'I', 'ANDY', 'You', 'ANDY', 'Andy']
#
#
# gold cluster 1 (185 mentions) <-> pred cluster 1 (45 mentions): 33 common mentions
# gold ==> ['RED', 'his', 'Red', 'your', 'you', 'You', 'you', 'RED', 'I', 'my', 'I', 'I', 'I', 'him', 'RED', 'his', 'He', 'RED', 'me', 'I', 'I', 'you', 'He', 'RED', 'I', 'RED', 'me', 'me', 'I', 'Red', 'Red', 'his', 'RED', 'RED', 'RED', 'Red', 'RED', 'RED', 'Red', 'RED', 'RED', 'I', 'I', 'I', 'my', 'Red', 'RED', 'I', 'RED', 'me']
# pred ==> ['Red', 'Red', 'Red', 'his', 'Red', 'Red', 'Red', 'Red', 'his', 'Red', 'his', 'his', 'Red', 'He', "RED'S", "Red's", 'Red', "RED'S", "RED'S", 'Red', 'Red', 'Red', 'Red', 'Red', 'Red', 'RED\n\t\tRed', "The name's", "The name's Red", 'Red', '1947) 37\n\n\tRed', "RED'S", 'Red', 'RED (V.O.)', 'He', 'he', 'RED (V.O.)', 'they', "Red's", "Red's", "RED'S", '42\n\n\tRed', 'Red', 'Red', 'Red', "RED'S"]
#
#
# gold cluster 5 (34 mentions) <-> pred cluster 2 (39 mentions): 23 common mentions
# gold ==> ['BYRON HADLEY, captain of the guard', 'his', 'HADLEY', 'I', 'HADLEY', 'Mr. Hadley, captain of the\n\t\tguard', 'Hadley', 'HADLEY', 'Hadley', 'his', 'Hadley', 'his', 'HADLEY', 'I', 'I', 'HADLEY', 'Hadley', 'HADLEY', 'Hadley', 'himself', 'HADLEY', 'HADLEY', 'my', 'Hadley', 'HADLEY', 'HADLEY', 'I', 'I', 'Hadley', 'his', 'Hadley', 'HADLEY', 'I', 'Hadley']
# pred ==> ['BYRON HADLEY, captain of the guard,', 'his', 'HADLEY', 'Hadley', 'his', 'HADLEY', 'Hadley', 'his', 'The\n\tman', 'his', 'himself', 'Hadley', 'his', 'I', 'me', 'HADLEY', 'I', 'I', 'HADLEY', 'Hadley', 'Hadley himself', 'himself', 'HADLEY', 'Hadley', 'HADLEY', 'HADLEY', 'Hadley', 'his', 'his', 'Hadley', 'him', 'Hadley', 'HADLEY', 'Hadley', 'his', 'Doc', 'He', 'his', 'his']
#
#
# gold cluster 2 (56 mentions) <-> pred cluster 5 (28 mentions): 18 common mentions
# gold ==> ['HEYWOOD', 'HEYWOOD', 'my', 'you', 'Heywood', 'you', 'HEYWOOD', 'I', 'HEYWOOD', 'my', 'You', 'you', 'HEYWOOD', 'I', 'me', 'Heywood', 'HEYWOOD', 'I', 'I', 'HEYWOOD', 'I', 'I', "HEYWOOD'S", 'HEYWOOD', 'Heywood', 'he', 'HEYWOOD', 'Heywood', 'his', 'HEYWOOD', 'I', 'Heywood', 'HEYWOOD', 'I', 'I', 'I', 'him', 'your', 'cheap bastard', 'HEYWOOD', 'mine', 'Heywood', 'HEYWOOD', 'HEYWOOD', 'Heywood', 'Heywood', 'Heywood', 'you', 'boy', 'HEYWOOD']
# pred ==> ["HEYWOOD'S", 'HEYWOOD', 'Heywood', "HEYWOOD\n\t\tMornin'", 'Heywood', 'his', 'HEYWOOD', 'Heywood', 'Heywood', 'HEYWOOD', 'HEYWOOD', 'his', 'He', 'He', 'him', 'him', 'his', 'Heywood', 'Heywood', 'Heywood!', 'HEYWOOD', 'Heywood', 'He', 'his', 'He', "Heywood's", 'Heywood', 'his']
#
#
# gold cluster 4 (40 mentions) <-> pred cluster 8 (16 mentions): 14 common mentions
# gold ==> ['WOMAN', 'her', 'her', 'She', 'her', 'her', 'her', 'She', 'her', 'her', 'her', 'her', 'WOMAN', 'The woman', 'WOMAN', 'I', 'your\n\t\twife', 'she', 'She', 'she', 'she', 'She', 'she', 'you', 'you', 'your\n\t\twife', 'She', 'her', 'her', 'she', 'her', 'her', 'her', 'your wife', 'her', 'a beautiful\n\t\tyoung woman', 'her', 'his\n\t\twife', 'his wife', 'she']
# pred ==> ['your\n\t\twife', 'she', 'She', 'she', 'I', 'she', 'She', 'she', 'her', 'your\n\t\twife', 'She', 'your wife', 'her', 'his\n\t\twife', 'his wife', 'she']
#
#
# gold cluster 3 (49 mentions) <-> pred cluster 4 (30 mentions): 13 common mentions
# gold ==> ['that chubby fat-ass', 'Fat-Ass', 'Fat-Ass', 'Faaaat-Ass', 'boy', 'you', 'you', 'you', "FAT-ASS'", 'Fat-Ass', 'you', 'you', 'your', 'yours', 'Fat-Ass', 'FAT-ASS', 'I', 'I', 'FAT-ASS', 'Fat-Ass', 'FAT-ASS', 'I', 'I', 'MY', "Fat-Ass'", 'your', "you fat\n\t\tfuckin' barrel of monkey-spunk", 'FAT-ASS', 'I', 'ME', 'you', 'Fat-Ass', 'Fat-Ass', 'him', 'Fat-Ass', 'Fat-ass', 'this tub of shit', 'Fat-Ass', 'him', 'Fat-Ass', 'that horse of\n\t\tmine', 'that boy', "that winnin' horse\n\t\tof mine", 'his', 'Poor bastard', 'his', 'his', 'his', 'He']
# pred ==> ['One man\n\tpaces like a caged animal', 'his', 'He', 'his', 'me', 'I', 'you', 'I', 'you', 'you', 'I', 'you', 'you', 'I', 'your', 'yours', 'I', 'I', 'I', 'MY', 'I', 'your', 'I', 'You', 'my', 'I', 'ME', 'I', 'I', 'I']
#
#
# gold cluster 6 (31 mentions) <-> pred cluster 10 (13 mentions): 10 common mentions
# gold ==> ['D.A.', 'D.A.', 'D.A.', 'his', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'I', 'me', 'D.A.', 'I', 'I', 'D.A.', 'D.A.', 'D.A.', 'D.A.', 'sir', 'The D.A.', 'his', 'D.A.', 'He', 'D.A.', 'I', 'I', 'D.A.', 'I', 'I']
# pred ==> ['D.A.', 'D.A.', 'his', 'D.A', 'D.A', 'D.A.', 'D.A.', 'D.A', 'D.A.', 'I', 'I', 'I', 'I']
#
#
# gold cluster 7 (24 mentions) <-> pred cluster 7 (20 mentions): 10 common mentions
# gold ==> ['BROOKS HATLEN', 'he', 'BROOKS', 'BROOKS', 'Brooks', 'Brooks', 'his', 'BROOKS', 'Brooks', 'his', 'BROOKS', 'Brooks Hatlen', 'He', 'him', 'Brooks', 'He', 'his', 'BROOKS', 'Brooks', 'his', 'He', 'his', 'Brooks', 'his']
# pred ==> ['BROOKS HATLEN', 'he', 'BROOKS', 'You', 'BROOKS', 'You', 'Brooks', 'Brooks', 'his', 'BROOKS', 'Brooks', 'his', 'BROOKS\n\t\tJake', 'his', 'I', 'him', 'he', 'that boy', 'him', 'him']
#
#
# gold cluster 8 (22 mentions) <-> pred cluster 3 (31 mentions): 10 common mentions
# gold ==> ['A MAN', 'He', 'He', 'his', 'his', 'He', 'He', 'him', 'his', 'He', 'him', 'you', 'Mr. Quentin', 'Glenn Quentin', 'The golf pro at the\n\t\tFalmouth Hills Country Club', 'The\n\t\tman', "Mr. Quentin's", 'her lover', 'her\n\t\tlover', 'her lover', 'Glenn\n\t\tQuentin', "the fella she was bangin'"]
# pred ==> ['He', 'He', 'his', 'his', 'He', 'He', 'him', 'his', 'He', 'him', 'He', 'his', 'His', 'He', 'He', 'him', 'You', 'you', 'He', 'He', 'his', 'He', 'He', 'his', 'His', 'He', 'He', 'His', 'He', 'his', 'he']
#
#
# gold cluster 10 (16 mentions) <-> pred cluster 17 (9 mentions): 7 common mentions
# gold ==> ['WARDEN SAMUEL NORTON', 'a colorless man in a gray\n\tsuit and a church pin in his lapel', 'He', 'he', 'He', 'NORTON', 'Mr. Norton, the warden', 'me', 'I', 'my', "Norton's", "Norton's", 'NORTON', 'I', 'the warden', 'him']
# pred ==> ['WARDEN SAMUEL NORTON', 'his', 'He', 'he', 'He', 'NORTON', 'the warden', "Norton's", "Norton's"]

# %%
bourne_map = {0:0, 1:1, 2:3, 3:2, 4:7}
basterds_map = {0:1, 1:10, 2:2, 3:8, 4:0}
shawshank_map = {0:0, 1:1, 2:5, 3:4, 4:8}

bourne_info["map"] = bourne_map
basterds_info["map"] = basterds_map
shawshank_info["map"] = shawshank_map

# %% [markdown]
# ## Scorch Input

# %%
for info in [bourne_info, basterds_info, shawshank_info]:
    mention_to_id = {}
    main_gold_clusters = []
    main_pred_clusters = []
    
    for i, j in info["map"].items():
        main_gold_clusters.append(info["gold"][i])
        main_pred_clusters.append(info["pred"][j])
    
    for clusters in [main_gold_clusters, main_pred_clusters]:
        for cluster in clusters:
            for i, j in cluster:
                if (i, j) not in mention_to_id:
                    mention_to_id[(i, j)] = len(mention_to_id)
    
    info["gold_id"] = [[mention_to_id[(i, j)] for i, j in cluster] for cluster in main_gold_clusters]    
    info["pred_id"] = [[mention_to_id[(i, j)] for i, j in cluster] for cluster in main_pred_clusters]
    
    gold_json = {"type":"clusters", "clusters": dict([(i, mention_ids) for i, mention_ids in enumerate(info["gold_id"])])}    
    pred_json = {"type":"clusters", "clusters": dict([(i, mention_ids) for i, mention_ids in enumerate(info["pred_id"])])}
    
    json.dump(gold_json, open(f"/proj/sbaruah/movie/coreference/corefstanford/scorch.{info['name']}.gold.json", "w"))    
    json.dump(pred_json, open(f"/proj/sbaruah/movie/coreference/corefstanford//scorch.{info['name']}.pred.json", "w"))
