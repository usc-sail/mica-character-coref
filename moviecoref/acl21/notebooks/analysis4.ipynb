# %%
import jsonlines
import pandas as pd
import numpy as np
from collections import Counter
import pickle
import json

# %% [markdown]
# ## Get gold and pred clusters

# %%
rec = None
with jsonlines.open(f"corefhoi/data/bourne.english.512.jsonlines") as reader:
    for obj in reader:
        rec = obj
print(rec.keys())
# Out:
# dict_keys(['doc_key', 'tokens', 'sentences', 'speakers', 'constituents', 'ner', 'clusters', 'sentence_map', 'subtoken_map', 'pronouns'])

# %%
pred = pickle.load(open(f"corefhoi/data/bourne.clusters.pkl", "rb"))

# %%
def get_gold_and_pred_clusters(script_name, indices = [0,1,2,3,4], verbose = False):
    gold_clusters_text = []
    gold_clusters = []
    with jsonlines.open(f"corefhoi/data/{script_name}.english.512.jsonlines") as reader:
        for obj in reader:
            tokens = obj["tokens"]
            gold_clusters = obj["clusters"]
            subtoken_map = obj["subtoken_map"]
    
    gold_clusters = sorted(gold_clusters, key = lambda x: len(x), reverse = True)
    for i in range(len(gold_clusters)):
        gold_clusters[i] = sorted(gold_clusters[i], key = lambda x: x[0])
        
    for cluster in gold_clusters:
        mentions = []
        for i, j in cluster:
            token_i = subtoken_map[i]
            token_j = subtoken_map[j]
            mention = " ".join(tokens[token_i: token_j + 1])
            mentions.append(mention)
        gold_clusters_text.append(mentions)
    
    pred_clusters = pickle.load(open(f"corefhoi/data/{script_name}.clusters.pkl", "rb"))
    pred_clusters = list(pred_clusters.values())[0]
    pred_clusters = [[[i, j] for i, j in cluster] for cluster in pred_clusters]
    pred_clusters = sorted(pred_clusters, key = lambda x: len(x), reverse = True)
    for i in range(len(pred_clusters)):
        pred_clusters[i] = sorted(pred_clusters[i], key = lambda x: x[0])
    
    pred_clusters_text = []
    for cluster in pred_clusters:
        mentions = []
        for i, j in cluster:
            token_i = subtoken_map[i]
            token_j = subtoken_map[j]
            mention = " ".join(tokens[token_i: token_j + 1])
            mentions.append(mention)
        pred_clusters_text.append(mentions)
    
    if verbose:
        print(f"{len(gold_clusters)} gold clusters. Top 20 clusters =>")
        for gi, (gold_cluster, gold_cluster_text) in enumerate(zip(gold_clusters[:20], gold_clusters_text[:20])):
            sampled_mentions = gold_cluster_text[:20]
            print(f"{gi:3d}\t{len(gold_cluster):3d} mentions\t{sampled_mentions}")
        print()

        print(f"{len(pred_clusters)} pred clusters. Top 20 clusters =>")
        for pi, (pred_cluster, pred_cluster_text) in enumerate(zip(pred_clusters[:22], pred_clusters_text[:22])):
            sampled_mentions = pred_cluster_text[:20]
            print(f"{pi:3d}\t{len(pred_cluster):3d} mentions\t{sampled_mentions}")
        print()
    
    intersection_map = np.zeros((len(gold_clusters), len(pred_clusters)), dtype=np.int)
    gold_to_pred_map = []

    for i, gold_cluster in enumerate(gold_clusters):
        for j, pred_cluster in enumerate(pred_clusters):
            gold_cluster_set = set([(k, l) for k, l in gold_cluster])
            pred_cluster_set = set([(k, l) for k, l in pred_cluster])
            intersection_map[i, j] = len(gold_cluster_set.intersection(pred_cluster_set))    

    while intersection_map.size and np.max(intersection_map):
        r, c = np.unravel_index(np.argmax(intersection_map, axis = None), intersection_map.shape)
        gold_to_pred_map.append([r, c, np.max(intersection_map)])
        intersection_map[r] = 0
        intersection_map[:,c] = 0

    if verbose:
        for gi, pi, count in gold_to_pred_map[:10]:
            print(f"gold cluster {gi} ({len(gold_clusters[gi])} mentions) <-> pred cluster {pi} ({len(pred_clusters[pi])} mentions): {count} common mentions")
            print(f"gold ==> {gold_clusters_text[gi][:50]}")    
            print(f"pred ==> {pred_clusters_text[pi][:50]}\n\n")
        print()
    
    gold_to_pred_map = [gold_to_pred_map[i] for i in indices]
    
    return gold_clusters, gold_clusters_text, pred_clusters, pred_clusters_text, gold_to_pred_map

# %%
script_name = "basterds"

gold_clusters, gold_clusters_text, pred_clusters, pred_clusters_text, gold_to_pred_map = get_gold_and_pred_clusters(script_name, verbose = True)
# Out:
# 23 gold clusters. Top 20 clusters =>
#   0	184 mentions	['she', 'she', 'she', "Frau Von Hammersmark 's", 'Frau Von Hammersmark', 'She', 'she', 'She', 'She', 'She', 'your fraulein Von Hammer', 'the fraulein of the hour , UFA diva , BRIDGET VON HAMMERSMARK', 'Bridget Von Hammersmark', 'her', 'her', 'BRIDGET / GENGUS', 'Fraulein Von Hammersmark', 'she', 'BRIDGET', 'my']
#   1	163 mentions	['ONE GERMAN MASTER SGT', 'MASTER SGT # 1', 'the Master Sgt', 'The Sgt over there', 'His', 'him', 'his', 'his', 'he', 'the German Master Sgt', 'his', 'the German Master Sgt', 'I', 'my', 'Wilhelm', 'This handsome happy Sgt', 'The German Master Sgt', 'his', 'his', 'He']
#   2	157 mentions	['A GERMAN VOICE', 'GERMAN VOICE', 'I', 'the unknown German', 'MAJOR DEITER HELLSTROM', 'The Major', 'he', 'MAJOR HELLSTROM', 'I', 'I', 'Major', 'MAJOR HELLSTROM', 'T', 'I', 'I', 'The Gestapo Major', 'MAJOR HELLSTROM', 'you', 'MAJOR HELLSTROM', 'you']
#   3	 97 mentions	['Hicox', 'You', 'I', 'You', 'You', 'Lt. Hicox', 'Lt. Hicox', 'sir', 'I', 'I', 'the limy Lieutenant', 'you', 'I', 'Hicox', 'him', 'you', 'Lieutenant', 'Lt. Bicox', 'him', 'you']
#   4	 61 mentions	['LT.ALDO RAINE', 'Aldo', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'Aldo', 'him', 'yours', 'Aldo', 'LT.ALDO', 'Lieutenant', 'LT.ALDO', 'LT.ALDO', "Aldo 's", 'you', 'you', 'Aldo', 'your', 'I', 'my']
#   5	 57 mentions	['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz', 'Stiglitz', 'STIGLITZ', 'He', 'your', 'Stiglitz', 'You', 'The renegade Gerry Sergeant', 'his', 'STIGLITZ', 'I']
#   6	 35 mentions	['GERMAN PRIVATE # 5', 'WINNETOU', 'I', 'I', 'you', 'he', 'he', 'he', 'He', 'He', 'he', 'he', 'WINNETOU', 'I', 'I', 'WINNETOU', 'I', 'I', 'He', 'WINNETOU']
#   7	 18 mentions	['Wilhelm Wicki', 'WICKI', 'Wicki', 'WICKI', 'WICXI', 'your', 'WICKI', 'Wicki', 'WICKI', 'you Lt. Saltzberg', 'Wicki', 'Wicki', 'WICKI', 'WICKI', 'WICKI', 'his', 'WICKI', 'WICKI']
#   8	 17 mentions	['Hirschberg', 'I', 'I', 'Hirschberg', 'HIRSCHBERG', 'him', 'he', 'Hirschbeg', 'Hirschberg', 'Hirscberg', 'Hirscberg', 'HIRSCHBERG', 'I', 'HIRSCHBERG', 'HIRSCHBERG', 'Hirschberg', 'Hirschberg']
#   9	 17 mentions	['his', 'this progeny', 'His', 'he', 'him', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', "Max 's", 'His', 'little Max', 'his', 'that little gatzenjammer Max', 'him']
#  10	 14 mentions	['We', 'WE', 'We', 'our', 'WE', 'our', 'We', 'our', 'we', 'WE', 'We', 'WE', 'we', 'We']
#  11	 13 mentions	['a Nazi', 'ONE LONE NAZI PRIVATE', 'himself', 'the German soldier', 'the urinating Nazi', 'The GERMAN PISSING PRIVATE', 'his', 'his', 'his', 'he', 'him', 'him', 'our urinating friend']
#  12	 10 mentions	['GERMAN PRIVATE # 4', 'EDGAR WALLACE', 'you', 'EDGAR WALLACE', 'EDGER WALLACE', 'I', 'He', 'YOU', 'Edgar Wallace', 'EDGAR WALLACE']
#  13	  9 mentions	['the YOUNG FRENCH BARMAID , the only other person in the establishment', 'The French Barmaid', 'She', 'her', 'she', 'The Barmaid', 'her', 'The French Barmaid', 'The FRENCH BARMAID']
#  14	  8 mentions	['GERMAN PRIVATE # 3', 'MATA HARI', 'MATA HARI', 'MATA HARI', 'My', 'I', 'Mata Hari', 'HATA HARI']
#  15	  6 mentions	['Eric', 'Eric', 'Eric', 'ERIC', 'Eric', 'Eric']
#  16	  4 mentions	['Donowitz', 'Sgt.Donowitz', 'Sgt .', 'Donowitz']
#  17	  4 mentions	['ONE FEMALE GERMAN SGT', 'FEMALE SGT # 2', 'FEMALE SGT / BEETHOVEN', 'Beethoven']
#  18	  3 mentions	['The Fubrer', 'Hitler', 'Hitler']
#  19	  3 mentions	['Goebbels', 'Goebbels', 'Goebbels']
#
# 177 pred clusters. Top 20 clusters =>
#   0	113 mentions	['Hicox', 'Lt. Hicox', 'himself', 'his', 'Lt. Hicox', 'Hicox', 'Lt. Bicox', 'Lt. Hicox', 'your', 'Sgt', 'Lt. Hicox', 'his', 'I', 'me', 'myself', 'my', 'my', 'my', 'My', "the Young Cap't"]
#   1	 98 mentions	['You', 'I', 'You', 'I', 'I', 'I', 'the limy Lieutenant', 'you', 'I', 'He', 'his', 'his', 'Lieutenant', 'Lieutenant', 'I', 'I', 'She', 'I', 'my', 'you']
#   2	 89 mentions	["Frau Von Hammersmark 's", 'Frau Von Hammersmark', 'She', 'she', 'She', 'She', 'She', 'Fraulein Von Hammersmark', 'she', 'Frau Von Hammersmark', 'your', 'yourself', 'Bridget Von Hammersmark', 'her', 'Frau Von Hammersmark', 'your', 'you', 'you', 'Bridget', 'Bridget Von Hammersmark']
#   3	 54 mentions	['The Major', 'he', 'Major', 'The Gestapo Major', 'the Gestapo Major', 'He', 'Major Hellstrom , the highest ranking officer in the room', 'MAJOR HELLSTROM', 'I', 'Major', 'The Gestapo Major', 'the Majors', 'Major', 'The Major', 'Major Hellstrom', 'Major', 'Major', 'you', 'Major', "the young Cap't"]
#   4	 46 mentions	['you', 'your', 'them', 'them', 'The Germans all', 'you', 'The Pretend Officers', 'You', 'your', 'your', 'you', 'your', 'you', 'Sgt.', 'your', 'you', 'your', 'The German Master Sgt.', 'The impostors', 'all three']
#   5	 41 mentions	['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'Stiglitz', 'Stiglitz', 'He', 'your', 'Stiglitz', 'The renegade Gerry Sergeant', 'his', 'STIGLITZ', 'I', 'you', 'you', 'he', 'him', 'that']
#   6	 35 mentions	['We', 'we', 'We', 'we', 'We', 'our', 'we', 'we', 'We', 'our', 'us', 'We', 'we', 'we', 'we', 'We', 'We', 'we', 'We', 'us']
#   7	 31 mentions	['a VOICE OFF SCREEN', 'I', 'her', 'the alive Bridget Von Hammersmark', 'the German celebrity', 'that', 'the girl on your side', 'Von Hammersmark', 'she', 'she', 'She', 'she', 'her', 'she', 'the girl', 'the girl', 'the girl', 'that girl', 'her', 'the girl']
#   8	 29 mentions	['The whole table', 'The table', 'The table', 'The Tableheartily', 'The Table', 'the whole Table', 'the table', 'the Table', 'the masquerading Germans table', 'the table', 'the Table', 'his table', 'The Table of game playing Soldiers', 'your table', 'the impostors table', 'That table', 'the table', 'the table', 'The Table', 'The Table']
#   9	 28 mentions	['WINNETOU', 'German# 5 ( WINNETOU )', 'I', 'I', 'you', 'you', 'he', 'he', 'he', 'He', 'He', 'he', 'he', 'WINNETOU', 'I', 'I', 'the character', 'The Character', 'this character', 'WINNETOU']
#  10	 26 mentions	['his', 'he', 'his', 'the German Master Sgt', 'his', 'the German Master Sgt', 'The German Master Sgt', 'his', 'his', 'He', 'his', 'I', 'I', 'He', 'his', 'the young father', 'the German Sgt', 'his', 'his', 'he']
#  11	 20 mentions	['my son', 'his', 'Wilhelm', 'This handsome happy Sgt', 'the Sgt.', 'this progeny', 'His', 'this German Sgt', 'he', 'him', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', 'little Max', 'his', 'that little gatzenjammer Max , growin up without a pop', 'him']
#  12	 18 mentions	["ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", 'That', "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE", "ALDO'S VOICE"]
#  13	 17 mentions	['LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'MATA HARI', 'MATA HARI', 'MATA HARI', 'My', 'I', 'I', 'I', 'I', 'I', 'ALDO']
#  14	 13 mentions	['five', "The Five Nazi's", 'their', 'The Five Germans', 'the German Soldiers', 'their', 'the five German soldiers', 'their', 'their', 'their', 'them', 'them', 'your friends']
#  15	 13 mentions	['BRIDGET', 'my', 'I', 'I', 'my', 'you', 'I', 'I', 'you', 'you', 'my', 'my', 'you']
#  16	 13 mentions	['Wilhelm', 'you', 'I', 'Wilhelm', 'Wilhelm', 'Wilhelm', 'your', 'you', 'you', 'Wilhelm', 'ya', 'Wilhelm', 'yap']
#  17	 13 mentions	['your', 'you', 'Willi', 'your', 'Willi', 'your', 'Willi', 'you', 'Willi', 'He', 'Willi', 'Willi', 'my']
#  18	 11 mentions	['your', 'Aldo .', 'Willi', 'your', 'you', 'you', 'you', 'Aldo', 'you', 'Aldo', 'his']
#  19	 10 mentions	["y'all", 'we', 'we', 'we', 'us', 'us', 'our', 'us', 'we', 'us']
#  20	 10 mentions	['the young German Sgt , with the machine gunn', 'The German Sgt', 'The young German Sgt', 'You', 'you', 'You', 'your', 'your', 'soldier', 'you']
#  21	  9 mentions	['Aldo', 'Aldo', 'him', 'yours', 'Aldo', 'Aldo', 'Aldo', 'Aldo', 'Aldo']
#
# gold cluster 0 (184 mentions) <-> pred cluster 2 (89 mentions): 84 common mentions
# gold ==> ['she', 'she', 'she', "Frau Von Hammersmark 's", 'Frau Von Hammersmark', 'She', 'she', 'She', 'She', 'She', 'your fraulein Von Hammer', 'the fraulein of the hour , UFA diva , BRIDGET VON HAMMERSMARK', 'Bridget Von Hammersmark', 'her', 'her', 'BRIDGET / GENGUS', 'Fraulein Von Hammersmark', 'she', 'BRIDGET', 'my', 'I', 'I', 'my', 'Frau Von Hammersmark', 'your', 'yourself', 'BRIDGET', 'Bridget Von Hammersmark', 'her', 'Frau Von Hammersmark', 'your', 'you', 'you', 'BRIDGET', 'I', 'you', 'you', 'BRIDGET', 'Bridget', 'Bridget Von Hammersmark', 'herself', 'She', 'her', 'BRIDGET', 'I', 'She', 'She', 'she', "Bridget 's", 'BRIDGET']
# pred ==> ["Frau Von Hammersmark 's", 'Frau Von Hammersmark', 'She', 'she', 'She', 'She', 'She', 'Fraulein Von Hammersmark', 'she', 'Frau Von Hammersmark', 'your', 'yourself', 'Bridget Von Hammersmark', 'her', 'Frau Von Hammersmark', 'your', 'you', 'you', 'Bridget', 'Bridget Von Hammersmark', 'herself', 'She', 'her', 'She', 'She', 'she', "Bridget 's", "Bridget 's", 'Bridget', "Bridget 's", 'Bridget Von Hammersmark at the other table', 'Bridget', 'Fraulein Von Bammersmark', 'her', 'you', 'I', 'she', 'her', 'fraulein', 'Bridget', 'her', 'I', 'She', 'her', 'her', 'you', 'fraulein', 'you', 'you', 'your']
#
#
# gold cluster 2 (157 mentions) <-> pred cluster 0 (113 mentions): 47 common mentions
# gold ==> ['A GERMAN VOICE', 'GERMAN VOICE', 'I', 'the unknown German', 'MAJOR DEITER HELLSTROM', 'The Major', 'he', 'MAJOR HELLSTROM', 'I', 'I', 'Major', 'MAJOR HELLSTROM', 'T', 'I', 'I', 'The Gestapo Major', 'MAJOR HELLSTROM', 'you', 'MAJOR HELLSTROM', 'you', 'You', 'MAJOR HELLSTROM', 'I', 'Major', 'the Gestapo Major', 'MAJOR HELLSTROM', 'Major Hellstrom', 'MAJOR HELLSTROM', 'I', 'Major', 'The Gestapo Major', 'Majors', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'MAJOR HELLSTROM', 'I', 'You', 'MAJOR BELLSTROM', 'MAJOR HELLSTROM', 'he', 'MAJOR HELLSTROM', 'Major', 'MAJOR HELLSTROM', 'me', 'MAJOR HELLSTROM', 'I', 'I', 'MAJOR HELLSTROM', 'The Major', 'MAJOR HELLSTROM']
# pred ==> ['Hicox', 'Lt. Hicox', 'himself', 'his', 'Lt. Hicox', 'Hicox', 'Lt. Bicox', 'Lt. Hicox', 'your', 'Sgt', 'Lt. Hicox', 'his', 'I', 'me', 'myself', 'my', 'my', 'my', 'My', "the Young Cap't", 'He', 'he', 'his', 'he', 'Lt. Hicox', 'he', 'Lt. Hicox', 'him', 'He', 'his', 'He', 'I', 'I', 'I', 'I', 'My', 'I', 'my', 'I', 'you', 'I', 'I', 'my', 'I', 'my', 'me', 'I', 'I', 'I', 'my']
#
#
# gold cluster 3 (97 mentions) <-> pred cluster 1 (98 mentions): 29 common mentions
# gold ==> ['Hicox', 'You', 'I', 'You', 'You', 'Lt. Hicox', 'Lt. Hicox', 'sir', 'I', 'I', 'the limy Lieutenant', 'you', 'I', 'Hicox', 'him', 'you', 'Lieutenant', 'Lt. Bicox', 'him', 'you', 'your', 'I', 'The British officer', 'him', 'Hicox', 'HICOX', 'one Brit', 'I', 'You', 'You', 'your', 'Hicox', 'Hicox', 'his', 'you', 'Hicox', 'Lt. Hicox', 'me', 'I', 'I', 'the officer', 'your', 'you', 'yours', 'you', 'HICOX', 'Lt. Hicox', 'his', 'I', 'me']
# pred ==> ['You', 'I', 'You', 'I', 'I', 'I', 'the limy Lieutenant', 'you', 'I', 'He', 'his', 'his', 'Lieutenant', 'Lieutenant', 'I', 'I', 'She', 'I', 'my', 'you', 'Lieutenant', 'I', 'I', 'me', 'I', 'I', 'the officer', 'me', 'your', 'you', 'Sgt .!', 'You', 'I', 'YOU', 'YOU', 'I', 'you', 'your', 'The Germans', 'I', 'I', 'I', 'yours', 'you', "Cap't", 'HICOX', 'I', 'I', 'you', 'your']
#
#
# gold cluster 1 (163 mentions) <-> pred cluster 10 (26 mentions): 25 common mentions
# gold ==> ['ONE GERMAN MASTER SGT', 'MASTER SGT # 1', 'the Master Sgt', 'The Sgt over there', 'His', 'him', 'his', 'his', 'he', 'the German Master Sgt', 'his', 'the German Master Sgt', 'I', 'my', 'Wilhelm', 'This handsome happy Sgt', 'The German Master Sgt', 'his', 'his', 'He', 'his', 'Wilhelm', 'I', 'this German Sgt . STIGLITZ Wonderful name , Sgt. SGT . POLA NEGRI Thank you , Lieutenant . When he \'s old enough to ride a bicycle , I will buy him a blue one . And I will paint on the side " The Blue Max " . He thrusts out his beer stein , for the officers to cheers . They do . Bridget finishes signing her autograph , with a big flourish . BRIDGET There you go . But wait , I \'m not finished yet . She reaches into her clutch , and pulls out some lipstick . Applies some ruby red color to her lips , and then kisses the napkin , leaving a big red lip print . Then hands the treasured item to the young father . BRIDGET Nothing but the best for little Maximilian . SGT . POLA NEGRI Thank you fraulein , thank you . Max may not know who you are now . But he will . I will show him all of your movies . He will grow up with your films , and this napkin on his wall . Then , to the whole tavern ... SGT . POLA NEGRI I purpose a toast to the greatest actress in Germany ! There is no Dietrich , there is no Riefenstahl , only Von Hammersmark ! The whole room toasts . This would be a good time for the German Sgt to go back to his table , and his men . And he almost does .... but ... since he is drunk , and star struck , he out wears his welcome . SGT . POLA NEGRI So , Frau Von Hammersmark , what brings you to France ? 97 . Feeling any good Nazi officer \'s patience would of been exhausted long ago , Lt. Hicox butts in . LT. HICOX None of your business , Sgt .', 'Sgt', 'I', 'I', 'He', 'his', 'you', 'the young father', 'I', 'I', 'the German Sgt', 'his', 'his', 'he', 'he', 'he', 'his', 'your', 'Sgt', 'You', 'your', 'your', 'you', 'your', 'you Sgt.', 'your', 'you']
# pred ==> ['his', 'he', 'his', 'the German Master Sgt', 'his', 'the German Master Sgt', 'The German Master Sgt', 'his', 'his', 'He', 'his', 'I', 'I', 'He', 'his', 'the young father', 'the German Sgt', 'his', 'his', 'he', 'he', 'he', 'his', 'The German Sgt', 'his', 'that man']
#
#
# gold cluster 6 (35 mentions) <-> pred cluster 9 (28 mentions): 22 common mentions
# gold ==> ['GERMAN PRIVATE # 5', 'WINNETOU', 'I', 'I', 'you', 'he', 'he', 'he', 'He', 'He', 'he', 'he', 'WINNETOU', 'I', 'I', 'WINNETOU', 'I', 'I', 'He', 'WINNETOU', 'my', 'WINNETOU', 'me', 'you', 'Winnetou', 'WINNETOU', 'I', 'he', 'his', 'Winnetou', 'YOU', 'WINNETOU', 'I', 'WINNETOU', 'he']
# pred ==> ['WINNETOU', 'German# 5 ( WINNETOU )', 'I', 'I', 'you', 'you', 'he', 'he', 'he', 'He', 'He', 'he', 'he', 'WINNETOU', 'I', 'I', 'the character', 'The Character', 'this character', 'WINNETOU', 'I', 'I', 'He', 'WINNETOU', 'my', 'WINNETOU', 'me', 'WINNETOU']
#
#
# gold cluster 5 (57 mentions) <-> pred cluster 5 (41 mentions): 18 common mentions
# gold ==> ['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'himself', 'his', 'Stiglitz', 'Stiglitz', 'Stiglitz', 'STIGLITZ', 'He', 'your', 'Stiglitz', 'You', 'The renegade Gerry Sergeant', 'his', 'STIGLITZ', 'I', 'you', 'you', 'He', 'his', 'his', 'This Gerry of yours , Stiglitz', 'he', 'Hugo Stiglitz', 'Stiglitz', 'STIGLITZ', 'He', 'Stiglitz', 'STIGLITZ', 'Hugo Stiglitz', 'him', 'Hugo', 'the slightly psychotic Stiglitz', 'STIGLITZ', 'Lieutenant', 'Stiglitz', 'STIGLITZ', 'STIGLITZ', 'you', 'Lt. Berlin', 'STIGLITZ', 'Hugo', 'his', 'Stiglitz', 'I', 'Hugo']
# pred ==> ['Hugo Stiglitz', 'himself', 'his', 'his', 'his', 'Stiglitz', 'Stiglitz', 'Stiglitz', 'He', 'your', 'Stiglitz', 'The renegade Gerry Sergeant', 'his', 'STIGLITZ', 'I', 'you', 'you', 'he', 'him', 'that', 'you', 'You', 'You', 'your', 'you', 'MAJOR HELLSTROM', 'you', 'You', 'I', 'Your', 'you', 'I', 'You', 'you', 'Your', 'The Captain', 'your', "Cap't", 'Your', 'sir', 'you']
#
#
# gold cluster 9 (17 mentions) <-> pred cluster 11 (20 mentions): 14 common mentions
# gold ==> ['his', 'this progeny', 'His', 'he', 'him', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', "Max 's", 'His', 'little Max', 'his', 'that little gatzenjammer Max', 'him']
# pred ==> ['my son', 'his', 'Wilhelm', 'This handsome happy Sgt', 'the Sgt.', 'this progeny', 'His', 'this German Sgt', 'he', 'him', 'little Maximilian', 'Max', 'he', 'him', 'He', 'his', 'little Max', 'his', 'that little gatzenjammer Max , growin up without a pop', 'him']
#
#
# gold cluster 4 (61 mentions) <-> pred cluster 21 (9 mentions): 9 common mentions
# gold ==> ['LT.ALDO RAINE', 'Aldo', 'LT.ALDO', 'LT.ALDO', 'LT.ALDO', 'Aldo', 'him', 'yours', 'Aldo', 'LT.ALDO', 'Lieutenant', 'LT.ALDO', 'LT.ALDO', "Aldo 's", 'you', 'you', 'Aldo', 'your', 'I', 'my', 'You', 'me', 'my', 'Aldo', 'I', 'you', 'Aldo', 'you', 'Aldo', 'Aldo', 'his', 'ALDO', 'I', 'ALDO', 'You', 'ALDO', 'your', 'you', 'ALDO', 'I', 'I', 'I', 'ALDO', 'i', 'I', 'ALDO', 'Aldo', 'Aldo', 'ALDO', 'I']
# pred ==> ['Aldo', 'Aldo', 'him', 'yours', 'Aldo', 'Aldo', 'Aldo', 'Aldo', 'Aldo']
#
#
# gold cluster 11 (13 mentions) <-> pred cluster 24 (7 mentions): 7 common mentions
# gold ==> ['a Nazi', 'ONE LONE NAZI PRIVATE', 'himself', 'the German soldier', 'the urinating Nazi', 'The GERMAN PISSING PRIVATE', 'his', 'his', 'his', 'he', 'him', 'him', 'our urinating friend']
# pred ==> ['The GERMAN PISSING PRIVATE', 'his', 'his', 'his', 'he', 'him', 'him']
#
#
# gold cluster 8 (17 mentions) <-> pred cluster 28 (7 mentions): 6 common mentions
# gold ==> ['Hirschberg', 'I', 'I', 'Hirschberg', 'HIRSCHBERG', 'him', 'he', 'Hirschbeg', 'Hirschberg', 'Hirscberg', 'Hirscberg', 'HIRSCHBERG', 'I', 'HIRSCHBERG', 'HIRSCHBERG', 'Hirschberg', 'Hirschberg']
# pred ==> ['Hirschberg', 'Hirschberg', 'Hirschbeg', 'you', 'Hirschberg', 'Hirscberg', 'Hirscberg']

# %%
shawshank_gold_to_pred = {0:0, 1:1, 2:9, 3:4, 4:3}
bourne_gold_to_pred = {0:0, 1:6, 2:1, 3:4, 4:9}
basterds_gold_to_pred = {0:2, 1:10, 2:3, 3:0, 4:21}

# %%
shawshank_info = {"map": shawshank_gold_to_pred, "name": "shawshank"}
gold_clusters, gold_clusters_text, pred_clusters, pred_clusters_text, gold_to_pred_map = get_gold_and_pred_clusters("shawshank", verbose = False)
shawshank_info["gold"] = gold_clusters
shawshank_info["pred"] = pred_clusters

bourne_info = {"map": bourne_gold_to_pred, "name": "bourne"}
gold_clusters, gold_clusters_text, pred_clusters, pred_clusters_text, gold_to_pred_map = get_gold_and_pred_clusters("bourne", verbose = False)
bourne_info["gold"] = gold_clusters
bourne_info["pred"] = pred_clusters

basterds_info = {"map": basterds_gold_to_pred, "name": "basterds"}
gold_clusters, gold_clusters_text, pred_clusters, pred_clusters_text, gold_to_pred_map = get_gold_and_pred_clusters("basterds", verbose = False)
basterds_info["gold"] = gold_clusters
basterds_info["pred"] = pred_clusters

infos = [shawshank_info, bourne_info, basterds_info]

# %% [markdown]
# ## Evaluate

# %%
def MUC(info):
    gold = [set([(i, j) for i, j in cluster]) for cluster in info["gold"]]
    pred = [set([(i, j) for i, j in cluster]) for cluster in info["pred"]]
    
    mention_to_gi = {}
    mention_to_pi = {}
    
    for gi, cluster in enumerate(gold):
        for mention in cluster:
            mention_to_gi[mention] = gi
            
    for pi, cluster in enumerate(pred):
        for mention in cluster:
            mention_to_pi[mention] = pi
            
    gold_partitions = []
    pred_partitions = []
    
    for cluster in gold:
        pi_set = set()
        for mention in cluster:
            if mention in mention_to_pi:
                pi_set.add(mention_to_pi[mention])
            else:
                pi_set.add(-1)
        gold_partitions.append(len(pi_set))
        
    for cluster in pred:
        gi_set = set()
        for mention in cluster:
            if mention in mention_to_gi:
                gi_set.add(mention_to_gi[mention])
            else:
                gi_set.add(-1)
        pred_partitions.append(len(gi_set))
        
    precision_numerator, precision_denominator = 0, 0
    recall_numerator, recall_denominator = 0, 0
    
    for cluster, partition in zip(pred, pred_partitions):
        precision_numerator += len(cluster) - partition
        precision_denominator += len(cluster) - 1
    
    for cluster, partition in zip(pred, gold_partitions):
        recall_numerator += len(cluster) - partition
        recall_denominator += len(cluster) - 1
        
    precision = precision_numerator/precision_denominator
    recall = recall_numerator/recall_denominator
    f1 = 2 * precision * recall / (precision + recall)
    
    return precision, recall, f1

# %%
def B3(info):
    gold = [set([(i, j) for i, j in cluster]) for cluster in info["gold"]]
    pred = [set([(i, j) for i, j in cluster]) for cluster in info["pred"]]
    precision_numerator, recall_numerator = 0, 0

    for gold_cluster in gold:
        for pred_cluster in pred:
            common = len(gold_cluster.intersection(pred_cluster))
            precision_numerator += common*common/(len(pred_cluster))
            recall_numerator += common*common/(len(gold_cluster))
    
    precision_denominator = sum([len(gold_cluster) for gold_cluster in gold])    
    recall_denominator = sum([len(pred_cluster) for pred_cluster in pred])
    
    precision = precision_numerator/precision_denominator
    recall = recall_numerator/recall_denominator
    f1 = 2 * precision * recall / (precision + recall)
    
    return precision, recall, f1

# %%
def CEAF(info):
    gold = [set([(i, j) for i, j in cluster]) for cluster in info["gold"]]
    pred = [set([(i, j) for i, j in cluster]) for cluster in info["pred"]]
    numerator = 0
    
    for gi, pi in info["map"].items():
        numerator += 2 * len(gold[gi].intersection(pred[pi]))/ (len(gold[gi]) + len(pred[pi]))

    precision = numerator/len(pred)
    recall = numerator/len(gold)
    f1 = 2 * precision * recall / (precision + recall)
    
    return precision, recall, f1

# %%
for info in infos:
    print(info["name"])
    info["metric"] = {}
    
    for metric in [B3, CEAF, MUC]:
        p, r, f = metric(info)
        info["metric"][metric.__name__] = {"p":p, "r":r, "f":f}
        print(f"\t{metric.__name__:5s}: precision = {p:.3f}, recall = {r:.3f}, f1 = {f:.3f}")
# Out:
# shawshank
# 	B3   : precision = 0.619, recall = 0.335, f1 = 0.435
# 	CEAF : precision = 0.019, recall = 0.073, f1 = 0.030
# 	MUC  : precision = 0.955, recall = 0.915, f1 = 0.934
# bourne
# 	B3   : precision = 0.644, recall = 0.288, f1 = 0.398
# 	CEAF : precision = 0.016, recall = 0.071, f1 = 0.026
# 	MUC  : precision = 0.961, recall = 0.921, f1 = 0.940
# basterds
# 	B3   : precision = 0.465, recall = 0.141, f1 = 0.217
# 	CEAF : precision = 0.010, recall = 0.078, f1 = 0.018
# 	MUC  : precision = 0.930, recall = 0.857, f1 = 0.892

# %% [markdown]
# ## Scorch input

# %%
for info in infos:
    mention_to_id = {}
    
    for clusters in [info["gold"], info["pred"]]:
        for cluster in clusters:
            for i, j in cluster:
                if (i, j) not in mention_to_id:
                    mention_to_id[(i, j)] = len(mention_to_id)
    
    info["gold_id"] = [[mention_to_id[(i, j)] for i, j in cluster] for cluster in info["gold"]]    
    info["pred_id"] = [[mention_to_id[(i, j)] for i, j in cluster] for cluster in info["pred"]]
    
    gold_json = {"type":"clusters", "clusters": dict([(i, mention_ids) for i, mention_ids in enumerate(info["gold_id"])])}    
    pred_json = {"type":"clusters", "clusters": dict([(i + 5, mention_ids) for i, mention_ids in enumerate(info["pred_id"])])}
    
    json.dump(gold_json, open(f"corefhoi/data/scorch.{info['name']}.gold.json", "w"))    
    json.dump(pred_json, open(f"corefhoi/data/scorch.{info['name']}.pred.json", "w"))

# %% [markdown]
# ## Error Analysis

# %%
bourne_info.keys()
# Out:
# dict_keys(['map', 'name', 'gold', 'pred', 'metric', 'gold_id', 'pred_id'])

# %%
with jsonlines.open(f"corefhoi/data/bourne.english.512.jsonlines") as reader:
    for obj in reader:
        bourne_rec = obj

# %%
bourne_rec.keys()
# Out:
# dict_keys(['doc_key', 'tokens', 'sentences', 'speakers', 'constituents', 'ner', 'clusters', 'sentence_map', 'subtoken_map', 'pronouns'])

# %%
bourne_info["map"]
# Out:
# {0: 0, 1: 6, 2: 1, 3: 4, 4: 9}

# %%
gold_cluster = bourne_info["gold"][0]
pred_cluster = bourne_info["pred"][0]

# %%
gold_cluster = set([(i, j) for i, j in gold_cluster])
pred_cluster = set([(i, j) for i, j in pred_cluster])

# %%
print(f"|G| = {len(gold_cluster)}, |P| = {len(pred_cluster)}, |G ⋂ P| = {len(gold_cluster.intersection(pred_cluster))}, |G - P| = {len(gold_cluster.difference(pred_cluster))}, |P - G| = {len(pred_cluster.difference(gold_cluster))}")
# Out:
# |G| = 421, |P| = 344, |G ⋂ P| = 311, |G - P| = 110, |P - G| = 33

# %%
for k, (i, j) in enumerate(gold_cluster.difference(pred_cluster)):
    ti, tj = bourne_rec["subtoken_map"][i], bourne_rec["subtoken_map"][j] + 1
    left, mention, right = " ".join(bourne_rec["tokens"][ti - 20: ti]), " ".join(bourne_rec["tokens"][ti: tj]), " ".join(bourne_rec["tokens"][tj: tj + 20])
    print(f"{k:3d}. left    = {left}")    
    print(f"{k:3d}. mention = {mention}")    
    print(f"{k:3d}. right   = {right}\n\n")
# Out:
#   0. left    = I guess I owe you an apology . 207 INT . HUB -- BACK ROOM 207 Vosen rushes in --
#   0. mention = BOURNE
#   0. right   = Is that official ? V.O. VOSEN Are we triangulating ?! OVERLAPPING LANDY No . Off the record . You know
#
#
#   1. left    = his front tires spinning wildly Bourne fights to straighten his car as another CRI sedan appears and tries to box
#   1. mention = Bourne 's
#   1. right   = car by sliding into his path . 283 OMITTED 283 284 EXT . MANHATTAN STREET -- DAY 284 Bourne just
#
#
#   2. left    = 's a bad place to pick , it 's too exposed . VOSEN He would n't have chosen it if
#   2. mention = he
#   2. right   = did n't have a reason . 223 EXT . MANHATTAN 223 LANDY walks east through the crowded streets . 224
#
#
#   3. left    = is there . Gun pointed at his head ... The two assassins look at each other ... then Bourne lowers
#   3. mention = his
#   3. right   = gun ... and disappears ... ON PAZ -- as the wheels start to turn ... 287B INT . HUB 287B
#
#
#   4. left    = into his path . 283 OMITTED 283 284 EXT . MANHATTAN STREET -- DAY 284 Bourne just manages to punch
#   4. mention = his
#   4. right   = car into the right rear of the CRI Sedan and race down the Avenue with Paz and the slightly damaged
#
#
#   5. left    = hits his bumper , then has to accelerate through the upcoming intersection . As he does , the cop car
#   5. mention = Bourne
#   5. right   = was listening to on the radio slams broadside into the CRI sedan drafting the bumper of the mangled cop car
#
#
#   6. left    = trying to find out who I was . Hirsch moves toward Bourne , completely unfazed by the gun . HIRSCH
#   6. mention = You
#   6. right   = still do n't have it all back , do you ? You have n't filled in all the pieces ?
#
#
#   7. left    = . HIRSCH You ca n't outrun what you did , Jason . You made yourself into who you are .
#   7. mention = BOURNE
#   7. right   = I 'm done running . That 's why I 'm here . To end you , to shut this down
#
#
#   8. left    = but not anymore . 322 INT . SRD TRAINING WING CORRIDOR -- LATE AFERNOON 322 Bourne stands with Hirsch .
#   8. mention = BOURNE
#   8. right   = Why me ? Why did you pick me ? A beat ... HIRSCH You really do n't remember , do
#
#
#   9. left    = A288A Wills pacing ... Bourne 's profile is up on Screen 2 . It says " David Webb ( AKA
#   9. mention = Jason Bourne
#   9. right   = ) " on the profile . A tech comes to Wills . TECH Sir , this may be nothing but
#
#
#  10. left    = CONT 'D 322 PRESENT DAY 322 BOURNE You said I 'd be saving American lives . Instead you just turned
#  10. mention = me
#  10. right   = into a killer . Bourne raises the gun to Hirsch . HIRSCH You could have left at any time .
#
#
#  11. left    = Puts a portable dictaphone up to VOSEN 'S SAFE and his play : VOSEN Noah Vosen . TAPE V.O. As
#  11. mention = he
#  11. right   = places the plastic slide we saw in the ECUs into the fingerprint reader . The safe pops open -- 234
#
#
#  12. left    = That 's why I 'm here . To end you , to shut this down . I 'm no longer
#  12. mention = Jason Bourne
#  12. right   = . HIRSCH So now you 're going to kill me ? BOURNE No . You do n't deserve the star
#
#
#  13. left    = still do n't have it all back , do you ? You have n't filled in all the pieces ?
#  13. mention = BOURNE
#  13. right   = Let 's start with the moment you found out I would n't execute Wombosi . The amnesia was n't the
#
#
#  14. left    = the ramp behind Bourne . He jams the accelerator down . He 'll be on top of Bourne -- running
#  14. mention = him
#  14. right   = over -- in seconds -- 260 EXT . PORT AUTHORITY -- DAY 260 A New Jersey - bound bus exits
#
#
#  15. left    = the intersection Paz swerves his car into that car and punches it into the side of Bourne 's car .
#  15. mention = Bourne 's
#  15. right   = car is knocked spinning , Paz keeps charging forward and slams into the back of Bourne 's car . With
#
#
#  16. left    = n't want to talk . BOURNE I 've spent three years running . Three years trying to find out who
#  16. mention = I
#  16. right   = was . Hirsch moves toward Bourne , completely unfazed by the gun . HIRSCH You still do n't have it
#
#
#  17. left    = the mangled cop car . Swerving wildly Paz avoids the pileup and slams his heavy SUV into the back of
#  17. mention = Bourne 's
#  17. right   = car , pushing him into the oncoming traffic . Several cars swerve left and right as Paz pushes Bourne sideways
#
#
#  18. left    = sweater off and ties a makeshift tourniquet for the officer . Then he hands the cop his radio back .
#  18. mention = BOURNE
#  18. right   = Stay out of sight until one of your own arrive . CONT 'D Bourne disappears . We pick him up
#
#
#  19. left    = Bourne 's car disappeared over the railing and reflexively fire into Bourne 's car but they 're too late !
#  19. mention = Bourne 's
#  19. right   = already out . He disappears from sight under the covered parking structure . LEAD CRI AGENT Get down there !
#
#
#  20. left    = figure . The man slumps over . Bourne stares at what he 's done . HIRSCH You 're no longer
#  20. mention = David Webb
#  20. right   = . From now on you 'll be known as Jason Bourne . Welcome to the program . CONT 'D Daniels
#
#
#  21. left    = , Pam. 207 INT . HUB -- BACK ROOM 207 BOURNE You look tired . V.O. Vosen realizes -- VOSEN
#  21. mention = He
#  21. right   = 's got line of sight on us ! rushing out 203 INT . LANDY'S OFFICE 203 She spins to look
#
#
#  22. left    = flips to another page -- another photo , and again " US Citizen . " BOURNE shoves the folders in
#  22. mention = his
#  22. right   = backpack and leaves . 234 INT . VOSE N'S SUV -- DAY 234 VOSEN This is a code ten abort
#
#
#  23. left    = . 232 INT . VOSE N'S SUV -- DAY 232 Vosen 's cell phone rings . VOSEN Noah Vosen .
#  23. mention = BOURNE
#  23. right   = This is Jason Bourne . V.O. VOSEN reels for a beat . Then quickly scans the streets , trying to
#
#
#  24. left    = LANDY No . Off the record . You know how it is . V.O. BACK ROOM TECH Trying -- OVERLAPPING
#  24. mention = BOURNE
#  24. right   = Good - bye . V.O. 203 INT . LANDY'S OFFICE 203 LANDY Wait. Wait . She opens a file on
#
#
#  25. left    = the flashback . He stares back at Hirsch .... HIRSCH Do you remember now ? Bourne lowers the gun .
#  25. mention = BOURNE
#  25. right   = I remember . I remember everything . HIRSCH You ca n't outrun what you did , Jason . You made
#
#
#  26. left    = you come in , and we 'll talk about it ? Bourne ? beat 204 INT . UNDEFINED SPACE 204
#  26. mention = BOURNE
#  26. right   = Get some rest , Pam. 207 INT . HUB -- BACK ROOM 207 BOURNE You look tired . V.O. Vosen
#
#
#  27. left    = US Citizen . " He flips to another page -- another photo , and again " US Citizen . "
#  27. mention = BOURNE
#  27. right   = shoves the folders in his backpack and leaves . 234 INT . VOSE N'S SUV -- DAY 234 VOSEN This
#
#
#  28. left    = this down . I 'm no longer Jason Bourne . HIRSCH So now you 're going to kill me ?
#  28. mention = BOURNE
#  28. right   = No . You do n't deserve the star they give you on the wall at Langley . Just then Bourne
#
#
#  29. left    = 're finished with you , you 'll no longer be David Webb . BOURNE I 'll be whoever you need
#  29. mention = me
#  29. right   = to be , sir . 322 PRESENT DAY 322 HIRSCH Stop running from the truth , Jason . You chose
#
#
#  30. left    = just ahead . Bourne slows , then speeds up quickly to time it right : The CRI car almost hits
#  30. mention = his
#  30. right   = bumper , then has to accelerate through the upcoming intersection . As he does , the cop car Bourne was
#
#
#  31. left    = him found ! 240B INT . CRI CAR -- DAY 240B The passenger side agent sees BOURNE , points --
#  31. mention = BOURNE
#  31. right   = cuts to the south side of the road so the passenger - side agent does n't have a shot ,
#
#
#  32. left    = . FB9 FLASHBACK FB9 HIRSCH When we 're finished with you , you 'll no longer be David Webb .
#  32. mention = BOURNE
#  32. right   = I 'll be whoever you need me to be , sir . 322 PRESENT DAY 322 HIRSCH Stop running from
#
#
#  33. left    = toward Bourne , completely unfazed by the gun . HIRSCH You still do n't have it all back , do
#  33. mention = you
#  33. right   = ? You have n't filled in all the pieces ? BOURNE Let 's start with the moment you found out
#
#
#  34. left    = up , sprints toward the hub -- 203 INT . LANDY'S OFFICE -- DAY 203 LANDY I guess I owe
#  34. mention = you
#  34. right   = an apology . 207 INT . HUB -- BACK ROOM 207 Vosen rushes in -- BOURNE Is that official ?
#
#
#  35. left    = to Tudor City , did you ? V.O. VOSEN No , I guess not . But if it 's me
#  35. mention = you
#  35. right   = want to talk to maybe we can arrange a meet . BOURNE Where are you right now ? V.O. VOSEN
#
#
#  36. left    = , BOURNE scoops out the " TREADSTONE : Blackbriar " folder Bourne saw Vosen putting into his safe . "
#  36. mention = He
#  36. right   = flips it open . He scans down the page . His eye stopping at the words " US Citizen .
#
#
#  37. left    = around a corner near CRI . He hears a siren turn on a few blocks away . Then another .
#  37. mention = He
#  37. right   = starts to run . 240 INT . CRONIN'S CAR -- DAY 240 A SEDAN pulls to a stop as a
#
#
#  38. left    = " TREADSTONE : Blackbriar " folder Bourne saw Vosen putting into his safe . " He flips it open .
#  38. mention = He
#  38. right   = scans down the page . His eye stopping at the words " US Citizen . " He flips to another
#
#
#  39. left    = he 's done . HIRSCH You 're no longer David Webb . From now on you 'll be known as
#  39. mention = Jason Bourne
#  39. right   = . Welcome to the program . CONT 'D Daniels pulls the hood off the figure to show that he is
#
#
#  40. left    = guess not . But if it 's me you want to talk to maybe we can arrange a meet .
#  40. mention = BOURNE
#  40. right   = Where are you right now ? V.O. VOSEN In my office . BOURNE I doubt that . If you were
#
#
#  41. left    = pushes him to the wall . Searches him for weapons . HIRSCH I 'm unarmed , Jason . completely calm
#  41. mention = BOURNE
#  41. right   = " David . " I 'm David Webb . shoving Hirsch hard against the wall CLOSE ON Bourne 's face
#
#
#  42. left    = across town . 2 ) Other CRI cars race back across town . 239 EXT . MANHATTAN -- DAY 239
#  42. mention = BOURNE
#  42. right   = walks out of a building , backpack over his shoulder . CAMERA BEGINS TO CRANE UP ... BOURNE walks around
#
#
#  43. left    = Wait . She opens a file on her desk . 204 INT . UNDEFINED SPACE 204 Bourne listening -- LANDY
#  43. mention = David Webb
#  43. right   = . That 's your real name . 207 INT . HUB -- BACK ROOM 207 VOSEN Why the hell did
#
#
#  44. left    = 's car . Bourne 's car is knocked spinning , Paz keeps charging forward and slams into the back of
#  44. mention = Bourne 's
#  44. right   = car . With his front tires spinning wildly Bourne fights to straighten his car as another CRI sedan appears and
#
#
#  45. left    = that keypad , that " room in use " sign from the first day ... 322 INT . ROOM WHERE
#  45. mention = BOURNE
#  45. right   = FIRST MET HIRSCH 322 Bourne and Hirsch enter ... HIRSCH You volunteered right here .... You did n't even blink
#
#
#  46. left    = him for weapons . HIRSCH I 'm unarmed , Jason . completely calm BOURNE " David . " I 'm
#  46. mention = David Webb
#  46. right   = . shoving Hirsch hard against the wall CLOSE ON Bourne 's face -- HIRSCH You were David Webb , but
#
#
#  47. left    = 204 INT . UNDEFINED SPACE 204 BOURNE Get some rest , Pam. 207 INT . HUB -- BACK ROOM 207
#  47. mention = BOURNE
#  47. right   = You look tired . V.O. Vosen realizes -- VOSEN He 's got line of sight on us ! rushing out
#
#
#  48. left    = path . Bourne instantly spins his car 180 degrees and continues on , barreling into the roadblock backwards . As
#  48. mention = Bourne 's
#  48. right   = car plows through the SUV 's he whips the wheel and his car spins through a reverse 180 as Paz
#
#
#  49. left    = all over Bourne as he slides a right hand turn onto South St. as Paz and the CRI sedan overwhelm
#  49. mention = Bourne 's
#  49. right   = battered vehicle . 284A OMITTED 284A 287 INT . BOURNE'S CAR -- DAY 287 On his police radio , Bourne
#
#
#  50. left    = maybe we can arrange a meet . BOURNE Where are you right now ? V.O. VOSEN In my office .
#  50. mention = BOURNE
#  50. right   = I doubt that . If you were in your office -- V.O. 233 INT . VOSE N'S OFFICE -- DAY
#
#
#  51. left    = that BOURNE is inside VOSEN'S office . BOURNE We 'd be having this conversation face - to - face .
#  51. mention = BOURNE
#  51. right   = hangs up . Puts a portable dictaphone up to VOSEN 'S SAFE and his play : VOSEN Noah Vosen .
#
#
#  52. left    = 's safe to enter a " restricted access elevator . " A guard comes . Bourne aims his pistol at
#  52. mention = him
#  52. right   = as the elevator door closes . 309R EXT . FIRST AVENUE -- OUTSIDE HOSPITAL -- LATE AFTERNOON 309R Landy walks
#
#
#  53. left    = . If you were in your office -- V.O. 233 INT . VOSE N'S OFFICE -- DAY 233 REVEAL that
#  53. mention = BOURNE
#  53. right   = is inside VOSEN'S office . BOURNE We 'd be having this conversation face - to - face . BOURNE hangs
#
#
#  54. left    = . You have to decide . CONT 'D BOURNE Who is he ? HIRSCH We 've been through that .
#  54. mention = BOURNE
#  54. right   = What did he do ? HIRSCH It does n't matter . You came to us . You volunteered . You
#
#
#  55. left    = reason . 223 EXT . MANHATTAN 223 LANDY walks east through the crowded streets . 224 EXT . MANHATTAN 224
#  55. mention = BOURNE
#  55. right   = walks down the street , enters a building . 225 OMITTED 225 225A EXT . TUDOR CITY ROOFTOP 225A Spotter
#
#
#  56. left    = n't the issue , it was the fact that I did n't pull the trigger .... HIRSCH One lapse meant
#  56. mention = your
#  56. right   = conditioning had failed . Bourne grabs Hirsch and slams him against the wall BOURNE It was always you , behind
#
#
#  57. left    = INT . LANDY'S OFFICE 203 LANDY Why do n't you come in , and we 'll talk about it ?
#  57. mention = Bourne
#  57. right   = ? beat 204 INT . UNDEFINED SPACE 204 BOURNE Get some rest , Pam. 207 INT . HUB -- BACK
#
#
#  58. left    = and slams into the back of Bourne 's car . With his front tires spinning wildly Bourne fights to straighten
#  58. mention = his
#  58. right   = car as another CRI sedan appears and tries to box Bourne 's car by sliding into his path . 283
#
#
#  59. left    = it open . He scans down the page . His eye stopping at the words " US Citizen . "
#  59. mention = He
#  59. right   = flips to another page -- another photo , and again " US Citizen . " BOURNE shoves the folders in
#
#
#  60. left    = back across town . 239 EXT . MANHATTAN -- DAY 239 BOURNE walks out of a building , backpack over
#  60. mention = his
#  60. right   = shoulder . CAMERA BEGINS TO CRANE UP ... BOURNE walks around a corner near CRI . He hears a siren
#
#
#  61. left    = , do you ? You have n't filled in all the pieces ? BOURNE Let 's start with the moment
#  61. mention = you
#  61. right   = found out I would n't execute Wombosi . The amnesia was n't the issue , it was the fact that
#
#
#  62. left    = to the wall . Searches him for weapons . HIRSCH I 'm unarmed , Jason . completely calm BOURNE "
#  62. mention = David
#  62. right   = . " I 'm David Webb . shoving Hirsch hard against the wall CLOSE ON Bourne 's face -- HIRSCH
#
#
#  63. left    = office -- V.O. 233 INT . VOSE N'S OFFICE -- DAY 233 REVEAL that BOURNE is inside VOSEN'S office .
#  63. mention = BOURNE
#  63. right   = We 'd be having this conversation face - to - face . BOURNE hangs up . Puts a portable dictaphone
#
#
#  64. left    = Rail dividing the street ahead . The nearly upended car grinds down the K - Rail until the rear of
#  64. mention = Bourne 's
#  64. right   = car strikes an obstruction which punches it back into the lane as it slams against the front of Paz 's
#
#
#  65. left    = DAY 239 BOURNE walks out of a building , backpack over his shoulder . CAMERA BEGINS TO CRANE UP ...
#  65. mention = BOURNE
#  65. right   = walks around a corner near CRI . He hears a siren turn on a few blocks away . Then another
#
#
#  66. left    = into the top of Bourne 's leg . REVEAL Paz , his SUV racing along the curb lane . As
#  66. mention = Bourne 's
#  66. right   = car crosses in front of a small car stopped at the intersection Paz swerves his car into that car and
#
#
#  67. left    = EXT . CIRCULAR RAMP 274A Two CRI cars race down from the roof to try to get to the level
#  67. mention = Bourne
#  67. right   = 's on . 275 INT ./ EXT . PARKING GARAGE -- TWO LEVELS BELOW ROOFTOP 275 Bourne cuts off a
#
#
#  68. left    = ? You have n't filled in all the pieces ? BOURNE Let 's start with the moment you found out
#  68. mention = I
#  68. right   = would n't execute Wombosi . The amnesia was n't the issue , it was the fact that I did n't
#
#
#  69. left    = . Searches him for weapons . HIRSCH I 'm unarmed , Jason . completely calm BOURNE " David . "
#  69. mention = I
#  69. right   = 'm David Webb . shoving Hirsch hard against the wall CLOSE ON Bourne 's face -- HIRSCH You were David
#
#
#  70. left    = the hospital . LANDY David ... Come in with me . It 's better if we do this together .
#  70. mention = BOURNE
#  70. right   = This is where it started for me , this is where it ends . shakes head She watches the doors
#
#
#  71. left    = beat . Then quickly scans the streets , trying to see if he can spot BOURNE . VOSEN How did
#  71. mention = you
#  71. right   = get this number ? BOURNE You did n't actually think I was coming to Tudor City , did you ?
#
#
#  72. left    = if he can spot BOURNE . VOSEN How did you get this number ? BOURNE You did n't actually think
#  72. mention = I
#  72. right   = was coming to Tudor City , did you ? V.O. VOSEN No , I guess not . But if it
#
#
#  73. left    = Bourne to a new threat , he pulls the officer into some cover and grabs the officer 's radio .
#  73. mention = BOURNE
#  73. right   = 10 - 13 . Shots fired . Officer down . Port Authority parking lot . Level four . Bourne rips
#
#
#  74. left    = small car stopped at the intersection Paz swerves his car into that car and punches it into the side of
#  74. mention = Bourne 's
#  74. right   = car . Bourne 's car is knocked spinning , Paz keeps charging forward and slams into the back of Bourne
#
#
#  75. left    = barreling into the roadblock backwards . As Bourne 's car plows through the SUV 's he whips the wheel and
#  75. mention = his
#  75. right   = car spins through a reverse 180 as Paz and the other sedan race through the wreckage in Bourne 's wake
#
#
#  76. left    = a code . It sinks in for Vosen ...oh ... shit ... 289 EXT . SEVENTH AVENUE -- DAY 289
#  76. mention = BOURNE
#  76. right   = emerges into the crowed street , headed uptown . 289A INT . HUB 289A Wills watches the techs work .
#
#
#  77. left    = V.O. VOSEN reels for a beat . Then quickly scans the streets , trying to see if he can spot
#  77. mention = BOURNE
#  77. right   = . VOSEN How did you get this number ? BOURNE You did n't actually think I was coming to Tudor
#
#
#  78. left    = the map up . AGENT 4 It 's a bad place to pick , it 's too exposed . VOSEN
#  78. mention = He
#  78. right   = would n't have chosen it if he did n't have a reason . 223 EXT . MANHATTAN 223 LANDY walks
#
#
#  79. left    = Just ahead of Bourne , two government SUVs slide into the intersection completely blocking his path . Bourne instantly spins
#  79. mention = his
#  79. right   = car 180 degrees and continues on , barreling into the roadblock backwards . As Bourne 's car plows through the
#
#
#  80. left    = , backpack over his shoulder . CAMERA BEGINS TO CRANE UP ... BOURNE walks around a corner near CRI .
#  80. mention = He
#  80. right   = hears a siren turn on a few blocks away . Then another . He starts to run . 240 INT
#
#
#  81. left    = FB9 FLASHBACK FB9 HIRSCH When we 're finished with you , you 'll no longer be David Webb . BOURNE
#  81. mention = I
#  81. right   = 'll be whoever you need me to be , sir . 322 PRESENT DAY 322 HIRSCH Stop running from the
#
#
#  82. left    = we cut to -- 289B INT . VOSE N'S SUV -- DAY 289B They race uptown . WILLS She gave
#  82. mention = him
#  82. right   = the facility . She gave him -- VOSEN into cell phone I know . Go! Go! Drive ! We 're
#
#
#  83. left    = , completely unfazed by the gun . HIRSCH You still do n't have it all back , do you ?
#  83. mention = You
#  83. right   = have n't filled in all the pieces ? BOURNE Let 's start with the moment you found out I would
#
#
#  84. left    = chose to stay . FB9 FLASHBACK FB9 HIRSCH When we 're finished with you , you 'll no longer be
#  84. mention = David Webb
#  84. right   = . BOURNE I 'll be whoever you need me to be , sir . 322 PRESENT DAY 322 HIRSCH Stop
#
#
#  85. left    = we can arrange a meet . BOURNE Where are you right now ? V.O. VOSEN In my office . BOURNE
#  85. mention = I
#  85. right   = doubt that . If you were in your office -- V.O. 233 INT . VOSE N'S OFFICE -- DAY 233
#
#
#  86. left    = found out I would n't execute Wombosi . The amnesia was n't the issue , it was the fact that
#  86. mention = I
#  86. right   = did n't pull the trigger .... HIRSCH One lapse meant your conditioning had failed . Bourne grabs Hirsch and slams
#
#
#  87. left    = -- BOURNE Is that official ? V.O. VOSEN Are we triangulating ?! OVERLAPPING LANDY No . Off the record .
#  87. mention = You
#  87. right   = know how it is . V.O. BACK ROOM TECH Trying -- OVERLAPPING BOURNE Good - bye . V.O. 203 INT
#
#
#  88. left    = struggles out of the car , knowing he has only a moment before the armed agents will fire down into
#  88. mention = his
#  88. right   = over - turned car . CRI AGENT Ho - ly shit ! 269 INT . VOSE N'S SUV -- DAY
#
#
#  89. left    = trigger .... HIRSCH One lapse meant your conditioning had failed . Bourne grabs Hirsch and slams him against the wall
#  89. mention = BOURNE
#  89. right   = It was always you , behind Conklin , behind Abbott .... They were just following orders . Bourne grabs Hirsch
#
#
#  90. left    = understand ? I want him found ! 240B INT . CRI CAR -- DAY 240B The passenger side agent sees
#  90. mention = BOURNE
#  90. right   = , points -- BOURNE cuts to the south side of the road so the passenger - side agent does n't
#
#
#  91. left    = A288A INT . HUB A288A Wills pacing ... Bourne 's profile is up on Screen 2 . It says "
#  91. mention = David Webb
#  91. right   = ( AKA Jason Bourne ) " on the profile . A tech comes to Wills . TECH Sir , this
#
#
#  92. left    = Cronin puts it together . CRONIN 4.15.71 ... Jesus , Pam . 240A EXT . MIDTOWN WEST -- DAY 240A
#  92. mention = BOURNE
#  92. right   = walking away from CRI . Agents leaving a building . Getting into unmarked sedans and peeling out . 240 AA
#
#
#  93. left    = I 'm David Webb . shoving Hirsch hard against the wall CLOSE ON Bourne 's face -- HIRSCH You were
#  93. mention = David Webb
#  93. right   = , but not anymore . 322 INT . SRD TRAINING WING CORRIDOR -- LATE AFERNOON 322 Bourne stands with Hirsch
#
#
#  94. left    = 270 The CRI agents race to the spot where Bourne 's car disappeared over the railing and reflexively fire into
#  94. mention = Bourne 's
#  94. right   = car but they 're too late ! Bourne 's already out . He disappears from sight under the covered parking
#
#
#  95. left    = the streets , trying to see if he can spot BOURNE . VOSEN How did you get this number ?
#  95. mention = BOURNE
#  95. right   = You did n't actually think I was coming to Tudor City , did you ? V.O. VOSEN No , I
#
#
#  96. left    = FB9 FLASHBACK FB9 Bourne hands over his dog tags .... HIRSCH Has everything been explained to you . CONT 'D
#  96. mention = BOURNE
#  96. right   = Yes , sir . 322 PRESENT DAY 322 HIRSCH You were a soldier ready to serve his country . Just
#
#
#  97. left    = HIRSCH Put the gun down . I would n't be here if I did n't want to talk . BOURNE
#  97. mention = I
#  97. right   = 've spent three years running . Three years trying to find out who I was . Hirsch moves toward Bourne
#
#
#  98. left    = a liar are you ? Or too weak to see this through ? This is it . Let go of
#  98. mention = David Webb
#  98. right   = . Will you give yourself to this program ? beat Bourne looks down , a gun in his hand .
#
#
#  99. left    = A beat ... HIRSCH You really do n't remember , do you ? You picked us , Jason . beat
#  99. mention = BOURNE
#  99. right   = What does that mean ? HIRSCH You volunteered . Hirsch uses his free hand to hit the keypad on the
#
#
# 100. left    = later the front end seesaws over the top , the sudden angle change exposes for an instant the bottom of
# 100. mention = Bourne 's
# 100. right   = car , to the shooters . Several rounds rip through the floorboard and tear past Bourne 's head just before
#
#
# 101. left    = possible ? Is it a trick ? 233 INT . DAY . VOSE N'S OFFICE 233 From the safe ,
# 101. mention = BOURNE
# 101. right   = scoops out the " TREADSTONE : Blackbriar " folder Bourne saw Vosen putting into his safe . " He flips
#
#
# 102. left    = 's car hits parked cars on the other side of the road . SMOKE and STEAM -- SIRENS -- CHAOS
# 102. mention = BOURNE
# 102. right   = kicks the window out of the police car . Gun up ... Ready -- NEARBY 287A PAZ in the car
#
#
# 103. left    = 203 LANDY'S cell phone rings . She answers it . LANDY Pamela Landy . 204 INT . UNDEFINED SPACE 204
# 103. mention = BOURNE
# 103. right   = I hear you 're still looking for me . 203 INT . LANDY'S OFFICE 203 LANDY puts down her pencil
#
#
# 104. left    = . HIRSCH Put the gun down . I would n't be here if I did n't want to talk .
# 104. mention = BOURNE
# 104. right   = I 've spent three years running . Three years trying to find out who I was . Hirsch moves toward
#
#
# 105. left    = against the front of Paz 's SUV , knocking the SUV sideways , into a row of parked cars .
# 105. mention = Bourne 's
# 105. right   = car hits parked cars on the other side of the road . SMOKE and STEAM -- SIRENS -- CHAOS BOURNE
#
#
# 106. left    = . " I 'm David Webb . shoving Hirsch hard against the wall CLOSE ON Bourne 's face -- HIRSCH
# 106. mention = You
# 106. right   = were David Webb , but not anymore . 322 INT . SRD TRAINING WING CORRIDOR -- LATE AFERNOON 322 Bourne
#
#
# 107. left    = made a decision ? This ca n't go on , you know . You have to decide . CONT 'D
# 107. mention = BOURNE
# 107. right   = Who is he ? HIRSCH We 've been through that . BOURNE What did he do ? HIRSCH It does
#
#
# 108. left    = FBB3 FLASHBACK FBB3 HIRSCH Your missions will save American lives . CONT 'D 322 PRESENT DAY 322 BOURNE You said
# 108. mention = I
# 108. right   = 'd be saving American lives . Instead you just turned me into a killer . Bourne raises the gun to
#
#
# 109. left    = perfect shot . FBB3 FLASHBACK FBB3 HIRSCH Your missions will save American lives . CONT 'D 322 PRESENT DAY 322
# 109. mention = BOURNE
# 109. right   = You said I 'd be saving American lives . Instead you just turned me into a killer . Bourne raises
