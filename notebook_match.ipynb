# %%
import numpy as np
import pandas as pd
import re
import spacy
from tqdm import tqdm
from nltk import wordpunct_tokenize
import jsonlines

# %%
parse_df = pd.read_csv("./data/annotation/parse.csv", index_col=None)
movies, raters = [], []

with open("./data/annotation/movies.txt") as fr:
    for line in fr:
        movie, rater = line.split()
        movies.append(movie)
        raters.append(rater)
        print(f"{movie:20s} rated by {rater}")
# Out:
# avengers_endgame     rated by prithvi
# dead_poets_society   rated by chakor
# john_wick            rated by prithvi
# prestige             rated by chakor
# quiet_place          rated by athashree
# zootopia             rated by athashree

# %%
nlp = spacy.load("en_core_web_sm")

# %%
movie_data = {}

# movie_data is a dictionary, indexed by movie names
# each dictionary record contains the following keys:
# 
#   rater           |   str         | name of the student worker who annotated the movie
#   script          |   str         | original movie script
#   lines           |   List[str]   | movie script divided into lines for parsing
#   tags            |   List[str]   | tags assigned by parser to script line, its length equals length of lines
#   begins          |   List[int]   | starting index of mentions
#   ends            |   List[int]   | ending index of mentions, length equals length of begins, begins and ends can be used to retrieve the mention text by indexing into script
#   characters      |   List[str]   | referred character by the mentions, character name might not appear anywhere in the mentions, length equals length of begins
#   wsbegins        |   List[int]   | number of non-whitespace characters (letters) preceding mention
#   wsends          |   List[int]   | number of non-whitespace characters (letter) preceding mention + number of non-whitespace characters (letters) in mention
#   tokens          |   List[str]   | script tokens
#   tkbegins        |   List[int]   | number of non-whitespace characters (letters) preceding the token
#   tkends          |   List[int]   | number of non-whitespace characters (letters) preceding the token + number of non-whitespace characters (letters) in token
#   tktags          |   List[str]   | tags assigned by parser extended to tags
#   tksentids       |   List[int]   | sentence ids of tokens
#   matchbegins     |   List[int]   | matched token ids of the starting index of mentions, length equals length of begins
#   matchends       |   List[int]   | matched token ids of the ending index of mentions, length equals length of matchbegins
# 
# by length: lines = tag, begins = end = characters = wsbegins = wsends = matchbegins = matchends, tokens = tkbegins = tkends = tktags = tksentids

for movie, rater in zip(movies, raters):

    script = open(f"./data/annotation/screenplay/{movie}.txt").read()
    lines = script.splitlines()
    tags = parse_df[parse_df["movie"] == movie]["robust"].tolist()
    
    assert len(lines) == len(tags)

    annotation_df = pd.read_csv(f"./data/annotation/csv/{movie}.csv", index_col=None)
    items = []
    for _, row in annotation_df.iterrows():
        begin, end, character = row["begin"], row["end"], row["entityLabel"]
        items.append((begin, end, character))
    
    items = sorted(items)
    begins, ends, characters, wsbegins, wsends = [], [], [], [], []
    for begin, end, character in items:
        wsbegin = len(re.sub("\s+", "", script[:begin]))
        wsend = wsbegin + len(re.sub("\s+", "", script[begin: end]))
        begins.append(begin)
        ends.append(end)
        characters.append(character)
        wsbegins.append(wsbegin)
        wsends.append(wsend)

    i, c, s = 0, 0, 0
    tokens, tkbegins, tkends, tktags, tksentids, segments, segment_tags = [], [], [], [], [], [], []
    
    while i < len(lines):
        j = i + 1
        while j < len(lines) and tags[j] == tags[i]:
            j += 1
        segment = re.sub("\s+", " ", "\n".join(lines[i: j]).strip())
        if segment:
            segments.append(segment)
            segment_tags.append(tags[i])
        i = j

    docs = nlp.pipe(segments, batch_size=10200)
    for i, doc in enumerate(docs):
        for sent in doc.sents:
            for stoken in sent:
                text = stoken.text
                for token in wordpunct_tokenize(text):
                    tkbegin = c
                    c += len(re.sub("\s+", "", token))
                    tkend = c
                    tksentid = s
                    tokens.append(token)
                    tkbegins.append(tkbegin)
                    tkends.append(tkend)
                    tksentids.append(tksentid)
                    tktags.append(segment_tags[i])
            s += 1
    
    matchbegins, matchends = [], []

    for begin in wsbegins:
        try:
            i = tkbegins.index(begin)
        except Exception:
            i = None
        matchbegins.append(i)
    
    for begin, end, wsbegin, wsend in zip(begins, ends, wsbegins, wsends):
        try:
            i = tkends.index(wsend)
        except Exception:
            mention = script[begin: end].rstrip()
            right_context = script[end:].lstrip()
            if mention.endswith(".") and right_context.startswith(".."):
                wsend -= 1
                try:
                    i = tkends.index(wsend)
                except Exception:
                    i = None
            else:
                i = None
        matchends.append(i)
    
    n_unmatched_begin_indices = sum(i is None for i in matchbegins)
    n_unmatched_end_indices = sum(i is None for i in matchends)
    
    movie_data[movie] = {
        "rater": rater,
        "begins": matchbegins,
        "ends": matchends,
        "characters": characters,
        "tokens": tokens,
        "tags": tktags,
        "sentids": tksentids
    }

    print(f"{movie:20s}: {len(lines):5d} script lines, {len(begins):4d} mentions, {len(tokens):5d} tokens, {n_unmatched_begin_indices:3d} mention begin indices unmatched, {n_unmatched_end_indices:3d} mention end indices unmatched")
# Out:
# avengers_endgame    :  8107 script lines, 5025 mentions, 35994 tokens,   0 mention begin indices unmatched,   0 mention end indices unmatched
# dead_poets_society  :  5649 script lines, 3778 mentions, 26367 tokens,   0 mention begin indices unmatched,   0 mention end indices unmatched
# john_wick           :  5541 script lines, 2580 mentions, 24989 tokens,   0 mention begin indices unmatched,   0 mention end indices unmatched
# prestige            : 10194 script lines, 5140 mentions, 36073 tokens,   0 mention begin indices unmatched,   0 mention end indices unmatched
# quiet_place         :  4435 script lines, 2786 mentions, 27875 tokens,   0 mention begin indices unmatched,   0 mention end indices unmatched
# zootopia            :  6081 script lines, 3677 mentions, 27249 tokens,   0 mention begin indices unmatched,   0 mention end indices unmatched

# %%
for movie, mdata in movie_data.items():
    tokens, tags, begins, ends = mdata["tokens"], mdata["tags"], mdata["begins"], mdata["ends"]
    for begin, end in zip(begins, ends):
        mention_tags = tags[begin: end + 1]
        contains_character = any(tag == "C" for tag in mention_tags)
        not_contains_character = any(tag != "C" for tag in mention_tags)
        if contains_character and not_contains_character:
            print(f"{tokens[begin: end + 1]} {mention_tags}")

# %%
movie_coref = {}

for movie, mdata in movie_data.items():
    rater, tokens, tags, sentids, begins, ends, characters = mdata["rater"], mdata["tokens"], mdata["tags"], mdata["sentids"], mdata["begins"], mdata["ends"], mdata["characters"]
    removed = np.zeros(len(tokens), dtype=int)
    speakers = np.full(len(tokens), fill_value="<SCRIPT>", dtype=object)
    # if tags[i: j] == "C" and is followed by some utterance, then we should remove tokens[i: j]
    # removed[: i] remains unchanged
    # removed[i: j] = -1
    # removed[j:] -= j - i
    # speakers[:j] remains unchanged
    # speakers[k] = <character-name> for some k >= j

    i = 0
    while i < len(tokens):
        if tags[i] == "C":
            j = i + 1
            while j < len(tokens) and tags[j] == tags[i]:
                j += 1
            k = j
            utterance_token_indices = []
            while k < len(tokens) and tags[k] not in "SC":
                if tags[k] in "DE":
                    utterance_token_indices.append(k)
                k += 1
            if utterance_token_indices:
                speaker = " ".join(tokens[i: j])
                for l in utterance_token_indices:
                    speakers[l] = speaker
                removed[i: j] = -1
                removed[j:] += j - i
            i = k
        else:
            i += 1
    
    removed = removed.tolist()
    
    newtokens, newtags, newsentids, newspeakers, cleaned_speakers, newbegins, newends, newcharacters = [], [], [], [], [], [], [], []

    i = 0
    while i < len(tokens):
        if removed[i] != -1:
            newtokens.append(tokens[i])
            newtags.append(tags[i])
            newspeakers.append(speakers[i])
            newsentids.append(sentids[i])
            cleaned_speaker = re.sub("\([^\)]+\)", "", speakers[i]).strip()
            cleaned_speaker = cleaned_speaker if cleaned_speaker else speakers[i]
            cleaned_speakers.append(cleaned_speaker)
        i += 1
    
    i, s = 0, 0
    while i < len(newsentids):
        j = i + 1
        while j < len(newsentids) and newsentids[j] == newsentids[i]:
            j += 1
        for k in range(i, j):
            newsentids[k] = s
        s += 1
        i = j

    for begin, end, character in zip(begins, ends, characters):
        if all(removed[i] != -1 for i in range(begin, end + 1)):
            newbegin = begin - removed[begin]
            newend = end - removed[end]
            newbegins.append(newbegin)
            newends.append(newend)
            newcharacters.append(character)
        else:
            assert all(tags[i] == "C" for i in range(begin, end + 1))
    
    movie_coref[movie] = {
        "rater": rater,
        "tokens": newtokens,
        "sentids": newsentids,
        "tags": newtags,
        "speakers": newspeakers,
        "cleaned_speakers": cleaned_speakers,
        "begins": newbegins,
        "ends": newends,
        "characters": newcharacters
    }

# %%
with jsonlines.open("test.jsonlines", "w") as writer:
    for movie, mdata in movie_coref.items():
        writer.write(mdata)

# %%
# bc: broadcast conversation
# bn: broadcast news
# mz: magazine genre (Sinorama magazine)
# nw: newswire genre
# pt: pivot text (The Bible)
# tc: telephone conversation (CallHome corpus)
# wb: web data
genres = ["bc", "bn", "mz", "nw", "pt", "tc", "wb"]

# %%
with jsonlines.open("movie.jsonlines", "w") as writer:
    for movie, mdata in movie_coref.items():
        document = {
            "document_id": f"nw_{movie}",
            "cased_words": mdata["tokens"],
            "sent_id": mdata["sentids"],
            "speaker": mdata["cleaned_speakers"],
        }
        writer.write(document)

# %%
movie_says = []

for movie, mdata in movie_data.items():
    rater, tokens, tags, sentids, begins, ends, characters = mdata["rater"], mdata["tokens"], mdata["tags"], mdata["sentids"], mdata["begins"], mdata["ends"], mdata["characters"]
    added = np.zeros(len(tokens), dtype=int)

    i = 0
    while i < len(tokens):
        if tags[i] == "C":
            j = i + 1
            while j < len(tokens) and tags[j] == tags[i]:
                j += 1
            k = j
            utterance_token_indices = []
            while k < len(tokens) and tags[k] not in "SC":
                if tags[k] in "DE":
                    utterance_token_indices.append(k)
                k += 1
            if utterance_token_indices:
                added[j - 1] = -1
                added[j:] += 1
            i = k
        else:
            i += 1
    added = added.tolist()

    newtokens, newtags, newsentids, newbegins, newends, newcharacters = [], [], [], [], [], []

    i = 0
    while i < len(tokens):
        newtokens.append(tokens[i])
        newtags.append(tags[i])
        newsentids.append(sentids[i])
        if added[i] == -1:
            newtokens.append("says")
            newtags.append("A")
            newsentids.append(sentids[i])
        i += 1

    i = 0
    while i < len(newtokens):
        if newtags[i] == "A" and i < len(newtokens) - 1 and newtags[i + 1] in "DE":
            j = i + 1
            sentid = newsentids[j]
            while j < len(newtokens) and newtags[j] in "DE" and newsentids[j] == sentid:
                newsentids[j] = newsentids[i]
                j += 1
            i = j
        else:
            i += 1
    
    i, s = 0, 0
    while i < len(newsentids):
        j = i + 1
        while j < len(newsentids) and newsentids[j] == newsentids[i]:
            j += 1
        for k in range(i, j):
            newsentids[k] = s
        s += 1
        i = j

    for begin, end, character in zip(begins, ends, characters):
        newbegin = begin + added[begin]
        newend = end + added[end]
        newbegins.append(newbegin)
        newends.append(newend)
        newcharacters.append(character)
    
    movie_says.append({
        "movie": movie,
        "rater": rater,
        "tokens": newtokens,
        "tags": newtags,
        "sentids": newsentids,
        "begins": newbegins,
        "ends": newends,
        "characters": newcharacters
    })

# %%
def convert_movie_coref_json_to_conll(movie_data):
    '''
    Convert movie json coreference to conll format dataframe. \\
    The dataframe contains the following columns:

        - rater
        - movie
        - token
        - sentence_id
        - tag
        - speaker
        - cleaned_speaker
        - character_coreference

    Sentences are separated by 1 newline.
    Movies are separated by 2 newlines
    '''

    #####################################################################
    #### initialize dataframe columns
    #####################################################################
    
    rater_col, movie_col, token_col, tag_col, sentid_col, character_col, speaker_col, cleaned_speaker_col = [], [], [], [], [], [], [], []

    #####################################################################
    #### loop over movies
    #####################################################################
    
    for mdata in movie_data:

        movie, rater, tokens, tags, sentids, begins, ends, characters = mdata["movie"], mdata["rater"], mdata["tokens"], mdata["tags"], mdata["sentids"], mdata["begins"], mdata["ends"], mdata["characters"]
        start = len(rater_col)

        #####################################################################
        #### populate columns
        #####################################################################
        
        for i in range(len(tokens)):
            rater_col.append(rater)
            movie_col.append(movie)
            token_col.append(tokens[i])
            tag_col.append(tags[i])
            sentid_col.append(sentids[i])
            character_col.append([])
            speaker_col.append("-")
            cleaned_speaker_col.append("-")
        

        #####################################################################
        #### populate coreference column
        #####################################################################
        
        for begin, end, character in zip(begins, ends, characters):
            for i in range(begin, end + 1):
                character_col[start + i].append(character)
        
        for i in range(len(tokens)):
            if character_col[start + i]:
                character_col[start + i] = ",".join(sorted(character_col[start + i]))
            else:
                character_col[start + i] = "-"

        #####################################################################
        #### populate speakers column
        #####################################################################
                
        if "speakers" in mdata and "cleaned_speakers" in mdata:
            speaker_col[start:] = mdata["speakers"]
            cleaned_speaker_col[start:] = mdata["cleaned_speakers"]

    #####################################################################
    #### create conll dataframe
    #####################################################################
    
    records = []
    i = 0

    while i < len(rater_col):
        if i and movie_col[i] != movie_col[i - 1]:
            records.append(["" for _ in range(8)])
            records.append(["" for _ in range(8)])
        elif i and sentid_col[i] != sentid_col[i - 1]:
            records.append(["" for _ in range(8)])
        records.append([rater_col[i], movie_col[i], token_col[i], sentid_col[i], tag_col[i], speaker_col[i], cleaned_speaker_col[i], character_col[i]])
        i += 1
    
    movie_coref_df = pd.DataFrame(records, columns=["rater", "movie", "token", "sentence_id", "tag", "speaker", "cleaned_speaker", "character_coreference"])
    
    #####################################################################
    #### return conll dataframe
    #####################################################################
    
    return movie_coref_df

# %%
df = convert_movie_coref_json_to_conll(movie_says)

# %%
df.to_csv("test.csv", sep="\t", index=False)

# %%
doc = nlp("""I added my suggestions to Tiancheng's google doc. My main concerns are:

Q3: I think this problem is too hard for this class without the hints. Close to zero students were able to give actually correct base cases for the DP problem on the last exam, and given the questions I've gotten in OH, I think students will similarly struggle with LP/ILP. I really suggest we give the students everything that's written in the solution except what's written in the boxes.
Q4: This is the question I'm most concerned about. This question is not stated as carefully or precisely as it needs to for it to be ready for the exam. I suggest the authors of this question review the precise language used to describe the polynomial-time approximation scheme for knapsack described in the book in section 11.8. I really, really suggest we replace this problem with something different.
Q6. I was concerned that this question was too obvious because the exact solution to this problem is the topic of an entire section of the book (11.3) and I expect students to at least know what topics are covered in the book, but other staff commented that they thought this question was too hard, so I guess that balances things out.
Q7. This question needs several hours of work to be ready for the exam. The grammar, problem statement, and formatting all need to be vastly improved. I suggest replacing this problem with a different problem that has already been properly edited.""")

# %%
for sent in doc:
    for token in doc:
        text = token.text
        pos = token.pos_
        ent = token.ent_type_
        ws = token.whitespace_
        tws = token.text_with_ws
        print(f"{text} '{ws}' '{tws}' {pos} {ent}")
    print()
# Out:
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# ...
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT
#
# I ' ' 'I ' PRON
# added ' ' 'added ' VERB
# my ' ' 'my ' PRON
# suggestions ' ' 'suggestions ' NOUN
# to ' ' 'to ' ADP
# Tiancheng '' 'Tiancheng' PROPN ORG
# 's ' ' ''s ' PART
# google ' ' 'google ' PROPN
# doc '' 'doc' PROPN
# . ' ' '. ' PUNCT
# My ' ' 'My ' PRON
# main ' ' 'main ' ADJ
# concerns ' ' 'concerns ' NOUN
# are '' 'are' AUX
# : '' ':' PUNCT
#
#
#  '' '
#
# ' SPACE
# Q3 '' 'Q3' PROPN
# : ' ' ': ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# too ' ' 'too ' ADV
# hard ' ' 'hard ' ADJ
# for ' ' 'for ' ADP
# this ' ' 'this ' DET
# class ' ' 'class ' NOUN
# without ' ' 'without ' ADP
# the ' ' 'the ' DET
# hints '' 'hints' NOUN
# . ' ' '. ' PUNCT
# Close ' ' 'Close ' ADV CARDINAL
# to ' ' 'to ' ADP CARDINAL
# zero ' ' 'zero ' NUM CARDINAL
# students ' ' 'students ' NOUN
# were ' ' 'were ' AUX
# able ' ' 'able ' ADJ
# to ' ' 'to ' PART
# give ' ' 'give ' VERB
# actually ' ' 'actually ' ADV
# correct ' ' 'correct ' ADJ
# base ' ' 'base ' NOUN
# cases ' ' 'cases ' NOUN
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# DP ' ' 'DP ' PROPN GPE
# problem ' ' 'problem ' NOUN
# on ' ' 'on ' ADP
# the ' ' 'the ' DET
# last ' ' 'last ' ADJ
# exam '' 'exam' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# given ' ' 'given ' VERB
# the ' ' 'the ' DET
# questions ' ' 'questions ' NOUN
# I '' 'I' PRON
# 've ' ' ''ve ' AUX
# gotten ' ' 'gotten ' VERB
# in ' ' 'in ' ADP
# OH '' 'OH' PROPN GPE
# , ' ' ', ' PUNCT
# I ' ' 'I ' PRON
# think ' ' 'think ' VERB
# students ' ' 'students ' NOUN
# will ' ' 'will ' AUX
# similarly ' ' 'similarly ' ADV
# struggle ' ' 'struggle ' VERB
# with ' ' 'with ' ADP
# LP '' 'LP' PROPN
# / '' '/' SYM
# ILP '' 'ILP' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# give ' ' 'give ' VERB
# the ' ' 'the ' DET
# students ' ' 'students ' NOUN
# everything ' ' 'everything ' PRON
# that '' 'that' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# solution ' ' 'solution ' NOUN
# except ' ' 'except ' SCONJ
# what '' 'what' PRON
# 's ' ' ''s ' AUX
# written ' ' 'written ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# boxes '' 'boxes' NOUN
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q4 '' 'Q4' PROPN
# : ' ' ': ' PUNCT
# This ' ' 'This ' PRON
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# question ' ' 'question ' NOUN
# I '' 'I' PRON
# 'm ' ' ''m ' AUX
# most ' ' 'most ' ADV
# concerned ' ' 'concerned ' ADJ
# about '' 'about' ADP
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# is ' ' 'is ' AUX
# not ' ' 'not ' PART
# stated ' ' 'stated ' VERB
# as ' ' 'as ' ADV
# carefully ' ' 'carefully ' ADV
# or ' ' 'or ' CCONJ
# precisely ' ' 'precisely ' ADV
# as ' ' 'as ' SCONJ
# it ' ' 'it ' PRON
# needs ' ' 'needs ' VERB
# to ' ' 'to ' PART
# for ' ' 'for ' SCONJ
# it ' ' 'it ' PRON
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# the ' ' 'the ' DET
# authors ' ' 'authors ' NOUN
# of ' ' 'of ' ADP
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# review ' ' 'review ' NOUN
# the ' ' 'the ' DET
# precise ' ' 'precise ' ADJ
# language ' ' 'language ' NOUN
# used ' ' 'used ' VERB
# to ' ' 'to ' PART
# describe ' ' 'describe ' VERB
# the ' ' 'the ' DET
# polynomial '' 'polynomial' ADJ
# - '' '-' PUNCT
# time ' ' 'time ' NOUN
# approximation ' ' 'approximation ' NOUN
# scheme ' ' 'scheme ' NOUN
# for ' ' 'for ' ADP
# knapsack ' ' 'knapsack ' NOUN
# described ' ' 'described ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# in ' ' 'in ' ADP
# section ' ' 'section ' NOUN LAW
# 11.8 '' '11.8' NUM LAW
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# really '' 'really' ADV
# , ' ' ', ' PUNCT
# really ' ' 'really ' ADV
# suggest ' ' 'suggest ' VERB
# we ' ' 'we ' PRON
# replace ' ' 'replace ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# something ' ' 'something ' PRON
# different '' 'different' ADJ
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q6 '' 'Q6' PROPN
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# was ' ' 'was ' AUX
# concerned ' ' 'concerned ' ADJ
# that ' ' 'that ' SCONJ
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# obvious ' ' 'obvious ' ADJ
# because ' ' 'because ' SCONJ
# the ' ' 'the ' DET
# exact ' ' 'exact ' ADJ
# solution ' ' 'solution ' NOUN
# to ' ' 'to ' ADP
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# is ' ' 'is ' AUX
# the ' ' 'the ' DET
# topic ' ' 'topic ' NOUN
# of ' ' 'of ' ADP
# an ' ' 'an ' DET
# entire ' ' 'entire ' ADJ
# section ' ' 'section ' NOUN
# of ' ' 'of ' ADP
# the ' ' 'the ' DET
# book ' ' 'book ' NOUN
# ( '' '(' PUNCT
# 11.3 '' '11.3' NUM CARDINAL
# ) ' ' ') ' PUNCT
# and ' ' 'and ' CCONJ
# I ' ' 'I ' PRON
# expect ' ' 'expect ' VERB
# students ' ' 'students ' NOUN
# to ' ' 'to ' PART
# at ' ' 'at ' ADV
# least ' ' 'least ' ADJ
# know ' ' 'know ' VERB
# what ' ' 'what ' PRON
# topics ' ' 'topics ' NOUN
# are ' ' 'are ' AUX
# covered ' ' 'covered ' VERB
# in ' ' 'in ' ADP
# the ' ' 'the ' DET
# book '' 'book' NOUN
# , ' ' ', ' PUNCT
# but ' ' 'but ' CCONJ
# other ' ' 'other ' ADJ
# staff ' ' 'staff ' NOUN
# commented ' ' 'commented ' VERB
# that ' ' 'that ' SCONJ
# they ' ' 'they ' PRON
# thought ' ' 'thought ' VERB
# this ' ' 'this ' DET
# question ' ' 'question ' NOUN
# was ' ' 'was ' AUX
# too ' ' 'too ' ADV
# hard '' 'hard' ADJ
# , ' ' ', ' PUNCT
# so ' ' 'so ' ADV
# I ' ' 'I ' PRON
# guess ' ' 'guess ' VERB
# that ' ' 'that ' SCONJ
# balances ' ' 'balances ' VERB
# things ' ' 'things ' NOUN
# out '' 'out' ADP
# . '' '.' PUNCT
#
#  '' '
# ' SPACE
# Q7 '' 'Q7' PROPN
# . ' ' '. ' PUNCT
# This ' ' 'This ' DET
# question ' ' 'question ' NOUN
# needs ' ' 'needs ' VERB
# several ' ' 'several ' ADJ TIME
# hours ' ' 'hours ' NOUN TIME
# of ' ' 'of ' ADP
# work ' ' 'work ' NOUN
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# ready ' ' 'ready ' ADJ
# for ' ' 'for ' ADP
# the ' ' 'the ' DET
# exam '' 'exam' NOUN
# . ' ' '. ' PUNCT
# The ' ' 'The ' DET
# grammar '' 'grammar' NOUN
# , ' ' ', ' PUNCT
# problem ' ' 'problem ' NOUN
# statement '' 'statement' NOUN
# , ' ' ', ' PUNCT
# and ' ' 'and ' CCONJ
# formatting ' ' 'formatting ' VERB
# all ' ' 'all ' PRON
# need ' ' 'need ' VERB
# to ' ' 'to ' PART
# be ' ' 'be ' AUX
# vastly ' ' 'vastly ' ADV
# improved '' 'improved' VERB
# . ' ' '. ' PUNCT
# I ' ' 'I ' PRON
# suggest ' ' 'suggest ' VERB
# replacing ' ' 'replacing ' VERB
# this ' ' 'this ' DET
# problem ' ' 'problem ' NOUN
# with ' ' 'with ' ADP
# a ' ' 'a ' DET
# different ' ' 'different ' ADJ
# problem ' ' 'problem ' NOUN
# that ' ' 'that ' PRON
# has ' ' 'has ' AUX
# already ' ' 'already ' ADV
# been ' ' 'been ' AUX
# properly ' ' 'properly ' ADV
# edited '' 'edited' VERB
# . '' '.' PUNCT

# %%
with jsonlines.open("./moviecoref/wl-coref/data/english_train.jsonlines") as reader:
    train_data = [data for data in reader]

with jsonlines.open("./moviecoref/wl-coref/data/english_development.jsonlines") as reader:
    dev_data = [data for data in reader]

with jsonlines.open("./moviecoref/wl-coref/data/english_test.jsonlines") as reader:
    test_data = [data for data in reader]

# %%
len(train_data), len(dev_data), len(test_data)
# Out:
# (2802, 343, 348)

# %%
n_tokens = 0
n_mentions = 0
n_clusters = 0

for data in train_data + dev_data + test_data:
    n_tokens += len(data["cased_words"])
    n_clusters += len(data["clusters"])
    n_mentions += sum(len(cluster) for cluster in data["clusters"])

print(f"{n_tokens} tokens, {n_clusters} clusters, {n_mentions} mentions")
# Out:
# 1631995 tokens, 44221 clusters, 194480 mentions

# %%
alldata = train_data + dev_data + test_data

# %%
prose_percentage = 1
num_speakers = 1

indexes = []

for i, data in enumerate(alldata):
    speakers = data["speaker"]
    frac_prose = sum(speaker == "-" for speaker in speakers)/len(speakers)
    n_speakers = len(set(speakers).difference(set(["-"])))
    if n_speakers >= num_speakers and frac_prose > prose_percentage/100:
        indexes.append(i)

print(f"{len(indexes)} documents with at least {num_speakers} speakers and at least {prose_percentage}% prose")
# Out:
# 98 documents with at least 1 speakers and at least 1% prose

# %%
def print_document(data):
    print(data["document_id"][:2])
    df = pd.DataFrame()
    df["token"] = data["cased_words"]
    df["speaker"] = data["speaker"]
    df["sent_id"] = data["sent_id"]

    for _, sent_df in df.groupby("sent_id"):
        sentence = " ".join(sent_df["token"])
        assert len(sent_df["speaker"].unique()) == 1
        speaker = sent_df["speaker"].values[0]
        if speaker == "-":
            print(f"{'prose':20s}: {sentence}")
        else:
            print(f"{speaker:20s}: {sentence}")

# %%
for id in indexes:
    data = alldata[id]
    print_document(data)
    print()
# Out:
# bc
# Speaker#5           : Hello , everyone .
# Speaker#5           : This is Across the Strait on CCTV International Channel .
# Speaker#5           : We welcome you to watch .
# Speaker#5           : First , let 's check out the main contents of today 's program .
# Speaker#6           : On August 17 , Taiwan 's investigation department and police held a press conference announcing the closing of the March 19 shooting case .
# Speaker#6           : Since the suspect identified by Taiwan police mysteriously died after the March 19 shooting incident , the case was not prosecuted .
# Speaker#6           : However , people from various circles in Taiwan think there are many suspicious points in this case .
# Speaker#6           : On August 17 , the Taiwan military held the Lianhsing 94 amphibious landing exercise , testing and enhancing the army 's response capabilities and its combat ability in repelling an enemy 's amphibious landing .
# Speaker#6           : Taiwan 's investigation department and police announced the closing of the March 19 shooting case .
# prose               : Well , why did Taiwan 's investigation department say this was the closing of the case instead of the actual truth about the shooting case ?
# Speaker#6           : Scholars will give you a detailed analysis on this edition of Hot Topic Analysis .
# Speaker#6           : On August 17 , Taiwan 's investigation department and police solved the case and announced the March 19 shooting case was closed .
# Speaker#6           : This case will not be prosecuted .
#
# wb
# prose               : A Saudi woman issues a voice recording in which she mourns her brother and demands the punishment of his killers .
# prose               : HAD1999
# _HADI999_           : In a unique way , a young Saudi woman has resorted to issuing a sound tape in which she mourns her brother murdered in Hafr Al Batin , in the hope of rekindling interest in his case , in which 3 young men were accused of killing him and which has not so far been resolved .
# _HADI999_           : The tape contains excerpts of poetry , dramatic voice recitals , detailed accounts of the young man 's murder circumstances of the background to the investigation of the case for which the young woman is demanding expedited proceedings and punishment of those involved .
# _HADI999_           : The details of the case go back 4 years to the time when the girl 's brother , Abdullah Khaled al - Harbi -LRB- 18 years old -RRB- , and his friend were murdered on the first day of Eidul Adha 1423 H .
# _HADI999_           : 3 young men were accused of killing both , and were investigated .
# _HADI999_           : Incriminating evidence was found despite denials by two of them and a confession to the crime by the third , according to the report prepared by colleague Safr Al - Azman and published by the Saudi paper " Al - watan " .
# _HADI999_           : The girl said that the idea of the tape was born following failure to obtain response to her demands that the investigation proceedings be expedited and the accused tried .
# _HADI999_           : She indicated that she had been working on the tape for about a year , writing its poems .
# _HADI999_           : She also wrote stories based on the incident and backed them up with religious hymns , chosing " A Cry of Pain " as its title .
# _HADI999_           : For his part , an unnamed source from the Public Investigation and Prosecutor 's Board in the Eastern Province explained that the case in question had been brought before the authorities concerned after it was returned from the Hafr Al Batin Court , indicating that the case had the attention of both the Prince of the Eastern Province and his deputy and that they were following up on it .
# _HADI999_           : The source disclosed that the case against the accussed had been re-opened following the formation of another high - ranking board that includes a number of investigators from the Ministry of the Interior who were moved to Central Investigation in the town of Dammam .
# _HADI999_           : Say something good , or be silent .
#
# wb
# prose               : Rejoice , people of Islam .
# prose               : The toughest of your soldiers against the Antichrist have returned to the truth .
# prose               : -LRB- Sons of Tamim . -RRB-
# prose               : Al - Musta'in Billah
# _المستعين_بالله_    : In the past , an Arab poet praised this tribe which humbled the thrones of the Persians and defeated their soldiers and their elephants .
# _المستعين_بالله_    : Its leader , al - Ahnaf ibn Qays -LRB- may Allah be pleased with him -RRB- , chased their king until he was killed , exiled and homeless .
# _المستعين_بالله_    : If the sons of Tamim were angry with you ........... you would think that all the people were angry .
# _المستعين_بالله_    : This is only because the sons of this tribe kept their pledge , were loyal , and were steadfast in confrontation and tough on the enemy .
# _المستعين_بالله_    : The Messenger of God -LRB- may God bless him and grant him salvation -RRB- , said about them that they are his people .
# _المستعين_بالله_    : The alms of our people come from them -LRB- meaning the alms of the sons of Tamim -RRB- narrated by Muslim .
# _المستعين_بالله_    : The truthful one and the one proved to be true -LRB- God bless him and grant him salvation -RRB- , said about them : " They are the toughest among my nation in battle .
# _المستعين_بالله_    : -LRB- They are the toughest of my nation against the Antichrist . -RRB-
# _المستعين_بالله_    : The people of Tamim in Iraq and a large part of al - Ahwaz have returned from the journey of Rafidite Safavid pride .
# _المستعين_بالله_    : This is because those for whom a happy ending has already been decreed by God in the written book and to whom the good tidings of this came in the language of the faithful one of the heavens and the earth -LRB- God 's blessings on him -RRB- was not to be left by God in the mire of deviation and the valleys of disobedience .
# _المستعين_بالله_    : From the heart I am telling you , sons of Tamim , children of al - Hamayil , al - Butama , al - Shirman , children of al - Kanan , people of Basra , al - Ahnaf , the great Abu al - Khasib , you swords of glory and soldiers of faith and people of Muhammad -LRB- may he have God 's blessing and peace -RRB- :
# _المستعين_بالله_    : Rejoice and be hopeful .
# _المستعين_بالله_    : God will really not forsake those who support His religion .
# _المستعين_بالله_    : Your sale will be profitable , as will be that of Muhammad , Abu Bakr , Umar , Uthman , Ali , al - Qaqa , Zahra ibn al - Huwayah , Ibn al - Mubarak , al - Darimi , al - Nisa'i , Abu Yala , and those in the forefront .
# _المستعين_بالله_    : Sons of Tamim , the cry of glory will always resound , striking terror in the adherents of Mazdaism , the sons of whores and group pleasures .
# _المستعين_بالله_    : God is Great !
# _المستعين_بالله_    : God is Great !
# _المستعين_بالله_    : And I am the brother of Daaaaarim .
# _المستعين_بالله_    : After me there will be people with the nickname al - Rafida who reject Islam and reject it .
# _المستعين_بالله_    : Their mark is that there is no Friday prayer and no congregational prayer .
# _المستعين_بالله_    : Let whoever encounters them fight them because they are polytheists .
# prose               : Al - Tarid
# _الطريد_            : They deserve this ...
# _الطريد_            : For your information there is a large portion of them in the Kingdom ... and an area named after them ... which is Hawtat Bani Tamim ..
# _الطريد_            : Among them are venerable sheikhs such as Muhammad bin Abd al - Wahhab and Ibn Uthaymin
# _الطريد_            : shary .
# _الطريد_            : maserdy@hotmail.com
#
# wb
# prose               : Hey , folks in Al - Qasim , is the news I heard true ?
# prose               : Honestly , I did not believe it .
# prose               : Nasri
# _نصري_              : I was talking to a young man from al - Qasim this afternoon on the Messenger ,
# _نصري_              : and he gave me this news that hit me like a bolt of lightening .
# _نصري_              : He said : there is a women 's coffee shop in Barida , and he gave me its name - " Jothun " .
# _نصري_              : What 's going on , folks ?
# _نصري_              : A women 's coffee shop , and where ! In Barida !
# _نصري_              : Anyways , I did not believe it .
# _نصري_              : I sat down in the evening to read a book , but I could n't .
# _نصري_              : " A women 's coffee shop in Barida " just locked into my mind .
# _نصري_              : as if I could feel the sights of the Barida people on that coffee shop -LRB- with a disco -RRB- I sat imagining that coffee shop .
# _نصري_              : As soon as you think of that coffee shop , the modern means of doing something sinful comes to your mind -LRB- text messages -RRB- , sealed with the words -LRB- sin and spread it -RRB- .
# _نصري_              : I sat imagining that coffee shop in its place
# _نصري_              : I imagined the organization surrounding it ,
# _نصري_              : I imagined the bearded ones speaking about women who came to sip cappuccinos ,
# _نصري_              : Drinking that coffee is forbidden by its very name , as everything that is unknown is forbidden .
# _نصري_              : You will not find " mocca " you will find the Al - Rasini blend .
# _نصري_              : By God , please , -LRB- a male reciter of the Koran who blends coffee -RRB- , I mean , a male coffee blend .
# _نصري_              : What will they offer there ?
# _نصري_              : Will it be the Qasimi kalija fresh from the bakery to the table ?
# _نصري_              : Will fatit take the place of gateau and tiramisu ?
# _نصري_              : We will not find croissants , to be replaced by the same letter -LRB- " carath " -LSB- = leek -RSB- and hot bread -RRB- ,
# _نصري_              : Will a bunch of be-socked and be-gloved ladies storm that place to report back to their husbands what is happening there ?
# _نصري_              : Will they volunteer to spread revivalist consciousness among the women -LRB- take your copy -RRB- made up of a bag containing books of horror stories + gloves + socks + the Virtues of Staying Home tape or the tape on Forbidden Acts in Shopping Malls ,
# _نصري_              : And so you will not smell the scent of perfume there , perhaps the fragrance of agarwood and frankincense , and maybe henna , the make - up of the women from the revivalist movement
# _نصري_              : and given the hallucinations of the revivalist women about the Evil Eye , there is no objection to a young girl doing the rounds with a cup into which all present will spit because a girl who visited the place yesterday evening had developed a headache and minds veered towards the illness of the revivalist women -LRB- the Evil Eye -RRB-
# _نصري_              : Aaaaahhh , how I wish to be standing now in that place
# _نصري_              : If you were saved from the lion do n't start wishing to hunt it Mona Lisa
# _موناليزا_          : Praise be to God
# _موناليزا_          : ..
# _موناليزا_          : This is a good deed from amongst my good deeds on the forum , that I made such creatures get out of here and shut the door behind them
# _موناليزا_          : do not forget this service of mine and do n't be afraid
# _موناليزا_          : I have forgiven you with a penalty clause
# _موناليزا_          : Thanks
# _موناليزا_          : Do not stare at the sun to find out its secrets , you might become blind
# prose               : Invulnerable
# _صامد_              : It seems my transmitted reply angered you more , Nasri , because I can see you .. have responded twice , I do not know whether out of hallucinating or the foolish talk from Saturday and Sunday .
# _صامد_              : The blame is on the poster and it might have been a female , I mean , not a male .
# _صامد_              : Anyways , it does not bother me whether you get your head angry or content , as it is nearer to it all .
# _صامد_              : I liked the reply of No. 69 , I asked it in the eighties and especially as the question was about you moving from one predicament to a lesser one .
# _صامد_              : We are waiting for the answer from you , Cafe Al - Rasini
# _صامد_              : Women are of two kinds : one who makes a home for the man and one that makes a man for the home , the second is greater .
# _صامد_              : hawawy100@hotmail.com
#
# wb
# prose               : Nasri
# _نصري_              : My brother Salaam 88 : Thank you for the present ,
# _نصري_              : Your present has been accepted .
# _نصري_              : My brother The Freedom : I did n't understand what you mean ?
# _نصري_              : My brother Abdullah : Thank you for gentle response .
# _نصري_              : My brother Numas My great respects for the al - Qasim people !
# _نصري_              : But constructive criticism even if satirical does not offend .
# _نصري_              : Do not be sensitive to this degree !
# _نصري_              : If you were saved from the lion do n't start wishing to hunt it
# prose               : Mim
# _ميم_               : Nasri A simple question I swear I do n't mean anything ... and I am not joking Are you a Sunni Moslem ??
# _ميم_               : -LRB- If you wish to answer me to my private email , you can do so -RRB-
# _ميم_               : --------------
# _ميم_               : Abu Mohammed .
# prose               : Ready For the Forum
# _زهاب_الساحة_       : A word to the moderators ... Do n't the people of this country , who have been badmouthed by this deviant , deserve respect from you ?
# _زهاب_الساحة_       : Do n't the members who belong to it deserve respect from you ?
# _زهاب_الساحة_       : Are n't the Islamic principles and religious precepts which this relapsed person has made fun of value to you ?
# _زهاب_الساحة_       : Moderators , you have disciplined , limited and deleted postings lighter than these ...
# _زهاب_الساحة_       : This member provokes the members , posters and readers with his postings and replies , and defames this forum at other forums ..
# _زهاب_الساحة_       : This sick person has exploited the free space made available to him to abuse religion , principles and members .
# _زهاب_الساحة_       : For this reason , it is a negative freedom that does n't work with this sick person .
# _زهاب_الساحة_       : Freedom is for those who research , debates and proposes serious matters about which he exchanges opinion and thoughts with others in respectful way .
# _زهاب_الساحة_       : But to badmouth a broad cross - section of the community and make fun of those posting under the pretext of " satirical criticism " , is acceptable neither to yourselves nor to your nations ..
# _زهاب_الساحة_       : God knows what the intentions are .
# _زهاب_الساحة_       : ageel-al9labah@hotmail.com..@z@aabalsaah
# prose               : Ready for the Forum
# _زهاب_الساحة_       : Brother Mim .. This sick person is looking for notoriety
# _زهاب_الساحة_       : He presents the liberals ' annoying and distressing subjects , then searches in Google to see who copied a subject and who spoke about it ...
# _زهاب_الساحة_       : The most important thing for him is to become famous ... even at the expense of his honor , if he has any
# _زهاب_الساحة_       : .. otherwise , what normal , reasonable person gets abused and insulted in a forum , then directs others to that forum , and links to where he was insulted to prove his notoriety !!
# _زهاب_الساحة_       : I hope the moderators will take serious action against this sick person ..
# _زهاب_الساحة_       : Because normal people have been stopped ...
# _زهاب_الساحة_       : and what about this mental ?
# _زهاب_الساحة_       : ageel-al9labah@hotmail.com..@z@aabal-Saah
# prose               : Mim
# _ميم_               : Brother Ready for the Forum Thank you for the brief introduction to Nasri
# _ميم_               : But I still insist on hearing the answer from him directly , my question is still open .
# _ميم_               : I repeat and I say it again ... If you want it to the private mail , I have no objection .
# _ميم_               : Only God brings success , no one else .
# prose               : Nasri
# _نصري_              : Our sister Hissa Machiavelli It seems that your aspirations are in conflict with your desires just as the first part of your handle cancels its last out .
# _نصري_              : The disadvantaged wishes and the strong acts , and you have disadvantaged yourself to satisfy others .
# _نصري_              : However , your contradictory handle has enabled me to invent myself a contradictory handle and call it The Unfaithful Divorcee .
# _نصري_              : It is shameful to decide that our desires are the correct act , and that they are the ideal for life .
# _نصري_              : Perhaps this is as a result of a concealed pride , but why do you judge the acts of others as sick and yours as perfect ?
# _نصري_              : The same rationale that allows you to judge the acts of others has allowed us to judge you !!
# _نصري_              : My brother Misu It seems that your insults are of two kinds : one encoded and the other decoded .
# _نصري_              : If only you would encode all your replies !
# _نصري_              : If you were saved from the lion do n't start wishing to hunt it
#
# wb
# prose               : After Forcing Her to Get Divorced , Saudi Woman Prefers Prison to Returning to Her Family
# prose               : Sarah al - Hamad
# _ساره_الحمد_        : The divorce case for inequality in lineage took a new turn , yesterday morning , when the wife refused to be handed over to her relatives in the police station of the governorate of al - Khobar , especially since the Saudi public , which has been following the case , was expecting that it would end after the Supreme Court , which is considered the highest judicial authority in Saudi Arabia , reached a verdict confirming the separation of the couple .
# _ساره_الحمد_        : Al - Watan has learned from security sources that the police of the governorate of al - Khobar submitted an official request to the administration of the prison at al - Dammam to bring the inmate Fatima on basis of the verdict issued by the Supreme Court two days ago , and the demand of members of her family to hand her over to them as her sole means of support .
# _ساره_الحمد_        : The sources added that when the wife entered the police station of the governorate of al - Khobar accompanied by some female prison guards and security men she was received by some of the members of her family and her mother with the aim of receiving her .
# _ساره_الحمد_        : The surprise was the refusal of Fatima to go with them .
# _ساره_الحمد_        : In spite of the endeavors that lasted for several hours , her brothers were unable to convince her to go with them to the house of the family in the governorate of al - Khobar .
# _ساره_الحمد_        : Officials in the police station of al - Khobar were embarrassed by the situation , because of the wife 's insistence not to go with her relatives .. While the law stipulates that the wife be handed over to them .
# _ساره_الحمد_        : So the officials just returned her to the al - Dammam prison to end the issue , and try to convince her in few days .
# _ساره_الحمد_        : Source http://www.alwatan.com.sa/daily/2007-01-31/first_page/first_page01.htm .
# _ساره_الحمد_        : sarialhamad@yahoo.com
# _ساره_الحمد_        : Sari Al - Hamad
# _ساره_الحمد_        : You can not light a fire with a wet match
# prose               : Sari2001
# _ساري2001_          : Allah suffices me and He is the best helper .
# _ساري2001_          : A word of truth not meant to be false .
# _ساري2001_          : mannofy@hotmail.com
# prose               : NetExpert
# _NetExpert_         : Previously an article about the conduct of the husband was published in this forum .
# _NetExpert_         : The posting of the article revealed other aspects .
# _NetExpert_         : He published copies of legal documents because he wanted to use them to prove that the issue was not based on inequality in lineage , but that it was related to behavioral aspects of the man ,
# _NetExpert_         : foremost among them is desertion and abandonment for a long time .
# _NetExpert_         : Now the newspapers , which I do not trust , still declare that inequality in lineage is the reason .
# _NetExpert_         : In fact , a lot of talk is circulating among people about this issue , because accepting the notion of the possibility of separating a wife from her husband by a decision outside the relationship -LRB- or even inside it -RRB- on the basis of disparity in the relative streams is a matter that robs the society of sleep and causes an exploding moral and social crisis which will have no end .
# _NetExpert_         : If what was previously published in the forum is true , that the man was separated from her for other reasons , that would be reassuring .
# _NetExpert_         : ِAnyway , transforming tradition and calling ignorance a legitimate basis for a verdict in a certain case is a matter which can not be accepted , believed , or trusted to be connected with Sharia .
# _NetExpert_         : Sharia is unequivocal and straightforward .
# _NetExpert_         : No one was forced to accept and consent to any marriage .
# _NetExpert_         : The glorious legislator would not have placed the decision of matrimony in the hand of the guardian and put conditions on it , and facilitate a legitimate alternative for him in case of his absence , unless the decision was final .
# _NetExpert_         : Then would someone come afterwards to annul this and lean on the -LRB- Revelation -RRB- in such a thing ???
# _NetExpert_         : As I said : if it was true that equality in lineage was the reason for the separation then may he perish , may he perish , may he perish !
# _NetExpert_         : This is a first and last point of view ...
#
# wb
# prose               : Ihsas2
# _إحساس2_            : /
# _إحساس2_            : Your evenings can be meetings ... for easy aims that can be attained
# _إحساس2_            : /
# _إحساس2_            : Fatima 's recent decision .. a normal reaction resulting from the wrong contact .. between two contradictory currents .. from which she tasted bitterness !
# _إحساس2_            : God willing , she will live her life .. peacefully in a sound framework after the end of this stage ..
# _إحساس2_            : However informed the passerby may be and whatever his knowledge .. the secrets remain hidden .. in drawers in a container .. and in consequence of this .. Opinions will be read with visions of unequal dimensions ..
# _إحساس2_            : /
# _إحساس2_            : My prayers for Fatima and for everyone compelled .. for quick relief .. from a god who is with us and our intentions and our deeds ..
# _إحساس2_            : he knows best / he is the wisest / he is the most merciful .
# _إحساس2_            : /
# _إحساس2_            : Your sister / Wad al - Abdullah
# _إحساس2_            : /
# prose               : Sarah al - Hamad
# _ساره_الحمد_        : Brother NetExpert
# _ساره_الحمد_        : Assuming that the couple 's order of separation is traced to what are referred to as " behavioral aspects " such as the desertion of the husband and a long - term conditional divorce , what should the wife do , I wonder .
# _ساره_الحمد_        : Hold on to her husband and prefer prison to going with her mother and siblings ?
# _ساره_الحمد_        : Then ... is the court entitled to interfere between a husband and his wife for flimsy " behavioral " reasons which the wife accepts ?
# _ساره_الحمد_        : It seems that the supposition to which you referred in your participation is illogical .
# _ساره_الحمد_        : And what is " behind the hill " is the issue of " equality in lineage , " nothing else ...
# _ساره_الحمد_        : I do not think that there is one Muslim who accepts the verdict of the Supreme Court because it is a racist verdict and blatant interference between a husband and his wife for trivial reasons .
# _ساره_الحمد_        : It is really shameful that the judiciary system in our country works to entrench racism in the name of religion .
# _ساره_الحمد_        : The Islamic religion is innocent of this ignorance , as we know .
# _ساره_الحمد_        : It is also shameful that the poor woman is alone in the dark prison instead of with the relevant charity associations extending a helpful and caring hand to her .
# _ساره_الحمد_        : Since when has prison been a social services center ?
# _ساره_الحمد_        : Then where is the Saudi Human Rights Society , considering what is happening to this woman ?
# _ساره_الحمد_        : Do n't those in charge of the society know that what is happening to the -LRB- Muslim Arab Saudi -RRB- woman harms us all , not to mention that it is a blatant violation of human rights ?
# _ساره_الحمد_        : sarialhamad@yahoo.com
# _ساره_الحمد_        : Sari al - Hamad
# _ساره_الحمد_        : You can not light a fire with a wet match
# prose               : Ta'abbata Shayan
# _تأبط_شيئا_         : God suffices for me , and He is the best agent .
# _تأبط_شيئا_         : Mansour al - Taymani , according to his former wife Ahlam , is a man with drug - related cases against him by the police of al - Jawf .
# _تأبط_شيئا_         : And morals cases .
# _تأبط_شيئا_         : The wife appeared on Al - Ekhbariyah channel to expose the man .
# _تأبط_شيئا_         : Why all this sympathy ?
# _تأبط_شيئا_         : God suffices for me against you liberals who defamed Fatima .
# _تأبط_شيئا_         : A question : do n't you think that Fatima was subjected to sorcery by this al - Taymani ?
# _تأبط_شيئا_         : And say , my Lord , increase my knowledge .
# _تأبط_شيئا_         : tabt_shaa@hotmail.com ..
# prose               : Sarah al - Hamad
# _ساره_الحمد_        : Mr. Ta'abbata Shayan
# _ساره_الحمد_        : The former wife is not a trusted source of information for a very simple reason , namely that she most likely still bears some grudge against her former husband and against the woman who " stole " that husband from her .
# _ساره_الحمد_        : Really , what would urge this woman to say what she said about her former husband in a program watched by everyone ?
# _ساره_الحمد_        : Does her conduct have any connection with noble morality ?
# _ساره_الحمد_        : The ones who defamed the wife , my dear , are undoubtedly the racist judges and the relatives of the wife .
# _ساره_الحمد_        : By the way , Ta'abbata , can we say -LRB- by analogy with what you mentioned -RRB- that the racist judges and the wife 's relatives were exposed to the sorcery of the former wife , Ahlam ?
# _ساره_الحمد_        : and why not ?!!...
# _ساره_الحمد_        : Have n't sorcery and liberalism and other amazing concepts become worn out excuses used by some to avoid facing reality frankly and courageously ?
# _ساره_الحمد_        : sarialhamad@yahoo.com
# _ساره_الحمد_        : Sari al - Hamad
# _ساره_الحمد_        : You can not light a fire with a wet match
# prose               : Mujahid 2005
# _مجاهد_2005_        : Islam has nothing to do with what they do .
# _مجاهد_2005_        : Allah suffices for us , and He is the best one to trust .
# _مجاهد_2005_        : Everything that is completed has shortcomings --
# _مجاهد_2005_        : mua4000@hotmail.com
# prose               : Ihsas2
# _إحساس2_            : /
# _إحساس2_            : There is no power or strength except with God ..
# _إحساس2_            : /
# _إحساس2_            : -LRB- Whoever shields a Muslim will be shielded by God in this world and the hereafter . -RRB-
# _إحساس2_            : /
# _إحساس2_            : Outstanding .. Ta'abbata Shayan
# _إحساس2_            : Be of assistance on the road of goodness .. and the spread of virtue .. and the warding off of negatives ..
# _إحساس2_            : -LRB- If any part of the matter were in my hand , no eye would have read it ... and no passerby would have come across it . -RRB-
# _إحساس2_            : /
# _إحساس2_            : May you and the forums remain above .. those who follow people 's deficiencies and faults .
# _إحساس2_            : /
# _إحساس2_            : Your sister / Wad al - Abdullah /
#
# wb
# prose               : Bullying , from Cairo to Riyadh ... facts and observations .
# prose               : Al Khareq .
# _الخارق_            : As an introduction to the topic , I will recount these two incidents for you :
# _الخارق_            : 1- In Al Sewedi district in Riyadh city , I stood in front of one of the mosques ,
# _الخارق_            : and I saw one of the Arab residents in a moment of astonishment while a car was leaving the place at a high speed .
# _الخارق_            : When I asked him what had happened , he stated that three young men had stolen his cell phone and wallet .
# _الخارق_            : I left the place to catch them , and get their license plate numbers .
# _الخارق_            : They had to stop at one of the traffic signs , which gets crowded , and they did not notice that I was behind them .
# _الخارق_            : I informed Operations of the incident , that they were in front of me at the time , and that there was a security patrol I had seen on the other side of the traffic sign .
# _الخارق_            : But I was shocked when Operations told me , " Do not bother with them .
# _الخارق_            : Go to the police department and report it . "
# _الخارق_            : Oh people , the thieves are in front of me ; inform the patrols about them .
# _الخارق_            : They told me , " It is none of your business . "
# _الخارق_            : I told them , " I will not go to the police department .
# _الخارق_            : This is their car number ; if you want them , chase them .
# _الخارق_            : The car might be stolen . "
# _الخارق_            : And I hung up out of oppression ...
# _الخارق_            : 2- On the eastern ring road , three young men in a Lexus car caught my attention .
# _الخارق_            : They were noticeably tense and confused .
# _الخارق_            : On the same road , there was a search point .
# _الخارق_            : I informed Operations , and I gave them the car number .
# _الخارق_            : They said there was no report on the car .
# _الخارق_            : I told them , " Inform the search point to check them . "
# _الخارق_            : He said to me , " You want to teach us our job ? "
# _الخارق_            : And they hung up .
# _الخارق_            : After about an hour , Operations called me , and they said , " Brother , do you know where the car went , right or left ?
# _الخارق_            : It turned out to be stolen . "
# _الخارق_            : I laughed the laugh of the oppressed , and I said oh , oh , nation .
# _الخارق_            : -------------------
# _الخارق_            : This is a small part of what is happening now in Saudi Arabia , in general , and what is happening in Riyadh , in particular .
# _الخارق_            : It reminds me of what used to happen in the city of Cairo .
# _الخارق_            : The bullying , depredation , and theft .
# _الخارق_            : But it is notable that the Egyptians strongly and very quickly eliminated this practice , and our Egyptian brothers treated the causes , the most important of which is strengthening the security agency and enforcing police members in the districts and street .
# _الخارق_            : At the same time , they know that the continuation of such actions affect the reputation of the country , in case they continue ; they would eliminate trust in the internal security of the country .
# _الخارق_            : Now , unfortunately , the bullying which was in Cairo moved to Riyadh , the capital , which has recently witnessed robberies , kidnappings , beatings .... etc.
# _الخارق_            : And we are still only watching what is happening now ; the citizen still faces many problems and robberies .
# _الخارق_            : The thief had some shyness before and fear of the security forces , but now , there is no fear .
# _الخارق_            : They are not ashamed ; one of them steals in front of everyone and in the morning , even from a policeman , and this happened in fact .
# _الخارق_            : The citizen now , these things which happen now have become normal to him .
# _الخارق_            : He is used to them , because of the negligence of security members and their indifference to what is happening now , their lack of consideration for the complaints of people and their reports , and the insistence of security patrols that it is essential to go to the police departments to report any security violations , though most reports need quick and instant action .
# _الخارق_            : And because of the complications happening now , the chaos about which we hear and see has prevailed .
# _الخارق_            : Unfortunately , these things were weak in the beginning , but they have grown now and reached the level they reached because of security weakness and indecisiveness toward such issues , which have become a daily reality before our eyes .
# _الخارق_            : They happen in our streets , homes , and cars .
# _الخارق_            : If these shameful practices which are happening in our country are not treated decisively , we should expect bigger than them .
# _الخارق_            : The citizen would be forced to own a weapon to protect himself , at the time when the security agencies failed to protect him ...
# _الخارق_            : I am talking here about what is happening in my surroundings and the surroundings of those close to me .
# _الخارق_            : I saw what is happening with my own eyes , so what do you think of a big city like the city of Riyadh ?
# _الخارق_            : You hardly enter a gathering or house without hearing horrible stories and tales , and the fear , the fear , is for Riyadh to become an example for criminality like the American city of Chicago ...
# _الخارق_            : So pay attention to your cell phone , wallets , houses , and cars , because the situation has become unbearable .
# _الخارق_            : Some time ago , my car was stolen , and I reported it .
# _الخارق_            : The officer said , " May God not offend you , but search for it with us . "
# _الخارق_            : The funny thing is that I found it myself after only two days .
# _الخارق_            : ..
#
# wb
# prose               : Urgent : An Overt and Direct Message of Threat to Saudi Arabia and Saudi Arabia Replies ..!!
# prose               : Al - Fahlawi
# _الفهلوي_           : Al - Arabiya :
# _الفهلوي_           : Iraqi Prime Minister Nouri al - Maliki considers the execution of Saddam as an internal matter and threatens to reexamine relations with any country that refuses to respect the will of the Iraqis in carrying out the execution on the holiday .
# _الفهلوي_           : _________________________
# _الفهلوي_           : I remembered after this news the saying of the fly to the mountain : Hold on well because I intend to fly .
# _الفهلوي_           : Really the worst misfortune is that which calls for laughter ..
# _الفهلوي_           : As if I know , you are complaining about the headline of the subject which contains resounding words such as " urgent " and " threat . " !!
# _الفهلوي_           : In fact I do not blame you because that government which is called the Iraqi government does not reach the level of attracting the attention of the Arabs . And because its positions are known beforehand -LRB- acting as an agent .. filthiness .. vulgarity of words .. political ignorance ... etc. -RRB-
# _الفهلوي_           : The evidence of that is that the Saudi Crown Prince replied to this dirty message before its declaration . Since he declared yesterday that Saudi Arabia will not interfere in the affairs of Iraq and encourages its sons to reunite .
# _الفهلوي_           : ______________
# _الفهلوي_           : What quasi-men is Iraq afflicted with ?
# _الفهلوي_           : What dirty agents are those who turn the rudder of governance in Iraq ?
# _الفهلوي_           : Let this quasi-man called Nouri al - Maliki know that when troubles come , after God , Saudi Arabia and Egypt are the impregnable dam for everyone in whose heart throbs an atom of faith and manliness and Arabism .
# _الفهلوي_           : To correspond with me use the following address : http://AbuAbdullaah.arabform.com .
# _الفهلوي_           : Your brother / Abu Abdullah .
# prose               : Qays the son of his father
# _قيس_ابن_ابيه_      : Let the threats come ; your threats wo n't harm me *** Does the buzz of the wings of flies harm anyone ?
# _قيس_ابن_ابيه_      : Does history repeat itself ?
# _قيس_ابن_ابيه_      : Nouri al - Maliki 's situation will be like that of Ibn al - Alqami after his great treason in the murder of the Caliph of the Muslims al - Mustasim .
# _قيس_ابن_ابيه_      : He who has high status does not carry a grudge .......... He who has anger in his nature does not attain greatness .......
# _قيس_ابن_ابيه_      : For correspondence ghais2001@hotmail.com
# prose               : gwardyola
# _gwardyola_         : Your government does not honor any Arab state by having relations with it ...
# _gwardyola_         : The day will come when you will be gone as a result of this deed of yours .
# _gwardyola_         : As for the relations with the Arab states and your government under the shadow of occupation , let them be gone unmourned , you subordinate Safavid executioner ...
# _gwardyola_         : By the will of God , your government agent will soon not exist in the land of Mesopotamia ...
# _gwardyola_         : gwardyola
# prose               : Last Request
# _اخررجاء_           : He must make threats , run away , and groan ..
# _اخررجاء_           : These are the instructions of the bedbugs Bus -LRB- Bush -RRB- , otherwise they will make him fly as they have made others fly .
# _اخررجاء_           : I am sure that all his statements come by e-mail from the White House .
# _اخررجاء_           : Great minds have goals ,,,, while others have wishes .
# _اخررجاء_           : Rajaaa100@Hotmail.Com .
# prose               : Leader of the great legions
# _قائد_الجحافل_الكبرى_: I have never in my life seen a president of a country more stupid than the president of the United States ..
# _قائد_الجحافل_الكبرى_: A stupid president in every meaning of the word ...
# _قائد_الجحافل_الكبرى_: He dragged his country and the Arab region into a quagmire ... and stupidly gave Iraq to Iran in such a way that would make a reasonable person think that there was a secret agreement between Bush and Iran to deliver Iraq .
# _قائد_الجحافل_الكبرى_: I am telling al - Maliki and the other henchmen of Bush .... not to overstep his status ...
# _قائد_الجحافل_الكبرى_: He is just a weak and powerless person ...
# _قائد_الجحافل_الكبرى_: His country is being run by the mullahs of Iran and he is just a trivial toy in the hand of Muqtada al - Sadr and al - Khomeini ... like it or not , despite Bush ...
# _قائد_الجحافل_الكبرى_: The evidence is the trial of Saddam which God exposed to everyone , Arabs , non-Arabs , and Westerners ....
# _قائد_الجحافل_الكبرى_: I really see destruction and evil spreading , encompassing Iraq .
# _قائد_الجحافل_الكبرى_: We are on the verge of destruction and ruin , very close in Iraq , incomparable to what happened to it in previous years ...
# _قائد_الجحافل_الكبرى_: Rather , Iraq will be a theater of major war operations which may be nuclear , burning the green and the dry , and turning Baghdad into the remains of a city inhabited by crows and the riding animals of the graves .
# _قائد_الجحافل_الكبرى_: I call upon my Sunni brothers to leave and avoid the fire of civil strife with the impure Shiites .
# _قائد_الجحافل_الكبرى_: May God fight them until God accomplishes with them what happened to the Rafidites and Shiites of Satan , and with His might may He use the transgressors to destroy the transgressors .
# _قائد_الجحافل_الكبرى_: Thanks to al - Fahlawi ....
# _قائد_الجحافل_الكبرى_: I enjoyed the simplicity of exposition and how close the words were to the heart and mind ...
# _قائد_الجحافل_الكبرى_: Many happy returns each year .
# _قائد_الجحافل_الكبرى_: On behalf of the leadership of the great legions ....
# prose               : Leader of the great legions
# _قائد_الجحافل_الكبرى_: What 's happening now reminds me of the film Fahrenheit 9/11 by the director Michael Moore which revealed the real personality of the cowboy and spoiled child of the Bush family , George W. Bush , on behalf of the leadership of the great legions ....
#
# wb
# prose               : Bread Seller
# _بائع_الخبز_        : Regards ..
# _بائع_الخبز_        : Sorry brother -LRB- al - Fahlawi -RRB- .. I was late in entering a comment ,,
# _بائع_الخبز_        : We tell al - Maliki .. The execution of Saddam is not an internal matter ..
# _بائع_الخبز_        : Those who overthrew his regime and arrested him are the armies of the coalition , and not the army of the government of al - Hakim and Muqtada .
# _بائع_الخبز_        : Thus the debate on the issue of his execution and his trial should have been an international matter for which an international court was formed ..
# _بائع_الخبز_        : Even the moderates among the American politicians have stated so ..
# _بائع_الخبز_        : Anyway .. al - Maliki .. knows the disgraceful situation over which he presides ..
# _بائع_الخبز_        : After his ratification of the implementation of Saddam 's death sentence .. he sensed the danger and fear of what he had done , which al - Hakim and Muqtada had involved him in , and behind them the Safavids .
# _بائع_الخبز_        : In a press interview conducted with him immediately after the ratification , he expressed the wish that his tenure would end soon and that he would not accept renewal .
# _بائع_الخبز_        : The bitter truth is that .. this government came through a forged legitimate way .. whose mask will be revealed in the near future ..
# _بائع_الخبز_        : God is the one from whom help is sought ..
# _بائع_الخبز_        : Above all those who have knowledge is the All - Knowing ..
# prose               : Al - Fahlawi
# _الفهلوي_           : Al - Asha :
# _الفهلوي_           : May you be safe and healthy every year , my eminent brother ..
# _الفهلوي_           : You are really truthful , my brother al - Asha , but I wish they knew ..
# _الفهلوي_           : There is much evidence against the Rafidites in particular ..
# _الفهلوي_           : Perhaps the most important of them is the " Shah of Iran " and how he " spoiled " after they ate his flesh and threw away his bones ..
# _الفهلوي_           : God , hasten the destruction of America and its agents ..
# _الفهلوي_           : Thank you brother al - Asha and I was happy to see you and your participation
# _الفهلوي_           : ______________________
# _الفهلوي_           : The Clever
# _الفهلوي_           : May Allah greet you and honor you my excellent maternal uncle ..
# _الفهلوي_           : Believe me .
# _الفهلوي_           : What you mentioned , despite its importance , is considered a drop in the ocean of Safavid Zoroastrian treachery ..
# _الفهلوي_           : My teeth drip blood on these traitors because of what I have read and what I have followed ..
# _الفهلوي_           : But we do not say anything except that troubles will befall a person who transgresses .
# _الفهلوي_           : I thank you very much for honoring us by passing by and for your kindness ..
# _الفهلوي_           : May God grant us and you success , and may He give our eyes and your eyes the pleasure of seeing the death and destruction of the traitors .
# _الفهلوي_           : To correspond with me use the following address : http://AbuAbdullaah.arabform.com .
# _الفهلوي_           : Your brother / Abu Abdullah .
# prose               : Al - Fahlawi
# _الفهلوي_           : I thank all brothers for their pleasant interaction on the subject ..
# _الفهلوي_           : I apologize to everyone for the late and collective reply ..
# _الفهلوي_           : This is because I was away from the forum these days .
# _الفهلوي_           : Again , thank you all very much .
# _الفهلوي_           : To correspond with me use the following address : http://AbuAbdullaah.arabform.com .
# _الفهلوي_           : Your brother / Abu Abdullah .
#
# wb
# prose               : Expressive image
# prose               : Al Waeli
# _الوائلي_           : Al Waeli , peace , mercy , and the blessing of God be upon you .
# _الوائلي_           : As a courtesy , not an order , please place in the political forum this picture , which goes back to 1973 - 1393 , at the time of King Faisal , may God have mercy on him , when he prevented the export of oil to America .
# _الوائلي_           : The picture shows the extent of our ability to stand in the face of America , and I hope the members would comment on the picture .
# _الوائلي_           : naifgh@msn.com
# prose               : Al Maghaweer
# _المغاوير_          : Things today are more complicated than before ...
# _المغاوير_          : and the lurkers for us are many ...
# _المغاوير_          : Also , the world today has become uni-polar ... as they say !
# _المغاوير_          : I wish things would stay like that ... but leave it to God ...
# _المغاوير_          : God shall decide .
# prose               : Abu Dalama
# _ابودلامة_          : Saturday , 12/24/1427 AH , 01/13/2007 AD .
# _ابودلامة_          : Question : I would like to ask His Highness Prince Saud whether the Kingdom of Saudi Arabia is ready to raise its production of oil , in case the Iranian crisis causes a reduction of the Iranian production or a rise in prices ?
# _ابودلامة_          : In other words , is the Kingdom of Saudi Arabia ready to use the oil weapon against the oil weapon ?
# _ابودلامة_          : I would also like to ask with regard to the Iranian crisis , what is the significance of the initiatives that the group of nations , of which the Kingdom of Saudi Arabia is part , I mean , the Gulf Cooperation Council , are undertaking in order to develop the project of the nuclear program ?
# _ابودلامة_          : Is this , I mean , the preparation a group of Sunni Arab countries are undertaking as a warning directed at the Iranian leadership ?
# _ابودلامة_          : Your Highness , the Minister : We are -LSB- handling -RSB- the issue of facing the oil weapon with the oil weapon , because we do not consider it an oil weapon .
# _ابودلامة_          : It is wealth to be used , and we are using this wealth in consideration of our national interests , the interests of the producing nations , and the interests of the consuming nations .
# _ابودلامة_          : His Highness the Oil Minister has very clearly clarified that the policy of the Kingdom is established on balance in the oil market .
# _ابودلامة_          : The Kingdom has historically proven that in times of crisis , it does what it should do as the biggest producer of oil , in a way that guarantees the stability of the oil markets .
# _ابودلامة_          : As for the nuclear program which the Gulf Cooperation Council has approved , I believe that among the most important reasons on which the Council agreed in this framework is to enter in this important industry , the importance of which not only includes a military aspect , but also a peaceful aspect , in order to establish an industry subject to strict controls that can not be violated , in order to guarantee its peaceful direction .
# _ابودلامة_          : And it may be an example for all who want to have this industry and have no intention of developing it , other than establishing nuclear weapons .
# _ابودلامة_          : This is the goal the Gulf Cooperation Council countries are seeking .
# _ابودلامة_          : http://www.mofa.gov.sa/detail.asp?InNewsItemID=59090&InTemplateKey=print
# _ابودلامة_          : For correspondence :
# _ابودلامة_          : alisau@gmail.com
# prose               : Al Waeli
# _الوائلي_           : Al Maghaweer and brother , Abu Dalama : Thank you for participating and expressing your opinion .
# _الوائلي_           : And I -LSB- agree with -RSB- Prince Faisal , that it is essential to consider the interests of the nation and the interests of development in the Kingdom , but I enclosed the picture per the request of its owner .
# _الوائلي_           : naifgh@msn.com
# prose               : Nader Abdullah
# _نادر_عبدالله_      : No doubt the political reading today differs from the situations in which the decision was made at that time .
# ...
# _613305_            : However , this should not provide an excuse to overthrow it by fair means or foul , as he is our father and the common choice of millions of laboring people .
# _613305_            : The fact that it " finally became our national character and main system after over half a century of international and domestic political transformation " is a stronger proof that it is the milestone for a new civilization resulted from the blood and sweat of thousands of proletarian revolutionary martyrs .
#
# wb
# prose               : Something Even More Absurd Than the " Breakneck 90 M/H On a Snowy Night " ?? My Personal Experience .
# prose               : poqi
# _poqi_              : Poster : poqi -LRB- poqi -RRB- , Area : Automobile .
# _poqi_              : Title : Something Even More Absurd Than the " Breakneck 90 M/H On a Snowy Night " ?? My Personal Experience .
# _poqi_              : Originating site : BBS Unknown Space -LRB- Tue Jan 16 22:51:46 2007 -RRB- .
# _poqi_              : I have deep feelings and a lot of sympathy with the author after reading the article Breakneck 90 m/h on a Snowy Night .
# _poqi_              : It also reminds me of something that I experienced several years ago , also related to an airport and meeting people .
# _poqi_              : A couple of years ago , my neighbor approached me to borrow my car , saying he was meeting his parents at the airport .
# _poqi_              : He also said both his wife and children wanted to go .
# _poqi_              : As his car was too small and mine was big , it could make his parents more comfortable .
# _poqi_              : He added that he would only use it for one morning and would return it to me before noon .
# _poqi_              : Although there was only a nodding acquaintance between the neighbor and me , we lived in the same apartment building after all and were both Chinese .
# _poqi_              : So I discussed with my wife back home and lent him the car as we thought we would not be using the car until the same afternoon .
# _poqi_              : And then something happened ...
# _poqi_              : At 1:00pm , the neighbor called me , saying he took his parents to a buffet and would probably not to be back until around 3:00pm .
# _poqi_              : I of course agreed and asked them not to rush .
# _poqi_              : This wait lasted till 5:30pm , when the neighbor told me in a half - crying tone that there was an accident , and everyone else was intact , except his father , who was in hospital for fractures .
# _poqi_              : I comforted him first and asked my friend to rush me to the hospital .
# _poqi_              : My neighbor showed me the police report at the hospital , which indicated it was all my neighbor 's fault .
# _poqi_              : He clashed into a truck going straight when he made a left turn .
# _poqi_              : My car was completely damaged and had been towed away .
# _poqi_              : I forced myself to refrain from the grief of loosing my beloved car -LRB- mine was liability - only coverage -RRB- and asked the friend to send their family home .
# _poqi_              : And then the nightmare began .
# _poqi_              : The next day , my neighbor called me , saying his father needed to undergo an operation in hospital and asked where the money would come from
# _poqi_              : I told him part would be covered by my car insurance .
# _poqi_              : After a while , he called again , saying the operation charge was high and it was difficult for them to afford
# _poqi_              : I tried my best to comfort him then and told him to think of a way slowly
# _poqi_              : Just then , a nearly crazy voice of a woman came from the other end of the line , saying her family had just saved several dozen thousand bucks for the down payment of a house ; where would they live afterwards if they spent this .
# _poqi_              : She also said my car was a Japanese one , which had poor safety performance and it was my car to blame for the car accident .
# _poqi_              : She added that I should pay the money because the car was mine .
# _poqi_              : I hung up the phone angrily as the dialog could not go on .
# _poqi_              : My wife -LSB- pw% -RSB- had been persuading me aside , saying some women would easily lose mind once in fury .
# _poqi_              : She asked me to take no heed of them and let them calm down first .
# _poqi_              : So I did n't take their words seriously but still felt angry .
# _poqi_              : Out of my expectation , a phone call on the third day completely changed my original idea .
# _poqi_              : The telephone rang just as I was about to go to work in the morning .
# _poqi_              : I thought it was a sales call and was prepared to end it perfunctorily .
# _poqi_              : Unexpectedly , coming from the other end of the line was a deep and resolute voice of a middle - aged man .
# _poqi_              : He said in an incontestable tone that my neighbor had a car accident as a result of borrowing my car , which traumatized them both physically and mentally and harmed their economic interests , and as the car owner , they would not sue me if I compensated them for the hospital charge and the costs of missing work hours -LRB- three times -RRB- , otherwise they would see me in court .
# _poqi_              : He added that he was certain about the case as a lawyer in business for ten years and the compensation he requested could double in court .
# _poqi_              : As a great Chinese guy , how could I be scared by a few remarks of the lawyer ?
# _poqi_              : I also took up the weapon of law for justice .
# _poqi_              : Of course , I also retained a lawyer .
# _poqi_              : Out of my expectation , my lawyer solved the problem by merely making two phone calls .
# _poqi_              : One was to the police station , asking for any additional findings in the investigation report of the accident .
# _poqi_              : There was additional findings unexpectedly , which were against them .
# _poqi_              : Someone at the junk yard found a bottle of unfinished wine without the lid inside the car and reported it to the police station .
# _poqi_              : The police found they put the bottle of unfinished wine in the car without the lid after lunch .
# _poqi_              : The second call was to their lawyer .
# _poqi_              : So their lawyer dropped the lawsuit .
# _poqi_              : Of course , they would not stop it there and came to discuss with me several times , sometimes honey - tongued and sometimes threatening .
# _poqi_              : The most classic one was : Do n't ever dream of living a life back to China , as we have people across the country .
# _poqi_              : Disgusting !
#
# wb
# prose               : I thank my Beijing friends and wish everyone a Happy New Year .
# prose               : mikecat
# _mikecat_           : Poster : mikecat -LRB- mikecat -RRB- , Section : Beijing .
# _mikecat_           : Topic : I thank my Beijing friends and wish everyone a Happy New Year .
# _mikecat_           : Posting station : BBS Unnamed space station -LRB- Mon Jan 1 12:05:53 2007 -RRB- .
# _mikecat_           : A month ago , I was really desperate , I lost my current job , which I was completely unprepared for , and had to find a job within a month to keep myself going .
# _mikecat_           : Now in this month with the Christmas holiday there 's really only three weeks of actual work time , and I do n't think any companies are going to be hiring people during this period .
# _mikecat_           : Despair , that sinking feeling weighing on my mind , so much pressure I could n't eat , could n't sleep ; I was simply going crazy .
# _mikecat_           : But I still needed to do something ; getting crazy - hysteric makes no sense .
# _mikecat_           : Then I started connecting with my friends in America ; I went to Maimaiti to ask for help , consulted about my status , and looked for a way to solve the problem .
# _mikecat_           : Even my relatives ' friends in America and my parents ' friends all got involved .
# _mikecat_           : Friends , it 's always friends who help me at key moments .
# _mikecat_           : Many friends got people they knew to recommend me , help me send out resumes , or call and commiserate with me .
# _mikecat_           : There was one friend who had just got an offer , but he did n't want to go , so he recommended me to go for him , but it was way off in LA , plus the salary was n't ideal , but at least it could help me keep the legal status , so I thought I would take it .
# _mikecat_           : After the telephone interview , I flew to LA , landing at 12:00 noon , and at 4:00 p.m. .
# _mikecat_           : I had the interview .
# _mikecat_           : By then 17 - 18 hours had passed since I 'd gotten up at 4:00 a.m.
# _mikecat_           : Although I was too tired to walk , I still had to pump up my spirits so I 'd be in peak form for the interview .
# _mikecat_           : The interview did n't last long , just two hours and it was over .
# _mikecat_           : I felt the interview went well , and started to feel confident .
# _mikecat_           : But on that day one senior level person was n't there , so the next day early I had to go back to talk to him .
# _mikecat_           : So the next day I got up at 7:00 and ran over to chat for an hour ; that guy was nice , did n't embarrass me , so after an hour it ended happily .
# _mikecat_           : After that the boss took me to the home office , and on the way he gave me an oral offer , and he said it would not be easy for me to come right away , that I should do the physical exam immediately and do all the paperwork , wait until after New Year 's , and the HR director would return and turn in the H1 .
# _mikecat_           : Then I went straight for the physical , and I filled out the application form , reference list , etc.
# _mikecat_           : At 3:00 p.m. , the dust finally settled .
# _mikecat_           : Finally before Christmas I received a Christmas present .
# _mikecat_           : Although I still have n't made the final decision to go , at least I have a guaranteed - minimum choice .
# _mikecat_           : So I am thanking everyone for helping me .
# _mikecat_           : I hope that all my friends who are still looking for work will be able to find their ideal job in the New Year .
# _mikecat_           : --
# _mikecat_           : * Source : ・ BBS Unnamed space station http://mitbbs.com ・ -LSB- FROM : 72.224. -RSB- .
#
# wb
# prose               : Guo Kai 's Economic Notes : Beijing 's Gas Price vs. US Gas Price
# prose               : Guo Kai 's Economic Notes
# _郭凯经济笔记_            : In the US the current average price of regular unleaded gas is about 2.3 US dollars per gallon -LRB- 3.78 liters -RRB- .
# _郭凯经济笔记_            : According to the official exchange rate of one US dollar for 7.9 RMB , this price is equivalent to 4.80 yuan / liter .
# _郭凯经济笔记_            : Note , this gas price includes all taxes .
# _郭凯经济笔记_            : The current gas price in Beijing is 5.09 yuan / liter , 2 mao and 9 fen more than in the US .
# _郭凯经济笔记_            : In fact , the gas price difference between the two places is larger than 2 mao and 9 fen because China 's gas price does not include so many taxes as in the US ; for example , the highway maintenance fee in China is paid separately .
# _郭凯经济笔记_            : Just now , I only narrated a fact .
# _郭凯经济笔记_            : But I believe that different persons see different problems in this fact .
# _郭凯经济笔记_            : Let me describe people 's two reactions that I can imagine , or the two problems I can see .
# _郭凯经济笔记_            : 1. The US gas price is too cheap .
# _郭凯经济笔记_            : In an absolute sense , the US gas price has +already been cheaper than China 's , and in a relative sense , the US gas price is even cheaper .
# _郭凯经济笔记_            : In the US , the money you pay for a meal at McDonald 's can fill up more than 10 liters of gas , but in Beijing you can get 5 - 6 liters of gas at most .
# _郭凯经济笔记_            : The US low gas price policy has undoubtedly led to this country 's excessive use of and overdependence on energy resources .
# _郭凯经济笔记_            : However , there is more to this matter , the whole world has to share the various negative effects caused by the US excessive energy consumption : global warming , and wars caused by oil , etc.
# _郭凯经济笔记_            : It is totally a joke that the US gas price could be cheaper than China 's .
# _郭凯经济笔记_            : 2. China 's gas price is too expensive .
# _郭凯经济笔记_            : Both Americans and Chinese buy gas from the international market , and the technology and cost of oil refinement are not too much different .
# _郭凯经济笔记_            : But with the US gas price including taxes even lower than China 's gas price excluding taxes , you can see how much money Chinese oil companies have made out of this .
# _郭凯经济笔记_            : If there are no price controls and monopolies , China 's gas price should n't have been this high .
# _郭凯经济笔记_            : I want to say that I think these two opinions are both correct .
# _郭凯经济笔记_            : So , on the issue of oil consumption , I think China and the US , the No. 1 and No. 2 oil consumers in the world , are also a funny pair .
# _郭凯经济笔记_            : From a global perspective , the US gas price is obviously too low .
# _郭凯经济笔记_            : So Mankiw at Harvard even formed a " Pigou Club , " gathering social celebrities who support levying higher taxes on gas prices -LRB- hereby raising gas prices -RRB- .
# _郭凯经济笔记_            : China 's gas prices are more complicated .
# _郭凯经济笔记_            : In fact , gas prices in China are probably not very high , but in order to reduce China 's future overdependence on gas , it may be better that China 's gas prices are higher .
# _郭凯经济笔记_            : But , the direct result of the gas price increase in China will be the increase of monopoly profits of the monopoly companies .
# _郭凯经济笔记_            : This part of money will not become the government tax revenue , will not be used for public welfare , and on the contrary , will only make the benefits of those people working at the monopoly department even better .
# _郭凯经济笔记_            : In other words , the gas price in China is too high in the distributive sense .
# _郭凯经济笔记_            : It is the price that transfers the entire social resources to a very small number of people .
# _郭凯经济笔记_            : But in terms of sustainability , China 's gas price may still be too low .
# _郭凯经济笔记_            : We need high gas prices to control the overdependence on energy imports .
# _郭凯经济笔记_            : Perhaps someone will condemn me , saying further increase of gas prices will make life unbearable for people .
# _郭凯经济笔记_            : If you are a taxi driver , my reply is : the reason your life is unbearable is not the gas price , but because of our taxi licensing regulation system .
# _郭凯经济笔记_            : If you are a car owner , my reply is : ride the subway and bus more often .
# _郭凯经济笔记_            : It saves money , reduces congestion , and also lets you know car owners are not in a position to say " life is unbearable . "
# _郭凯经济笔记_            : Compared with most people , your life is already quite good .
# _darling0823_       : darling0823
# _darling0823_       : Comparing McDonald 's in the US with McDonald 's in China may not be right .
# _darling0823_       : Eating a meal at McDonald 's in the US is more comparable to buying a 5 - yuan boxed meal in China .

# %%
doc = nlp("James says he is unwell")

for token in doc:
    nertag = token.ent_type_
    if not nertag:
        nertag = "-"
    print(token.text, token.tag_, nertag)
# Out:
# James NNP PERSON
# says VBZ -
# he PRP -
# is VBZ -
# unwell JJ -

# %%
df = pd.read_csv("/workspace/mica-text-coref/results/movie_coref.conll", index_col=None, sep="\t")

# %%
movie_coref_wl = []

with jsonlines.open("./results/movie_coref.wl.output.jsonlines") as reader:
    for data in reader:
        movie_coref_wl.append(data)

# %%
for data in movie_coref_wl:
    print(len(data["span_clusters"]))
# Out:
# 572
# 505
# 421
# 555
# 361
# 478
